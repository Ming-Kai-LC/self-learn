# %% [markdown]
# # Mini-Project 03: Notebook as Presentation
#
# **Duration**: 45 minutes | **Difficulty**: Intermediate
#
# ## Project Goal
# Convert a Jupyter notebook into a professional presentation using RISE or similar tools.
#
# ## Skills Applied
# - Slide-based layout
# - Visual design
# - Content organization
# - Export formats

# %% [markdown]
# # Introduction to Data Science
#
# ## A Beginner's Guide
#
# **Presenter**: [Your Name]
# **Date**: 2024
#
# ---

# %% [markdown]
# # Agenda
#
# 1. What is Data Science?
# 2. Key Tools and Technologies
# 3. Data Analysis Example
# 4. Visualization Demo
# 5. Q&A

# %% [markdown]
# # What is Data Science?
#
# Data Science is the field of study that combines:
#
# - **Statistics**: Understanding data patterns
# - **Programming**: Automating analysis
# - **Domain Knowledge**: Applying insights
# - **Communication**: Telling the story
#
# <div style="text-align:center; margin-top:30px;">
#     <strong style="font-size:24px;">Data + Analysis + Insight = Impact</strong>
# </div>

# %% [markdown]
# # Key Tools
#
# | Tool | Purpose | Level |
# |------|---------|-------|
# | Python | Programming | Beginner |
# | Pandas | Data Manipulation | Beginner |
# | Matplotlib | Visualization | Beginner |
# | Scikit-learn | Machine Learning | Intermediate |
# | TensorFlow | Deep Learning | Advanced |

# %% [markdown]
# # Live Demo: Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# Create sample data
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [2000, 2200, 2500, 2800, 3000, 3200],
}
df = pd.DataFrame(data)
df

# %% [markdown]
# # Visualization Example

# %%
plt.figure(figsize=(10, 5))
plt.plot(df["Month"], df["Sales"], marker="o", linewidth=2, markersize=8)
plt.title("Monthly Sales Trend", fontsize=16, fontweight="bold")
plt.xlabel("Month", fontsize=12)
plt.ylabel("Sales ($)", fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

growth = ((df["Sales"].iloc[-1] - df["Sales"].iloc[0]) / df["Sales"].iloc[0]) * 100
print(f"\n📈 Growth: {growth:.1f}% over 6 months")

# %% [markdown]
# # Key Takeaways
#
# ✅ Data Science combines multiple disciplines
# ✅ Python is the most popular language
# ✅ Visualization is crucial for communication
# ✅ Jupyter notebooks are perfect for analysis
#
# <div style="background-color:#4ECDC4; padding:20px; margin-top:30px; border-radius:10px;">
# <h2 style="color:white; text-align:center;">Start Your Data Science Journey Today!</h2>
# </div>

# %% [markdown]
# # Thank You!
#
# ## Questions?
#
# **Contact**: your.email@example.com
# **Resources**: [link to materials]
#
# ---
#
# ### Next Steps
# 1. Practice with sample datasets
# 2. Join online communities
# 3. Build portfolio projects
# 4. Keep learning!

# %% [markdown]
# ---
#
# ## How to Use This as a Presentation
#
# ### Method 1: RISE Extension
# 1. Install RISE: `pip install RISE`
# 2. Click the presentation icon in toolbar
# 3. Use Space/Arrow keys to navigate
#
# ### Method 2: Export to Slides
# ```bash
# jupyter nbconvert presentation.ipynb --to slides --post serve
# ```
#
# ### Presentation Tips
# - Use `slideshow` cell metadata to control slide types
# - Keep slides simple and visual
# - Run code live for impact
# - Use fragments for progressive reveal
#
# **Congratulations!** You've created a presentation notebook!
#
# ---
#
# ## Project Complete!
#
# You've now completed all three mini-projects:
# 1. ✅ Data Analysis Report
# 2. ✅ Interactive Dashboard
# 3. ✅ Presentation Notebook
#
# **Next**: Check out the reference guides for quick lookups!
