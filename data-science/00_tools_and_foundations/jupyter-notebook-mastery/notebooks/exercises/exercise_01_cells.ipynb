# %% [markdown]
# # Exercise 01: Cell Manipulation
#
# **Duration**: 20 minutes | **Level**: Easy-Medium
#
# ## Objectives
# Practice cell operations, keyboard shortcuts, and efficient notebook navigation.
#
# ---
#
# ## Instructions
#
# Complete all exercises using **keyboard shortcuts only** (no mouse clicks on toolbar).
# Time yourself - can you complete all tasks in under 10 minutes?

# %% [markdown]
# ## Task 1: Cell Creation (2 points)
#
# Using keyboard shortcuts:
# 1. Insert a code cell **below** this cell
# 2. In that cell, create a list: `fruits = ['apple', 'banana', 'orange']`
# 3. Insert another code cell below
# 4. Print the list with a loop
#
# **Shortcuts to use**: B (insert below), Enter (edit mode), Shift+Enter (run)

# %% [markdown]
# ## Task 2: Cell Type Conversion (2 points)
#
# 1. Insert a code cell below
# 2. Convert it to markdown (shortcut: M)
# 3. Type: `## This is a heading`
# 4. Render it (Shift+Enter)
# 5. Convert it back to code (shortcut: Y)
# 6. Delete the cell (DD)

# %% [markdown]
# ## Task 3: Copy and Modify (3 points)
#
# 1. Copy the cell below (shortcut: C)
# 2. Paste it three times (shortcut: V)
# 3. Modify each copy to print different numbers
# 4. Run all three cells
# 5. Delete the middle cell (DD)

# %%
# Copy this cell
print(f"Square of 5 is {5**2}")

# %% [markdown]
# ## Task 4: Multi-Cell Selection (3 points)
#
# 1. Select the three cells below using Shift+↓
# 2. Run all three at once (Shift+Enter)
# 3. Select them again
# 4. Copy them (C)
# 5. Move below this cell and paste (V)
# 6. Delete the pasted cells (DD while selected)

# %%
x = 10

# %%
y = 20

# %%
print(f"Sum: {x + y}")

# %% [markdown]
# ## Task 5: Efficient Coding (5 points)
#
# Create a small calculator using only keyboard shortcuts:
#
# 1. Insert 4 code cells below
# 2. Cell 1: Define `a = 25` and `b = 5`
# 3. Cell 2: Calculate and print addition
# 4. Cell 3: Calculate and print multiplication
# 5. Cell 4: Calculate and print division
# 6. Run all cells in sequence
# 7. Select cells 2-4 and merge them (Shift+M)
#
# **Challenge**: Complete this in under 2 minutes!

# %% [markdown]
# ## Solutions
#
# ### Task 5 Solution

# %%
# Solution
a = 25
b = 5

# %%
# After merging, should look like:
print(f"Addition: {a + b}")
print(f"Multiplication: {a * b}")
print(f"Division: {a / b}")

# %% [markdown]
# ## Bonus Challenge (5 bonus points)
#
# Complete all of the following in under 60 seconds:
#
# 1. Insert 5 code cells
# 2. In each cell, print numbers 1-5
# 3. Run all 5 cells
# 4. Select all 5 cells
# 5. Delete them all at once
# 6. Undo the deletion (Z)
# 7. Delete them again

# %% [markdown]
# ## Summary
#
# ### Shortcuts Practiced
# - **B**: Insert cell below
# - **A**: Insert cell above
# - **DD**: Delete cell
# - **Z**: Undo
# - **M**: Convert to markdown
# - **Y**: Convert to code
# - **C**: Copy cell
# - **V**: Paste cell
# - **Shift+M**: Merge cells
# - **Shift+↑/↓**: Select multiple cells
#
# ### Scoring
# - Total possible: 15 points (20 with bonus)
# - 15+: Keyboard ninja! 🥷
# - 12-14: Excellent work! ⭐
# - 9-11: Good progress! 👍
# - <9: Keep practicing! 💪
#
# ---
#
# **Next**: Exercise 02 - Markdown Mastery
