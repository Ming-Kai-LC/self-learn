# %% [markdown]
# # Module 05: Containerization with Docker\n\n**Difficulty**: ⭐⭐  \n**Estimated Time**: 55 minutes  \n**Prerequisites**: \n- Module 04: Creating ML APIs with FastAPI\n- Basic command-line knowledge\n\n## Learning Objectives\n\nBy the end of this notebook, you will be able to:\n1. Understand Docker concepts and benefits for ML\n2. Create Dockerfiles for ML applications\n3. Build and run Docker containers\n4. Use Docker Compose for multi-container setups\n5. Optimize Docker images for ML models

# %% [markdown]
# ## 1. Introduction\n\nDocker enables consistent deployment across environments. Learn to containerize ML applications for reliable, reproducible deployments.

# %%
# Setup: Import required libraries\nimport numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport warnings\n\nwarnings.filterwarnings('ignore')\nnp.random.seed(42)\n\nprint('✓ Libraries imported successfully')

# %% [markdown]
# ## 2. Docker Basics\n\nUnderstanding containers vs VMs, Docker architecture, and key concepts

# %%
# Code example for: Docker Basics\n\n# TODO: Implement example\nprint(f'Section 2: Docker Basics')

# %% [markdown]
# ## 3. Creating Dockerfiles\n\nWriting Dockerfiles for ML applications with proper layering

# %%
# Code example for: Creating Dockerfiles\n\n# TODO: Implement example\nprint(f'Section 3: Creating Dockerfiles')

# %% [markdown]
# ## 4. Building Images\n\nBest practices for building efficient Docker images

# %%
# Code example for: Building Images\n\n# TODO: Implement example\nprint(f'Section 4: Building Images')

# %% [markdown]
# ## 5. Docker Compose\n\nOrchestrating multi-container applications

# %%
# Code example for: Docker Compose\n\n# TODO: Implement example\nprint(f'Section 5: Docker Compose')

# %% [markdown]
# ### 🎯 Exercise 1: Create Dockerfile\n\nBuild a Dockerfile for your ML API\n\n**Requirements:**\n1. Base image selection\n2. Dependency installation\n3. Model copying\n4. Port exposure

# %%
# Your solution here\n\n# TODO: Implement your solution

# %% [markdown]
# ### 🎯 Exercise 2: Optimize Image Size\n\nReduce Docker image size\n\n**Requirements:**\n1. Multi-stage builds\n2. Layer caching\n3. Size comparison

# %%
# Your solution here\n\n# TODO: Implement your solution

# %% [markdown]
# ### 🎯 Exercise 3: Docker Compose Setup\n\nCreate docker-compose.yml\n\n**Requirements:**\n1. API service\n2. Database service\n3. Network configuration

# %%
# Your solution here\n\n# TODO: Implement your solution

# %% [markdown]
# ## Summary\n\n### Key Concepts Covered\n\n1. Docker fundamentals and benefits\n2. Dockerfile creation\n3. Image optimization\n4. Multi-container orchestration\n\n### What's Next\n\nIn **Module 06**, learn about different model serving patterns and when to use each.\n\n### Additional Resources\n\n- Docker Documentation: https://docs.docker.com/\n- Docker Best Practices: https://docs.docker.com/develop/dev-best-practices/

# %% [markdown]
# ---\n\n## Next Steps\n\nProceed to **Module 06** to continue your MLOps learning journey.\n\n**Before moving on, ensure you understand the key concepts from this module.**
