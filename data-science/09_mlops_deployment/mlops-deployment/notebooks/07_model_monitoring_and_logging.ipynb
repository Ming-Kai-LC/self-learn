# %% [markdown]
# # Module 07: Model Monitoring and Logging\n\n**Difficulty**: ⭐⭐  \n**Estimated Time**: 60 minutes  \n**Prerequisites**: \n- Module 06: Model Serving Patterns\n- Basic understanding of logging\n\n## Learning Objectives\n\nBy the end of this notebook, you will be able to:\n1. Implement comprehensive logging for ML systems\n2. Set up Prometheus metrics\n3. Monitor model performance in production\n4. Create alerting rules\n5. Build monitoring dashboards

# %% [markdown]
# ## 1. Introduction\n\nProduction models need continuous monitoring. Learn to track performance, detect issues, and alert when problems occur.

# %%
# Setup: Import required libraries\nimport numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport warnings\n\nwarnings.filterwarnings('ignore')\nnp.random.seed(42)\n\nprint('✓ Libraries imported successfully')

# %% [markdown]
# ## 2. Logging Strategies\n\nStructured logging for ML applications

# %%
# Code example for: Logging Strategies\n\n# TODO: Implement example\nprint(f'Section 2: Logging Strategies')

# %% [markdown]
# ## 3. Prometheus Metrics\n\nCollecting and exposing ML metrics

# %%
# Code example for: Prometheus Metrics\n\n# TODO: Implement example\nprint(f'Section 3: Prometheus Metrics')

# %% [markdown]
# ## 4. Performance Monitoring\n\nTracking latency, throughput, and accuracy

# %%
# Code example for: Performance Monitoring\n\n# TODO: Implement example\nprint(f'Section 4: Performance Monitoring')

# %% [markdown]
# ## 5. Alerting\n\nSetting up alerts for anomalies

# %%
# Code example for: Alerting\n\n# TODO: Implement example\nprint(f'Section 5: Alerting')

# %% [markdown]
# ## 6. Dashboards\n\nVisualizing model performance

# %%
# Code example for: Dashboards\n\n# TODO: Implement example\nprint(f'Section 6: Dashboards')

# %% [markdown]
# ### 🎯 Exercise 1: Implement Logging\n\nAdd comprehensive logging\n\n**Requirements:**\n1. Request/response logging\n2. Error tracking\n3. Log aggregation

# %%
# Your solution here\n\n# TODO: Implement your solution

# %% [markdown]
# ### 🎯 Exercise 2: Prometheus Setup\n\nConfigure Prometheus metrics\n\n**Requirements:**\n1. Custom metrics\n2. Metric export\n3. Visualization

# %%
# Your solution here\n\n# TODO: Implement your solution

# %% [markdown]
# ### 🎯 Exercise 3: Alert Rules\n\nCreate alerting system\n\n**Requirements:**\n1. Thresholds\n2. Alert routing\n3. Testing

# %%
# Your solution here\n\n# TODO: Implement your solution

# %% [markdown]
# ## Summary\n\n### Key Concepts Covered\n\n1. Logging best practices\n2. Metrics collection\n3. Monitoring strategies\n4. Alert configuration\n\n### What's Next\n\nIn **Module 08**, learn to detect and handle data drift in production.\n\n### Additional Resources\n\n- Prometheus: https://prometheus.io/\n- ML Monitoring: https://christophergs.com/machine%20learning/2020/03/14/how-to-monitor-machine-learning-models/

# %% [markdown]
# ---\n\n## Next Steps\n\nProceed to **Module 08** to continue your MLOps learning journey.\n\n**Before moving on, ensure you understand the key concepts from this module.**
