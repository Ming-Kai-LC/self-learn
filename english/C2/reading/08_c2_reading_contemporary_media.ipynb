# %% [markdown]
# # C2 Reading 08: Contemporary Media
#
# **Difficulty**: ⭐⭐⭐⭐
# **Time**: 60-75 min
#
# ## Learning Objectives
#
# 1. News analysis
# 2. Opinion pieces
# 3. Cultural commentary
# 4. Critical reading

# %%
print('C2 Reading: Contemporary Media')
print('Level: Mastery')

# %% [markdown]
# ## Content
#
# C2 mastery: News analysis, Opinion pieces, Cultural commentary, Critical reading
#
# ## Practice
# Native-level reading in all contexts.
