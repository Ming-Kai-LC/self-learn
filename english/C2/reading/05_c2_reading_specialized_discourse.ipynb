# %% [markdown]
# # C2 Reading 05: Specialized Discourse
#
# **Difficulty**: ⭐⭐⭐⭐
# **Time**: 60-75 min
#
# ## Learning Objectives
#
# 1. Field-specific texts
# 2. Expert materials
# 3. Technical precision
# 4. Professional level

# %%
print('C2 Reading: Specialized Discourse')
print('Level: Mastery')

# %% [markdown]
# ## Content
#
# C2 mastery: Field-specific texts, Expert materials, Technical precision, Professional level
#
# ## Practice
# Native-level reading in all contexts.
