# %% [markdown]
# # C2 Listening 05: Media and Entertainment
#
# **Difficulty**: ⭐⭐⭐⭐
# **Time**: 60-75 min
#
# ## Learning Objectives
#
# 1. Films/TV
# 2. Podcasts
# 3. Radio
# 4. Native-level enjoyment

# %%
print('C2 Listening: Media and Entertainment')
print('Level: Mastery')

# %% [markdown]
# ## Content
#
# C2 mastery: Films/TV, Podcasts, Radio, Native-level enjoyment
#
# ## Practice
# Native-level comprehension in all contexts.
