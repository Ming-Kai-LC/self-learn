# %% [markdown]
# # C2 Listening 01: Native Speech Comprehension
#
# **Difficulty**: ⭐⭐⭐⭐
# **Time**: 60-75 min
#
# ## Learning Objectives
#
# 1. Any accent
# 2. Any speed
# 3. Colloquial speech
# 4. Complete understanding

# %%
print('C2 Listening: Native Speech Comprehension')
print('Level: Mastery')

# %% [markdown]
# ## Content
#
# C2 mastery: Any accent, Any speed, Colloquial speech, Complete understanding
#
# ## Practice
# Native-level comprehension in all contexts.
