# %% [markdown]
# # C2 Listening 06: Multiple Speakers and Accents
#
# **Difficulty**: ⭐⭐⭐⭐
# **Time**: 60-75 min
#
# ## Learning Objectives
#
# 1. Group discussions
# 2. Accent variety
# 3. Fast exchanges
# 4. Perfect tracking

# %%
print('C2 Listening: Multiple Speakers and Accents')
print('Level: Mastery')

# %% [markdown]
# ## Content
#
# C2 mastery: Group discussions, Accent variety, Fast exchanges, Perfect tracking
#
# ## Practice
# Native-level comprehension in all contexts.
