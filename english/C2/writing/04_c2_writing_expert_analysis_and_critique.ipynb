# %% [markdown]
# # C2 Writing 04: Expert Analysis and Critique
#
# **Difficulty**: ⭐⭐⭐⭐ (Proficient/Mastery)
# **Time**: 60-75 min
# **Prerequisites**: C1 level
#
# ## Learning Objectives
#
# At C2 level, you will demonstrate mastery of:
#
# 1. Sophisticated analysis
# 2. Nuanced evaluation
# 3. Theoretical frameworks
# 4. Critical synthesis
# 5. Expert judgment
# 6. Field contribution

# %% [markdown]
# ## Expert Analysis and Critique - C2 Writing
#
# Topics: Sophisticated analysis, Nuanced evaluation, Theoretical frameworks, Critical synthesis, Expert judgment, Field contribution
#
# ### Mastery Focus
# Write expert-level analytical pieces

# %%
# Expert Analysis and Critique
print('C2 Writing: Expert Analysis and Critique')
print('Level: Mastery - Native-equivalent proficiency')
print('Resources: Professional publications, expert-level materials, peer-reviewed journals')

# %% [markdown]
# ## Mastery-Level Content
#
# ### Expert Foundation
#
# At C2 level, expert analysis and critique requires complete mastery of sophisticated analysis and nuanced evaluation. You will demonstrate native-equivalent proficiency in all aspects of sophisticated written communication.
#
# ### Core Competencies
#
# **Sophisticated analysis**: Demonstrating expert-level proficiency
# **Nuanced evaluation**: Demonstrating expert-level proficiency
# **Theoretical frameworks**: Demonstrating expert-level proficiency
# **Critical synthesis**: Demonstrating expert-level proficiency
#
# ### Advanced Practice
#
# Engage in mastery-level tasks:
#
# 1. **Expert Task**: Demonstrate sophisticated analysis at professional level
# 2. **Advanced Application**: Apply nuanced evaluation in complex contexts
# 3. **Mastery Challenge**: Integrate theoretical frameworks seamlessly
# 4. **Professional Portfolio**: Create publication-quality work
# 5. **Peer Review**: Engage with expert feedback

# %%
# Mastery Portfolio
from datetime import datetime

mastery_portfolio = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C2 Writing 04',
    'competencies': ['Sophisticated analysis', 'Nuanced evaluation', 'Theoretical frameworks', 'Critical synthesis'],
    'expert_feedback': 'Professional critique and evaluation',
    'publication_ready': 'Yes/No',
    'mastery_level': 'Self-assessment: /10',
    'professional_applications': 'List real-world uses',
    'reflections': 'Expert-level insights and growth'
}

print('Mastery Portfolio Initiated')
print(f"Module: {mastery_portfolio['module']}")
print(f"Core Competencies: {', '.join(mastery_portfolio['competencies'])}")

# %% [markdown]
# ## Expert-Level AI Integration
#
# ### Professional Critique (ChatGPT/Claude):
#
# ```
# I am demonstrating C2-level mastery in expert analysis and critique. Please provide expert-level critique on:
# 1. Sophisticated analysis - demonstrating professional standards
# 2. Nuanced evaluation - assessing native-equivalent proficiency
# 3. Theoretical frameworks - evaluating publication readiness
# 4. Critical synthesis - identifying opportunities for refinement
# 5. Overall assessment against professional/native-speaker benchmarks
#
# Provide specific examples where improvement is possible, and acknowledge areas of mastery.
#
# [Attach your professional writing]
# ```
#
# ### Collaborative Development:
#
# ```
# As a C2-level writer, I'm developing expert analysis and critique. Engage with me as a peer:
# 1. Discuss sophisticated approaches and methodologies
# 2. Explore theoretical frameworks and contemporary discourse
# 3. Challenge my assumptions with expert-level insights
# 4. Recommend cutting-edge resources and professional communities
# ```

# %% [markdown]
# ## Professional Standards
#
# ### Publication-Quality Requirements:
#
# 1. **Linguistic Excellence**: Native-equivalent precision and fluency
# 2. **Intellectual Rigor**: Sophisticated analysis and original insight
# 3. **Professional Standards**: Adherence to field-specific conventions
# 4. **Sophisticated analysis**: Demonstrated at expert level
# 5. **Nuanced evaluation**: Seamless integration
# 6. **Peer Review Ready**: Meeting professional publication standards
#
# ### Continuous Refinement:
#
# - Engage with professional writing communities
# - Seek expert feedback from native speakers and field professionals
# - Maintain awareness of evolving standards and contemporary discourse
# - Contribute to the field through publication and professional engagement
#
# ## Summary
#
# **Mastery Achieved**: Sophisticated analysis, Nuanced evaluation, Theoretical frameworks, Critical synthesis
#
# **Professional Development**: At C2 level, you demonstrate native-equivalent proficiency. Continue engaging with professional communities, publishing your work, and contributing to your field.
