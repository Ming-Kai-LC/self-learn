# %% [markdown]
# # B1 Speaking 11: Simple Discussions
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Agreeing
# 2. Disagreeing
# 3. Opinions
# 4. Reasons
# 5. Turn-taking

# %% [markdown]
# ## Simple Discussions - B1 Speaking Practice
#
# Key topics: Agreeing, Disagreeing, Opinions, Reasons, Turn-taking
#
# ### Why This Matters
# Simple Discussions skills are essential for everyday B1 communication.

# %%
# Simple Discussions Practice
print('B1 Speaking: Simple Discussions')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Agreeing, Disagreeing, Opinions, Reasons, Turn-taking')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Agreeing
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Disagreeing
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Agreeing, Disagreeing, Opinions
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 12
