# %% [markdown]
# # B1 Speaking 14: Travel Situations
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Hotels
# 2. Airports
# 3. Asking info
# 4. Problems
# 5. Bookings

# %% [markdown]
# ## Travel Situations - B1 Speaking Practice
#
# Key topics: Hotels, Airports, Asking info, Problems, Bookings
#
# ### Why This Matters
# Travel Situations skills are essential for everyday B1 communication.

# %%
# Travel Situations Practice
print('B1 Speaking: Travel Situations')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Hotels, Airports, Asking info, Problems, Bookings')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Hotels
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Airports
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Hotels, Airports, Asking info
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 15
