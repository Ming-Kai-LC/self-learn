# %% [markdown]
# # B1 Speaking 02: Pronunciation Basics
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Vowel sounds
# 2. Consonants
# 3. Word stress
# 4. Sentence stress
# 5. Intonation

# %% [markdown]
# ## Pronunciation Basics - B1 Speaking Practice
#
# Key topics: Vowel sounds, Consonants, Word stress, Sentence stress, Intonation
#
# ### Why This Matters
# Pronunciation Basics skills are essential for everyday B1 communication.

# %%
# Pronunciation Basics Practice
print('B1 Speaking: Pronunciation Basics')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Vowel sounds, Consonants, Word stress, Sentence stress, Intonation')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Vowel sounds
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Consonants
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Vowel sounds, Consonants, Word stress
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 03
