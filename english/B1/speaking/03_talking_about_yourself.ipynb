# %% [markdown]
# # B1 Speaking 03: Talking About Yourself
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Background
# 2. Hobbies
# 3. Work
# 4. Family
# 5. Interests

# %% [markdown]
# ## Talking About Yourself - B1 Speaking Practice
#
# Key topics: Background, Hobbies, Work, Family, Interests
#
# ### Why This Matters
# Talking About Yourself skills are essential for everyday B1 communication.

# %%
# Talking About Yourself Practice
print('B1 Speaking: Talking About Yourself')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Background, Hobbies, Work, Family, Interests')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Background
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Hobbies
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Background, Hobbies, Work
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 04
