# %% [markdown]
# # B1 Speaking 13: Shopping Restaurants
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Ordering
# 2. Asking prices
# 3. Complaining
# 4. Preferences
# 5. Polite requests

# %% [markdown]
# ## Shopping Restaurants - B1 Speaking Practice
#
# Key topics: Ordering, Asking prices, Complaining, Preferences, Polite requests
#
# ### Why This Matters
# Shopping Restaurants skills are essential for everyday B1 communication.

# %%
# Shopping Restaurants Practice
print('B1 Speaking: Shopping Restaurants')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Ordering, Asking prices, Complaining, Preferences, Polite requests')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Ordering
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Asking prices
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Ordering, Asking prices, Complaining
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 14
