# %% [markdown]
# # B1 Speaking 05: Past Experiences
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Past simple
# 2. Storytelling
# 3. Experiences
# 4. Time markers
# 5. Details

# %% [markdown]
# ## Past Experiences - B1 Speaking Practice
#
# Key topics: Past simple, Storytelling, Experiences, Time markers, Details
#
# ### Why This Matters
# Past Experiences skills are essential for everyday B1 communication.

# %%
# Past Experiences Practice
print('B1 Speaking: Past Experiences')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Past simple, Storytelling, Experiences, Time markers, Details')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Past simple
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Storytelling
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Past simple, Storytelling, Experiences
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 06
