# %% [markdown]
# # B1 Speaking 10: Expressing Preferences
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Like/love/hate
# 2. Prefer
# 3. Would rather
# 4. Giving reasons
# 5. Comparing

# %% [markdown]
# ## Expressing Preferences - B1 Speaking Practice
#
# Key topics: Like/love/hate, Prefer, Would rather, Giving reasons, Comparing
#
# ### Why This Matters
# Expressing Preferences skills are essential for everyday B1 communication.

# %%
# Expressing Preferences Practice
print('B1 Speaking: Expressing Preferences')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Like/love/hate, Prefer, Would rather, Giving reasons, Comparing')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Like/love/hate
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Prefer
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Like/love/hate, Prefer, Would rather
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 11
