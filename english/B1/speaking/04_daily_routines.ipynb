# %% [markdown]
# # B1 Speaking 04: Daily Routines
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Present simple
# 2. Time expressions
# 3. Frequency adverbs
# 4. Sequencing
# 5. Habits

# %% [markdown]
# ## Daily Routines - B1 Speaking Practice
#
# Key topics: Present simple, Time expressions, Frequency adverbs, Sequencing, Habits
#
# ### Why This Matters
# Daily Routines skills are essential for everyday B1 communication.

# %%
# Daily Routines Practice
print('B1 Speaking: Daily Routines')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Present simple, Time expressions, Frequency adverbs, Sequencing, Habits')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Present simple
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Time expressions
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Present simple, Time expressions, Frequency adverbs
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 05
