# %% [markdown]
# # B1 Speaking 01: Basic Conversations
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Introductions
# 2. Greetings
# 3. Small talk
# 4. Asking questions
# 5. Responding

# %% [markdown]
# ## Basic Conversations - B1 Speaking Practice
#
# Key topics: Introductions, Greetings, Small talk, Asking questions, Responding
#
# ### Why This Matters
# Basic Conversations skills are essential for everyday B1 communication.

# %%
# Basic Conversations Practice
print('B1 Speaking: Basic Conversations')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Introductions, Greetings, Small talk, Asking questions, Responding')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Introductions
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Greetings
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Introductions, Greetings, Small talk
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 02
