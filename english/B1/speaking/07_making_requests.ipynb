# %% [markdown]
# # B1 Speaking 07: Making Requests
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Can/Could
# 2. Would you
# 3. Polite language
# 4. Permission
# 5. Offers

# %% [markdown]
# ## Making Requests - B1 Speaking Practice
#
# Key topics: Can/Could, Would you, Polite language, Permission, Offers
#
# ### Why This Matters
# Making Requests skills are essential for everyday B1 communication.

# %%
# Making Requests Practice
print('B1 Speaking: Making Requests')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Can/Could, Would you, Polite language, Permission, Offers')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Can/Could
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Would you
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Can/Could, Would you, Polite language
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 08
