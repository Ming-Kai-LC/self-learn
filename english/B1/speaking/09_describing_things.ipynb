# %% [markdown]
# # B1 Speaking 09: Describing Things
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Adjectives
# 2. Comparatives
# 3. Superlatives
# 4. It's/There's
# 5. Details

# %% [markdown]
# ## Describing Things - B1 Speaking Practice
#
# Key topics: Adjectives, Comparatives, Superlatives, It's/There's, Details
#
# ### Why This Matters
# Describing Things skills are essential for everyday B1 communication.

# %%
# Describing Things Practice
print('B1 Speaking: Describing Things')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Adjectives, Comparatives, Superlatives, It's/There's, Details')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Adjectives
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Comparatives
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Adjectives, Comparatives, Superlatives
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 10
