# %% [markdown]
# # B1 Speaking 12: Telephone Basics
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Answering
# 2. Making calls
# 3. Messages
# 4. Spelling
# 5. Numbers

# %% [markdown]
# ## Telephone Basics - B1 Speaking Practice
#
# Key topics: Answering, Making calls, Messages, Spelling, Numbers
#
# ### Why This Matters
# Telephone Basics skills are essential for everyday B1 communication.

# %%
# Telephone Basics Practice
print('B1 Speaking: Telephone Basics')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Answering, Making calls, Messages, Spelling, Numbers')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Answering
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Making calls
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Answering, Making calls, Messages
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 13
