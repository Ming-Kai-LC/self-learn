# %% [markdown]
# # B1 Speaking 06: Future Plans
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Going to
# 2. Will
# 3. Present continuous
# 4. Arrangements
# 5. Predictions

# %% [markdown]
# ## Future Plans - B1 Speaking Practice
#
# Key topics: Going to, Will, Present continuous, Arrangements, Predictions
#
# ### Why This Matters
# Future Plans skills are essential for everyday B1 communication.

# %%
# Future Plans Practice
print('B1 Speaking: Future Plans')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Going to, Will, Present continuous, Arrangements, Predictions')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Going to
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Will
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Going to, Will, Present continuous
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 07
