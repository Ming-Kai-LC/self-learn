# %% [markdown]
# # B1 Speaking 08: Giving Directions
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Location words
# 2. Prepositions
# 3. Imperatives
# 4. Landmarks
# 5. Clarifying

# %% [markdown]
# ## Giving Directions - B1 Speaking Practice
#
# Key topics: Location words, Prepositions, Imperatives, Landmarks, Clarifying
#
# ### Why This Matters
# Giving Directions skills are essential for everyday B1 communication.

# %%
# Giving Directions Practice
print('B1 Speaking: Giving Directions')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Location words, Prepositions, Imperatives, Landmarks, Clarifying')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Location words
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Prepositions
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Mastered: Location words, Prepositions, Imperatives
#
# **Daily Practice**: 10 min Gliglish + AI conversations
#
# **Next**: B1 Speaking 09
