# %% [markdown]
# # B1 Speaking 15: B1 Speaking Assessment
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Conversation test
# 2. Self-evaluation
# 3. Progress review
# 4. Strengths
# 5. B2 preparation

# %% [markdown]
# ## B1 Speaking Assessment - B1 Speaking Practice
#
# Key topics: Conversation test, Self-evaluation, Progress review, Strengths, B2 preparation
#
# ### Why This Matters
# B1 Speaking Assessment skills are essential for everyday B1 communication.

# %%
# B1 Speaking Assessment Practice
print('B1 Speaking: B1 Speaking Assessment')\nprint('Practice with Gliglish or ChatGPT')\nprint('Topics: Conversation test, Self-evaluation, Progress review, Strengths, B2 preparation')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Conversation test
# Practice with AI conversation (5-10 min).
#
# ### Task 2: Self-evaluation
# Record yourself and review.
#
# ### Task 3: Real Situations
# Use in real conversations when possible.

# %% [markdown]
# ## Summary
#
# Completed B1 Speaking! Ready for B2.
#
# **Next**: Start B2 Speaking for professional fluency
