# %% [markdown]
# # B1 Listening 06: Telephone Messages
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Taking messages
# 2. Key details
# 3. Names/numbers
# 4. Purpose
# 5. Actions

# %% [markdown]
# ## Telephone Messages - B1 Listening
#
# Topics: Taking messages, Key details, Names/numbers, Purpose, Actions
#
# ### Practice Focus
# Develop telephone messages skills for everyday comprehension.

# %%
# Telephone Messages
print('B1 Listening: Telephone Messages')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice taking messages
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Taking messages, Key details, Names/numbers
