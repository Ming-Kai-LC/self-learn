# %% [markdown]
# # B1 Listening 01: Podcast Basics
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Finding podcasts
# 2. Slow English
# 3. Transcripts
# 4. Repetition
# 5. Comprehension

# %% [markdown]
# ## Podcast Basics - B1 Listening
#
# Topics: Finding podcasts, Slow English, Transcripts, Repetition, Comprehension
#
# ### Practice Focus
# Develop podcast basics skills for everyday comprehension.

# %%
# Podcast Basics
print('B1 Listening: Podcast Basics')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice finding podcasts
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Finding podcasts, Slow English, Transcripts
