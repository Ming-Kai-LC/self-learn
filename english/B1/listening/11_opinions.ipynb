# %% [markdown]
# # B1 Listening 11: Opinions
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Agreeing
# 2. Disagreeing
# 3. Reasons
# 4. Preferences
# 5. Understanding viewpoints

# %% [markdown]
# ## Opinions - B1 Listening
#
# Topics: Agreeing, Disagreeing, Reasons, Preferences, Understanding viewpoints
#
# ### Practice Focus
# Develop opinions skills for everyday comprehension.

# %%
# Opinions
print('B1 Listening: Opinions')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice agreeing
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Agreeing, Disagreeing, Reasons
