# %% [markdown]
# # B1 Listening 14: Note Taking
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Key words
# 2. Main ideas
# 3. Organization
# 4. Abbreviations
# 5. Review

# %% [markdown]
# ## Note Taking - B1 Listening
#
# Topics: Key words, Main ideas, Organization, Abbreviations, Review
#
# ### Practice Focus
# Develop note taking skills for everyday comprehension.

# %%
# Note Taking
print('B1 Listening: Note Taking')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice key words
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Key words, Main ideas, Organization
