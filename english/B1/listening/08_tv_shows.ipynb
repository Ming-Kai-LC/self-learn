# %% [markdown]
# # B1 Listening 08: TV Shows
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Subtitles use
# 2. Storylines
# 3. Characters
# 4. Dialogues
# 5. Context

# %% [markdown]
# ## TV Shows - B1 Listening
#
# Topics: Subtitles use, Storylines, Characters, Dialogues, Context
#
# ### Practice Focus
# Develop tv shows skills for everyday comprehension.

# %%
# TV Shows
print('B1 Listening: TV Shows')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice subtitles use
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Subtitles use, Storylines, Characters
