# %% [markdown]
# # B1 Listening 05: Announcements
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Airport/station
# 2. Important info
# 3. Numbers/times
# 4. Actions needed
# 5. Understanding

# %% [markdown]
# ## Announcements - B1 Listening
#
# Topics: Airport/station, Important info, Numbers/times, Actions needed, Understanding
#
# ### Practice Focus
# Develop announcements skills for everyday comprehension.

# %%
# Announcements
print('B1 Listening: Announcements')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice airport/station
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Airport/station, Important info, Numbers/times
