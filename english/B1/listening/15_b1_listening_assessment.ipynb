# %% [markdown]
# # B1 Listening 15: B1 Listening Assessment
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Comprehension test
# 2. Progress check
# 3. Strategies review
# 4. Weak areas
# 5. B2 preparation

# %% [markdown]
# ## B1 Listening Assessment - B1 Listening
#
# Topics: Comprehension test, Progress check, Strategies review, Weak areas, B2 preparation
#
# ### Practice Focus
# Develop b1 listening assessment skills for everyday comprehension.

# %%
# B1 Listening Assessment
print('B1 Listening: B1 Listening Assessment')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice comprehension test
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Comprehension test, Progress check, Strategies review
