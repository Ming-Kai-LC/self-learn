# %% [markdown]
# # B1 Listening 12: Past Events
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Narratives
# 2. Sequence
# 3. Past tenses
# 4. Details
# 5. Time markers

# %% [markdown]
# ## Past Events - B1 Listening
#
# Topics: Narratives, Sequence, Past tenses, Details, Time markers
#
# ### Practice Focus
# Develop past events skills for everyday comprehension.

# %%
# Past Events
print('B1 Listening: Past Events')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice narratives
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Narratives, Sequence, Past tenses
