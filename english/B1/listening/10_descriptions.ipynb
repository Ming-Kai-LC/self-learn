# %% [markdown]
# # B1 Listening 10: Descriptions
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. People
# 2. Places
# 3. Objects
# 4. Features
# 5. Vocabulary

# %% [markdown]
# ## Descriptions - B1 Listening
#
# Topics: People, Places, Objects, Features, Vocabulary
#
# ### Practice Focus
# Develop descriptions skills for everyday comprehension.

# %%
# Descriptions
print('B1 Listening: Descriptions')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice people
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: People, Places, Objects
