# %% [markdown]
# # B1 Listening 13: Future Plans
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Intentions
# 2. Predictions
# 3. Arrangements
# 4. Will/going to
# 5. Time references

# %% [markdown]
# ## Future Plans - B1 Listening
#
# Topics: Intentions, Predictions, Arrangements, Will/going to, Time references
#
# ### Practice Focus
# Develop future plans skills for everyday comprehension.

# %%
# Future Plans
print('B1 Listening: Future Plans')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice intentions
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Intentions, Predictions, Arrangements
