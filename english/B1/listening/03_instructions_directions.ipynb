# %% [markdown]
# # B1 Listening 03: Instructions Directions
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Following steps
# 2. Location words
# 3. Sequence
# 4. Understanding
# 5. Clarifying

# %% [markdown]
# ## Instructions Directions - B1 Listening
#
# Topics: Following steps, Location words, Sequence, Understanding, Clarifying
#
# ### Practice Focus
# Develop instructions directions skills for everyday comprehension.

# %%
# Instructions Directions
print('B1 Listening: Instructions Directions')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice following steps
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Following steps, Location words, Sequence
