# %% [markdown]
# # B1 Listening 02: Simple Conversations
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Dialogues
# 2. Questions answers
# 3. Main ideas
# 4. Details
# 5. Context

# %% [markdown]
# ## Simple Conversations - B1 Listening
#
# Topics: Dialogues, Questions answers, Main ideas, Details, Context
#
# ### Practice Focus
# Develop simple conversations skills for everyday comprehension.

# %%
# Simple Conversations
print('B1 Listening: Simple Conversations')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice dialogues
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Dialogues, Questions answers, Main ideas
