# %% [markdown]
# # B1 Listening 04: News Bulletins
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Headlines
# 2. Main stories
# 3. Key information
# 4. Vocabulary
# 5. Summary

# %% [markdown]
# ## News Bulletins - B1 Listening
#
# Topics: Headlines, Main stories, Key information, Vocabulary, Summary
#
# ### Practice Focus
# Develop news bulletins skills for everyday comprehension.

# %%
# News Bulletins
print('B1 Listening: News Bulletins')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice headlines
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Headlines, Main stories, Key information
