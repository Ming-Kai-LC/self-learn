# %% [markdown]
# # B1 Listening 07: Short Talks
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Presentations
# 2. Main topic
# 3. Key points
# 4. Examples
# 5. Conclusions

# %% [markdown]
# ## Short Talks - B1 Listening
#
# Topics: Presentations, Main topic, Key points, Examples, Conclusions
#
# ### Practice Focus
# Develop short talks skills for everyday comprehension.

# %%
# Short Talks
print('B1 Listening: Short Talks')\nprint('Resources: podcasts, YouTube, slow English')

# %% [markdown]
# ## Tasks
#
# 1. Listen to recommended content
# 2. Practice presentations
# 3. Discuss with AI to verify understanding
#
# ## Summary
#
# Mastered: Presentations, Main topic, Key points
