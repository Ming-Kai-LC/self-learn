# %% [markdown]
# # B1 Reading 03: Short Articles
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. News articles
# 2. Topics
# 3. Main points
# 4. Vocabulary
# 5. Summary

# %% [markdown]
# ## Short Articles - B1 Reading
#
# Topics: News articles, Topics, Main points, Vocabulary, Summary
#
# ### Practice Focus
# Build short articles skills for B1 comprehension.

# %%
# Short Articles
print('B1 Reading: Short Articles')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice news articles
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: News articles, Topics, Main points
