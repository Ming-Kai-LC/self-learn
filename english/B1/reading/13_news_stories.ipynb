# %% [markdown]
# # B1 Reading 13: News Stories
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Current events
# 2. Who/what/where/when
# 3. Details
# 4. Understanding
# 5. Discussion

# %% [markdown]
# ## News Stories - B1 Reading
#
# Topics: Current events, Who/what/where/when, Details, Understanding, Discussion
#
# ### Practice Focus
# Build news stories skills for B1 comprehension.

# %%
# News Stories
print('B1 Reading: News Stories')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice current events
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Current events, Who/what/where/when, Details
