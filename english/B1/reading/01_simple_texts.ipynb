# %% [markdown]
# # B1 Reading 01: Simple Texts
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Reading basics
# 2. Main ideas
# 3. Details
# 4. Vocabulary
# 5. Comprehension

# %% [markdown]
# ## Simple Texts - B1 Reading
#
# Topics: Reading basics, Main ideas, Details, Vocabulary, Comprehension
#
# ### Practice Focus
# Build simple texts skills for B1 comprehension.

# %%
# Simple Texts
print('B1 Reading: Simple Texts')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice reading basics
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Reading basics, Main ideas, Details
