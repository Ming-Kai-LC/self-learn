# %% [markdown]
# # B1 Reading 14: Scanning Skimming
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Quick reading
# 2. Finding information
# 3. Main ideas
# 4. Speed
# 5. Efficiency

# %% [markdown]
# ## Scanning Skimming - B1 Reading
#
# Topics: Quick reading, Finding information, Main ideas, Speed, Efficiency
#
# ### Practice Focus
# Build scanning skimming skills for B1 comprehension.

# %%
# Scanning Skimming
print('B1 Reading: Scanning Skimming')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice quick reading
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Quick reading, Finding information, Main ideas
