# %% [markdown]
# # B1 Reading 05: Timetables Schedules
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Reading times
# 2. Dates
# 3. Locations
# 4. Information extraction
# 5. Planning

# %% [markdown]
# ## Timetables Schedules - B1 Reading
#
# Topics: Reading times, Dates, Locations, Information extraction, Planning
#
# ### Practice Focus
# Build timetables schedules skills for B1 comprehension.

# %%
# Timetables Schedules
print('B1 Reading: Timetables Schedules')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice reading times
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Reading times, Dates, Locations
