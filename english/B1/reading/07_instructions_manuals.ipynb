# %% [markdown]
# # B1 Reading 07: Instructions Manuals
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Steps
# 2. Sequence
# 3. Warnings
# 4. Diagrams
# 5. Understanding

# %% [markdown]
# ## Instructions Manuals - B1 Reading
#
# Topics: Steps, Sequence, Warnings, Diagrams, Understanding
#
# ### Practice Focus
# Build instructions manuals skills for B1 comprehension.

# %%
# Instructions Manuals
print('B1 Reading: Instructions Manuals')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice steps
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Steps, Sequence, Warnings
