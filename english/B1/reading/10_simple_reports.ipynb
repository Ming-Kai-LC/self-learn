# %% [markdown]
# # B1 Reading 10: Simple Reports
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Factual information
# 2. Organization
# 3. Data
# 4. Conclusions
# 5. Understanding

# %% [markdown]
# ## Simple Reports - B1 Reading
#
# Topics: Factual information, Organization, Data, Conclusions, Understanding
#
# ### Practice Focus
# Build simple reports skills for B1 comprehension.

# %%
# Simple Reports
print('B1 Reading: Simple Reports')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice factual information
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Factual information, Organization, Data
