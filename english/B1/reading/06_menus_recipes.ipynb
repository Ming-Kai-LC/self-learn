# %% [markdown]
# # B1 Reading 06: Menus Recipes
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Food vocabulary
# 2. Instructions
# 3. Ingredients
# 4. Quantities
# 5. Steps

# %% [markdown]
# ## Menus Recipes - B1 Reading
#
# Topics: Food vocabulary, Instructions, Ingredients, Quantities, Steps
#
# ### Practice Focus
# Build menus recipes skills for B1 comprehension.

# %%
# Menus Recipes
print('B1 Reading: Menus Recipes')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice food vocabulary
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Food vocabulary, Instructions, Ingredients
