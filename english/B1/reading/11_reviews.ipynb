# %% [markdown]
# # B1 Reading 11: Reviews
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Products/movies/books
# 2. Opinions
# 3. Reasons
# 4. Recommendations
# 5. Evaluation

# %% [markdown]
# ## Reviews - B1 Reading
#
# Topics: Products/movies/books, Opinions, Reasons, Recommendations, Evaluation
#
# ### Practice Focus
# Build reviews skills for B1 comprehension.

# %%
# Reviews
print('B1 Reading: Reviews')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice products/movies/books
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Products/movies/books, Opinions, Reasons
