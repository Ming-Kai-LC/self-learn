# %% [markdown]
# # B1 Reading 04: Advertisements
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Products/services
# 2. Key info
# 3. Prices/details
# 4. Understanding purpose
# 5. Evaluation

# %% [markdown]
# ## Advertisements - B1 Reading
#
# Topics: Products/services, Key info, Prices/details, Understanding purpose, Evaluation
#
# ### Practice Focus
# Build advertisements skills for B1 comprehension.

# %%
# Advertisements
print('B1 Reading: Advertisements')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice products/services
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Products/services, Key info, Prices/details
