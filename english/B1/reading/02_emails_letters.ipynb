# %% [markdown]
# # B1 Reading 02: Emails Letters
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Personal emails
# 2. Simple letters
# 3. Purpose
# 4. Key information
# 5. Responding

# %% [markdown]
# ## Emails Letters - B1 Reading
#
# Topics: Personal emails, Simple letters, Purpose, Key information, Responding
#
# ### Practice Focus
# Build emails letters skills for B1 comprehension.

# %%
# Emails Letters
print('B1 Reading: Emails Letters')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice personal emails
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Personal emails, Simple letters, Purpose
