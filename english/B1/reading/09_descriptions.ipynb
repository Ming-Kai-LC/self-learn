# %% [markdown]
# # B1 Reading 09: Descriptions
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. People/places
# 2. Adjectives
# 3. Details
# 4. Imagery
# 5. Comprehension

# %% [markdown]
# ## Descriptions - B1 Reading
#
# Topics: People/places, Adjectives, Details, Imagery, Comprehension
#
# ### Practice Focus
# Build descriptions skills for B1 comprehension.

# %%
# Descriptions
print('B1 Reading: Descriptions')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice people/places
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: People/places, Adjectives, Details
