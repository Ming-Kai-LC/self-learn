# %% [markdown]
# # B1 Reading 08: Stories Narratives
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Plot
# 2. Characters
# 3. Setting
# 4. Events
# 5. Understanding

# %% [markdown]
# ## Stories Narratives - B1 Reading
#
# Topics: Plot, Characters, Setting, Events, Understanding
#
# ### Practice Focus
# Build stories narratives skills for B1 comprehension.

# %%
# Stories Narratives
print('B1 Reading: Stories Narratives')\nprint('Resources: simple news, graded readers, websites')

# %% [markdown]
# ## Tasks
#
# 1. Read recommended texts
# 2. Practice plot
# 3. Discuss content with AI
#
# ## Summary
#
# Mastered: Plot, Characters, Setting
