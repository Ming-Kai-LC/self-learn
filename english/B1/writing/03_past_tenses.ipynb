# %% [markdown]
# # B1 Writing 03: Past Tenses
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Past simple
# 2. Past continuous
# 3. Past perfect
# 4. Time markers
# 5. Storytelling

# %% [markdown]
# ## Past Tenses - B1 Intermediate Writing
#
# Key topics: Past simple, Past continuous, Past perfect, Time markers, Storytelling
#
# ### Why This Matters
# Mastering past tenses is essential for B1 intermediate writing competence.

# %%
# Past Tenses Practice
print('B1 Writing: Past Tenses')\nprint('Practice with AI feedback')\nprint('Topics: Past simple, Past continuous, Past perfect, Time markers, Storytelling')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Past simple
# Practice this skill with ChatGPT/Claude feedback.
#
# ### Task 2: Past continuous
# Write examples and get corrections.
#
# ### Task 3: Real Application
# Apply to real-world writing situations.

# %% [markdown]
# ## Summary
#
# Mastered: Past simple, Past continuous, Past perfect
#
# **Practice**: Daily writing (10-15 min) with AI feedback
#
# **Next**: B1 Writing 04
