# %% [markdown]
# # B1 Writing 12: Narratives Stories
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Story structure
# 2. Past tenses
# 3. Time sequence
# 4. Descriptions
# 5. Endings

# %% [markdown]
# ## Narratives Stories - B1 Intermediate Writing
#
# Key topics: Story structure, Past tenses, Time sequence, Descriptions, Endings
#
# ### Why This Matters
# Mastering narratives stories is essential for B1 intermediate writing competence.

# %%
# Narratives Stories Practice
print('B1 Writing: Narratives Stories')\nprint('Practice with AI feedback')\nprint('Topics: Story structure, Past tenses, Time sequence, Descriptions, Endings')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Story structure
# Practice this skill with ChatGPT/Claude feedback.
#
# ### Task 2: Past tenses
# Write examples and get corrections.
#
# ### Task 3: Real Application
# Apply to real-world writing situations.

# %% [markdown]
# ## Summary
#
# Mastered: Story structure, Past tenses, Time sequence
#
# **Practice**: Daily writing (10-15 min) with AI feedback
#
# **Next**: B1 Writing 13
