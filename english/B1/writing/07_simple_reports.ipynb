# %% [markdown]
# # B1 Writing 07: Simple Reports
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Report structure
# 2. Factual writing
# 3. Organization
# 4. Clear language
# 5. Conclusions

# %% [markdown]
# ## Simple Reports - B1 Intermediate Writing
#
# Key topics: Report structure, Factual writing, Organization, Clear language, Conclusions
#
# ### Why This Matters
# Mastering simple reports is essential for B1 intermediate writing competence.

# %%
# Simple Reports Practice
print('B1 Writing: Simple Reports')\nprint('Practice with AI feedback')\nprint('Topics: Report structure, Factual writing, Organization, Clear language, Conclusions')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Report structure
# Practice this skill with ChatGPT/Claude feedback.
#
# ### Task 2: Factual writing
# Write examples and get corrections.
#
# ### Task 3: Real Application
# Apply to real-world writing situations.

# %% [markdown]
# ## Summary
#
# Mastered: Report structure, Factual writing, Organization
#
# **Practice**: Daily writing (10-15 min) with AI feedback
#
# **Next**: B1 Writing 08
