# %% [markdown]
# # B1 Writing 13: Basic Paragraphs
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Topic sentence
# 2. Supporting sentences
# 3. Examples
# 4. Concluding sentence
# 5. Unity

# %% [markdown]
# ## Basic Paragraphs - B1 Intermediate Writing
#
# Key topics: Topic sentence, Supporting sentences, Examples, Concluding sentence, Unity
#
# ### Why This Matters
# Mastering basic paragraphs is essential for B1 intermediate writing competence.

# %%
# Basic Paragraphs Practice
print('B1 Writing: Basic Paragraphs')\nprint('Practice with AI feedback')\nprint('Topics: Topic sentence, Supporting sentences, Examples, Concluding sentence, Unity')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Topic sentence
# Practice this skill with ChatGPT/Claude feedback.
#
# ### Task 2: Supporting sentences
# Write examples and get corrections.
#
# ### Task 3: Real Application
# Apply to real-world writing situations.

# %% [markdown]
# ## Summary
#
# Mastered: Topic sentence, Supporting sentences, Examples
#
# **Practice**: Daily writing (10-15 min) with AI feedback
#
# **Next**: B1 Writing 14
