# %% [markdown]
# # B1 Writing 09: Comparing Contrasting
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Comparison structures
# 2. Contrast words
# 3. Similarities differences
# 4. Organizing
# 5. Examples

# %% [markdown]
# ## Comparing Contrasting - B1 Intermediate Writing
#
# Key topics: Comparison structures, Contrast words, Similarities differences, Organizing, Examples
#
# ### Why This Matters
# Mastering comparing contrasting is essential for B1 intermediate writing competence.

# %%
# Comparing Contrasting Practice
print('B1 Writing: Comparing Contrasting')\nprint('Practice with AI feedback')\nprint('Topics: Comparison structures, Contrast words, Similarities differences, Organizing, Examples')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Comparison structures
# Practice this skill with ChatGPT/Claude feedback.
#
# ### Task 2: Contrast words
# Write examples and get corrections.
#
# ### Task 3: Real Application
# Apply to real-world writing situations.

# %% [markdown]
# ## Summary
#
# Mastered: Comparison structures, Contrast words, Similarities differences
#
# **Practice**: Daily writing (10-15 min) with AI feedback
#
# **Next**: B1 Writing 10
