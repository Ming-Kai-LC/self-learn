# %% [markdown]
# # B1 Writing 01: Simple Emails
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Email structure
# 2. Greetings
# 3. Basic requests
# 4. Closing
# 5. Common phrases

# %% [markdown]
# ## Simple Emails - B1 Intermediate Writing
#
# Key topics: Email structure, Greetings, Basic requests, Closing, Common phrases
#
# ### Why This Matters
# Mastering simple emails is essential for B1 intermediate writing competence.

# %%
# Simple Emails Practice
print('B1 Writing: Simple Emails')\nprint('Practice with AI feedback')\nprint('Topics: Email structure, Greetings, Basic requests, Closing, Common phrases')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Email structure
# Practice this skill with ChatGPT/Claude feedback.
#
# ### Task 2: Greetings
# Write examples and get corrections.
#
# ### Task 3: Real Application
# Apply to real-world writing situations.

# %% [markdown]
# ## Summary
#
# Mastered: Email structure, Greetings, Basic requests
#
# **Practice**: Daily writing (10-15 min) with AI feedback
#
# **Next**: B1 Writing 02
