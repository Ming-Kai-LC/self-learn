# %% [markdown]
# # B1 Writing 05: Describing People
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Appearance
# 2. Personality
# 3. Characteristics
# 4. Comparisons
# 5. Adjectives

# %% [markdown]
# ## Describing People - B1 Intermediate Writing
#
# Key topics: Appearance, Personality, Characteristics, Comparisons, Adjectives
#
# ### Why This Matters
# Mastering describing people is essential for B1 intermediate writing competence.

# %%
# Describing People Practice
print('B1 Writing: Describing People')\nprint('Practice with AI feedback')\nprint('Topics: Appearance, Personality, Characteristics, Comparisons, Adjectives')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Appearance
# Practice this skill with ChatGPT/Claude feedback.
#
# ### Task 2: Personality
# Write examples and get corrections.
#
# ### Task 3: Real Application
# Apply to real-world writing situations.

# %% [markdown]
# ## Summary
#
# Mastered: Appearance, Personality, Characteristics
#
# **Practice**: Daily writing (10-15 min) with AI feedback
#
# **Next**: B1 Writing 06
