# %% [markdown]
# # B1 Writing 11: Instructions Procedures
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Sequence words
# 2. Imperatives
# 3. Clear steps
# 4. Safety warnings
# 5. Results

# %% [markdown]
# ## Instructions Procedures - B1 Intermediate Writing
#
# Key topics: Sequence words, Imperatives, Clear steps, Safety warnings, Results
#
# ### Why This Matters
# Mastering instructions procedures is essential for B1 intermediate writing competence.

# %%
# Instructions Procedures Practice
print('B1 Writing: Instructions Procedures')\nprint('Practice with AI feedback')\nprint('Topics: Sequence words, Imperatives, Clear steps, Safety warnings, Results')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Sequence words
# Practice this skill with ChatGPT/Claude feedback.
#
# ### Task 2: Imperatives
# Write examples and get corrections.
#
# ### Task 3: Real Application
# Apply to real-world writing situations.

# %% [markdown]
# ## Summary
#
# Mastered: Sequence words, Imperatives, Clear steps
#
# **Practice**: Daily writing (10-15 min) with AI feedback
#
# **Next**: B1 Writing 12
