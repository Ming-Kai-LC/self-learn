# %% [markdown]
# # B1 Writing 06: Describing Places
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A2 level
#
# ## Learning Objectives
#
# 1. Location words
# 2. Prepositions
# 3. Features
# 4. Directions
# 5. Descriptions

# %% [markdown]
# ## Describing Places - B1 Intermediate Writing
#
# Key topics: Location words, Prepositions, Features, Directions, Descriptions
#
# ### Why This Matters
# Mastering describing places is essential for B1 intermediate writing competence.

# %%
# Describing Places Practice
print('B1 Writing: Describing Places')\nprint('Practice with AI feedback')\nprint('Topics: Location words, Prepositions, Features, Directions, Descriptions')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Location words
# Practice this skill with ChatGPT/Claude feedback.
#
# ### Task 2: Prepositions
# Write examples and get corrections.
#
# ### Task 3: Real Application
# Apply to real-world writing situations.

# %% [markdown]
# ## Summary
#
# Mastered: Location words, Prepositions, Features
#
# **Practice**: Daily writing (10-15 min) with AI feedback
#
# **Next**: B1 Writing 07
