# %% [markdown]
# # A2 Listening 06: Daily Routines
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand morning routine
# 2. Understand work day
# 3. Understand free time
# 4. Understand time expressions
# 5. Understand activities

# %% [markdown]
# ## Daily Routines - A2 Listening
#
# Topics: Morning routine, Work day, Free time, Time expressions, Activities
#
# ### Practice Focus
# Listen to descriptions of routines

# %%
# Daily Routines
print('A2 Listening: Daily Routines')
print('Resources: slow English podcasts, easy videos, simple audio')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice listening to morning routine and work day. The audio is slow and clear.
#
# ### Part 2: What to Listen For
#
# **Morning routine**: Listen carefully for this
# **Work day**: Listen carefully for this
# **Free time**: Listen carefully for this
#
# ### Part 3: Listening Exercises
#
# Practice listening:
#
# 1. **Exercise 1**: Listen for morning routine
# 2. **Exercise 2**: Focus on work day
# 3. **Exercise 3**: Catch free time
# 4. **Exercise 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Listening 06',
    'topics': ['Morning routine', 'Work day', 'Free time'],
    'audio_sources': 'List what you listened to',
    'understood': '% you understood',
    'notes': 'Difficult words or parts'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Practice:
#
# ```
# I am A2 level. Help me practice daily routines.
# Please:
# 1. Recommend easy listening materials
# 2. Give me practice with morning routine
# 3. Ask me questions about what I heard
# 4. Use simple English
# ```
#
# ### Listening Resources:
#
# Good websites for A2:
# - Voice of America (Learning English)
# - BBC Learning English
# - Easy English YouTube
# - Slow English podcasts

# %% [markdown]
# ## Tasks
#
# 1. Find easy listening materials
# 2. Listen for morning routine
# 3. Listen again and check understanding
# 4. Answer questions about the audio
# 5. Practice every day
#
# ## Summary
#
# You practiced: Morning routine, Work day, Free time
#
# **Next Steps**: Listen to more English every day. Don't worry if you don't understand everything!
