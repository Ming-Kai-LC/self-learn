# %% [markdown]
# # A2 Listening 03: Simple Instructions
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand directions
# 2. Understand how to do things
# 3. Understand step by step
# 4. Understand commands
# 5. Understand imperatives

# %% [markdown]
# ## Simple Instructions - A2 Listening
#
# Topics: Directions, How to do things, Step by step, Commands, Imperatives
#
# ### Practice Focus
# Follow simple spoken instructions

# %%
# Simple Instructions
print('A2 Listening: Simple Instructions')
print('Resources: slow English podcasts, easy videos, simple audio')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice listening to directions and how to do things. The audio is slow and clear.
#
# ### Part 2: What to Listen For
#
# **Directions**: Listen carefully for this
# **How to do things**: Listen carefully for this
# **Step by step**: Listen carefully for this
#
# ### Part 3: Listening Exercises
#
# Practice listening:
#
# 1. **Exercise 1**: Listen for directions
# 2. **Exercise 2**: Focus on how to do things
# 3. **Exercise 3**: Catch step by step
# 4. **Exercise 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Listening 03',
    'topics': ['Directions', 'How to do things', 'Step by step'],
    'audio_sources': 'List what you listened to',
    'understood': '% you understood',
    'notes': 'Difficult words or parts'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Practice:
#
# ```
# I am A2 level. Help me practice simple instructions.
# Please:
# 1. Recommend easy listening materials
# 2. Give me practice with directions
# 3. Ask me questions about what I heard
# 4. Use simple English
# ```
#
# ### Listening Resources:
#
# Good websites for A2:
# - Voice of America (Learning English)
# - BBC Learning English
# - Easy English YouTube
# - Slow English podcasts

# %% [markdown]
# ## Tasks
#
# 1. Find easy listening materials
# 2. Listen for directions
# 3. Listen again and check understanding
# 4. Answer questions about the audio
# 5. Practice every day
#
# ## Summary
#
# You practiced: Directions, How to do things, Step by step
#
# **Next Steps**: Listen to more English every day. Don't worry if you don't understand everything!
