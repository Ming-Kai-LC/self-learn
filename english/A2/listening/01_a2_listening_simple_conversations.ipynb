# %% [markdown]
# # A2 Listening 01: Simple Conversations
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand basic dialogues
# 2. Understand greetings
# 3. Understand questions and answers
# 4. Understand everyday talk
# 5. Understand clear speech

# %% [markdown]
# ## Simple Conversations - A2 Listening
#
# Topics: Basic dialogues, Greetings, Questions and answers, Everyday talk, Clear speech
#
# ### Practice Focus
# Understand simple daily conversations

# %%
# Simple Conversations
print('A2 Listening: Simple Conversations')
print('Resources: slow English podcasts, easy videos, simple audio')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice listening to basic dialogues and greetings. The audio is slow and clear.
#
# ### Part 2: What to Listen For
#
# **Basic dialogues**: Listen carefully for this
# **Greetings**: Listen carefully for this
# **Questions and answers**: Listen carefully for this
#
# ### Part 3: Listening Exercises
#
# Practice listening:
#
# 1. **Exercise 1**: Listen for basic dialogues
# 2. **Exercise 2**: Focus on greetings
# 3. **Exercise 3**: Catch questions and answers
# 4. **Exercise 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Listening 01',
    'topics': ['Basic dialogues', 'Greetings', 'Questions and answers'],
    'audio_sources': 'List what you listened to',
    'understood': '% you understood',
    'notes': 'Difficult words or parts'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Practice:
#
# ```
# I am A2 level. Help me practice simple conversations.
# Please:
# 1. Recommend easy listening materials
# 2. Give me practice with basic dialogues
# 3. Ask me questions about what I heard
# 4. Use simple English
# ```
#
# ### Listening Resources:
#
# Good websites for A2:
# - Voice of America (Learning English)
# - BBC Learning English
# - Easy English YouTube
# - Slow English podcasts

# %% [markdown]
# ## Tasks
#
# 1. Find easy listening materials
# 2. Listen for basic dialogues
# 3. Listen again and check understanding
# 4. Answer questions about the audio
# 5. Practice every day
#
# ## Summary
#
# You practiced: Basic dialogues, Greetings, Questions and answers
#
# **Next Steps**: Listen to more English every day. Don't worry if you don't understand everything!
