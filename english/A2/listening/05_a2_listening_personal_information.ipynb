# %% [markdown]
# # A2 Listening 05: Personal Information
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand name and age
# 2. Understand job
# 3. Understand family
# 4. Understand address
# 5. Understand contact details

# %% [markdown]
# ## Personal Information - A2 Listening
#
# Topics: Name and age, Job, Family, Address, Contact details
#
# ### Practice Focus
# Understand personal details

# %%
# Personal Information
print('A2 Listening: Personal Information')
print('Resources: slow English podcasts, easy videos, simple audio')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice listening to name and age and job. The audio is slow and clear.
#
# ### Part 2: What to Listen For
#
# **Name and age**: Listen carefully for this
# **Job**: Listen carefully for this
# **Family**: Listen carefully for this
#
# ### Part 3: Listening Exercises
#
# Practice listening:
#
# 1. **Exercise 1**: Listen for name and age
# 2. **Exercise 2**: Focus on job
# 3. **Exercise 3**: Catch family
# 4. **Exercise 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Listening 05',
    'topics': ['Name and age', 'Job', 'Family'],
    'audio_sources': 'List what you listened to',
    'understood': '% you understood',
    'notes': 'Difficult words or parts'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Practice:
#
# ```
# I am A2 level. Help me practice personal information.
# Please:
# 1. Recommend easy listening materials
# 2. Give me practice with name and age
# 3. Ask me questions about what I heard
# 4. Use simple English
# ```
#
# ### Listening Resources:
#
# Good websites for A2:
# - Voice of America (Learning English)
# - BBC Learning English
# - Easy English YouTube
# - Slow English podcasts

# %% [markdown]
# ## Tasks
#
# 1. Find easy listening materials
# 2. Listen for name and age
# 3. Listen again and check understanding
# 4. Answer questions about the audio
# 5. Practice every day
#
# ## Summary
#
# You practiced: Name and age, Job, Family
#
# **Next Steps**: Listen to more English every day. Don't worry if you don't understand everything!
