# %% [markdown]
# # A2 Listening 02: Short Announcements
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand public announcements
# 2. Understand times
# 3. Understand places
# 4. Understand important information
# 5. Understand numbers

# %% [markdown]
# ## Short Announcements - A2 Listening
#
# Topics: Public announcements, Times, Places, Important information, Numbers
#
# ### Practice Focus
# Understand basic announcements

# %%
# Short Announcements
print('A2 Listening: Short Announcements')
print('Resources: slow English podcasts, easy videos, simple audio')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice listening to public announcements and times. The audio is slow and clear.
#
# ### Part 2: What to Listen For
#
# **Public announcements**: Listen carefully for this
# **Times**: Listen carefully for this
# **Places**: Listen carefully for this
#
# ### Part 3: Listening Exercises
#
# Practice listening:
#
# 1. **Exercise 1**: Listen for public announcements
# 2. **Exercise 2**: Focus on times
# 3. **Exercise 3**: Catch places
# 4. **Exercise 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Listening 02',
    'topics': ['Public announcements', 'Times', 'Places'],
    'audio_sources': 'List what you listened to',
    'understood': '% you understood',
    'notes': 'Difficult words or parts'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Practice:
#
# ```
# I am A2 level. Help me practice short announcements.
# Please:
# 1. Recommend easy listening materials
# 2. Give me practice with public announcements
# 3. Ask me questions about what I heard
# 4. Use simple English
# ```
#
# ### Listening Resources:
#
# Good websites for A2:
# - Voice of America (Learning English)
# - BBC Learning English
# - Easy English YouTube
# - Slow English podcasts

# %% [markdown]
# ## Tasks
#
# 1. Find easy listening materials
# 2. Listen for public announcements
# 3. Listen again and check understanding
# 4. Answer questions about the audio
# 5. Practice every day
#
# ## Summary
#
# You practiced: Public announcements, Times, Places
#
# **Next Steps**: Listen to more English every day. Don't worry if you don't understand everything!
