# %% [markdown]
# # A2 Listening 12: A2 Listening Assessment
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand listening test
# 2. Understand comprehension
# 3. Understand progress check
# 4. Understand details
# 5. Understand b1 readiness

# %% [markdown]
# ## A2 Listening Assessment - A2 Listening
#
# Topics: Listening test, Comprehension, Progress check, Details, B1 readiness
#
# ### Practice Focus
# Assess A2 listening proficiency

# %%
# A2 Listening Assessment
print('A2 Listening: A2 Listening Assessment')
print('Resources: slow English podcasts, easy videos, simple audio')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice listening to listening test and comprehension. The audio is slow and clear.
#
# ### Part 2: What to Listen For
#
# **Listening test**: Listen carefully for this
# **Comprehension**: Listen carefully for this
# **Progress check**: Listen carefully for this
#
# ### Part 3: Listening Exercises
#
# Practice listening:
#
# 1. **Exercise 1**: Listen for listening test
# 2. **Exercise 2**: Focus on comprehension
# 3. **Exercise 3**: Catch progress check
# 4. **Exercise 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Listening 12',
    'topics': ['Listening test', 'Comprehension', 'Progress check'],
    'audio_sources': 'List what you listened to',
    'understood': '% you understood',
    'notes': 'Difficult words or parts'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Practice:
#
# ```
# I am A2 level. Help me practice a2 listening assessment.
# Please:
# 1. Recommend easy listening materials
# 2. Give me practice with listening test
# 3. Ask me questions about what I heard
# 4. Use simple English
# ```
#
# ### Listening Resources:
#
# Good websites for A2:
# - Voice of America (Learning English)
# - BBC Learning English
# - Easy English YouTube
# - Slow English podcasts

# %% [markdown]
# ## Tasks
#
# 1. Find easy listening materials
# 2. Listen for listening test
# 3. Listen again and check understanding
# 4. Answer questions about the audio
# 5. Practice every day
#
# ## Summary
#
# You practiced: Listening test, Comprehension, Progress check
#
# **Next Steps**: Listen to more English every day. Don't worry if you don't understand everything!
