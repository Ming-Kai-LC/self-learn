# %% [markdown]
# # A2 Listening 08: Weather and Plans
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand weather forecast
# 2. Understand tomorrow
# 3. Understand plans
# 4. Understand going to
# 5. Understand predictions

# %% [markdown]
# ## Weather and Plans - A2 Listening
#
# Topics: Weather forecast, Tomorrow, Plans, Going to, Predictions
#
# ### Practice Focus
# Listen to weather and future plans

# %%
# Weather and Plans
print('A2 Listening: Weather and Plans')
print('Resources: slow English podcasts, easy videos, simple audio')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice listening to weather forecast and tomorrow. The audio is slow and clear.
#
# ### Part 2: What to Listen For
#
# **Weather forecast**: Listen carefully for this
# **Tomorrow**: Listen carefully for this
# **Plans**: Listen carefully for this
#
# ### Part 3: Listening Exercises
#
# Practice listening:
#
# 1. **Exercise 1**: Listen for weather forecast
# 2. **Exercise 2**: Focus on tomorrow
# 3. **Exercise 3**: Catch plans
# 4. **Exercise 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Listening 08',
    'topics': ['Weather forecast', 'Tomorrow', 'Plans'],
    'audio_sources': 'List what you listened to',
    'understood': '% you understood',
    'notes': 'Difficult words or parts'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Practice:
#
# ```
# I am A2 level. Help me practice weather and plans.
# Please:
# 1. Recommend easy listening materials
# 2. Give me practice with weather forecast
# 3. Ask me questions about what I heard
# 4. Use simple English
# ```
#
# ### Listening Resources:
#
# Good websites for A2:
# - Voice of America (Learning English)
# - BBC Learning English
# - Easy English YouTube
# - Slow English podcasts

# %% [markdown]
# ## Tasks
#
# 1. Find easy listening materials
# 2. Listen for weather forecast
# 3. Listen again and check understanding
# 4. Answer questions about the audio
# 5. Practice every day
#
# ## Summary
#
# You practiced: Weather forecast, Tomorrow, Plans
#
# **Next Steps**: Listen to more English every day. Don't worry if you don't understand everything!
