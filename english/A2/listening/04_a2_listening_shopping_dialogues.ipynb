# %% [markdown]
# # A2 Listening 04: Shopping Dialogues
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand at the shop
# 2. Understand prices
# 3. Understand asking questions
# 4. Understand what do you want
# 5. Understand payment

# %% [markdown]
# ## Shopping Dialogues - A2 Listening
#
# Topics: At the shop, Prices, Asking questions, What do you want, Payment
#
# ### Practice Focus
# Understand shopping conversations

# %%
# Shopping Dialogues
print('A2 Listening: Shopping Dialogues')
print('Resources: slow English podcasts, easy videos, simple audio')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice listening to at the shop and prices. The audio is slow and clear.
#
# ### Part 2: What to Listen For
#
# **At the shop**: Listen carefully for this
# **Prices**: Listen carefully for this
# **Asking questions**: Listen carefully for this
#
# ### Part 3: Listening Exercises
#
# Practice listening:
#
# 1. **Exercise 1**: Listen for at the shop
# 2. **Exercise 2**: Focus on prices
# 3. **Exercise 3**: Catch asking questions
# 4. **Exercise 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Listening 04',
    'topics': ['At the shop', 'Prices', 'Asking questions'],
    'audio_sources': 'List what you listened to',
    'understood': '% you understood',
    'notes': 'Difficult words or parts'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Practice:
#
# ```
# I am A2 level. Help me practice shopping dialogues.
# Please:
# 1. Recommend easy listening materials
# 2. Give me practice with at the shop
# 3. Ask me questions about what I heard
# 4. Use simple English
# ```
#
# ### Listening Resources:
#
# Good websites for A2:
# - Voice of America (Learning English)
# - BBC Learning English
# - Easy English YouTube
# - Slow English podcasts

# %% [markdown]
# ## Tasks
#
# 1. Find easy listening materials
# 2. Listen for at the shop
# 3. Listen again and check understanding
# 4. Answer questions about the audio
# 5. Practice every day
#
# ## Summary
#
# You practiced: At the shop, Prices, Asking questions
#
# **Next Steps**: Listen to more English every day. Don't worry if you don't understand everything!
