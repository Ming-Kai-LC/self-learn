# %% [markdown]
# # A2 Speaking 07: Simple Opinions
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Talk about i like
# 2. Talk about i don't like
# 3. Talk about i think
# 4. Talk about preferences
# 5. Talk about reasons

# %% [markdown]
# ## Simple Opinions - A2 Speaking
#
# Topics: I like, I don't like, I think, Preferences, Reasons
#
# ### Practice Focus
# Express simple opinions

# %%
# Simple Opinions
print('A2 Speaking: Simple Opinions')
print('Resources: Gliglish AI, ELSA Speak, language exchange, simple conversations')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice i like and i don't like. This helps you speak in everyday situations.
#
# ### Part 2: Key Phrases
#
# **I like**: Important for basic conversations
# **I don't like**: Important for basic conversations
# **I think**: Important for basic conversations
#
# ### Part 3: Practice Activities
#
# Try speaking about:
#
# 1. **Activity 1**: Practice i like
# 2. **Activity 2**: Talk about i don't like
# 3. **Activity 3**: Use i think in sentences
# 4. **Activity 4**: Have a simple conversation with AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Speaking 07',
    'topics': ['I like', "I don't like", 'I think'],
    'ai_tool': 'Gliglish AI or ELSA Speak',
    'minutes_practiced': 0,
    'notes': 'Write what you practiced'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Simple Opinions
# Level: A2 Elementary
# I want to practice:
# - I like
# - I don't like
# - I think
#
# Please speak slowly and use simple words.
# ```
#
# ### ChatGPT Voice (Simple):
#
# ```
# I am A2 level. Let's practice simple opinions.
# Ask me simple questions.
# Use easy English.
# Help me when I make mistakes.
# ```

# %% [markdown]
# ## Tasks
#
# 1. Listen to simple examples
# 2. Repeat the words and phrases
# 3. Practice i like with AI
# 4. Record yourself speaking
# 5. Practice every day for 10 minutes
#
# ## Summary
#
# You practiced: I like, I don't like, I think
#
# **Next Steps**: Keep practicing! Speak more English every day.
