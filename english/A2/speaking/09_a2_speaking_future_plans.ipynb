# %% [markdown]
# # A2 Speaking 09: Future Plans
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Talk about going to
# 2. Talk about will
# 3. Talk about tomorrow
# 4. Talk about next week
# 5. Talk about plans

# %% [markdown]
# ## Future Plans - A2 Speaking
#
# Topics: Going to, Will, Tomorrow, Next week, Plans
#
# ### Practice Focus
# Discuss future plans

# %%
# Future Plans
print('A2 Speaking: Future Plans')
print('Resources: Gliglish AI, ELSA Speak, language exchange, simple conversations')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice going to and will. This helps you speak in everyday situations.
#
# ### Part 2: Key Phrases
#
# **Going to**: Important for basic conversations
# **Will**: Important for basic conversations
# **Tomorrow**: Important for basic conversations
#
# ### Part 3: Practice Activities
#
# Try speaking about:
#
# 1. **Activity 1**: Practice going to
# 2. **Activity 2**: Talk about will
# 3. **Activity 3**: Use tomorrow in sentences
# 4. **Activity 4**: Have a simple conversation with AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Speaking 09',
    'topics': ['Going to', 'Will', 'Tomorrow'],
    'ai_tool': 'Gliglish AI or ELSA Speak',
    'minutes_practiced': 0,
    'notes': 'Write what you practiced'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Future Plans
# Level: A2 Elementary
# I want to practice:
# - Going to
# - Will
# - Tomorrow
#
# Please speak slowly and use simple words.
# ```
#
# ### ChatGPT Voice (Simple):
#
# ```
# I am A2 level. Let's practice future plans.
# Ask me simple questions.
# Use easy English.
# Help me when I make mistakes.
# ```

# %% [markdown]
# ## Tasks
#
# 1. Listen to simple examples
# 2. Repeat the words and phrases
# 3. Practice going to with AI
# 4. Record yourself speaking
# 5. Practice every day for 10 minutes
#
# ## Summary
#
# You practiced: Going to, Will, Tomorrow
#
# **Next Steps**: Keep practicing! Speak more English every day.
