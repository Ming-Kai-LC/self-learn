# %% [markdown]
# # A2 Speaking 12: A2 Speaking Assessment
#
# **Difficulty**: ⭐
# **Time**: 30-40 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Talk about speaking test
# 2. Talk about conversation
# 3. Talk about progress check
# 4. Talk about fluency
# 5. Talk about b1 readiness

# %% [markdown]
# ## A2 Speaking Assessment - A2 Speaking
#
# Topics: Speaking test, Conversation, Progress check, Fluency, B1 readiness
#
# ### Practice Focus
# Assess A2 speaking proficiency

# %%
# A2 Speaking Assessment
print('A2 Speaking: A2 Speaking Assessment')
print('Resources: Gliglish AI, ELSA Speak, language exchange, simple conversations')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice speaking test and conversation. This helps you speak in everyday situations.
#
# ### Part 2: Key Phrases
#
# **Speaking test**: Important for basic conversations
# **Conversation**: Important for basic conversations
# **Progress check**: Important for basic conversations
#
# ### Part 3: Practice Activities
#
# Try speaking about:
#
# 1. **Activity 1**: Practice speaking test
# 2. **Activity 2**: Talk about conversation
# 3. **Activity 3**: Use progress check in sentences
# 4. **Activity 4**: Have a simple conversation with AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Speaking 12',
    'topics': ['Speaking test', 'Conversation', 'Progress check'],
    'ai_tool': 'Gliglish AI or ELSA Speak',
    'minutes_practiced': 0,
    'notes': 'Write what you practiced'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: A2 Speaking Assessment
# Level: A2 Elementary
# I want to practice:
# - Speaking test
# - Conversation
# - Progress check
#
# Please speak slowly and use simple words.
# ```
#
# ### ChatGPT Voice (Simple):
#
# ```
# I am A2 level. Let's practice a2 speaking assessment.
# Ask me simple questions.
# Use easy English.
# Help me when I make mistakes.
# ```

# %% [markdown]
# ## Tasks
#
# 1. Listen to simple examples
# 2. Repeat the words and phrases
# 3. Practice speaking test with AI
# 4. Record yourself speaking
# 5. Practice every day for 10 minutes
#
# ## Summary
#
# You practiced: Speaking test, Conversation, Progress check
#
# **Next Steps**: Keep practicing! Speak more English every day.
