# %% [markdown]
# # A2 Speaking 03: Talking About Daily Life
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Talk about daily routine
# 2. Talk about work
# 3. Talk about school
# 4. Talk about free time
# 5. Talk about weekends

# %% [markdown]
# ## Talking About Daily Life - A2 Speaking
#
# Topics: Daily routine, Work, School, Free time, Weekends
#
# ### Practice Focus
# Describe your daily activities

# %%
# Talking About Daily Life
print('A2 Speaking: Talking About Daily Life')
print('Resources: Gliglish AI, ELSA Speak, language exchange, simple conversations')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice daily routine and work. This helps you speak in everyday situations.
#
# ### Part 2: Key Phrases
#
# **Daily routine**: Important for basic conversations
# **Work**: Important for basic conversations
# **School**: Important for basic conversations
#
# ### Part 3: Practice Activities
#
# Try speaking about:
#
# 1. **Activity 1**: Practice daily routine
# 2. **Activity 2**: Talk about work
# 3. **Activity 3**: Use school in sentences
# 4. **Activity 4**: Have a simple conversation with AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Speaking 03',
    'topics': ['Daily routine', 'Work', 'School'],
    'ai_tool': 'Gliglish AI or ELSA Speak',
    'minutes_practiced': 0,
    'notes': 'Write what you practiced'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Talking About Daily Life
# Level: A2 Elementary
# I want to practice:
# - Daily routine
# - Work
# - School
#
# Please speak slowly and use simple words.
# ```
#
# ### ChatGPT Voice (Simple):
#
# ```
# I am A2 level. Let's practice talking about daily life.
# Ask me simple questions.
# Use easy English.
# Help me when I make mistakes.
# ```

# %% [markdown]
# ## Tasks
#
# 1. Listen to simple examples
# 2. Repeat the words and phrases
# 3. Practice daily routine with AI
# 4. Record yourself speaking
# 5. Practice every day for 10 minutes
#
# ## Summary
#
# You practiced: Daily routine, Work, School
#
# **Next Steps**: Keep practicing! Speak more English every day.
