# %% [markdown]
# # A2 Speaking 06: Family and Friends
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Talk about family members
# 2. Talk about relationships
# 3. Talk about descriptions
# 4. Talk about ages
# 5. Talk about occupations

# %% [markdown]
# ## Family and Friends - A2 Speaking
#
# Topics: Family members, Relationships, Descriptions, Ages, Occupations
#
# ### Practice Focus
# Talk about family and friends

# %%
# Family and Friends
print('A2 Speaking: Family and Friends')
print('Resources: Gliglish AI, ELSA Speak, language exchange, simple conversations')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice family members and relationships. This helps you speak in everyday situations.
#
# ### Part 2: Key Phrases
#
# **Family members**: Important for basic conversations
# **Relationships**: Important for basic conversations
# **Descriptions**: Important for basic conversations
#
# ### Part 3: Practice Activities
#
# Try speaking about:
#
# 1. **Activity 1**: Practice family members
# 2. **Activity 2**: Talk about relationships
# 3. **Activity 3**: Use descriptions in sentences
# 4. **Activity 4**: Have a simple conversation with AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Speaking 06',
    'topics': ['Family members', 'Relationships', 'Descriptions'],
    'ai_tool': 'Gliglish AI or ELSA Speak',
    'minutes_practiced': 0,
    'notes': 'Write what you practiced'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Family and Friends
# Level: A2 Elementary
# I want to practice:
# - Family members
# - Relationships
# - Descriptions
#
# Please speak slowly and use simple words.
# ```
#
# ### ChatGPT Voice (Simple):
#
# ```
# I am A2 level. Let's practice family and friends.
# Ask me simple questions.
# Use easy English.
# Help me when I make mistakes.
# ```

# %% [markdown]
# ## Tasks
#
# 1. Listen to simple examples
# 2. Repeat the words and phrases
# 3. Practice family members with AI
# 4. Record yourself speaking
# 5. Practice every day for 10 minutes
#
# ## Summary
#
# You practiced: Family members, Relationships, Descriptions
#
# **Next Steps**: Keep practicing! Speak more English every day.
