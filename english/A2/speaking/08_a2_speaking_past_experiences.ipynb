# %% [markdown]
# # A2 Speaking 08: Past Experiences
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Talk about past simple
# 2. Talk about yesterday
# 3. Talk about last week
# 4. Talk about experiences
# 5. Talk about stories

# %% [markdown]
# ## Past Experiences - A2 Speaking
#
# Topics: Past simple, Yesterday, Last week, Experiences, Stories
#
# ### Practice Focus
# Talk about past events

# %%
# Past Experiences
print('A2 Speaking: Past Experiences')
print('Resources: Gliglish AI, ELSA Speak, language exchange, simple conversations')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice past simple and yesterday. This helps you speak in everyday situations.
#
# ### Part 2: Key Phrases
#
# **Past simple**: Important for basic conversations
# **Yesterday**: Important for basic conversations
# **Last week**: Important for basic conversations
#
# ### Part 3: Practice Activities
#
# Try speaking about:
#
# 1. **Activity 1**: Practice past simple
# 2. **Activity 2**: Talk about yesterday
# 3. **Activity 3**: Use last week in sentences
# 4. **Activity 4**: Have a simple conversation with AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Speaking 08',
    'topics': ['Past simple', 'Yesterday', 'Last week'],
    'ai_tool': 'Gliglish AI or ELSA Speak',
    'minutes_practiced': 0,
    'notes': 'Write what you practiced'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Past Experiences
# Level: A2 Elementary
# I want to practice:
# - Past simple
# - Yesterday
# - Last week
#
# Please speak slowly and use simple words.
# ```
#
# ### ChatGPT Voice (Simple):
#
# ```
# I am A2 level. Let's practice past experiences.
# Ask me simple questions.
# Use easy English.
# Help me when I make mistakes.
# ```

# %% [markdown]
# ## Tasks
#
# 1. Listen to simple examples
# 2. Repeat the words and phrases
# 3. Practice past simple with AI
# 4. Record yourself speaking
# 5. Practice every day for 10 minutes
#
# ## Summary
#
# You practiced: Past simple, Yesterday, Last week
#
# **Next Steps**: Keep practicing! Speak more English every day.
