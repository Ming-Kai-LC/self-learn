# %% [markdown]
# # A2 Speaking 01: Basic Introductions
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Talk about name
# 2. Talk about age
# 3. Talk about country
# 4. Talk about job
# 5. Talk about hobbies

# %% [markdown]
# ## Basic Introductions - A2 Speaking
#
# Topics: Name, Age, Country, Job, Hobbies
#
# ### Practice Focus
# Introduce yourself simply

# %%
# Basic Introductions
print('A2 Speaking: Basic Introductions')
print('Resources: Gliglish AI, ELSA Speak, language exchange, simple conversations')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice name and age. This helps you speak in everyday situations.
#
# ### Part 2: Key Phrases
#
# **Name**: Important for basic conversations
# **Age**: Important for basic conversations
# **Country**: Important for basic conversations
#
# ### Part 3: Practice Activities
#
# Try speaking about:
#
# 1. **Activity 1**: Practice name
# 2. **Activity 2**: Talk about age
# 3. **Activity 3**: Use country in sentences
# 4. **Activity 4**: Have a simple conversation with AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Speaking 01',
    'topics': ['Name', 'Age', 'Country'],
    'ai_tool': 'Gliglish AI or ELSA Speak',
    'minutes_practiced': 0,
    'notes': 'Write what you practiced'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Basic Introductions
# Level: A2 Elementary
# I want to practice:
# - Name
# - Age
# - Country
#
# Please speak slowly and use simple words.
# ```
#
# ### ChatGPT Voice (Simple):
#
# ```
# I am A2 level. Let's practice basic introductions.
# Ask me simple questions.
# Use easy English.
# Help me when I make mistakes.
# ```

# %% [markdown]
# ## Tasks
#
# 1. Listen to simple examples
# 2. Repeat the words and phrases
# 3. Practice name with AI
# 4. Record yourself speaking
# 5. Practice every day for 10 minutes
#
# ## Summary
#
# You practiced: Name, Age, Country
#
# **Next Steps**: Keep practicing! Speak more English every day.
