# %% [markdown]
# # A2 Speaking 11: Telephone Conversations
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Talk about answering phone
# 2. Talk about taking messages
# 3. Talk about simple phone calls
# 4. Talk about polite language
# 5. Talk about numbers

# %% [markdown]
# ## Telephone Conversations - A2 Speaking
#
# Topics: Answering phone, Taking messages, Simple phone calls, Polite language, Numbers
#
# ### Practice Focus
# Handle simple phone calls

# %%
# Telephone Conversations
print('A2 Speaking: Telephone Conversations')
print('Resources: Gliglish AI, ELSA Speak, language exchange, simple conversations')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice answering phone and taking messages. This helps you speak in everyday situations.
#
# ### Part 2: Key Phrases
#
# **Answering phone**: Important for basic conversations
# **Taking messages**: Important for basic conversations
# **Simple phone calls**: Important for basic conversations
#
# ### Part 3: Practice Activities
#
# Try speaking about:
#
# 1. **Activity 1**: Practice answering phone
# 2. **Activity 2**: Talk about taking messages
# 3. **Activity 3**: Use simple phone calls in sentences
# 4. **Activity 4**: Have a simple conversation with AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Speaking 11',
    'topics': ['Answering phone', 'Taking messages', 'Simple phone calls'],
    'ai_tool': 'Gliglish AI or ELSA Speak',
    'minutes_practiced': 0,
    'notes': 'Write what you practiced'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Telephone Conversations
# Level: A2 Elementary
# I want to practice:
# - Answering phone
# - Taking messages
# - Simple phone calls
#
# Please speak slowly and use simple words.
# ```
#
# ### ChatGPT Voice (Simple):
#
# ```
# I am A2 level. Let's practice telephone conversations.
# Ask me simple questions.
# Use easy English.
# Help me when I make mistakes.
# ```

# %% [markdown]
# ## Tasks
#
# 1. Listen to simple examples
# 2. Repeat the words and phrases
# 3. Practice answering phone with AI
# 4. Record yourself speaking
# 5. Practice every day for 10 minutes
#
# ## Summary
#
# You practiced: Answering phone, Taking messages, Simple phone calls
#
# **Next Steps**: Keep practicing! Speak more English every day.
