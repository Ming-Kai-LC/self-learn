# %% [markdown]
# # A2 Speaking 04: Shopping and Ordering
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Talk about at the shop
# 2. Talk about prices
# 3. Talk about ordering food
# 4. Talk about asking questions
# 5. Talk about polite requests

# %% [markdown]
# ## Shopping and Ordering - A2 Speaking
#
# Topics: At the shop, Prices, Ordering food, Asking questions, Polite requests
#
# ### Practice Focus
# Shop and order in English

# %%
# Shopping and Ordering
print('A2 Speaking: Shopping and Ordering')
print('Resources: Gliglish AI, ELSA Speak, language exchange, simple conversations')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will practice at the shop and prices. This helps you speak in everyday situations.
#
# ### Part 2: Key Phrases
#
# **At the shop**: Important for basic conversations
# **Prices**: Important for basic conversations
# **Ordering food**: Important for basic conversations
#
# ### Part 3: Practice Activities
#
# Try speaking about:
#
# 1. **Activity 1**: Practice at the shop
# 2. **Activity 2**: Talk about prices
# 3. **Activity 3**: Use ordering food in sentences
# 4. **Activity 4**: Have a simple conversation with AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Speaking 04',
    'topics': ['At the shop', 'Prices', 'Ordering food'],
    'ai_tool': 'Gliglish AI or ELSA Speak',
    'minutes_practiced': 0,
    'notes': 'Write what you practiced'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Shopping and Ordering
# Level: A2 Elementary
# I want to practice:
# - At the shop
# - Prices
# - Ordering food
#
# Please speak slowly and use simple words.
# ```
#
# ### ChatGPT Voice (Simple):
#
# ```
# I am A2 level. Let's practice shopping and ordering.
# Ask me simple questions.
# Use easy English.
# Help me when I make mistakes.
# ```

# %% [markdown]
# ## Tasks
#
# 1. Listen to simple examples
# 2. Repeat the words and phrases
# 3. Practice at the shop with AI
# 4. Record yourself speaking
# 5. Practice every day for 10 minutes
#
# ## Summary
#
# You practiced: At the shop, Prices, Ordering food
#
# **Next Steps**: Keep practicing! Speak more English every day.
