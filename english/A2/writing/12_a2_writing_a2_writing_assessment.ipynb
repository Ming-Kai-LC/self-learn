# %% [markdown]
# # A2 Writing 12: A2 Writing Assessment
#
# **Difficulty**: ⭐
# **Time**: 40-45 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand writing test
# 2. Understand personal letter
# 3. Understand progress check
# 4. Understand error correction
# 5. Understand b1 readiness

# %% [markdown]
# ## A2 Writing Assessment - A2 Writing
#
# Topics: Writing test, Personal letter, Progress check, Error correction, B1 readiness
#
# ### Practice Focus
# Assess A2 writing proficiency

# %%
# A2 Writing Assessment
print('A2 Writing: A2 Writing Assessment')
print('Resources: simple worksheets, guided templates, basic examples')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will learn writing test and personal letter. This is important for everyday writing.
#
# ### Part 2: Key Concepts
#
# **Writing test**: Simple and useful for A2 learners
# **Personal letter**: Simple and useful for A2 learners
# **Progress check**: Simple and useful for A2 learners
#
# ### Part 3: Practice Exercises
#
# Try these simple exercises:
#
# 1. **Task 1**: Practice writing test
# 2. **Task 2**: Use personal letter in your writing
# 3. **Task 3**: Write about progress check
# 4. **Task 4**: Get feedback from AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Writing 12',
    'topics': ['Writing test', 'Personal letter', 'Progress check'],
    'exercises_completed': 0,
    'notes': 'Write your notes here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt (Simple):
#
# ```
# I am learning A2 English. Please help me practice a2 writing assessment.
# Check my writing for:
# 1. Writing test
# 2. Personal letter
# 3. Basic grammar mistakes
# 4. Simple vocabulary
#
# Please use easy English to give me feedback.
# [Write your text here]
# ```
#
# ### Practice with AI:
#
# Ask ChatGPT or Claude:
# - Give me 3 simple examples
# - Check my writing for mistakes
# - Help me write a better sentence

# %% [markdown]
# ## Tasks
#
# 1. Read the simple examples
# 2. Practice writing test
# 3. Write 3-5 simple sentences
# 4. Ask AI to check your writing
# 5. Fix your mistakes and try again
#
# ## Summary
#
# You learned: Writing test, Personal letter, Progress check
#
# **Next Steps**: Practice more and move to the next module!
