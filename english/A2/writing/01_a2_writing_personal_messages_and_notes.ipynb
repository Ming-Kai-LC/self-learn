# %% [markdown]
# # A2 Writing 01: Personal Messages and Notes
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand simple messages
# 2. Understand personal notes
# 3. Understand basic greetings
# 4. Understand thanks
# 5. Understand invitations

# %% [markdown]
# ## Personal Messages and Notes - A2 Writing
#
# Topics: Simple messages, Personal notes, Basic greetings, Thanks, Invitations
#
# ### Practice Focus
# Write simple personal messages

# %%
# Personal Messages and Notes
print('A2 Writing: Personal Messages and Notes')
print('Resources: simple worksheets, guided templates, basic examples')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will learn simple messages and personal notes. This is important for everyday writing.
#
# ### Part 2: Key Concepts
#
# **Simple messages**: Simple and useful for A2 learners
# **Personal notes**: Simple and useful for A2 learners
# **Basic greetings**: Simple and useful for A2 learners
#
# ### Part 3: Practice Exercises
#
# Try these simple exercises:
#
# 1. **Task 1**: Practice simple messages
# 2. **Task 2**: Use personal notes in your writing
# 3. **Task 3**: Write about basic greetings
# 4. **Task 4**: Get feedback from AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Writing 01',
    'topics': ['Simple messages', 'Personal notes', 'Basic greetings'],
    'exercises_completed': 0,
    'notes': 'Write your notes here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt (Simple):
#
# ```
# I am learning A2 English. Please help me practice personal messages and notes.
# Check my writing for:
# 1. Simple messages
# 2. Personal notes
# 3. Basic grammar mistakes
# 4. Simple vocabulary
#
# Please use easy English to give me feedback.
# [Write your text here]
# ```
#
# ### Practice with AI:
#
# Ask ChatGPT or Claude:
# - Give me 3 simple examples
# - Check my writing for mistakes
# - Help me write a better sentence

# %% [markdown]
# ## Tasks
#
# 1. Read the simple examples
# 2. Practice simple messages
# 3. Write 3-5 simple sentences
# 4. Ask AI to check your writing
# 5. Fix your mistakes and try again
#
# ## Summary
#
# You learned: Simple messages, Personal notes, Basic greetings
#
# **Next Steps**: Practice more and move to the next module!
