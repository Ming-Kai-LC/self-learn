# %% [markdown]
# # A2 Writing 03: Simple Descriptions
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand describing people
# 2. Understand describing places
# 3. Understand adjectives
# 4. Understand basic sentences
# 5. Understand details

# %% [markdown]
# ## Simple Descriptions - A2 Writing
#
# Topics: Describing people, Describing places, Adjectives, Basic sentences, Details
#
# ### Practice Focus
# Describe people and places simply

# %%
# Simple Descriptions
print('A2 Writing: Simple Descriptions')
print('Resources: simple worksheets, guided templates, basic examples')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will learn describing people and describing places. This is important for everyday writing.
#
# ### Part 2: Key Concepts
#
# **Describing people**: Simple and useful for A2 learners
# **Describing places**: Simple and useful for A2 learners
# **Adjectives**: Simple and useful for A2 learners
#
# ### Part 3: Practice Exercises
#
# Try these simple exercises:
#
# 1. **Task 1**: Practice describing people
# 2. **Task 2**: Use describing places in your writing
# 3. **Task 3**: Write about adjectives
# 4. **Task 4**: Get feedback from AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Writing 03',
    'topics': ['Describing people', 'Describing places', 'Adjectives'],
    'exercises_completed': 0,
    'notes': 'Write your notes here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt (Simple):
#
# ```
# I am learning A2 English. Please help me practice simple descriptions.
# Check my writing for:
# 1. Describing people
# 2. Describing places
# 3. Basic grammar mistakes
# 4. Simple vocabulary
#
# Please use easy English to give me feedback.
# [Write your text here]
# ```
#
# ### Practice with AI:
#
# Ask ChatGPT or Claude:
# - Give me 3 simple examples
# - Check my writing for mistakes
# - Help me write a better sentence

# %% [markdown]
# ## Tasks
#
# 1. Read the simple examples
# 2. Practice describing people
# 3. Write 3-5 simple sentences
# 4. Ask AI to check your writing
# 5. Fix your mistakes and try again
#
# ## Summary
#
# You learned: Describing people, Describing places, Adjectives
#
# **Next Steps**: Practice more and move to the next module!
