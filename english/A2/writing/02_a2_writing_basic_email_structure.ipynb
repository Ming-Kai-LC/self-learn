# %% [markdown]
# # A2 Writing 02: Basic Email Structure
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand email greetings
# 2. Understand subject lines
# 3. Understand simple requests
# 4. Understand closing phrases
# 5. Understand email format

# %% [markdown]
# ## Basic Email Structure - A2 Writing
#
# Topics: Email greetings, Subject lines, Simple requests, Closing phrases, Email format
#
# ### Practice Focus
# Compose basic emails correctly

# %%
# Basic Email Structure
print('A2 Writing: Basic Email Structure')
print('Resources: simple worksheets, guided templates, basic examples')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will learn email greetings and subject lines. This is important for everyday writing.
#
# ### Part 2: Key Concepts
#
# **Email greetings**: Simple and useful for A2 learners
# **Subject lines**: Simple and useful for A2 learners
# **Simple requests**: Simple and useful for A2 learners
#
# ### Part 3: Practice Exercises
#
# Try these simple exercises:
#
# 1. **Task 1**: Practice email greetings
# 2. **Task 2**: Use subject lines in your writing
# 3. **Task 3**: Write about simple requests
# 4. **Task 4**: Get feedback from AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Writing 02',
    'topics': ['Email greetings', 'Subject lines', 'Simple requests'],
    'exercises_completed': 0,
    'notes': 'Write your notes here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt (Simple):
#
# ```
# I am learning A2 English. Please help me practice basic email structure.
# Check my writing for:
# 1. Email greetings
# 2. Subject lines
# 3. Basic grammar mistakes
# 4. Simple vocabulary
#
# Please use easy English to give me feedback.
# [Write your text here]
# ```
#
# ### Practice with AI:
#
# Ask ChatGPT or Claude:
# - Give me 3 simple examples
# - Check my writing for mistakes
# - Help me write a better sentence

# %% [markdown]
# ## Tasks
#
# 1. Read the simple examples
# 2. Practice email greetings
# 3. Write 3-5 simple sentences
# 4. Ask AI to check your writing
# 5. Fix your mistakes and try again
#
# ## Summary
#
# You learned: Email greetings, Subject lines, Simple requests
#
# **Next Steps**: Practice more and move to the next module!
