# %% [markdown]
# # A2 Writing 10: Short Social Media Posts
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand social media
# 2. Understand casual writing
# 3. Understand updates
# 4. Understand comments
# 5. Understand informal language

# %% [markdown]
# ## Short Social Media Posts - A2 Writing
#
# Topics: Social media, Casual writing, Updates, Comments, Informal language
#
# ### Practice Focus
# Write simple social media content

# %%
# Short Social Media Posts
print('A2 Writing: Short Social Media Posts')
print('Resources: simple worksheets, guided templates, basic examples')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will learn social media and casual writing. This is important for everyday writing.
#
# ### Part 2: Key Concepts
#
# **Social media**: Simple and useful for A2 learners
# **Casual writing**: Simple and useful for A2 learners
# **Updates**: Simple and useful for A2 learners
#
# ### Part 3: Practice Exercises
#
# Try these simple exercises:
#
# 1. **Task 1**: Practice social media
# 2. **Task 2**: Use casual writing in your writing
# 3. **Task 3**: Write about updates
# 4. **Task 4**: Get feedback from AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Writing 10',
    'topics': ['Social media', 'Casual writing', 'Updates'],
    'exercises_completed': 0,
    'notes': 'Write your notes here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt (Simple):
#
# ```
# I am learning A2 English. Please help me practice short social media posts.
# Check my writing for:
# 1. Social media
# 2. Casual writing
# 3. Basic grammar mistakes
# 4. Simple vocabulary
#
# Please use easy English to give me feedback.
# [Write your text here]
# ```
#
# ### Practice with AI:
#
# Ask ChatGPT or Claude:
# - Give me 3 simple examples
# - Check my writing for mistakes
# - Help me write a better sentence

# %% [markdown]
# ## Tasks
#
# 1. Read the simple examples
# 2. Practice social media
# 3. Write 3-5 simple sentences
# 4. Ask AI to check your writing
# 5. Fix your mistakes and try again
#
# ## Summary
#
# You learned: Social media, Casual writing, Updates
#
# **Next Steps**: Practice more and move to the next module!
