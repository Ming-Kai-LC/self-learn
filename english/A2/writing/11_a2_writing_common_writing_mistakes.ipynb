# %% [markdown]
# # A2 Writing 11: Common Writing Mistakes
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand articles (a/an/the)
# 2. Understand plural forms
# 3. Understand subject-verb agreement
# 4. Understand capitalization
# 5. Understand punctuation

# %% [markdown]
# ## Common Writing Mistakes - A2 Writing
#
# Topics: Articles (a/an/the), Plural forms, Subject-verb agreement, Capitalization, Punctuation
#
# ### Practice Focus
# Identify and fix common errors

# %%
# Common Writing Mistakes
print('A2 Writing: Common Writing Mistakes')
print('Resources: simple worksheets, guided templates, basic examples')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will learn articles (a/an/the) and plural forms. This is important for everyday writing.
#
# ### Part 2: Key Concepts
#
# **Articles (a/an/the)**: Simple and useful for A2 learners
# **Plural forms**: Simple and useful for A2 learners
# **Subject-verb agreement**: Simple and useful for A2 learners
#
# ### Part 3: Practice Exercises
#
# Try these simple exercises:
#
# 1. **Task 1**: Practice articles (a/an/the)
# 2. **Task 2**: Use plural forms in your writing
# 3. **Task 3**: Write about subject-verb agreement
# 4. **Task 4**: Get feedback from AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Writing 11',
    'topics': ['Articles (a/an/the)', 'Plural forms', 'Subject-verb agreement'],
    'exercises_completed': 0,
    'notes': 'Write your notes here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt (Simple):
#
# ```
# I am learning A2 English. Please help me practice common writing mistakes.
# Check my writing for:
# 1. Articles (a/an/the)
# 2. Plural forms
# 3. Basic grammar mistakes
# 4. Simple vocabulary
#
# Please use easy English to give me feedback.
# [Write your text here]
# ```
#
# ### Practice with AI:
#
# Ask ChatGPT or Claude:
# - Give me 3 simple examples
# - Check my writing for mistakes
# - Help me write a better sentence

# %% [markdown]
# ## Tasks
#
# 1. Read the simple examples
# 2. Practice articles (a/an/the)
# 3. Write 3-5 simple sentences
# 4. Ask AI to check your writing
# 5. Fix your mistakes and try again
#
# ## Summary
#
# You learned: Articles (a/an/the), Plural forms, Subject-verb agreement
#
# **Next Steps**: Practice more and move to the next module!
