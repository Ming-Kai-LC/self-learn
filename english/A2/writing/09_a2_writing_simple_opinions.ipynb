# %% [markdown]
# # A2 Writing 09: Simple Opinions
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand i think
# 2. Understand i like
# 3. Understand reasons
# 4. Understand because
# 5. Understand simple arguments

# %% [markdown]
# ## Simple Opinions - A2 Writing
#
# Topics: I think, I like, Reasons, Because, Simple arguments
#
# ### Practice Focus
# Express basic opinions with reasons

# %%
# Simple Opinions
print('A2 Writing: Simple Opinions')
print('Resources: simple worksheets, guided templates, basic examples')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will learn i think and i like. This is important for everyday writing.
#
# ### Part 2: Key Concepts
#
# **I think**: Simple and useful for A2 learners
# **I like**: Simple and useful for A2 learners
# **Reasons**: Simple and useful for A2 learners
#
# ### Part 3: Practice Exercises
#
# Try these simple exercises:
#
# 1. **Task 1**: Practice i think
# 2. **Task 2**: Use i like in your writing
# 3. **Task 3**: Write about reasons
# 4. **Task 4**: Get feedback from AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Writing 09',
    'topics': ['I think', 'I like', 'Reasons'],
    'exercises_completed': 0,
    'notes': 'Write your notes here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt (Simple):
#
# ```
# I am learning A2 English. Please help me practice simple opinions.
# Check my writing for:
# 1. I think
# 2. I like
# 3. Basic grammar mistakes
# 4. Simple vocabulary
#
# Please use easy English to give me feedback.
# [Write your text here]
# ```
#
# ### Practice with AI:
#
# Ask ChatGPT or Claude:
# - Give me 3 simple examples
# - Check my writing for mistakes
# - Help me write a better sentence

# %% [markdown]
# ## Tasks
#
# 1. Read the simple examples
# 2. Practice i think
# 3. Write 3-5 simple sentences
# 4. Ask AI to check your writing
# 5. Fix your mistakes and try again
#
# ## Summary
#
# You learned: I think, I like, Reasons
#
# **Next Steps**: Practice more and move to the next module!
