# %% [markdown]
# # A2 Writing 06: Short Paragraphs
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand topic sentences
# 2. Understand supporting details
# 3. Understand linking words
# 4. Understand paragraph unity
# 5. Understand basic structure

# %% [markdown]
# ## Short Paragraphs - A2 Writing
#
# Topics: Topic sentences, Supporting details, Linking words, Paragraph unity, Basic structure
#
# ### Practice Focus
# Write organized short paragraphs

# %%
# Short Paragraphs
print('A2 Writing: Short Paragraphs')
print('Resources: simple worksheets, guided templates, basic examples')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will learn topic sentences and supporting details. This is important for everyday writing.
#
# ### Part 2: Key Concepts
#
# **Topic sentences**: Simple and useful for A2 learners
# **Supporting details**: Simple and useful for A2 learners
# **Linking words**: Simple and useful for A2 learners
#
# ### Part 3: Practice Exercises
#
# Try these simple exercises:
#
# 1. **Task 1**: Practice topic sentences
# 2. **Task 2**: Use supporting details in your writing
# 3. **Task 3**: Write about linking words
# 4. **Task 4**: Get feedback from AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Writing 06',
    'topics': ['Topic sentences', 'Supporting details', 'Linking words'],
    'exercises_completed': 0,
    'notes': 'Write your notes here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt (Simple):
#
# ```
# I am learning A2 English. Please help me practice short paragraphs.
# Check my writing for:
# 1. Topic sentences
# 2. Supporting details
# 3. Basic grammar mistakes
# 4. Simple vocabulary
#
# Please use easy English to give me feedback.
# [Write your text here]
# ```
#
# ### Practice with AI:
#
# Ask ChatGPT or Claude:
# - Give me 3 simple examples
# - Check my writing for mistakes
# - Help me write a better sentence

# %% [markdown]
# ## Tasks
#
# 1. Read the simple examples
# 2. Practice topic sentences
# 3. Write 3-5 simple sentences
# 4. Ask AI to check your writing
# 5. Fix your mistakes and try again
#
# ## Summary
#
# You learned: Topic sentences, Supporting details, Linking words
#
# **Next Steps**: Practice more and move to the next module!
