# %% [markdown]
# # A2 Writing 04: Daily Routine Writing
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Understand present simple
# 2. Understand time expressions
# 3. Understand daily activities
# 4. Understand sequence words
# 5. Understand routines

# %% [markdown]
# ## Daily Routine Writing - A2 Writing
#
# Topics: Present simple, Time expressions, Daily activities, Sequence words, Routines
#
# ### Practice Focus
# Write about daily activities

# %%
# Daily Routine Writing
print('A2 Writing: Daily Routine Writing')
print('Resources: simple worksheets, guided templates, basic examples')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will learn present simple and time expressions. This is important for everyday writing.
#
# ### Part 2: Key Concepts
#
# **Present simple**: Simple and useful for A2 learners
# **Time expressions**: Simple and useful for A2 learners
# **Daily activities**: Simple and useful for A2 learners
#
# ### Part 3: Practice Exercises
#
# Try these simple exercises:
#
# 1. **Task 1**: Practice present simple
# 2. **Task 2**: Use time expressions in your writing
# 3. **Task 3**: Write about daily activities
# 4. **Task 4**: Get feedback from AI

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Writing 04',
    'topics': ['Present simple', 'Time expressions', 'Daily activities'],
    'exercises_completed': 0,
    'notes': 'Write your notes here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt (Simple):
#
# ```
# I am learning A2 English. Please help me practice daily routine writing.
# Check my writing for:
# 1. Present simple
# 2. Time expressions
# 3. Basic grammar mistakes
# 4. Simple vocabulary
#
# Please use easy English to give me feedback.
# [Write your text here]
# ```
#
# ### Practice with AI:
#
# Ask ChatGPT or Claude:
# - Give me 3 simple examples
# - Check my writing for mistakes
# - Help me write a better sentence

# %% [markdown]
# ## Tasks
#
# 1. Read the simple examples
# 2. Practice present simple
# 3. Write 3-5 simple sentences
# 4. Ask AI to check your writing
# 5. Fix your mistakes and try again
#
# ## Summary
#
# You learned: Present simple, Time expressions, Daily activities
#
# **Next Steps**: Practice more and move to the next module!
