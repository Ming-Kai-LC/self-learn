# %% [markdown]
# # A2 Reading 01: Simple Signs and Notices
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Read and understand public signs
# 2. Read and understand warnings
# 3. Read and understand information
# 4. Read and understand simple messages
# 5. Read and understand key words

# %% [markdown]
# ## Simple Signs and Notices - A2 Reading
#
# Topics: Public signs, Warnings, Information, Simple messages, Key words
#
# ### Practice Focus
# Read and understand everyday signs

# %%
# Simple Signs and Notices
print('A2 Reading: Simple Signs and Notices')
print('Resources: simple texts, graded readers, easy websites')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will read public signs and warnings. The texts are short and simple.
#
# ### Part 2: Reading Tips
#
# **Public signs**: Look for this when reading
# **Warnings**: Look for this when reading
# **Information**: Look for this when reading
#
# ### Part 3: Reading Practice
#
# Read the examples and:
#
# 1. **Task 1**: Find public signs
# 2. **Task 2**: Understand warnings
# 3. **Task 3**: Practice information
# 4. **Task 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Reading 01',
    'topics': ['Public signs', 'Warnings', 'Information'],
    'texts_read': 'What did you read?',
    'new_words': 'List new vocabulary',
    'notes': 'Write your understanding'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Help:
#
# ```
# I am reading simple signs and notices at A2 level.
# Please:
# 1. Help me understand difficult words
# 2. Explain the main ideas in simple English
# 3. Ask me questions to check understanding
# 4. Recommend similar easy texts
# ```
#
# ### Reading Resources:
#
# Good websites for A2 reading:
# - News in Levels (Level 1-2)
# - Breaking News English (Level 0-1)
# - British Council Learn English
# - VOA Learning English

# %% [markdown]
# ## Tasks
#
# 1. Read the example texts slowly
# 2. Look for public signs
# 3. Write down new words
# 4. Answer comprehension questions
# 5. Read more examples
#
# ## Summary
#
# You practiced: Public signs, Warnings, Information
#
# **Next Steps**: Read a little bit every day. It gets easier with practice!
