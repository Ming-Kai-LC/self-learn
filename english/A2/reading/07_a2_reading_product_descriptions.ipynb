# %% [markdown]
# # A2 Reading 07: Product Descriptions
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Read and understand features
# 2. Read and understand how to use
# 3. Read and understand instructions
# 4. Read and understand details
# 5. Read and understand specifications

# %% [markdown]
# ## Product Descriptions - A2 Reading
#
# Topics: Features, How to use, Instructions, Details, Specifications
#
# ### Practice Focus
# Understand product information

# %%
# Product Descriptions
print('A2 Reading: Product Descriptions')
print('Resources: simple texts, graded readers, easy websites')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will read features and how to use. The texts are short and simple.
#
# ### Part 2: Reading Tips
#
# **Features**: Look for this when reading
# **How to use**: Look for this when reading
# **Instructions**: Look for this when reading
#
# ### Part 3: Reading Practice
#
# Read the examples and:
#
# 1. **Task 1**: Find features
# 2. **Task 2**: Understand how to use
# 3. **Task 3**: Practice instructions
# 4. **Task 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Reading 07',
    'topics': ['Features', 'How to use', 'Instructions'],
    'texts_read': 'What did you read?',
    'new_words': 'List new vocabulary',
    'notes': 'Write your understanding'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Help:
#
# ```
# I am reading product descriptions at A2 level.
# Please:
# 1. Help me understand difficult words
# 2. Explain the main ideas in simple English
# 3. Ask me questions to check understanding
# 4. Recommend similar easy texts
# ```
#
# ### Reading Resources:
#
# Good websites for A2 reading:
# - News in Levels (Level 1-2)
# - Breaking News English (Level 0-1)
# - British Council Learn English
# - VOA Learning English

# %% [markdown]
# ## Tasks
#
# 1. Read the example texts slowly
# 2. Look for features
# 3. Write down new words
# 4. Answer comprehension questions
# 5. Read more examples
#
# ## Summary
#
# You practiced: Features, How to use, Instructions
#
# **Next Steps**: Read a little bit every day. It gets easier with practice!
