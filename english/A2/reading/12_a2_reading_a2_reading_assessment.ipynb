# %% [markdown]
# # A2 Reading 12: A2 Reading Assessment
#
# **Difficulty**: ⭐
# **Time**: 30-35 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Read and understand reading test
# 2. Read and understand comprehension
# 3. Read and understand progress check
# 4. Read and understand speed
# 5. Read and understand b1 readiness

# %% [markdown]
# ## A2 Reading Assessment - A2 Reading
#
# Topics: Reading test, Comprehension, Progress check, Speed, B1 readiness
#
# ### Practice Focus
# Assess A2 reading proficiency

# %%
# A2 Reading Assessment
print('A2 Reading: A2 Reading Assessment')
print('Resources: simple texts, graded readers, easy websites')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will read reading test and comprehension. The texts are short and simple.
#
# ### Part 2: Reading Tips
#
# **Reading test**: Look for this when reading
# **Comprehension**: Look for this when reading
# **Progress check**: Look for this when reading
#
# ### Part 3: Reading Practice
#
# Read the examples and:
#
# 1. **Task 1**: Find reading test
# 2. **Task 2**: Understand comprehension
# 3. **Task 3**: Practice progress check
# 4. **Task 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Reading 12',
    'topics': ['Reading test', 'Comprehension', 'Progress check'],
    'texts_read': 'What did you read?',
    'new_words': 'List new vocabulary',
    'notes': 'Write your understanding'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Help:
#
# ```
# I am reading a2 reading assessment at A2 level.
# Please:
# 1. Help me understand difficult words
# 2. Explain the main ideas in simple English
# 3. Ask me questions to check understanding
# 4. Recommend similar easy texts
# ```
#
# ### Reading Resources:
#
# Good websites for A2 reading:
# - News in Levels (Level 1-2)
# - Breaking News English (Level 0-1)
# - British Council Learn English
# - VOA Learning English

# %% [markdown]
# ## Tasks
#
# 1. Read the example texts slowly
# 2. Look for reading test
# 3. Write down new words
# 4. Answer comprehension questions
# 5. Read more examples
#
# ## Summary
#
# You practiced: Reading test, Comprehension, Progress check
#
# **Next Steps**: Read a little bit every day. It gets easier with practice!
