# %% [markdown]
# # A2 Reading 06: Simple Articles
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Read and understand short news
# 2. Read and understand easy topics
# 3. Read and understand main ideas
# 4. Read and understand who/what/when/where
# 5. Read and understand understanding

# %% [markdown]
# ## Simple Articles - A2 Reading
#
# Topics: Short news, Easy topics, Main ideas, Who/what/when/where, Understanding
#
# ### Practice Focus
# Read simple news articles

# %%
# Simple Articles
print('A2 Reading: Simple Articles')
print('Resources: simple texts, graded readers, easy websites')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will read short news and easy topics. The texts are short and simple.
#
# ### Part 2: Reading Tips
#
# **Short news**: Look for this when reading
# **Easy topics**: Look for this when reading
# **Main ideas**: Look for this when reading
#
# ### Part 3: Reading Practice
#
# Read the examples and:
#
# 1. **Task 1**: Find short news
# 2. **Task 2**: Understand easy topics
# 3. **Task 3**: Practice main ideas
# 4. **Task 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Reading 06',
    'topics': ['Short news', 'Easy topics', 'Main ideas'],
    'texts_read': 'What did you read?',
    'new_words': 'List new vocabulary',
    'notes': 'Write your understanding'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Help:
#
# ```
# I am reading simple articles at A2 level.
# Please:
# 1. Help me understand difficult words
# 2. Explain the main ideas in simple English
# 3. Ask me questions to check understanding
# 4. Recommend similar easy texts
# ```
#
# ### Reading Resources:
#
# Good websites for A2 reading:
# - News in Levels (Level 1-2)
# - Breaking News English (Level 0-1)
# - British Council Learn English
# - VOA Learning English

# %% [markdown]
# ## Tasks
#
# 1. Read the example texts slowly
# 2. Look for short news
# 3. Write down new words
# 4. Answer comprehension questions
# 5. Read more examples
#
# ## Summary
#
# You practiced: Short news, Easy topics, Main ideas
#
# **Next Steps**: Read a little bit every day. It gets easier with practice!
