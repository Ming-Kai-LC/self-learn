# %% [markdown]
# # A2 Reading 03: Basic Emails
#
# **Difficulty**: ⭐
# **Time**: 20-25 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Read and understand email structure
# 2. Read and understand greetings
# 3. Read and understand simple requests
# 4. Read and understand information
# 5. Read and understand closing

# %% [markdown]
# ## Basic Emails - A2 Reading
#
# Topics: Email structure, Greetings, Simple requests, Information, Closing
#
# ### Practice Focus
# Read simple emails

# %%
# Basic Emails
print('A2 Reading: Basic Emails')
print('Resources: simple texts, graded readers, easy websites')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will read email structure and greetings. The texts are short and simple.
#
# ### Part 2: Reading Tips
#
# **Email structure**: Look for this when reading
# **Greetings**: Look for this when reading
# **Simple requests**: Look for this when reading
#
# ### Part 3: Reading Practice
#
# Read the examples and:
#
# 1. **Task 1**: Find email structure
# 2. **Task 2**: Understand greetings
# 3. **Task 3**: Practice simple requests
# 4. **Task 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Reading 03',
    'topics': ['Email structure', 'Greetings', 'Simple requests'],
    'texts_read': 'What did you read?',
    'new_words': 'List new vocabulary',
    'notes': 'Write your understanding'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Help:
#
# ```
# I am reading basic emails at A2 level.
# Please:
# 1. Help me understand difficult words
# 2. Explain the main ideas in simple English
# 3. Ask me questions to check understanding
# 4. Recommend similar easy texts
# ```
#
# ### Reading Resources:
#
# Good websites for A2 reading:
# - News in Levels (Level 1-2)
# - Breaking News English (Level 0-1)
# - British Council Learn English
# - VOA Learning English

# %% [markdown]
# ## Tasks
#
# 1. Read the example texts slowly
# 2. Look for email structure
# 3. Write down new words
# 4. Answer comprehension questions
# 5. Read more examples
#
# ## Summary
#
# You practiced: Email structure, Greetings, Simple requests
#
# **Next Steps**: Read a little bit every day. It gets easier with practice!
