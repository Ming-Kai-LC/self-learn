# %% [markdown]
# # A2 Reading 08: Short Stories
#
# **Difficulty**: ⭐
# **Time**: 25-30 min
# **Prerequisites**: A1 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Read and understand simple stories
# 2. Read and understand characters
# 3. Read and understand events
# 4. Read and understand past tense
# 5. Read and understand story order

# %% [markdown]
# ## Short Stories - A2 Reading
#
# Topics: Simple stories, Characters, Events, Past tense, Story order
#
# ### Practice Focus
# Read and enjoy simple stories

# %%
# Short Stories
print('A2 Reading: Short Stories')
print('Resources: simple texts, graded readers, easy websites')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# At A2 level, you will read simple stories and characters. The texts are short and simple.
#
# ### Part 2: Reading Tips
#
# **Simple stories**: Look for this when reading
# **Characters**: Look for this when reading
# **Events**: Look for this when reading
#
# ### Part 3: Reading Practice
#
# Read the examples and:
#
# 1. **Task 1**: Find simple stories
# 2. **Task 2**: Understand characters
# 3. **Task 3**: Practice events
# 4. **Task 4**: Answer simple questions

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'A2 Reading 08',
    'topics': ['Simple stories', 'Characters', 'Events'],
    'texts_read': 'What did you read?',
    'new_words': 'List new vocabulary',
    'notes': 'Write your understanding'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Help:
#
# ```
# I am reading short stories at A2 level.
# Please:
# 1. Help me understand difficult words
# 2. Explain the main ideas in simple English
# 3. Ask me questions to check understanding
# 4. Recommend similar easy texts
# ```
#
# ### Reading Resources:
#
# Good websites for A2 reading:
# - News in Levels (Level 1-2)
# - Breaking News English (Level 0-1)
# - British Council Learn English
# - VOA Learning English

# %% [markdown]
# ## Tasks
#
# 1. Read the example texts slowly
# 2. Look for simple stories
# 3. Write down new words
# 4. Answer comprehension questions
# 5. Read more examples
#
# ## Summary
#
# You practiced: Simple stories, Characters, Events
#
# **Next Steps**: Read a little bit every day. It gets easier with practice!
