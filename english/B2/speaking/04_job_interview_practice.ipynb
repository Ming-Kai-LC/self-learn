# %% [markdown]
# # B2 Speaking 04: Job Interview Practice
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Common questions
# 2. STAR method
# 3. Behavioral questions
# 4. Salary negotiation
# 5. Follow-up

# %% [markdown]
# ## Job Interview Practice - B2 Speaking Essentials
#
# Key topics: Common questions, STAR method, Behavioral questions, Salary negotiation, Follow-up
#
# ### Why This Matters
# Mastering job interview practice is essential for B2-level professional communication.

# %%
# Job Interview Practice Practice
print('B2 Speaking: Job Interview Practice')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Common questions, STAR method, Behavioral questions, Salary negotiation, Follow-up')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Common questions
# Use AI to practice this skill through conversation.
#
# ### Task 2: STAR method
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Common questions, STAR method, Behavioral questions
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 05
