# %% [markdown]
# # B2 Speaking 06: Meeting Participation
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Contributing ideas
# 2. Agreeing/disagreeing
# 3. Interrupting politely
# 4. Summarizing
# 5. Action items

# %% [markdown]
# ## Meeting Participation - B2 Speaking Essentials
#
# Key topics: Contributing ideas, Agreeing/disagreeing, Interrupting politely, Summarizing, Action items
#
# ### Why This Matters
# Mastering meeting participation is essential for B2-level professional communication.

# %%
# Meeting Participation Practice
print('B2 Speaking: Meeting Participation')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Contributing ideas, Agreeing/disagreeing, Interrupting politely, Summarizing, Action items')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Contributing ideas
# Use AI to practice this skill through conversation.
#
# ### Task 2: Agreeing/disagreeing
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Contributing ideas, Agreeing/disagreeing, Interrupting politely
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 07
