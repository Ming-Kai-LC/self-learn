# %% [markdown]
# # B2 Speaking 20: Assessment
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Self-assessment
# 2. Progress review
# 3. Skill evaluation
# 4. Next steps
# 5. C1 preparation

# %% [markdown]
# ## Assessment - B2 Speaking Essentials
#
# Key topics: Self-assessment, Progress review, Skill evaluation, Next steps, C1 preparation
#
# ### Why This Matters
# Mastering assessment is essential for B2-level professional communication.

# %%
# Assessment Practice
print('B2 Speaking: Assessment')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Self-assessment, Progress review, Skill evaluation, Next steps, C1 preparation')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Self-assessment
# Use AI to practice this skill through conversation.
#
# ### Task 2: Progress review
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Self-assessment, Progress review, Skill evaluation
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 21
