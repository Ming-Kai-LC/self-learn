# %% [markdown]
# # B2 Speaking 19: Portfolio Project
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Recording preparation
# 2. Self-evaluation
# 3. Improvement tracking
# 4. Presentation
# 5. Reflection

# %% [markdown]
# ## Portfolio Project - B2 Speaking Essentials
#
# Key topics: Recording preparation, Self-evaluation, Improvement tracking, Presentation, Reflection
#
# ### Why This Matters
# Mastering portfolio project is essential for B2-level professional communication.

# %%
# Portfolio Project Practice
print('B2 Speaking: Portfolio Project')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Recording preparation, Self-evaluation, Improvement tracking, Presentation, Reflection')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Recording preparation
# Use AI to practice this skill through conversation.
#
# ### Task 2: Self-evaluation
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Recording preparation, Self-evaluation, Improvement tracking
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 20
