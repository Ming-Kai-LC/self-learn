# %% [markdown]
# # B2 Speaking 05: Presentation Skills
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Structure
# 2. Opening/closing
# 3. Visual aids
# 4. Q&A handling
# 5. Delivery techniques

# %% [markdown]
# ## Presentation Skills - B2 Speaking Essentials
#
# Key topics: Structure, Opening/closing, Visual aids, Q&A handling, Delivery techniques
#
# ### Why This Matters
# Mastering presentation skills is essential for B2-level professional communication.

# %%
# Presentation Skills Practice
print('B2 Speaking: Presentation Skills')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Structure, Opening/closing, Visual aids, Q&A handling, Delivery techniques')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Structure
# Use AI to practice this skill through conversation.
#
# ### Task 2: Opening/closing
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Structure, Opening/closing, Visual aids
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 06
