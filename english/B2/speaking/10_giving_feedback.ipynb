# %% [markdown]
# # B2 Speaking 10: Giving Feedback
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Positive feedback
# 2. Constructive criticism
# 3. Sandwich method
# 4. Specific examples
# 5. Follow-up

# %% [markdown]
# ## Giving Feedback - B2 Speaking Essentials
#
# Key topics: Positive feedback, Constructive criticism, Sandwich method, Specific examples, Follow-up
#
# ### Why This Matters
# Mastering giving feedback is essential for B2-level professional communication.

# %%
# Giving Feedback Practice
print('B2 Speaking: Giving Feedback')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Positive feedback, Constructive criticism, Sandwich method, Specific examples, Follow-up')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Positive feedback
# Use AI to practice this skill through conversation.
#
# ### Task 2: Constructive criticism
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Positive feedback, Constructive criticism, Sandwich method
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 11
