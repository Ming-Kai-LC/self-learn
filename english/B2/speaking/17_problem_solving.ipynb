# %% [markdown]
# # B2 Speaking 17: Problem Solving
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Identifying issues
# 2. Proposing solutions
# 3. Analyzing options
# 4. Making decisions
# 5. Action planning

# %% [markdown]
# ## Problem Solving - B2 Speaking Essentials
#
# Key topics: Identifying issues, Proposing solutions, Analyzing options, Making decisions, Action planning
#
# ### Why This Matters
# Mastering problem solving is essential for B2-level professional communication.

# %%
# Problem Solving Practice
print('B2 Speaking: Problem Solving')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Identifying issues, Proposing solutions, Analyzing options, Making decisions, Action planning')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Identifying issues
# Use AI to practice this skill through conversation.
#
# ### Task 2: Proposing solutions
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Identifying issues, Proposing solutions, Analyzing options
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 18
