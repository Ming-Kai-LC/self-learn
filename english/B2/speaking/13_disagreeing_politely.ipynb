# %% [markdown]
# # B2 Speaking 13: Disagreeing Politely
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Softening language
# 2. Alternative views
# 3. Respectful tone
# 4. Finding common ground
# 5. Professional disagreement

# %% [markdown]
# ## Disagreeing Politely - B2 Speaking Essentials
#
# Key topics: Softening language, Alternative views, Respectful tone, Finding common ground, Professional disagreement
#
# ### Why This Matters
# Mastering disagreeing politely is essential for B2-level professional communication.

# %%
# Disagreeing Politely Practice
print('B2 Speaking: Disagreeing Politely')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Softening language, Alternative views, Respectful tone, Finding common ground, Professional disagreement')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Softening language
# Use AI to practice this skill through conversation.
#
# ### Task 2: Alternative views
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Softening language, Alternative views, Respectful tone
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 14
