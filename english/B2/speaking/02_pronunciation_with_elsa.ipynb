# %% [markdown]
# # B2 Speaking 02: Pronunciation with ELSA
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. ELSA setup
# 2. Problem sounds
# 3. Intonation
# 4. Word stress
# 5. Practice routine

# %% [markdown]
# ## Pronunciation with ELSA - B2 Speaking Essentials
#
# Key topics: ELSA setup, Problem sounds, Intonation, Word stress, Practice routine
#
# ### Why This Matters
# Mastering pronunciation with elsa is essential for B2-level professional communication.

# %%
# Pronunciation with ELSA Practice
print('B2 Speaking: Pronunciation with ELSA')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: ELSA setup, Problem sounds, Intonation, Word stress, Practice routine')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: ELSA setup
# Use AI to practice this skill through conversation.
#
# ### Task 2: Problem sounds
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: ELSA setup, Problem sounds, Intonation
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 03
