# %% [markdown]
# # B2 Speaking 03: Workplace Role Play
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Meeting scenarios
# 2. Client calls
# 3. Presentations
# 4. Feedback sessions
# 5. Practice techniques

# %% [markdown]
# ## Workplace Role Play - B2 Speaking Essentials
#
# Key topics: Meeting scenarios, Client calls, Presentations, Feedback sessions, Practice techniques
#
# ### Why This Matters
# Mastering workplace role play is essential for B2-level professional communication.

# %%
# Workplace Role Play Practice
print('B2 Speaking: Workplace Role Play')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Meeting scenarios, Client calls, Presentations, Feedback sessions, Practice techniques')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Meeting scenarios
# Use AI to practice this skill through conversation.
#
# ### Task 2: Client calls
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Meeting scenarios, Client calls, Presentations
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 04
