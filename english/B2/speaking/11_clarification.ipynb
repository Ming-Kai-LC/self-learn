# %% [markdown]
# # B2 Speaking 11: Clarification
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Asking for repetition
# 2. Checking understanding
# 3. Paraphrasing
# 4. Confirming details
# 5. Polite questioning

# %% [markdown]
# ## Clarification - B2 Speaking Essentials
#
# Key topics: Asking for repetition, Checking understanding, Paraphrasing, Confirming details, Polite questioning
#
# ### Why This Matters
# Mastering clarification is essential for B2-level professional communication.

# %%
# Clarification Practice
print('B2 Speaking: Clarification')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Asking for repetition, Checking understanding, Paraphrasing, Confirming details, Polite questioning')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Asking for repetition
# Use AI to practice this skill through conversation.
#
# ### Task 2: Checking understanding
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Asking for repetition, Checking understanding, Paraphrasing
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 12
