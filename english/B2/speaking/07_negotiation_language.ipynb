# %% [markdown]
# # B2 Speaking 07: Negotiation Language
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Making proposals
# 2. Compromising
# 3. Persuading
# 4. Handling objections
# 5. Closing deals

# %% [markdown]
# ## Negotiation Language - B2 Speaking Essentials
#
# Key topics: Making proposals, Compromising, Persuading, Handling objections, Closing deals
#
# ### Why This Matters
# Mastering negotiation language is essential for B2-level professional communication.

# %%
# Negotiation Language Practice
print('B2 Speaking: Negotiation Language')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Making proposals, Compromising, Persuading, Handling objections, Closing deals')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Making proposals
# Use AI to practice this skill through conversation.
#
# ### Task 2: Compromising
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Making proposals, Compromising, Persuading
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 08
