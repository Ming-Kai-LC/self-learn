# %% [markdown]
# # B2 Speaking 08: Small Talk Mastery
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Topics
# 2. Ice breakers
# 3. Keeping conversations going
# 4. Cultural considerations
# 5. Networking

# %% [markdown]
# ## Small Talk Mastery - B2 Speaking Essentials
#
# Key topics: Topics, Ice breakers, Keeping conversations going, Cultural considerations, Networking
#
# ### Why This Matters
# Mastering small talk mastery is essential for B2-level professional communication.

# %%
# Small Talk Mastery Practice
print('B2 Speaking: Small Talk Mastery')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Topics, Ice breakers, Keeping conversations going, Cultural considerations, Networking')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Topics
# Use AI to practice this skill through conversation.
#
# ### Task 2: Ice breakers
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Topics, Ice breakers, Keeping conversations going
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 09
