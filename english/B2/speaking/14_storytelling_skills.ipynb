# %% [markdown]
# # B2 Speaking 14: Storytelling Skills
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Narrative structure
# 2. Engaging openings
# 3. Descriptive language
# 4. Pacing
# 5. Memorable endings

# %% [markdown]
# ## Storytelling Skills - B2 Speaking Essentials
#
# Key topics: Narrative structure, Engaging openings, Descriptive language, Pacing, Memorable endings
#
# ### Why This Matters
# Mastering storytelling skills is essential for B2-level professional communication.

# %%
# Storytelling Skills Practice
print('B2 Speaking: Storytelling Skills')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Narrative structure, Engaging openings, Descriptive language, Pacing, Memorable endings')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Narrative structure
# Use AI to practice this skill through conversation.
#
# ### Task 2: Engaging openings
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Narrative structure, Engaging openings, Descriptive language
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 15
