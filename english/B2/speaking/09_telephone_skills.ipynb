# %% [markdown]
# # B2 Speaking 09: Telephone Skills
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Speaking 01
#
# ## Learning Objectives
#
# 1. Professional greetings
# 2. Taking messages
# 3. Handling problems
# 4. Voicemail
# 5. Conference calls

# %% [markdown]
# ## Telephone Skills - B2 Speaking Essentials
#
# Key topics: Professional greetings, Taking messages, Handling problems, Voicemail, Conference calls
#
# ### Why This Matters
# Mastering telephone skills is essential for B2-level professional communication.

# %%
# Telephone Skills Practice
print('B2 Speaking: Telephone Skills')\nprint('Practice with Gliglish, ChatGPT, or Claude')\nprint('Topics: Professional greetings, Taking messages, Handling problems, Voicemail, Conference calls')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Professional greetings
# Use AI to practice this skill through conversation.
#
# ### Task 2: Taking messages
# Record yourself and review for improvement.
#
# ### Task 3: Integration
# Combine with previous modules for comprehensive practice.

# %% [markdown]
# ## Summary
#
# You've mastered: Professional greetings, Taking messages, Handling problems
#
# **AI Practice**: Use Gliglish (10 min daily) + ChatGPT/Claude discussions
#
# **Next**: Continue to B2 Speaking module 10
