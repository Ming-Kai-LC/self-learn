# %% [markdown]
# # B2 Writing 13: Summarizing
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: Previous modules
#
# ## Learning Objectives
#
# 1. Main ideas
# 2. Paraphrasing
# 3. Condensing
# 4. Reporting
# 5. Length

# %% [markdown]
# ## Summarizing Essentials
#
# Key topics: Main ideas, Paraphrasing, Condensing, Reporting, Length

# %%
# Summarizing Practice
print('Summarizing - B2 Writing')
print('Complete exercises with AI feedback')

# %% [markdown]
# ## Summary
#
# Mastered: Main ideas, Paraphrasing, Condensing
#
# **Next module**: Continue B2 writing progression
