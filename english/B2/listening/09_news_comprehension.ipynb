# %% [markdown]
# # B2 Listening 09: News Comprehension
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Listening 01
#
# ## Learning Objectives
#
# 1. BBC/NPR
# 2. Main stories
# 3. Details
# 4. Opinions
# 5. Current events

# %% [markdown]
# ## News Comprehension - B2 Listening Essentials
#
# Key topics: BBC/NPR, Main stories, Details, Opinions, Current events
#
# ### Why This Matters
# Mastering news comprehension improves your B2 listening comprehension and prepares you for real-world English.

# %%
# News Comprehension Practice
print('B2 Listening: News Comprehension')\nprint('Use podcasts, YouTube, and AI for practice')\nprint('Topics: BBC/NPR, Main stories, Details, Opinions, Current events')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: BBC/NPR
# Listen to recommended content and practice this skill.
#
# ### Task 2: Main stories
# Apply the 3-Listen Method for comprehension.
#
# ### Task 3: Discussion
# Discuss what you heard with ChatGPT/Claude to verify understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: BBC/NPR, Main stories, Details
#
# **Practice Resources**: See resources/podcasts.md and youtube_channels.md
#
# **Next**: Continue to B2 Listening module 10
