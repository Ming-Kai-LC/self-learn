# %% [markdown]
# # B2 Listening 12: Presentation Analysis
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Listening 01
#
# ## Learning Objectives
#
# 1. Structure
# 2. Visual descriptions
# 3. Q&A sections
# 4. Technical content
# 5. Persuasive elements

# %% [markdown]
# ## Presentation Analysis - B2 Listening Essentials
#
# Key topics: Structure, Visual descriptions, Q&A sections, Technical content, Persuasive elements
#
# ### Why This Matters
# Mastering presentation analysis improves your B2 listening comprehension and prepares you for real-world English.

# %%
# Presentation Analysis Practice
print('B2 Listening: Presentation Analysis')\nprint('Use podcasts, YouTube, and AI for practice')\nprint('Topics: Structure, Visual descriptions, Q&A sections, Technical content, Persuasive elements')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Structure
# Listen to recommended content and practice this skill.
#
# ### Task 2: Visual descriptions
# Apply the 3-Listen Method for comprehension.
#
# ### Task 3: Discussion
# Discuss what you heard with ChatGPT/Claude to verify understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Structure, Visual descriptions, Q&A sections
#
# **Practice Resources**: See resources/podcasts.md and youtube_channels.md
#
# **Next**: Continue to B2 Listening module 13
