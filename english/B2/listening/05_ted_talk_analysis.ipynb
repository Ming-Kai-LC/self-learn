# %% [markdown]
# # B2 Listening 05: TED Talk Analysis
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Listening 01
#
# ## Learning Objectives
#
# 1. Main ideas
# 2. Supporting details
# 3. Vocabulary
# 4. Speaker intent
# 5. Critical listening

# %% [markdown]
# ## TED Talk Analysis - B2 Listening Essentials
#
# Key topics: Main ideas, Supporting details, Vocabulary, Speaker intent, Critical listening
#
# ### Why This Matters
# Mastering ted talk analysis improves your B2 listening comprehension and prepares you for real-world English.

# %%
# TED Talk Analysis Practice
print('B2 Listening: TED Talk Analysis')\nprint('Use podcasts, YouTube, and AI for practice')\nprint('Topics: Main ideas, Supporting details, Vocabulary, Speaker intent, Critical listening')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Main ideas
# Listen to recommended content and practice this skill.
#
# ### Task 2: Supporting details
# Apply the 3-Listen Method for comprehension.
#
# ### Task 3: Discussion
# Discuss what you heard with ChatGPT/Claude to verify understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Main ideas, Supporting details, Vocabulary
#
# **Practice Resources**: See resources/podcasts.md and youtube_channels.md
#
# **Next**: Continue to B2 Listening module 06
