# %% [markdown]
# # B2 Listening 16: Phone Conversations
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Listening 01
#
# ## Learning Objectives
#
# 1. Greetings
# 2. Messages
# 3. Problems
# 4. Clarification
# 5. Professional calls

# %% [markdown]
# ## Phone Conversations - B2 Listening Essentials
#
# Key topics: Greetings, Messages, Problems, Clarification, Professional calls
#
# ### Why This Matters
# Mastering phone conversations improves your B2 listening comprehension and prepares you for real-world English.

# %%
# Phone Conversations Practice
print('B2 Listening: Phone Conversations')\nprint('Use podcasts, YouTube, and AI for practice')\nprint('Topics: Greetings, Messages, Problems, Clarification, Professional calls')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Greetings
# Listen to recommended content and practice this skill.
#
# ### Task 2: Messages
# Apply the 3-Listen Method for comprehension.
#
# ### Task 3: Discussion
# Discuss what you heard with ChatGPT/Claude to verify understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Greetings, Messages, Problems
#
# **Practice Resources**: See resources/podcasts.md and youtube_channels.md
#
# **Next**: Continue to B2 Listening module 17
