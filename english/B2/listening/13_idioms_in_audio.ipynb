# %% [markdown]
# # B2 Listening 13: Idioms in Audio
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Listening 01
#
# ## Learning Objectives
#
# 1. Common idioms
# 2. Context clues
# 3. Figurative language
# 4. Cultural references
# 5. Natural usage

# %% [markdown]
# ## Idioms in Audio - B2 Listening Essentials
#
# Key topics: Common idioms, Context clues, Figurative language, Cultural references, Natural usage
#
# ### Why This Matters
# Mastering idioms in audio improves your B2 listening comprehension and prepares you for real-world English.

# %%
# Idioms in Audio Practice
print('B2 Listening: Idioms in Audio')\nprint('Use podcasts, YouTube, and AI for practice')\nprint('Topics: Common idioms, Context clues, Figurative language, Cultural references, Natural usage')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Common idioms
# Listen to recommended content and practice this skill.
#
# ### Task 2: Context clues
# Apply the 3-Listen Method for comprehension.
#
# ### Task 3: Discussion
# Discuss what you heard with ChatGPT/Claude to verify understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Common idioms, Context clues, Figurative language
#
# **Practice Resources**: See resources/podcasts.md and youtube_channels.md
#
# **Next**: Continue to B2 Listening module 14
