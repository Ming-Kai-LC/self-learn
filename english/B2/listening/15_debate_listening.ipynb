# %% [markdown]
# # B2 Listening 15: Debate Listening
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Listening 01
#
# ## Learning Objectives
#
# 1. Arguments
# 2. Rebuttals
# 3. Evidence
# 4. Logical flow
# 5. Bias detection

# %% [markdown]
# ## Debate Listening - B2 Listening Essentials
#
# Key topics: Arguments, Rebuttals, Evidence, Logical flow, Bias detection
#
# ### Why This Matters
# Mastering debate listening improves your B2 listening comprehension and prepares you for real-world English.

# %%
# Debate Listening Practice
print('B2 Listening: Debate Listening')\nprint('Use podcasts, YouTube, and AI for practice')\nprint('Topics: Arguments, Rebuttals, Evidence, Logical flow, Bias detection')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Arguments
# Listen to recommended content and practice this skill.
#
# ### Task 2: Rebuttals
# Apply the 3-Listen Method for comprehension.
#
# ### Task 3: Discussion
# Discuss what you heard with ChatGPT/Claude to verify understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Arguments, Rebuttals, Evidence
#
# **Practice Resources**: See resources/podcasts.md and youtube_channels.md
#
# **Next**: Continue to B2 Listening module 16
