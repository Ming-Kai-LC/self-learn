# %% [markdown]
# # B2 Listening 03: Real Exam English Accents
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Listening 01
#
# ## Learning Objectives
#
# 1. UK accent
# 2. US accent
# 3. Australian accent
# 4. Multi-speaker
# 5. Accent adaptation

# %% [markdown]
# ## Real Exam English Accents - B2 Listening Essentials
#
# Key topics: UK accent, US accent, Australian accent, Multi-speaker, Accent adaptation
#
# ### Why This Matters
# Mastering real exam english accents improves your B2 listening comprehension and prepares you for real-world English.

# %%
# Real Exam English Accents Practice
print('B2 Listening: Real Exam English Accents')\nprint('Use podcasts, YouTube, and AI for practice')\nprint('Topics: UK accent, US accent, Australian accent, Multi-speaker, Accent adaptation')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: UK accent
# Listen to recommended content and practice this skill.
#
# ### Task 2: US accent
# Apply the 3-Listen Method for comprehension.
#
# ### Task 3: Discussion
# Discuss what you heard with ChatGPT/Claude to verify understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: UK accent, US accent, Australian accent
#
# **Practice Resources**: See resources/podcasts.md and youtube_channels.md
#
# **Next**: Continue to B2 Listening module 04
