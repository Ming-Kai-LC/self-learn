# %% [markdown]
# # B2 Listening 07: British vs American
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Listening 01
#
# ## Learning Objectives
#
# 1. Pronunciation differences
# 2. Vocabulary
# 3. Grammar variations
# 4. Practice resources
# 5. Adaptation

# %% [markdown]
# ## British vs American - B2 Listening Essentials
#
# Key topics: Pronunciation differences, Vocabulary, Grammar variations, Practice resources, Adaptation
#
# ### Why This Matters
# Mastering british vs american improves your B2 listening comprehension and prepares you for real-world English.

# %%
# British vs American Practice
print('B2 Listening: British vs American')\nprint('Use podcasts, YouTube, and AI for practice')\nprint('Topics: Pronunciation differences, Vocabulary, Grammar variations, Practice resources, Adaptation')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Pronunciation differences
# Listen to recommended content and practice this skill.
#
# ### Task 2: Vocabulary
# Apply the 3-Listen Method for comprehension.
#
# ### Task 3: Discussion
# Discuss what you heard with ChatGPT/Claude to verify understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Pronunciation differences, Vocabulary, Grammar variations
#
# **Practice Resources**: See resources/podcasts.md and youtube_channels.md
#
# **Next**: Continue to B2 Listening module 08
