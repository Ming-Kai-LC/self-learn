# %% [markdown]
# # B2 Reading 06: Technical Documentation
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Manuals
# 2. Instructions
# 3. Specifications
# 4. Diagrams
# 5. Procedures

# %% [markdown]
# ## Technical Documentation - B2 Reading Essentials
#
# Key topics: Manuals, Instructions, Specifications, Diagrams, Procedures
#
# ### Why This Matters
# Mastering technical documentation enhances your B2 reading comprehension and speed.

# %%
# Technical Documentation Practice
print('B2 Reading: Technical Documentation')\nprint('Use Breaking News English and other resources')\nprint('Topics: Manuals, Instructions, Specifications, Diagrams, Procedures')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Manuals
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Instructions
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Manuals, Instructions, Specifications
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 07
