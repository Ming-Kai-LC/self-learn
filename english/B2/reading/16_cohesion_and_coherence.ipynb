# %% [markdown]
# # B2 Reading 16: Cohesion and Coherence
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Linking devices
# 2. Paragraph unity
# 3. Text flow
# 4. Logical connections
# 5. Reader guidance

# %% [markdown]
# ## Cohesion and Coherence - B2 Reading Essentials
#
# Key topics: Linking devices, Paragraph unity, Text flow, Logical connections, Reader guidance
#
# ### Why This Matters
# Mastering cohesion and coherence enhances your B2 reading comprehension and speed.

# %%
# Cohesion and Coherence Practice
print('B2 Reading: Cohesion and Coherence')\nprint('Use Breaking News English and other resources')\nprint('Topics: Linking devices, Paragraph unity, Text flow, Logical connections, Reader guidance')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Linking devices
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Paragraph unity
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Linking devices, Paragraph unity, Text flow
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 17
