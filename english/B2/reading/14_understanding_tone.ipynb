# %% [markdown]
# # B2 Reading 14: Understanding Tone
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Formal/informal
# 2. Author attitude
# 3. Emotional language
# 4. Purpose
# 5. Audience

# %% [markdown]
# ## Understanding Tone - B2 Reading Essentials
#
# Key topics: Formal/informal, Author attitude, Emotional language, Purpose, Audience
#
# ### Why This Matters
# Mastering understanding tone enhances your B2 reading comprehension and speed.

# %%
# Understanding Tone Practice
print('B2 Reading: Understanding Tone')\nprint('Use Breaking News English and other resources')\nprint('Topics: Formal/informal, Author attitude, Emotional language, Purpose, Audience')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Formal/informal
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Author attitude
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Formal/informal, Author attitude, Emotional language
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 15
