# %% [markdown]
# # B2 Reading 03: Scanning for Information
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Finding details
# 2. Keywords
# 3. Numbers/dates
# 4. Specific info
# 5. Speed reading

# %% [markdown]
# ## Scanning for Information - B2 Reading Essentials
#
# Key topics: Finding details, Keywords, Numbers/dates, Specific info, Speed reading
#
# ### Why This Matters
# Mastering scanning for information enhances your B2 reading comprehension and speed.

# %%
# Scanning for Information Practice
print('B2 Reading: Scanning for Information')\nprint('Use Breaking News English and other resources')\nprint('Topics: Finding details, Keywords, Numbers/dates, Specific info, Speed reading')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Finding details
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Keywords
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Finding details, Keywords, Numbers/dates
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 04
