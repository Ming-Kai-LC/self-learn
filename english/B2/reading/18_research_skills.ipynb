# %% [markdown]
# # B2 Reading 18: Research Skills
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Finding sources
# 2. Evaluating reliability
# 3. Note-taking
# 4. Synthesis
# 5. Citation

# %% [markdown]
# ## Research Skills - B2 Reading Essentials
#
# Key topics: Finding sources, Evaluating reliability, Note-taking, Synthesis, Citation
#
# ### Why This Matters
# Mastering research skills enhances your B2 reading comprehension and speed.

# %%
# Research Skills Practice
print('B2 Reading: Research Skills')\nprint('Use Breaking News English and other resources')\nprint('Topics: Finding sources, Evaluating reliability, Note-taking, Synthesis, Citation')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Finding sources
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Evaluating reliability
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Finding sources, Evaluating reliability, Note-taking
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 19
