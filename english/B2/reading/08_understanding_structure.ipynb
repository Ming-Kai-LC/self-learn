# %% [markdown]
# # B2 Reading 08: Understanding Structure
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Organization patterns
# 2. Text types
# 3. Logical flow
# 4. Transitions
# 5. Coherence

# %% [markdown]
# ## Understanding Structure - B2 Reading Essentials
#
# Key topics: Organization patterns, Text types, Logical flow, Transitions, Coherence
#
# ### Why This Matters
# Mastering understanding structure enhances your B2 reading comprehension and speed.

# %%
# Understanding Structure Practice
print('B2 Reading: Understanding Structure')\nprint('Use Breaking News English and other resources')\nprint('Topics: Organization patterns, Text types, Logical flow, Transitions, Coherence')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Organization patterns
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Text types
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Organization patterns, Text types, Logical flow
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 09
