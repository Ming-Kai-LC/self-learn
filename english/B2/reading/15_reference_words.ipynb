# %% [markdown]
# # B2 Reading 15: Reference Words
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Pronouns
# 2. Demonstratives
# 3. Articles
# 4. Cohesion
# 5. Text links

# %% [markdown]
# ## Reference Words - B2 Reading Essentials
#
# Key topics: Pronouns, Demonstratives, Articles, Cohesion, Text links
#
# ### Why This Matters
# Mastering reference words enhances your B2 reading comprehension and speed.

# %%
# Reference Words Practice
print('B2 Reading: Reference Words')\nprint('Use Breaking News English and other resources')\nprint('Topics: Pronouns, Demonstratives, Articles, Cohesion, Text links')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Pronouns
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Demonstratives
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Pronouns, Demonstratives, Articles
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 16
