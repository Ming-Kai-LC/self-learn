# %% [markdown]
# # B2 Reading 12: Reading Speed Building
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. WPM increase
# 2. Chunking
# 3. Reducing regression
# 4. Pointer use
# 5. Progressive challenge

# %% [markdown]
# ## Reading Speed Building - B2 Reading Essentials
#
# Key topics: WPM increase, Chunking, Reducing regression, Pointer use, Progressive challenge
#
# ### Why This Matters
# Mastering reading speed building enhances your B2 reading comprehension and speed.

# %%
# Reading Speed Building Practice
print('B2 Reading: Reading Speed Building')\nprint('Use Breaking News English and other resources')\nprint('Topics: WPM increase, Chunking, Reducing regression, Pointer use, Progressive challenge')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: WPM increase
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Chunking
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: WPM increase, Chunking, Reducing regression
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 13
