# %% [markdown]
# # B2 Reading 10: Critical Reading
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Evaluation
# 2. Arguments
# 3. Evidence
# 4. Assumptions
# 5. Conclusions

# %% [markdown]
# ## Critical Reading - B2 Reading Essentials
#
# Key topics: Evaluation, Arguments, Evidence, Assumptions, Conclusions
#
# ### Why This Matters
# Mastering critical reading enhances your B2 reading comprehension and speed.

# %%
# Critical Reading Practice
print('B2 Reading: Critical Reading')\nprint('Use Breaking News English and other resources')\nprint('Topics: Evaluation, Arguments, Evidence, Assumptions, Conclusions')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Evaluation
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Arguments
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Evaluation, Arguments, Evidence
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 11
