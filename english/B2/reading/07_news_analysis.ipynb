# %% [markdown]
# # B2 Reading 07: News Analysis
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Headlines
# 2. Lead paragraphs
# 3. Bias detection
# 4. Fact vs opinion
# 5. Critical thinking

# %% [markdown]
# ## News Analysis - B2 Reading Essentials
#
# Key topics: Headlines, Lead paragraphs, Bias detection, Fact vs opinion, Critical thinking
#
# ### Why This Matters
# Mastering news analysis enhances your B2 reading comprehension and speed.

# %%
# News Analysis Practice
print('B2 Reading: News Analysis')\nprint('Use Breaking News English and other resources')\nprint('Topics: Headlines, Lead paragraphs, Bias detection, Fact vs opinion, Critical thinking')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Headlines
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Lead paragraphs
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Headlines, Lead paragraphs, Bias detection
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 08
