# %% [markdown]
# # B2 Reading 11: Academic Texts
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Research papers
# 2. Abstracts
# 3. Methodology
# 4. Results
# 5. Citations

# %% [markdown]
# ## Academic Texts - B2 Reading Essentials
#
# Key topics: Research papers, Abstracts, Methodology, Results, Citations
#
# ### Why This Matters
# Mastering academic texts enhances your B2 reading comprehension and speed.

# %%
# Academic Texts Practice
print('B2 Reading: Academic Texts')\nprint('Use Breaking News English and other resources')\nprint('Topics: Research papers, Abstracts, Methodology, Results, Citations')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Research papers
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Abstracts
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Research papers, Abstracts, Methodology
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 12
