# %% [markdown]
# # B2 Reading 04: Vocabulary from Context
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Context clues
# 2. Inference
# 3. Word formation
# 4. Guessing meaning
# 5. Dictionary-free reading

# %% [markdown]
# ## Vocabulary from Context - B2 Reading Essentials
#
# Key topics: Context clues, Inference, Word formation, Guessing meaning, Dictionary-free reading
#
# ### Why This Matters
# Mastering vocabulary from context enhances your B2 reading comprehension and speed.

# %%
# Vocabulary from Context Practice
print('B2 Reading: Vocabulary from Context')\nprint('Use Breaking News English and other resources')\nprint('Topics: Context clues, Inference, Word formation, Guessing meaning, Dictionary-free reading')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Context clues
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Inference
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Context clues, Inference, Word formation
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 05
