# %% [markdown]
# # B2 Reading 09: Inferencing Skills
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Implied meaning
# 2. Drawing conclusions
# 3. Author intent
# 4. Reading between lines
# 5. Context analysis

# %% [markdown]
# ## Inferencing Skills - B2 Reading Essentials
#
# Key topics: Implied meaning, Drawing conclusions, Author intent, Reading between lines, Context analysis
#
# ### Why This Matters
# Mastering inferencing skills enhances your B2 reading comprehension and speed.

# %%
# Inferencing Skills Practice
print('B2 Reading: Inferencing Skills')\nprint('Use Breaking News English and other resources')\nprint('Topics: Implied meaning, Drawing conclusions, Author intent, Reading between lines, Context analysis')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Implied meaning
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Drawing conclusions
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Implied meaning, Drawing conclusions, Author intent
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 10
