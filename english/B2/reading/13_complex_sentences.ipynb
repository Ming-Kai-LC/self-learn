# %% [markdown]
# # B2 Reading 13: Complex Sentences
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Long sentences
# 2. Multiple clauses
# 3. Subject-verb ID
# 4. Simplification
# 5. Comprehension

# %% [markdown]
# ## Complex Sentences - B2 Reading Essentials
#
# Key topics: Long sentences, Multiple clauses, Subject-verb ID, Simplification, Comprehension
#
# ### Why This Matters
# Mastering complex sentences enhances your B2 reading comprehension and speed.

# %%
# Complex Sentences Practice
print('B2 Reading: Complex Sentences')\nprint('Use Breaking News English and other resources')\nprint('Topics: Long sentences, Multiple clauses, Subject-verb ID, Simplification, Comprehension')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Long sentences
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Multiple clauses
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Long sentences, Multiple clauses, Subject-verb ID
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 14
