# %% [markdown]
# # B2 Reading 02: Skimming Techniques
#
# **Difficulty**: ⭐⭐
# **Time**: 30-40 min
# **Prerequisites**: B2 Reading 01
#
# ## Learning Objectives
#
# 1. Quick reading
# 2. Main ideas
# 3. Text structure
# 4. Efficient scanning
# 5. Time management

# %% [markdown]
# ## Skimming Techniques - B2 Reading Essentials
#
# Key topics: Quick reading, Main ideas, Text structure, Efficient scanning, Time management
#
# ### Why This Matters
# Mastering skimming techniques enhances your B2 reading comprehension and speed.

# %%
# Skimming Techniques Practice
print('B2 Reading: Skimming Techniques')\nprint('Use Breaking News English and other resources')\nprint('Topics: Quick reading, Main ideas, Text structure, Efficient scanning, Time management')

# %% [markdown]
# ## Practice Tasks
#
# ### Task 1: Quick reading
# Read articles from Breaking News English focusing on this skill.
#
# ### Task 2: Main ideas
# Apply the 4-Read Strategy with emphasis on this technique.
#
# ### Task 3: AI Discussion
# Discuss article content with ChatGPT/Claude to deepen understanding.

# %% [markdown]
# ## Summary
#
# You've mastered: Quick reading, Main ideas, Text structure
#
# **Practice Resources**: Breaking News English, news websites (see resources/websites.md)
#
# **Next**: Continue to B2 Reading module 03
