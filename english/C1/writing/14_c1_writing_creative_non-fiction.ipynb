# %% [markdown]
# # C1 Writing 14: Creative Non-Fiction
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master narrative techniques
# 2. Master descriptive writing
# 3. Master personal essays
# 4. Master literary devices
# 5. Master author voice

# %% [markdown]
# ## Creative Non-Fiction - C1 Writing
#
# Topics: Narrative techniques, Descriptive writing, Personal essays, Literary devices, Author voice
#
# ### Practice Focus
# Blend creativity with factual writing

# %%
# Creative Non-Fiction
print('C1 Writing: Creative Non-Fiction')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of narrative techniques and descriptive writing. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Narrative techniques**: Essential for advanced writing proficiency
# **Descriptive writing**: Essential for advanced writing proficiency
# **Personal essays**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply narrative techniques in a professional context
# 2. **Task 2**: Demonstrate descriptive writing in your writing
# 3. **Task 3**: Integrate personal essays effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 14',
    'topics_practiced': ['Narrative techniques', 'Descriptive writing', 'Personal essays'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level creative non-fiction. Please review my writing and provide detailed feedback on:
# 1. Narrative techniques
# 2. Descriptive writing
# 3. Personal essays
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice creative non-fiction at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice narrative techniques techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Narrative techniques, Descriptive writing, Personal essays
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
