# %% [markdown]
# # C1 Writing 06: Critical Reviews and Evaluations
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master critical analysis
# 2. Master evaluation criteria
# 3. Master balanced judgments
# 4. Master evidence-based critique
# 5. Master scholarly reviews

# %% [markdown]
# ## Critical Reviews and Evaluations - C1 Writing
#
# Topics: Critical analysis, Evaluation criteria, Balanced judgments, Evidence-based critique, Scholarly reviews
#
# ### Practice Focus
# Write sophisticated critical evaluations

# %%
# Critical Reviews and Evaluations
print('C1 Writing: Critical Reviews and Evaluations')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of critical analysis and evaluation criteria. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Critical analysis**: Essential for advanced writing proficiency
# **Evaluation criteria**: Essential for advanced writing proficiency
# **Balanced judgments**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply critical analysis in a professional context
# 2. **Task 2**: Demonstrate evaluation criteria in your writing
# 3. **Task 3**: Integrate balanced judgments effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 06',
    'topics_practiced': ['Critical analysis', 'Evaluation criteria', 'Balanced judgments'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level critical reviews and evaluations. Please review my writing and provide detailed feedback on:
# 1. Critical analysis
# 2. Evaluation criteria
# 3. Balanced judgments
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice critical reviews and evaluations at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice critical analysis techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Critical analysis, Evaluation criteria, Balanced judgments
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
