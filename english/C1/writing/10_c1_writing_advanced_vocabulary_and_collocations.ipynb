# %% [markdown]
# # C1 Writing 10: Advanced Vocabulary and Collocations
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master academic word list
# 2. Master discipline-specific terms
# 3. Master fixed expressions
# 4. Master connotations
# 5. Master precision

# %% [markdown]
# ## Advanced Vocabulary and Collocations - C1 Writing
#
# Topics: Academic word list, Discipline-specific terms, Fixed expressions, Connotations, Precision
#
# ### Practice Focus
# Expand advanced vocabulary range

# %%
# Advanced Vocabulary and Collocations
print('C1 Writing: Advanced Vocabulary and Collocations')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of academic word list and discipline-specific terms. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Academic word list**: Essential for advanced writing proficiency
# **Discipline-specific terms**: Essential for advanced writing proficiency
# **Fixed expressions**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply academic word list in a professional context
# 2. **Task 2**: Demonstrate discipline-specific terms in your writing
# 3. **Task 3**: Integrate fixed expressions effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 10',
    'topics_practiced': ['Academic word list', 'Discipline-specific terms', 'Fixed expressions'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level advanced vocabulary and collocations. Please review my writing and provide detailed feedback on:
# 1. Academic word list
# 2. Discipline-specific terms
# 3. Fixed expressions
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice advanced vocabulary and collocations at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice academic word list techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Academic word list, Discipline-specific terms, Fixed expressions
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
