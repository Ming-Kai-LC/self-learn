# %% [markdown]
# # C1 Writing 01: Advanced Academic Writing
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master thesis statements
# 2. Master academic tone
# 3. Master research integration
# 4. Master citation styles
# 5. Master critical analysis

# %% [markdown]
# ## Advanced Academic Writing - C1 Writing
#
# Topics: Thesis statements, Academic tone, Research integration, Citation styles, Critical analysis
#
# ### Practice Focus
# Develop academic writing skills for research papers and essays

# %%
# Advanced Academic Writing
print('C1 Writing: Advanced Academic Writing')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of thesis statements and academic tone. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Thesis statements**: Essential for advanced writing proficiency
# **Academic tone**: Essential for advanced writing proficiency
# **Research integration**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply thesis statements in a professional context
# 2. **Task 2**: Demonstrate academic tone in your writing
# 3. **Task 3**: Integrate research integration effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 01',
    'topics_practiced': ['Thesis statements', 'Academic tone', 'Research integration'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level advanced academic writing. Please review my writing and provide detailed feedback on:
# 1. Thesis statements
# 2. Academic tone
# 3. Research integration
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice advanced academic writing at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice thesis statements techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Thesis statements, Academic tone, Research integration
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
