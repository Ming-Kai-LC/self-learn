# %% [markdown]
# # C1 Writing 09: Complex Sentence Structures
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master subordination
# 2. Master nominal clauses
# 3. Master participle clauses
# 4. Master inversion
# 5. Master cleft sentences

# %% [markdown]
# ## Complex Sentence Structures - C1 Writing
#
# Topics: Subordination, Nominal clauses, Participle clauses, Inversion, Cleft sentences
#
# ### Practice Focus
# Employ sophisticated grammatical structures

# %%
# Complex Sentence Structures
print('C1 Writing: Complex Sentence Structures')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of subordination and nominal clauses. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Subordination**: Essential for advanced writing proficiency
# **Nominal clauses**: Essential for advanced writing proficiency
# **Participle clauses**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply subordination in a professional context
# 2. **Task 2**: Demonstrate nominal clauses in your writing
# 3. **Task 3**: Integrate participle clauses effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 09',
    'topics_practiced': ['Subordination', 'Nominal clauses', 'Participle clauses'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level complex sentence structures. Please review my writing and provide detailed feedback on:
# 1. Subordination
# 2. Nominal clauses
# 3. Participle clauses
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice complex sentence structures at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice subordination techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Subordination, Nominal clauses, Participle clauses
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
