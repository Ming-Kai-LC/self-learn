# %% [markdown]
# # C1 Writing 04: Nuanced Register and Style
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master formality levels
# 2. Master hedging language
# 3. Master emphasis techniques
# 4. Master tone control
# 5. Master cultural sensitivity

# %% [markdown]
# ## Nuanced Register and Style - C1 Writing
#
# Topics: Formality levels, Hedging language, Emphasis techniques, Tone control, Cultural sensitivity
#
# ### Practice Focus
# Adapt writing style for different audiences

# %%
# Nuanced Register and Style
print('C1 Writing: Nuanced Register and Style')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of formality levels and hedging language. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Formality levels**: Essential for advanced writing proficiency
# **Hedging language**: Essential for advanced writing proficiency
# **Emphasis techniques**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply formality levels in a professional context
# 2. **Task 2**: Demonstrate hedging language in your writing
# 3. **Task 3**: Integrate emphasis techniques effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 04',
    'topics_practiced': ['Formality levels', 'Hedging language', 'Emphasis techniques'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level nuanced register and style. Please review my writing and provide detailed feedback on:
# 1. Formality levels
# 2. Hedging language
# 3. Emphasis techniques
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice nuanced register and style at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice formality levels techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Formality levels, Hedging language, Emphasis techniques
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
