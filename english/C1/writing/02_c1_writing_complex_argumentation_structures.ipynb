# %% [markdown]
# # C1 Writing 02: Complex Argumentation Structures
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master counter-arguments
# 2. Master concessions
# 3. Master refutation
# 4. Master synthesis
# 5. Master logical fallacies

# %% [markdown]
# ## Complex Argumentation Structures - C1 Writing
#
# Topics: Counter-arguments, Concessions, Refutation, Synthesis, Logical fallacies
#
# ### Practice Focus
# Master advanced argumentation techniques

# %%
# Complex Argumentation Structures
print('C1 Writing: Complex Argumentation Structures')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of counter-arguments and concessions. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Counter-arguments**: Essential for advanced writing proficiency
# **Concessions**: Essential for advanced writing proficiency
# **Refutation**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply counter-arguments in a professional context
# 2. **Task 2**: Demonstrate concessions in your writing
# 3. **Task 3**: Integrate refutation effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 02',
    'topics_practiced': ['Counter-arguments', 'Concessions', 'Refutation'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level complex argumentation structures. Please review my writing and provide detailed feedback on:
# 1. Counter-arguments
# 2. Concessions
# 3. Refutation
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice complex argumentation structures at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice counter-arguments techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Counter-arguments, Concessions, Refutation
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
