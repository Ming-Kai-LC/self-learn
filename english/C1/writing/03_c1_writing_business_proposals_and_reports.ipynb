# %% [markdown]
# # C1 Writing 03: Business Proposals and Reports
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 50-55 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master executive summaries
# 2. Master data analysis
# 3. Master recommendations
# 4. Master financial projections
# 5. Master professional formatting

# %% [markdown]
# ## Business Proposals and Reports - C1 Writing
#
# Topics: Executive summaries, Data analysis, Recommendations, Financial projections, Professional formatting
#
# ### Practice Focus
# Write sophisticated business documents

# %%
# Business Proposals and Reports
print('C1 Writing: Business Proposals and Reports')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of executive summaries and data analysis. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Executive summaries**: Essential for advanced writing proficiency
# **Data analysis**: Essential for advanced writing proficiency
# **Recommendations**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply executive summaries in a professional context
# 2. **Task 2**: Demonstrate data analysis in your writing
# 3. **Task 3**: Integrate recommendations effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 03',
    'topics_practiced': ['Executive summaries', 'Data analysis', 'Recommendations'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level business proposals and reports. Please review my writing and provide detailed feedback on:
# 1. Executive summaries
# 2. Data analysis
# 3. Recommendations
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice business proposals and reports at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice executive summaries techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Executive summaries, Data analysis, Recommendations
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
