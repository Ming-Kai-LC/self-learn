# %% [markdown]
# # C1 Writing 08: Persuasive and Rhetorical Techniques
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master ethos/pathos/logos
# 2. Master rhetorical devices
# 3. Master persuasive strategies
# 4. Master audience analysis
# 5. Master compelling narratives

# %% [markdown]
# ## Persuasive and Rhetorical Techniques - C1 Writing
#
# Topics: Ethos/pathos/logos, Rhetorical devices, Persuasive strategies, Audience analysis, Compelling narratives
#
# ### Practice Focus
# Use advanced persuasion techniques

# %%
# Persuasive and Rhetorical Techniques
print('C1 Writing: Persuasive and Rhetorical Techniques')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of ethos/pathos/logos and rhetorical devices. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Ethos/pathos/logos**: Essential for advanced writing proficiency
# **Rhetorical devices**: Essential for advanced writing proficiency
# **Persuasive strategies**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply ethos/pathos/logos in a professional context
# 2. **Task 2**: Demonstrate rhetorical devices in your writing
# 3. **Task 3**: Integrate persuasive strategies effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 08',
    'topics_practiced': ['Ethos/pathos/logos', 'Rhetorical devices', 'Persuasive strategies'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level persuasive and rhetorical techniques. Please review my writing and provide detailed feedback on:
# 1. Ethos/pathos/logos
# 2. Rhetorical devices
# 3. Persuasive strategies
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice persuasive and rhetorical techniques at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice ethos/pathos/logos techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Ethos/pathos/logos, Rhetorical devices, Persuasive strategies
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
