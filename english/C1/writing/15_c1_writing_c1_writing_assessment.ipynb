# %% [markdown]
# # C1 Writing 15: C1 Writing Assessment
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 60-90 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master comprehensive test
# 2. Master timed writing
# 3. Master portfolio review
# 4. Master progress evaluation
# 5. Master c2 readiness

# %% [markdown]
# ## C1 Writing Assessment - C1 Writing
#
# Topics: Comprehensive test, Timed writing, Portfolio review, Progress evaluation, C2 readiness
#
# ### Practice Focus
# Assess C1 writing proficiency

# %%
# C1 Writing Assessment
print('C1 Writing: C1 Writing Assessment')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of comprehensive test and timed writing. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Comprehensive test**: Essential for advanced writing proficiency
# **Timed writing**: Essential for advanced writing proficiency
# **Portfolio review**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply comprehensive test in a professional context
# 2. **Task 2**: Demonstrate timed writing in your writing
# 3. **Task 3**: Integrate portfolio review effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 15',
    'topics_practiced': ['Comprehensive test', 'Timed writing', 'Portfolio review'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level c1 writing assessment. Please review my writing and provide detailed feedback on:
# 1. Comprehensive test
# 2. Timed writing
# 3. Portfolio review
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice c1 writing assessment at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice comprehensive test techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Comprehensive test, Timed writing, Portfolio review
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
