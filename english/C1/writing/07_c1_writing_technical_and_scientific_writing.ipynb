# %% [markdown]
# # C1 Writing 07: Technical and Scientific Writing
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 50-55 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master technical precision
# 2. Master process descriptions
# 3. Master scientific method
# 4. Master data presentation
# 5. Master objectivity

# %% [markdown]
# ## Technical and Scientific Writing - C1 Writing
#
# Topics: Technical precision, Process descriptions, Scientific method, Data presentation, Objectivity
#
# ### Practice Focus
# Master technical writing conventions

# %%
# Technical and Scientific Writing
print('C1 Writing: Technical and Scientific Writing')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of technical precision and process descriptions. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Technical precision**: Essential for advanced writing proficiency
# **Process descriptions**: Essential for advanced writing proficiency
# **Scientific method**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply technical precision in a professional context
# 2. **Task 2**: Demonstrate process descriptions in your writing
# 3. **Task 3**: Integrate scientific method effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 07',
    'topics_practiced': ['Technical precision', 'Process descriptions', 'Scientific method'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level technical and scientific writing. Please review my writing and provide detailed feedback on:
# 1. Technical precision
# 2. Process descriptions
# 3. Scientific method
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice technical and scientific writing at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice technical precision techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Technical precision, Process descriptions, Scientific method
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
