# %% [markdown]
# # C1 Writing 05: Advanced Cohesion and Coherence
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master discourse markers
# 2. Master referencing systems
# 3. Master paragraph transitions
# 4. Master text organization
# 5. Master flow

# %% [markdown]
# ## Advanced Cohesion and Coherence - C1 Writing
#
# Topics: Discourse markers, Referencing systems, Paragraph transitions, Text organization, Flow
#
# ### Practice Focus
# Create seamlessly connected texts

# %%
# Advanced Cohesion and Coherence
print('C1 Writing: Advanced Cohesion and Coherence')
print('Resources: academic journals, business publications, professional writing guides')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced writing at C1 level requires mastery of discourse markers and referencing systems. This module covers sophisticated techniques used in professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Discourse markers**: Essential for advanced writing proficiency
# **Referencing systems**: Essential for advanced writing proficiency
# **Paragraph transitions**: Essential for advanced writing proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced writing tasks:
#
# 1. **Task 1**: Apply discourse markers in a professional context
# 2. **Task 2**: Demonstrate referencing systems in your writing
# 3. **Task 3**: Integrate paragraph transitions effectively
# 4. **Task 4**: Create a comprehensive piece using all concepts

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Writing 05',
    'topics_practiced': ['Discourse markers', 'Referencing systems', 'Paragraph transitions'],
    'ai_feedback': 'Use ChatGPT or Claude for detailed writing feedback',
    'notes': 'Record your progress and insights here'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT Prompt for Feedback:
#
# ```
# I'm working on C1-level advanced cohesion and coherence. Please review my writing and provide detailed feedback on:
# 1. Discourse markers
# 2. Referencing systems
# 3. Paragraph transitions
# 4. Overall coherence and sophistication
# 5. Suggestions for improvement at advanced level
#
# [Paste your writing here]
# ```
#
# ### Claude Prompt for Practice:
#
# ```
# Help me practice advanced cohesion and coherence at C1 level. Provide:
# 1. A challenging writing task
# 2. Model examples of excellent writing
# 3. Specific criteria for advanced proficiency
# 4. Detailed constructive feedback on my attempts
# ```

# %% [markdown]
# ## Tasks
#
# 1. Study advanced examples and models
# 2. Practice discourse markers techniques
# 3. Get AI feedback on your writing
# 4. Revise and refine based on feedback
# 5. Build a portfolio of advanced writing samples
#
# ## Summary
#
# Mastered: Discourse markers, Referencing systems, Paragraph transitions
#
# **Next Steps**: Continue developing sophistication in academic and professional writing contexts.
