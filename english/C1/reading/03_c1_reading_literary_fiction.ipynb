# %% [markdown]
# # C1 Reading 03: Literary Fiction
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 50-55 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master literary devices
# 2. Master character analysis
# 3. Master themes and symbolism
# 4. Master author's style
# 5. Master cultural context

# %% [markdown]
# ## Literary Fiction - C1 Reading
#
# Topics: Literary devices, Character analysis, Themes and symbolism, Author's style, Cultural context
#
# ### Practice Focus
# Appreciate and analyze literary works

# %%
# Literary Fiction
print('C1 Reading: Literary Fiction')
print('Resources: academic journals, quality newspapers, literary works, professional publications')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced reading at C1 level requires mastery of literary devices and character analysis. This module develops sophisticated reading skills for complex authentic texts.
#
# ### Part 2: Key Concepts
#
# **Literary devices**: Essential for advanced reading proficiency
# **Character analysis**: Essential for advanced reading proficiency
# **Themes and symbolism**: Essential for advanced reading proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced reading tasks:
#
# 1. **Task 1**: Read texts featuring literary devices
# 2. **Task 2**: Practice character analysis skills
# 3. **Task 3**: Focus on themes and symbolism
# 4. **Task 4**: Comprehensive reading analysis

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Reading 03',
    'topics_practiced': ['Literary devices', 'Character analysis', 'Themes and symbolism'],
    'texts_read': 'List articles, books, or documents',
    'vocabulary': 'New advanced words learned',
    'notes': 'Key insights and comprehension notes'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Comprehension:
#
# ```
# I just read [title/article] focusing on literary fiction. Please:
# 1. Test my comprehension with challenging questions
# 2. Ask about literary devices
# 3. Check my understanding of character analysis
# 4. Discuss implicit meanings and nuances
# 5. Recommend similar challenging materials
# ```
#
# ### Claude for Analysis:
#
# ```
# Help me improve my literary fiction skills. Provide:
# 1. Reading strategies for this type of text
# 2. Common challenges at C1 level
# 3. Vocabulary building techniques
# 4. Recommended reading list
# ```

# %% [markdown]
# ## Tasks
#
# 1. Find appropriate challenging reading materials
# 2. Practice literary devices comprehension
# 3. Annotate and analyze the text
# 4. Discuss insights with AI
# 5. Build vocabulary from context
#
# ## Summary
#
# Mastered: Literary devices, Character analysis, Themes and symbolism
#
# **Next Steps**: Continue reading diverse authentic materials to maintain and enhance C1 proficiency.
