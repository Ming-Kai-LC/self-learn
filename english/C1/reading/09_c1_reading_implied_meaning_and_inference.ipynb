# %% [markdown]
# # C1 Reading 09: Implied Meaning and Inference
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master reading between lines
# 2. Master author's intent
# 3. Master tone and attitude
# 4. Master implicit information
# 5. Master subtle meanings

# %% [markdown]
# ## Implied Meaning and Inference - C1 Reading
#
# Topics: Reading between lines, Author's intent, Tone and attitude, Implicit information, Subtle meanings
#
# ### Practice Focus
# Understand implicit meanings in texts

# %%
# Implied Meaning and Inference
print('C1 Reading: Implied Meaning and Inference')
print('Resources: academic journals, quality newspapers, literary works, professional publications')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced reading at C1 level requires mastery of reading between lines and author's intent. This module develops sophisticated reading skills for complex authentic texts.
#
# ### Part 2: Key Concepts
#
# **Reading between lines**: Essential for advanced reading proficiency
# **Author's intent**: Essential for advanced reading proficiency
# **Tone and attitude**: Essential for advanced reading proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced reading tasks:
#
# 1. **Task 1**: Read texts featuring reading between lines
# 2. **Task 2**: Practice author's intent skills
# 3. **Task 3**: Focus on tone and attitude
# 4. **Task 4**: Comprehensive reading analysis

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Reading 09',
    'topics_practiced': ['Reading between lines', "Author's intent", 'Tone and attitude'],
    'texts_read': 'List articles, books, or documents',
    'vocabulary': 'New advanced words learned',
    'notes': 'Key insights and comprehension notes'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Comprehension:
#
# ```
# I just read [title/article] focusing on implied meaning and inference. Please:
# 1. Test my comprehension with challenging questions
# 2. Ask about reading between lines
# 3. Check my understanding of author's intent
# 4. Discuss implicit meanings and nuances
# 5. Recommend similar challenging materials
# ```
#
# ### Claude for Analysis:
#
# ```
# Help me improve my implied meaning and inference skills. Provide:
# 1. Reading strategies for this type of text
# 2. Common challenges at C1 level
# 3. Vocabulary building techniques
# 4. Recommended reading list
# ```

# %% [markdown]
# ## Tasks
#
# 1. Find appropriate challenging reading materials
# 2. Practice reading between lines comprehension
# 3. Annotate and analyze the text
# 4. Discuss insights with AI
# 5. Build vocabulary from context
#
# ## Summary
#
# Mastered: Reading between lines, Author's intent, Tone and attitude
#
# **Next Steps**: Continue reading diverse authentic materials to maintain and enhance C1 proficiency.
