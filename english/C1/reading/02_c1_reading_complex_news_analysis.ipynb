# %% [markdown]
# # C1 Reading 02: Complex News Analysis
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master in-depth articles
# 2. Master editorial analysis
# 3. Master multiple perspectives
# 4. Master bias detection
# 5. Master critical reading

# %% [markdown]
# ## Complex News Analysis - C1 Reading
#
# Topics: In-depth articles, Editorial analysis, Multiple perspectives, Bias detection, Critical reading
#
# ### Practice Focus
# Analyze sophisticated news content

# %%
# Complex News Analysis
print('C1 Reading: Complex News Analysis')
print('Resources: academic journals, quality newspapers, literary works, professional publications')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced reading at C1 level requires mastery of in-depth articles and editorial analysis. This module develops sophisticated reading skills for complex authentic texts.
#
# ### Part 2: Key Concepts
#
# **In-depth articles**: Essential for advanced reading proficiency
# **Editorial analysis**: Essential for advanced reading proficiency
# **Multiple perspectives**: Essential for advanced reading proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced reading tasks:
#
# 1. **Task 1**: Read texts featuring in-depth articles
# 2. **Task 2**: Practice editorial analysis skills
# 3. **Task 3**: Focus on multiple perspectives
# 4. **Task 4**: Comprehensive reading analysis

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Reading 02',
    'topics_practiced': ['In-depth articles', 'Editorial analysis', 'Multiple perspectives'],
    'texts_read': 'List articles, books, or documents',
    'vocabulary': 'New advanced words learned',
    'notes': 'Key insights and comprehension notes'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Comprehension:
#
# ```
# I just read [title/article] focusing on complex news analysis. Please:
# 1. Test my comprehension with challenging questions
# 2. Ask about in-depth articles
# 3. Check my understanding of editorial analysis
# 4. Discuss implicit meanings and nuances
# 5. Recommend similar challenging materials
# ```
#
# ### Claude for Analysis:
#
# ```
# Help me improve my complex news analysis skills. Provide:
# 1. Reading strategies for this type of text
# 2. Common challenges at C1 level
# 3. Vocabulary building techniques
# 4. Recommended reading list
# ```

# %% [markdown]
# ## Tasks
#
# 1. Find appropriate challenging reading materials
# 2. Practice in-depth articles comprehension
# 3. Annotate and analyze the text
# 4. Discuss insights with AI
# 5. Build vocabulary from context
#
# ## Summary
#
# Mastered: In-depth articles, Editorial analysis, Multiple perspectives
#
# **Next Steps**: Continue reading diverse authentic materials to maintain and enhance C1 proficiency.
