# %% [markdown]
# # C1 Reading 05: Legal and Technical Documents
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 50-55 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master legal language
# 2. Master contracts
# 3. Master terms and conditions
# 4. Master technical specifications
# 5. Master formal register

# %% [markdown]
# ## Legal and Technical Documents - C1 Reading
#
# Topics: Legal language, Contracts, Terms and conditions, Technical specifications, Formal register
#
# ### Practice Focus
# Understand formal legal and technical texts

# %%
# Legal and Technical Documents
print('C1 Reading: Legal and Technical Documents')
print('Resources: academic journals, quality newspapers, literary works, professional publications')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced reading at C1 level requires mastery of legal language and contracts. This module develops sophisticated reading skills for complex authentic texts.
#
# ### Part 2: Key Concepts
#
# **Legal language**: Essential for advanced reading proficiency
# **Contracts**: Essential for advanced reading proficiency
# **Terms and conditions**: Essential for advanced reading proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced reading tasks:
#
# 1. **Task 1**: Read texts featuring legal language
# 2. **Task 2**: Practice contracts skills
# 3. **Task 3**: Focus on terms and conditions
# 4. **Task 4**: Comprehensive reading analysis

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Reading 05',
    'topics_practiced': ['Legal language', 'Contracts', 'Terms and conditions'],
    'texts_read': 'List articles, books, or documents',
    'vocabulary': 'New advanced words learned',
    'notes': 'Key insights and comprehension notes'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Comprehension:
#
# ```
# I just read [title/article] focusing on legal and technical documents. Please:
# 1. Test my comprehension with challenging questions
# 2. Ask about legal language
# 3. Check my understanding of contracts
# 4. Discuss implicit meanings and nuances
# 5. Recommend similar challenging materials
# ```
#
# ### Claude for Analysis:
#
# ```
# Help me improve my legal and technical documents skills. Provide:
# 1. Reading strategies for this type of text
# 2. Common challenges at C1 level
# 3. Vocabulary building techniques
# 4. Recommended reading list
# ```

# %% [markdown]
# ## Tasks
#
# 1. Find appropriate challenging reading materials
# 2. Practice legal language comprehension
# 3. Annotate and analyze the text
# 4. Discuss insights with AI
# 5. Build vocabulary from context
#
# ## Summary
#
# Mastered: Legal language, Contracts, Terms and conditions
#
# **Next Steps**: Continue reading diverse authentic materials to maintain and enhance C1 proficiency.
