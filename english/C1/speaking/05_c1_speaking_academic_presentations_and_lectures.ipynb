# %% [markdown]
# # C1 Speaking 05: Academic Presentations and Lectures
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 50-55 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master academic discourse
# 2. Master citing sources orally
# 3. Master complex explanations
# 4. Master scholarly discussions
# 5. Master conference presentations

# %% [markdown]
# ## Academic Presentations and Lectures - C1 Speaking
#
# Topics: Academic discourse, Citing sources orally, Complex explanations, Scholarly discussions, Conference presentations
#
# ### Practice Focus
# Deliver academic presentations confidently

# %%
# Academic Presentations and Lectures
print('C1 Speaking: Academic Presentations and Lectures')
print('Resources: Gliglish AI, Speak.com, native conversations, TED talks')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced speaking at C1 level requires mastery of academic discourse and citing sources orally. This module develops sophisticated oral communication skills for professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Academic discourse**: Essential for advanced speaking proficiency
# **Citing sources orally**: Essential for advanced speaking proficiency
# **Complex explanations**: Essential for advanced speaking proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced speaking tasks:
#
# 1. **Task 1**: Practice academic discourse with AI
# 2. **Task 2**: Demonstrate citing sources orally in conversations
# 3. **Task 3**: Apply complex explanations in role-plays
# 4. **Task 4**: Record and analyze your performance

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Speaking 05',
    'topics_practiced': ['Academic discourse', 'Citing sources orally', 'Complex explanations'],
    'ai_tools': ['Gliglish AI', 'Speak.com', 'ChatGPT voice'],
    'recording_url': 'Save your practice recordings here',
    'notes': 'Record your progress and areas for improvement'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Academic Presentations and Lectures
# Level: C1 Advanced
# Focus areas:
# - Academic discourse
# - Citing sources orally
# - Complex explanations
#
# Request detailed feedback on fluency, accuracy, and sophistication.
# ```
#
# ### ChatGPT Voice Prompt:
#
# ```
# I'm practicing academic presentations and lectures at C1 level. Let's have a conversation where you:
# 1. Challenge me with sophisticated topics
# 2. Ask follow-up questions
# 3. Provide immediate feedback on my speaking
# 4. Suggest improvements for advanced proficiency
# ```

# %% [markdown]
# ## Tasks
#
# 1. Review model examples and native speakers
# 2. Practice academic discourse with AI tools
# 3. Record yourself and self-evaluate
# 4. Get feedback from AI or native speakers
# 5. Refine and practice again
#
# ## Summary
#
# Mastered: Academic discourse, Citing sources orally, Complex explanations
#
# **Next Steps**: Continue developing near-native fluency and sophistication in all speaking contexts.
