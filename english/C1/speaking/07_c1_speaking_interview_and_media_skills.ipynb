# %% [markdown]
# # C1 Speaking 07: Interview and Media Skills
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master media interviews
# 2. Master sound bites
# 3. Master message control
# 4. Master handling tough questions
# 5. Master public speaking

# %% [markdown]
# ## Interview and Media Skills - C1 Speaking
#
# Topics: Media interviews, Sound bites, Message control, Handling tough questions, Public speaking
#
# ### Practice Focus
# Excel in interview and media situations

# %%
# Interview and Media Skills
print('C1 Speaking: Interview and Media Skills')
print('Resources: Gliglish AI, Speak.com, native conversations, TED talks')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced speaking at C1 level requires mastery of media interviews and sound bites. This module develops sophisticated oral communication skills for professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Media interviews**: Essential for advanced speaking proficiency
# **Sound bites**: Essential for advanced speaking proficiency
# **Message control**: Essential for advanced speaking proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced speaking tasks:
#
# 1. **Task 1**: Practice media interviews with AI
# 2. **Task 2**: Demonstrate sound bites in conversations
# 3. **Task 3**: Apply message control in role-plays
# 4. **Task 4**: Record and analyze your performance

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Speaking 07',
    'topics_practiced': ['Media interviews', 'Sound bites', 'Message control'],
    'ai_tools': ['Gliglish AI', 'Speak.com', 'ChatGPT voice'],
    'recording_url': 'Save your practice recordings here',
    'notes': 'Record your progress and areas for improvement'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Interview and Media Skills
# Level: C1 Advanced
# Focus areas:
# - Media interviews
# - Sound bites
# - Message control
#
# Request detailed feedback on fluency, accuracy, and sophistication.
# ```
#
# ### ChatGPT Voice Prompt:
#
# ```
# I'm practicing interview and media skills at C1 level. Let's have a conversation where you:
# 1. Challenge me with sophisticated topics
# 2. Ask follow-up questions
# 3. Provide immediate feedback on my speaking
# 4. Suggest improvements for advanced proficiency
# ```

# %% [markdown]
# ## Tasks
#
# 1. Review model examples and native speakers
# 2. Practice media interviews with AI tools
# 3. Record yourself and self-evaluate
# 4. Get feedback from AI or native speakers
# 5. Refine and practice again
#
# ## Summary
#
# Mastered: Media interviews, Sound bites, Message control
#
# **Next Steps**: Continue developing near-native fluency and sophistication in all speaking contexts.
