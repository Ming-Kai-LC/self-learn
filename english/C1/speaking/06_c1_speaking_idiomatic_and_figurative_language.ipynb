# %% [markdown]
# # C1 Speaking 06: Idiomatic and Figurative Language
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master advanced idioms
# 2. Master metaphors
# 3. Master phrasal verbs
# 4. Master cultural references
# 5. Master native expressions

# %% [markdown]
# ## Idiomatic and Figurative Language - C1 Speaking
#
# Topics: Advanced idioms, Metaphors, Phrasal verbs, Cultural references, Native expressions
#
# ### Practice Focus
# Use idiomatic language naturally

# %%
# Idiomatic and Figurative Language
print('C1 Speaking: Idiomatic and Figurative Language')
print('Resources: Gliglish AI, Speak.com, native conversations, TED talks')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced speaking at C1 level requires mastery of advanced idioms and metaphors. This module develops sophisticated oral communication skills for professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Advanced idioms**: Essential for advanced speaking proficiency
# **Metaphors**: Essential for advanced speaking proficiency
# **Phrasal verbs**: Essential for advanced speaking proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced speaking tasks:
#
# 1. **Task 1**: Practice advanced idioms with AI
# 2. **Task 2**: Demonstrate metaphors in conversations
# 3. **Task 3**: Apply phrasal verbs in role-plays
# 4. **Task 4**: Record and analyze your performance

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Speaking 06',
    'topics_practiced': ['Advanced idioms', 'Metaphors', 'Phrasal verbs'],
    'ai_tools': ['Gliglish AI', 'Speak.com', 'ChatGPT voice'],
    'recording_url': 'Save your practice recordings here',
    'notes': 'Record your progress and areas for improvement'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Idiomatic and Figurative Language
# Level: C1 Advanced
# Focus areas:
# - Advanced idioms
# - Metaphors
# - Phrasal verbs
#
# Request detailed feedback on fluency, accuracy, and sophistication.
# ```
#
# ### ChatGPT Voice Prompt:
#
# ```
# I'm practicing idiomatic and figurative language at C1 level. Let's have a conversation where you:
# 1. Challenge me with sophisticated topics
# 2. Ask follow-up questions
# 3. Provide immediate feedback on my speaking
# 4. Suggest improvements for advanced proficiency
# ```

# %% [markdown]
# ## Tasks
#
# 1. Review model examples and native speakers
# 2. Practice advanced idioms with AI tools
# 3. Record yourself and self-evaluate
# 4. Get feedback from AI or native speakers
# 5. Refine and practice again
#
# ## Summary
#
# Mastered: Advanced idioms, Metaphors, Phrasal verbs
#
# **Next Steps**: Continue developing near-native fluency and sophistication in all speaking contexts.
