# %% [markdown]
# # C1 Speaking 13: Facilitating Meetings and Workshops
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 50-55 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master meeting management
# 2. Master facilitation techniques
# 3. Master consensus building
# 4. Master time management
# 5. Master participation engagement

# %% [markdown]
# ## Facilitating Meetings and Workshops - C1 Speaking
#
# Topics: Meeting management, Facilitation techniques, Consensus building, Time management, Participation engagement
#
# ### Practice Focus
# Facilitate professional meetings effectively

# %%
# Facilitating Meetings and Workshops
print('C1 Speaking: Facilitating Meetings and Workshops')
print('Resources: Gliglish AI, Speak.com, native conversations, TED talks')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced speaking at C1 level requires mastery of meeting management and facilitation techniques. This module develops sophisticated oral communication skills for professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Meeting management**: Essential for advanced speaking proficiency
# **Facilitation techniques**: Essential for advanced speaking proficiency
# **Consensus building**: Essential for advanced speaking proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced speaking tasks:
#
# 1. **Task 1**: Practice meeting management with AI
# 2. **Task 2**: Demonstrate facilitation techniques in conversations
# 3. **Task 3**: Apply consensus building in role-plays
# 4. **Task 4**: Record and analyze your performance

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Speaking 13',
    'topics_practiced': ['Meeting management', 'Facilitation techniques', 'Consensus building'],
    'ai_tools': ['Gliglish AI', 'Speak.com', 'ChatGPT voice'],
    'recording_url': 'Save your practice recordings here',
    'notes': 'Record your progress and areas for improvement'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Facilitating Meetings and Workshops
# Level: C1 Advanced
# Focus areas:
# - Meeting management
# - Facilitation techniques
# - Consensus building
#
# Request detailed feedback on fluency, accuracy, and sophistication.
# ```
#
# ### ChatGPT Voice Prompt:
#
# ```
# I'm practicing facilitating meetings and workshops at C1 level. Let's have a conversation where you:
# 1. Challenge me with sophisticated topics
# 2. Ask follow-up questions
# 3. Provide immediate feedback on my speaking
# 4. Suggest improvements for advanced proficiency
# ```

# %% [markdown]
# ## Tasks
#
# 1. Review model examples and native speakers
# 2. Practice meeting management with AI tools
# 3. Record yourself and self-evaluate
# 4. Get feedback from AI or native speakers
# 5. Refine and practice again
#
# ## Summary
#
# Mastered: Meeting management, Facilitation techniques, Consensus building
#
# **Next Steps**: Continue developing near-native fluency and sophistication in all speaking contexts.
