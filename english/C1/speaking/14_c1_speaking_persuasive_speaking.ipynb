# %% [markdown]
# # C1 Speaking 14: Persuasive Speaking
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master rhetorical devices
# 2. Master emotional appeals
# 3. Master logical arguments
# 4. Master credibility building
# 5. Master call to action

# %% [markdown]
# ## Persuasive Speaking - C1 Speaking
#
# Topics: Rhetorical devices, Emotional appeals, Logical arguments, Credibility building, Call to action
#
# ### Practice Focus
# Deliver persuasive speeches and pitches

# %%
# Persuasive Speaking
print('C1 Speaking: Persuasive Speaking')
print('Resources: Gliglish AI, Speak.com, native conversations, TED talks')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced speaking at C1 level requires mastery of rhetorical devices and emotional appeals. This module develops sophisticated oral communication skills for professional and academic contexts.
#
# ### Part 2: Key Concepts
#
# **Rhetorical devices**: Essential for advanced speaking proficiency
# **Emotional appeals**: Essential for advanced speaking proficiency
# **Logical arguments**: Essential for advanced speaking proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced speaking tasks:
#
# 1. **Task 1**: Practice rhetorical devices with AI
# 2. **Task 2**: Demonstrate emotional appeals in conversations
# 3. **Task 3**: Apply logical arguments in role-plays
# 4. **Task 4**: Record and analyze your performance

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Speaking 14',
    'topics_practiced': ['Rhetorical devices', 'Emotional appeals', 'Logical arguments'],
    'ai_tools': ['Gliglish AI', 'Speak.com', 'ChatGPT voice'],
    'recording_url': 'Save your practice recordings here',
    'notes': 'Record your progress and areas for improvement'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### Gliglish AI Practice:
#
# ```
# Topic: Persuasive Speaking
# Level: C1 Advanced
# Focus areas:
# - Rhetorical devices
# - Emotional appeals
# - Logical arguments
#
# Request detailed feedback on fluency, accuracy, and sophistication.
# ```
#
# ### ChatGPT Voice Prompt:
#
# ```
# I'm practicing persuasive speaking at C1 level. Let's have a conversation where you:
# 1. Challenge me with sophisticated topics
# 2. Ask follow-up questions
# 3. Provide immediate feedback on my speaking
# 4. Suggest improvements for advanced proficiency
# ```

# %% [markdown]
# ## Tasks
#
# 1. Review model examples and native speakers
# 2. Practice rhetorical devices with AI tools
# 3. Record yourself and self-evaluate
# 4. Get feedback from AI or native speakers
# 5. Refine and practice again
#
# ## Summary
#
# Mastered: Rhetorical devices, Emotional appeals, Logical arguments
#
# **Next Steps**: Continue developing near-native fluency and sophistication in all speaking contexts.
