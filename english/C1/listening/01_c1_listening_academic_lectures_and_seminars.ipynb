# %% [markdown]
# # C1 Listening 01: Academic Lectures and Seminars
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master complex lectures
# 2. Master note-taking strategies
# 3. Master following arguments
# 4. Master technical vocabulary
# 5. Master lecture structure

# %% [markdown]
# ## Academic Lectures and Seminars - C1 Listening
#
# Topics: Complex lectures, Note-taking strategies, Following arguments, Technical vocabulary, Lecture structure
#
# ### Practice Focus
# Comprehend advanced academic lectures

# %%
# Academic Lectures and Seminars
print('C1 Listening: Academic Lectures and Seminars')
print('Resources: TED talks, podcasts, BBC Radio, academic lectures, authentic media')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced listening at C1 level requires mastery of complex lectures and note-taking strategies. This module develops sophisticated listening comprehension for complex authentic materials.
#
# ### Part 2: Key Concepts
#
# **Complex lectures**: Essential for advanced listening proficiency
# **Note-taking strategies**: Essential for advanced listening proficiency
# **Following arguments**: Essential for advanced listening proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced listening tasks:
#
# 1. **Task 1**: Listen to materials featuring complex lectures
# 2. **Task 2**: Practice note-taking strategies recognition
# 3. **Task 3**: Focus on following arguments
# 4. **Task 4**: Comprehensive listening with all skills

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Listening 01',
    'topics_practiced': ['Complex lectures', 'Note-taking strategies', 'Following arguments'],
    'materials': 'List audio/video materials used',
    'comprehension_rate': '% understood',
    'notes': 'Record difficult sections and vocabulary'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Comprehension Check:
#
# ```
# I just listened to [material] focusing on academic lectures and seminars. Please:
# 1. Ask me comprehension questions to test my understanding
# 2. Focus on complex lectures
# 3. Check if I caught note-taking strategies
# 4. Provide feedback on what I might have missed
# 5. Suggest similar materials for practice
# ```
#
# ### Claude for Analysis:
#
# ```
# Help me improve my academic lectures and seminars skills. Provide:
# 1. Strategies for better comprehension
# 2. Common challenges at C1 level
# 3. Recommended authentic materials
# 4. Progress tracking methods
# ```

# %% [markdown]
# ## Tasks
#
# 1. Find appropriate authentic listening materials
# 2. Practice complex lectures comprehension
# 3. Take notes and summarize what you heard
# 4. Verify comprehension with transcripts
# 5. Repeat with increasingly challenging content
#
# ## Summary
#
# Mastered: Complex lectures, Note-taking strategies, Following arguments
#
# **Next Steps**: Continue building listening stamina and comprehension of authentic materials at natural speed.
