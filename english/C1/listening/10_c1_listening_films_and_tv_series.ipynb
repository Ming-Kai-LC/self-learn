# %% [markdown]
# # C1 Listening 10: Films and TV Series
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 50-55 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master movie dialogues
# 2. Master tv series
# 3. Master slang and colloquialisms
# 4. Master cultural references
# 5. Master entertainment listening

# %% [markdown]
# ## Films and TV Series - C1 Listening
#
# Topics: Movie dialogues, TV series, Slang and colloquialisms, Cultural references, Entertainment listening
#
# ### Practice Focus
# Enjoy authentic entertainment media

# %%
# Films and TV Series
print('C1 Listening: Films and TV Series')
print('Resources: TED talks, podcasts, BBC Radio, academic lectures, authentic media')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced listening at C1 level requires mastery of movie dialogues and tv series. This module develops sophisticated listening comprehension for complex authentic materials.
#
# ### Part 2: Key Concepts
#
# **Movie dialogues**: Essential for advanced listening proficiency
# **TV series**: Essential for advanced listening proficiency
# **Slang and colloquialisms**: Essential for advanced listening proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced listening tasks:
#
# 1. **Task 1**: Listen to materials featuring movie dialogues
# 2. **Task 2**: Practice tv series recognition
# 3. **Task 3**: Focus on slang and colloquialisms
# 4. **Task 4**: Comprehensive listening with all skills

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Listening 10',
    'topics_practiced': ['Movie dialogues', 'TV series', 'Slang and colloquialisms'],
    'materials': 'List audio/video materials used',
    'comprehension_rate': '% understood',
    'notes': 'Record difficult sections and vocabulary'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Comprehension Check:
#
# ```
# I just listened to [material] focusing on films and tv series. Please:
# 1. Ask me comprehension questions to test my understanding
# 2. Focus on movie dialogues
# 3. Check if I caught tv series
# 4. Provide feedback on what I might have missed
# 5. Suggest similar materials for practice
# ```
#
# ### Claude for Analysis:
#
# ```
# Help me improve my films and tv series skills. Provide:
# 1. Strategies for better comprehension
# 2. Common challenges at C1 level
# 3. Recommended authentic materials
# 4. Progress tracking methods
# ```

# %% [markdown]
# ## Tasks
#
# 1. Find appropriate authentic listening materials
# 2. Practice movie dialogues comprehension
# 3. Take notes and summarize what you heard
# 4. Verify comprehension with transcripts
# 5. Repeat with increasingly challenging content
#
# ## Summary
#
# Mastered: Movie dialogues, TV series, Slang and colloquialisms
#
# **Next Steps**: Continue building listening stamina and comprehension of authentic materials at natural speed.
