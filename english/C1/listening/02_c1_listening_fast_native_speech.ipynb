# %% [markdown]
# # C1 Listening 02: Fast Native Speech
#
# **Difficulty**: ⭐⭐⭐
# **Time**: 45-50 min
# **Prerequisites**: B2 level
#
# ## Learning Objectives
#
# By the end of this module, you will:
#
# 1. Master natural speed
# 2. Master connected speech
# 3. Master elision and assimilation
# 4. Master reduced forms
# 5. Master rapid comprehension

# %% [markdown]
# ## Fast Native Speech - C1 Listening
#
# Topics: Natural speed, Connected speech, Elision and assimilation, Reduced forms, Rapid comprehension
#
# ### Practice Focus
# Understand native speakers at natural speed

# %%
# Fast Native Speech
print('C1 Listening: Fast Native Speech')
print('Resources: TED talks, podcasts, BBC Radio, academic lectures, authentic media')

# %% [markdown]
# ## Content
#
# ### Part 1: Introduction
#
# Advanced listening at C1 level requires mastery of natural speed and connected speech. This module develops sophisticated listening comprehension for complex authentic materials.
#
# ### Part 2: Key Concepts
#
# **Natural speed**: Essential for advanced listening proficiency
# **Connected speech**: Essential for advanced listening proficiency
# **Elision and assimilation**: Essential for advanced listening proficiency
#
# ### Part 3: Practice Exercises
#
# Complete the following advanced listening tasks:
#
# 1. **Task 1**: Listen to materials featuring natural speed
# 2. **Task 2**: Practice connected speech recognition
# 3. **Task 3**: Focus on elision and assimilation
# 4. **Task 4**: Comprehensive listening with all skills

# %%
# Practice Log
from datetime import datetime

practice_log = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'module': 'C1 Listening 02',
    'topics_practiced': ['Natural speed', 'Connected speech', 'Elision and assimilation'],
    'materials': 'List audio/video materials used',
    'comprehension_rate': '% understood',
    'notes': 'Record difficult sections and vocabulary'
}

print('Practice Log Created')
print(f"Module: {practice_log['module']}")
print(f"Topics: {', '.join(practice_log['topics_practiced'])}")

# %% [markdown]
# ## AI Integration
#
# ### ChatGPT for Comprehension Check:
#
# ```
# I just listened to [material] focusing on fast native speech. Please:
# 1. Ask me comprehension questions to test my understanding
# 2. Focus on natural speed
# 3. Check if I caught connected speech
# 4. Provide feedback on what I might have missed
# 5. Suggest similar materials for practice
# ```
#
# ### Claude for Analysis:
#
# ```
# Help me improve my fast native speech skills. Provide:
# 1. Strategies for better comprehension
# 2. Common challenges at C1 level
# 3. Recommended authentic materials
# 4. Progress tracking methods
# ```

# %% [markdown]
# ## Tasks
#
# 1. Find appropriate authentic listening materials
# 2. Practice natural speed comprehension
# 3. Take notes and summarize what you heard
# 4. Verify comprehension with transcripts
# 5. Repeat with increasingly challenging content
#
# ## Summary
#
# Mastered: Natural speed, Connected speech, Elision and assimilation
#
# **Next Steps**: Continue building listening stamina and comprehension of authentic materials at natural speed.
