# %% [markdown]
# # Module 18: As...As Comparisons - Equality and Inequality - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks focusing on as...as patterns

# %% [markdown]
# ## Task 1: Finding Things in Common - Interview
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# - Work in pairs or small groups
# - Use as...as patterns throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use as...as patterns naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 1: Finding Things in Common - Interview
print("Finding Things in Common - Interview")
print("=" * 60)
print(f"\nUse as...as patterns in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: As...As Challenge - Finding Equalities
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# - Work in pairs or small groups
# - Use as...as patterns throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use as...as patterns naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 2: As...As Challenge - Finding Equalities
print("As...As Challenge - Finding Equalities")
print("=" * 60)
print(f"\nUse as...as patterns in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: Equality vs Inequality Sorting Game
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# - Work in pairs or small groups
# - Use as...as patterns throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use as...as patterns naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 3: Equality vs Inequality Sorting Game
print("Equality vs Inequality Sorting Game")
print("=" * 60)
print(f"\nUse as...as patterns in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Myth Busting - Is X Really As...As Y?
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# - Work in pairs or small groups
# - Use as...as patterns throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use as...as patterns naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 4: Myth Busting - Is X Really As...As Y?
print("Myth Busting - Is X Really As...As Y?")
print("=" * 60)
print(f"\nUse as...as patterns in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: Comparing Twins or Similar Things
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# - Work in pairs or small groups
# - Use as...as patterns throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use as...as patterns naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 5: Comparing Twins or Similar Things
print("Comparing Twins or Similar Things")
print("=" * 60)
print(f"\nUse as...as patterns in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: As Soon As Possible - Urgent Tasks Role Play
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# - Work in pairs or small groups
# - Use as...as patterns throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use as...as patterns naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 6: As Soon As Possible - Urgent Tasks Role Play
print("As Soon As Possible - Urgent Tasks Role Play")
print("=" * 60)
print(f"\nUse as...as patterns in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Finding Equal Qualities in Different Things
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# - Work in pairs or small groups
# - Use as...as patterns throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use as...as patterns naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 7: Finding Equal Qualities in Different Things
print("Finding Equal Qualities in Different Things")
print("=" * 60)
print(f"\nUse as...as patterns in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Similarity Search Activity
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# - Work in pairs or small groups
# - Use as...as patterns throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use as...as patterns naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 8: Similarity Search Activity
print("Similarity Search Activity")
print("=" * 60)
print(f"\nUse as...as patterns in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")
