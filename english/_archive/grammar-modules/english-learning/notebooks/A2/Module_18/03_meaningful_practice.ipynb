# %% [markdown]
# # Module 18: As...As Comparisons - Equality and Inequality - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using as...as patterns in real contexts

# %% [markdown]
# ## Activity 1: Things That Are the Same in My Life
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# 1. Write 8-10 sentences using as...as patterns
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using as...as patterns to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 1: Things That Are the Same in My Life
print("Things That Are the Same in My Life")
print("=" * 60)
print(f"\nUse as...as patterns to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 2: Not As...As - Finding Differences
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# 1. Write 8-10 sentences using as...as patterns
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using as...as patterns to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 2: Not As...As - Finding Differences
print("Not As...As - Finding Differences")
print("=" * 60)
print(f"\nUse as...as patterns to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 3: Equal Comparisons - People I Know
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# 1. Write 8-10 sentences using as...as patterns
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using as...as patterns to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 3: Equal Comparisons - People I Know
print("Equal Comparisons - People I Know")
print("=" * 60)
print(f"\nUse as...as patterns to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 4: As...As Challenges and Achievements
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# 1. Write 8-10 sentences using as...as patterns
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using as...as patterns to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 4: As...As Challenges and Achievements
print("As...As Challenges and Achievements")
print("=" * 60)
print(f"\nUse as...as patterns to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 5: Comparing Similarities Between Cities/Countries
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# 1. Write 8-10 sentences using as...as patterns
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using as...as patterns to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 5: Comparing Similarities Between Cities/Countries
print("Comparing Similarities Between Cities/Countries")
print("=" * 60)
print(f"\nUse as...as patterns to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 6: As Good As or Better Than?
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# 1. Write 8-10 sentences using as...as patterns
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using as...as patterns to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 6: As Good As or Better Than?
print("As Good As or Better Than?")
print("=" * 60)
print(f"\nUse as...as patterns to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 7: Things That Aren't As Good As They Used To Be
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# 1. Write 8-10 sentences using as...as patterns
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using as...as patterns to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 7: Things That Aren't As Good As They Used To Be
print("Things That Aren't As Good As They Used To Be")
print("=" * 60)
print(f"\nUse as...as patterns to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 8: As Much/Many As Comparisons
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# 1. Write 8-10 sentences using as...as patterns
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using as...as patterns to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 8: As Much/Many As Comparisons
print("As Much/Many As Comparisons")
print("=" * 60)
print(f"\nUse as...as patterns to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 9: Equal Abilities and Skills
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# 1. Write 8-10 sentences using as...as patterns
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using as...as patterns to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 9: Equal Abilities and Skills
print("Equal Abilities and Skills")
print("=" * 60)
print(f"\nUse as...as patterns to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 10: As Soon As Possible - My Plans
#
# **Comparison Focus:** as...as patterns
#
# ### Instructions:
# 1. Write 8-10 sentences using as...as patterns
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using as...as patterns to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 10: As Soon As Possible - My Plans
print("As Soon As Possible - My Plans")
print("=" * 60)
print(f"\nUse as...as patterns to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")
