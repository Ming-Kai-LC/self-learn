# %% [markdown]
# # Module 02: Past Continuous vs Past Simple - Phase 2: Controlled Practice
#
# ## Overview
# 85 exercises to master the difference between past continuous and past simple
#
# **Exercise Types:**
# - Tense Identification (10)
# - Choose Correct Tense (15)
# - Complete with Correct Form (15)
# - When/While Sentences (10)
# - Error Correction (10)
# - Interrupted Actions (10)
# - Parallel Actions (5)
# - Time Markers (5)
# - Mixed Sentences (10)
# - Context Application (5)
#
# **Total: 85 exercises** *(Enhanced for stronger grammar foundation)*

# %% [markdown]
# ## Exercise Set: Tense Identification (10 exercises)
#
# **Focus:** Identify whether past simple or past continuous should be used

# %%
# Tense Identification Exercises
print("Tense Identification")
print("=" * 60)

for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise]")

print("\n[Answers with explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set: Choose Correct Tense (15 exercises)
#
# **Focus:** Select the appropriate tense for each sentence

# %%
# Choose Correct Tense Exercises
print("Choose Correct Tense")
print("=" * 60)

for i in range(1, 15 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise]")

print("\n[Answers with explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set: Complete with Correct Form (15 exercises)
#
# **Focus:** Fill gaps with correct form of given verbs

# %%
# Complete with Correct Form Exercises
print("Complete with Correct Form")
print("=" * 60)

for i in range(1, 15 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise]")

print("\n[Answers with explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set: When/While Sentences (10 exercises)
#
# **Focus:** Complete sentences using when/while appropriately

# %%
# When/While Sentences Exercises
print("When/While Sentences")
print("=" * 60)

for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise]")

print("\n[Answers with explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set: Error Correction (10 exercises)
#
# **Focus:** Find and correct tense errors

# %%
# Error Correction Exercises
print("Error Correction")
print("=" * 60)

for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise]")

print("\n[Answers with explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set: Interrupted Actions (10 exercises)
#
# **Focus:** Describe interrupted actions correctly

# %%
# Interrupted Actions Exercises
print("Interrupted Actions")
print("=" * 60)

for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise]")

print("\n[Answers with explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set: Parallel Actions (5 exercises)
#
# **Focus:** Describe simultaneous actions in the past

# %%
# Parallel Actions Exercises
print("Parallel Actions")
print("=" * 60)

for i in range(1, 5 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise]")

print("\n[Answers with explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set: Time Markers (5 exercises)
#
# **Focus:** Match time markers with appropriate tenses

# %%
# Time Markers Exercises
print("Time Markers")
print("=" * 60)

for i in range(1, 5 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise]")

print("\n[Answers with explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set: Mixed Sentences (10 exercises)
#
# **Focus:** Convert between tenses and combine them

# %%
# Mixed Sentences Exercises
print("Mixed Sentences")
print("=" * 60)

for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise]")

print("\n[Answers with explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set: Context Application (5 exercises)
#
# **Focus:** Use both tenses in story contexts

# %%
# Context Application Exercises
print("Context Application")
print("=" * 60)

for i in range(1, 5 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise]")

print("\n[Answers with explanations at end of notebook]")
