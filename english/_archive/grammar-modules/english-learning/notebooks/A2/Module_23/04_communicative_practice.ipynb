# %% [markdown]
# # A2 Module 23: Relative Clauses - Who, Which, That, Where
# ## Phase 4: Communicative Practice
#
# **Total Tasks:** 8
# **Focus:** Real-world communication with relative clauses
#
# ---
#
# ## Welcome to Communicative Practice!
#
# In this final phase, you'll use relative clauses in authentic communication scenarios.
#
# ### Task Philosophy
#
# - Focus on COMMUNICATION, not perfection
# - Use natural, conversational language
# - Mistakes are okay - fluency is the goal
# - Apply what you've learned naturally
#
# ### Task Structure
#
# Each task presents a real-world scenario where you need to communicate using the grammar you've learned.
#
# **Let's communicate!**
#
# ---

# %% [markdown]
# ## Task 1: Describing People Role-Play
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with relative clauses
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the relative clauses structures naturally

# %%
# Task 1: Describing People Role-Play

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 2: Lost and Found Descriptions
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with relative clauses
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the relative clauses structures naturally

# %%
# Task 2: Lost and Found Descriptions

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 3: Travel Guide Creation
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with relative clauses
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the relative clauses structures naturally

# %%
# Task 3: Travel Guide Creation

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 4: Celebrity Description Game
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with relative clauses
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the relative clauses structures naturally

# %%
# Task 4: Celebrity Description Game

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 5: Ideal Partner/Friend Description
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with relative clauses
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the relative clauses structures naturally

# %%
# Task 5: Ideal Partner/Friend Description

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 6: Place Recommendations
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with relative clauses
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the relative clauses structures naturally

# %%
# Task 6: Place Recommendations

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 7: Detailed Product Reviews
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with relative clauses
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the relative clauses structures naturally

# %%
# Task 7: Detailed Product Reviews

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 8: Story Enhancement with Details
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with relative clauses
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the relative clauses structures naturally

# %%
# Task 8: Story Enhancement with Details

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ---
#
# ## 🎉 Module 23 Complete!
#
# Congratulations! You've finished **Relative Clauses - Who, Which, That, Where**!
#
# ### What You've Achieved
#
# [DONE] Completed 15 introduction sections
# [DONE] Practiced through 85 exercises
# [DONE] Created 10 personalized activities
# [DONE] Communicated in 8 real-world tasks
#
# ### Mastery Checklist
#
# Can you confidently:
# - [ ] Use 'who' for people in relative clauses
# - [ ] Use 'which' and 'that' for things in relative clauses
# - [ ] Use 'where' for places in relative clauses
# - [ ] Form sentences with relative clauses correctly
# - [ ] Understand defining relative clauses (no commas at A2)
#
# ### Time Investment
#
# You've invested approximately 5-6 hours in this module. Well done!
#
# ### Next Steps
#
# Continue to **Module 24: Question Formation - Comprehensive Review Across All Tenses**
#
# ### Spaced Repetition
#
# Review this module after:
# - 1 day
# - 3 days
# - 7 days
# - 14 days
# - 30 days
#
# ---
#
# Progress: Module Complete! 4 of 4 phases done
