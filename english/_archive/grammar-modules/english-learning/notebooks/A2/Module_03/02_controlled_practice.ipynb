# %% [markdown]
# # Module 03: Past Continuous for Interrupted Actions - Phase 2: Controlled Practice

# %% [markdown]
# ## Section 1
#
# Content for Controlled Practice

# %%
# Section 1
print("Section 1")

# %% [markdown]
# ## Section 2
#
# Content for Controlled Practice

# %%
# Section 2
print("Section 2")

# %% [markdown]
# ## Section 3
#
# Content for Controlled Practice

# %%
# Section 3
print("Section 3")

# %% [markdown]
# ## Section 4
#
# Content for Controlled Practice

# %%
# Section 4
print("Section 4")

# %% [markdown]
# ## Section 5
#
# Content for Controlled Practice

# %%
# Section 5
print("Section 5")

# %% [markdown]
# ## Section 6
#
# Content for Controlled Practice

# %%
# Section 6
print("Section 6")

# %% [markdown]
# ## Section 7
#
# Content for Controlled Practice

# %%
# Section 7
print("Section 7")

# %% [markdown]
# ## Section 8
#
# Content for Controlled Practice

# %%
# Section 8
print("Section 8")
