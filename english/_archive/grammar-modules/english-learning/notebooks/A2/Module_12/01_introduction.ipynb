# %% [markdown]
# # Module 12: Must/Have To - Obligation and Necessity - Phase 1: Introduction
#
# ## Learning Objectives
# - Form sentences with must and have to for obligations
# - Distinguish between must (internal obligation) and have to (external rules)
# - Use has to/have to correctly with different subjects
# - Form questions and negatives with have to (do/does + have to)
# - Understand when to use must vs have to in context
#
# **Target Level:** A2
# **Estimated Time:** 5-6 hours
# **Modal Focus:** must/have to
#
# ## Important Modal Verb Rules
#
# All modal verbs share these characteristics:
# - No -s in third person (he should, NOT he shoulds)
# - Followed by base verb (should go, NOT should to go)
# - No 'to' before the modal (NOT to should)
# - Questions: Modal + subject + base verb
# - Negatives: Modal + not + base verb

# %% [markdown]
# ## 1. Introduction to Must and Have To
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Introduction to Must and Have To - Practice
print("Introduction to Must and Have To")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 2. Formation - Must + base verb
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Must + base verb - Practice
print("Formation - Must + base verb")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 3. Formation - Have to / Has to + base verb
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Have to / Has to + base verb - Practice
print("Formation - Have to / Has to + base verb")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 4. Must vs Have to - Internal vs External Obligation
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Must vs Have to - Internal vs External Obligation - Practice
print("Must vs Have to - Internal vs External Obligation")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 5. Negatives - Must not vs Don't have to (Preview)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Negatives - Must not vs Don't have to (Preview) - Practice
print("Negatives - Must not vs Don't have to (Preview)")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 6. Questions with Have to (Do/Does... have to?)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Questions with Have to (Do/Does... have to?) - Practice
print("Questions with Have to (Do/Does... have to?)")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 7. Short Answers
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Short Answers - Practice
print("Short Answers")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 8. Expressing Rules and Requirements
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Expressing Rules and Requirements - Practice
print("Expressing Rules and Requirements")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 9. Talking About Necessity
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Talking About Necessity - Practice
print("Talking About Necessity")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 10. Personal Obligations vs External Rules
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Personal Obligations vs External Rules - Practice
print("Personal Obligations vs External Rules")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 11. Common Collocations
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Collocations - Practice
print("Common Collocations")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 12. Pronunciation - Have to /hæftə/
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Pronunciation - Have to /hæftə/ - Practice
print("Pronunciation - Have to /hæftə/")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 13. Common Mistakes with Must/Have to
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Mistakes with Must/Have to - Practice
print("Common Mistakes with Must/Have to")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 14. Register and Formality
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Register and Formality - Practice
print("Register and Formality")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")

# %% [markdown]
# ## 15. Practice Conversations - Rules and Obligations
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with must/have to:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** must/have to + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Practice Conversations - Rules and Obligations - Practice
print("Practice Conversations - Rules and Obligations")
print("=" * 60)

examples = [
    "Example sentence 1 with must/have to",
    "Example sentence 2 with must/have to",
    "Example sentence 3 with must/have to",
    "Example sentence 4 with must/have to",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using must/have to")
print("Remember: must/have to + base verb (no 'to', no -s)")
