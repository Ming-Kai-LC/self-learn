# %% [markdown]
# # Module 12: Must/Have To - Obligation and Necessity - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks focusing on obligation, necessity, rules, requirements

# %% [markdown]
# ## Task 1: Comparing Rules - School vs Work
#
# **Modal Focus:** must/have to
# **Communicative Goal:** necessity
#
# ### Instructions:
# - Work in pairs or small groups
# - Use must/have to throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use must/have to for necessity
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 1: Comparing Rules - School vs Work
print("Comparing Rules - School vs Work")
print("=" * 60)
print(f"\nCommunicative Goal: necessity")
print(f"\nUseful must/have to questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: Creating a Guidebook for Visitors
#
# **Modal Focus:** must/have to
# **Communicative Goal:** rules
#
# ### Instructions:
# - Work in pairs or small groups
# - Use must/have to throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use must/have to for rules
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 2: Creating a Guidebook for Visitors
print("Creating a Guidebook for Visitors")
print("=" * 60)
print(f"\nCommunicative Goal: rules")
print(f"\nUseful must/have to questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: Obligations Interview
#
# **Modal Focus:** must/have to
# **Communicative Goal:** requirements
#
# ### Instructions:
# - Work in pairs or small groups
# - Use must/have to throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use must/have to for requirements
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 3: Obligations Interview
print("Obligations Interview")
print("=" * 60)
print(f"\nCommunicative Goal: requirements")
print(f"\nUseful must/have to questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Must-Do List for Success
#
# **Modal Focus:** must/have to
# **Communicative Goal:** obligation
#
# ### Instructions:
# - Work in pairs or small groups
# - Use must/have to throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use must/have to for obligation
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 4: Must-Do List for Success
print("Must-Do List for Success")
print("=" * 60)
print(f"\nCommunicative Goal: obligation")
print(f"\nUseful must/have to questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: Rule-Making Activity
#
# **Modal Focus:** must/have to
# **Communicative Goal:** necessity
#
# ### Instructions:
# - Work in pairs or small groups
# - Use must/have to throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use must/have to for necessity
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 5: Rule-Making Activity
print("Rule-Making Activity")
print("=" * 60)
print(f"\nCommunicative Goal: necessity")
print(f"\nUseful must/have to questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: Obligation Debate
#
# **Modal Focus:** must/have to
# **Communicative Goal:** rules
#
# ### Instructions:
# - Work in pairs or small groups
# - Use must/have to throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use must/have to for rules
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 6: Obligation Debate
print("Obligation Debate")
print("=" * 60)
print(f"\nCommunicative Goal: rules")
print(f"\nUseful must/have to questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Cultural Comparison - Rules in Different Countries
#
# **Modal Focus:** must/have to
# **Communicative Goal:** requirements
#
# ### Instructions:
# - Work in pairs or small groups
# - Use must/have to throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use must/have to for requirements
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 7: Cultural Comparison - Rules in Different Countries
print("Cultural Comparison - Rules in Different Countries")
print("=" * 60)
print(f"\nCommunicative Goal: requirements")
print(f"\nUseful must/have to questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Personal vs External Obligations Discussion
#
# **Modal Focus:** must/have to
# **Communicative Goal:** obligation
#
# ### Instructions:
# - Work in pairs or small groups
# - Use must/have to throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use must/have to for obligation
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 8: Personal vs External Obligations Discussion
print("Personal vs External Obligations Discussion")
print("=" * 60)
print(f"\nCommunicative Goal: obligation")
print(f"\nUseful must/have to questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")
