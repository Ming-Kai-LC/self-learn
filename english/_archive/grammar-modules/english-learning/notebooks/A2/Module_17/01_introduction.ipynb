# %% [markdown]
# # Module 17: Superlative Adjectives - The Best, The Biggest, The Most - Phase 1: Introduction
#
# ## Learning Objectives
# - Form superlatives: the + adjective + -est, the most + adjective
# - Apply the same spelling rules as comparatives
# - Use superlatives with 'in' (the tallest in the class) and 'of' (the best of all)
# - Master irregular superlatives: the best, the worst, the farthest
# - Combine with 'one of the' for emphasis
#
# **Target Level:** A2
# **Estimated Time:** 5-6 hours
# **Comparison Focus:** superlative adjectives
#
# ## Important Formation Rules
#
# - the + adjective + -est
# - the most + adjective
# - one of the + superlative
#
# ### Common Errors to Avoid:
# - ❌ more better → ✅ better
# - ❌ more taller → ✅ taller
# - ❌ She is taller her brother → ✅ She is taller than her brother

# %% [markdown]
# ## 1. Introduction to Superlative Adjectives
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Introduction to Superlative Adjectives - Practice
print("Introduction to Superlative Adjectives")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 2. Formation - The + Adjective + -est
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Formation - The + Adjective + -est - Practice
print("Formation - The + Adjective + -est")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 3. Formation - The Most + Adjective
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Formation - The Most + Adjective - Practice
print("Formation - The Most + Adjective")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 4. Same Spelling Rules as Comparatives
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Same Spelling Rules as Comparatives - Practice
print("Same Spelling Rules as Comparatives")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 5. Using 'The' with Superlatives (Always!)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Using 'The' with Superlatives (Always!) - Practice
print("Using 'The' with Superlatives (Always!)")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 6. Superlatives with 'In' (the tallest in the class)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Superlatives with 'In' (the tallest in the class) - Practice
print("Superlatives with 'In' (the tallest in the class)")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 7. Superlatives with 'Of' (the best of all)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Superlatives with 'Of' (the best of all) - Practice
print("Superlatives with 'Of' (the best of all)")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 8. Irregular Superlatives (the best, the worst)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Irregular Superlatives (the best, the worst) - Practice
print("Irregular Superlatives (the best, the worst)")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 9. One of the + Superlative + Plural Noun
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# One of the + Superlative + Plural Noun - Practice
print("One of the + Superlative + Plural Noun")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 10. Describing Extremes - People
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Describing Extremes - People - Practice
print("Describing Extremes - People")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 11. Describing Extremes - Places and Things
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Describing Extremes - Places and Things - Practice
print("Describing Extremes - Places and Things")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 12. World Records and Superlatives
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# World Records and Superlatives - Practice
print("World Records and Superlatives")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 13. Common Mistakes with Superlatives
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Common Mistakes with Superlatives - Practice
print("Common Mistakes with Superlatives")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 14. Pronunciation of -est Endings
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Pronunciation of -est Endings - Practice
print("Pronunciation of -est Endings")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 15. Practice Conversations - Talking About Bests and Worsts
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with superlative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Practice Conversations - Talking About Bests and Worsts - Practice
print("Practice Conversations - Talking About Bests and Worsts")
print("=" * 60)

# Formation reminder for superlative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with superlative adjectives",
    "Example sentence 2 with superlative adjectives",
    "Example sentence 3 with superlative adjectives",
    "Example sentence 4 with superlative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using superlative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)
