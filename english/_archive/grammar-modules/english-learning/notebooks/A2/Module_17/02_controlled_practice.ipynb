# %% [markdown]
# # Module 17: Superlative Adjectives - The Best, The Biggest, The Most - Phase 2: Controlled Practice
#
# ## Overview
# 85 exercises to master superlative adjectives
#
# **Total: 85 exercises** *(Enhanced for comparison accuracy)*
# **Focus:** the + adjective + -est, the most + adjective, one of the + superlative

# %% [markdown]
# ## Exercise Set 1: Formation - Comparatives/Superlatives (9 exercises)
#
# **Focus:** Master correct formation
# **Comparison Type:** superlative adjectives
#
# ### Instructions:
# Complete all 9 exercises below. Pay attention to:
# - ✓ Correct spelling (double consonants, -y to -i)
# - ✓ Choosing -er/-est vs more/most correctly
# - ✓ Including 'than' in comparatives
# - ✓ Including 'the' in superlatives
# - ✓ Using correct irregular forms
#
# **Remember:**
# - 1 syllable → -er/-est (tall, big, old)
# - 2 syllables ending in -y → -ier/-iest (happy, easy, busy)
# - 3+ syllables → more/most (expensive, comfortable, interesting)
# - Irregular → memorize (good/better/best, bad/worse/worst)

# %%
# Exercise Set 1: Formation - Comparatives/Superlatives
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Formation - Comparatives/Superlatives")
print("=" * 60)

# Quick reference for superlative adjectives
formation_guide = {
    "1_syllable": "add -er/-est",
    "2_syllable_y": "-y to -ier/-iest",
    "3+_syllables": "more/most",
    "irregular": "good→better→best, bad→worse→worst",
}

print("\nQuick Reference:")
for pattern, rule in formation_guide.items():
    print(f"  {pattern}: {rule}")

print("\n" + "=" * 60)
print(f"\nComplete 9 exercises below:")
print()

# 9 exercises with superlative adjectives
for i in range(1, 9 + 1):
    print(f"{i}. Exercise {i}: [Comparison exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation checklist:")
print("□ Correct spelling?")
print("□ Right form (-er/-est or more/most)?")
print("□ 'Than' in comparatives?")
print("□ 'The' in superlatives?")
print("□ Checked irregular forms?")

# %% [markdown]
# ## Exercise Set 2: Spelling Practice (9 exercises)
#
# **Focus:** Apply spelling rules correctly
# **Comparison Type:** superlative adjectives
#
# ### Instructions:
# Complete all 9 exercises below. Pay attention to:
# - ✓ Correct spelling (double consonants, -y to -i)
# - ✓ Choosing -er/-est vs more/most correctly
# - ✓ Including 'than' in comparatives
# - ✓ Including 'the' in superlatives
# - ✓ Using correct irregular forms
#
# **Remember:**
# - 1 syllable → -er/-est (tall, big, old)
# - 2 syllables ending in -y → -ier/-iest (happy, easy, busy)
# - 3+ syllables → more/most (expensive, comfortable, interesting)
# - Irregular → memorize (good/better/best, bad/worse/worst)

# %%
# Exercise Set 2: Spelling Practice
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Spelling Practice")
print("=" * 60)

# Quick reference for superlative adjectives
formation_guide = {
    "1_syllable": "add -er/-est",
    "2_syllable_y": "-y to -ier/-iest",
    "3+_syllables": "more/most",
    "irregular": "good→better→best, bad→worse→worst",
}

print("\nQuick Reference:")
for pattern, rule in formation_guide.items():
    print(f"  {pattern}: {rule}")

print("\n" + "=" * 60)
print(f"\nComplete 9 exercises below:")
print()

# 9 exercises with superlative adjectives
for i in range(1, 9 + 1):
    print(f"{i}. Exercise {i}: [Comparison exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation checklist:")
print("□ Correct spelling?")
print("□ Right form (-er/-est or more/most)?")
print("□ 'Than' in comparatives?")
print("□ 'The' in superlatives?")
print("□ Checked irregular forms?")

# %% [markdown]
# ## Exercise Set 3: Gap Filling (9 exercises)
#
# **Focus:** Complete sentences with correct forms
# **Comparison Type:** superlative adjectives
#
# ### Instructions:
# Complete all 9 exercises below. Pay attention to:
# - ✓ Correct spelling (double consonants, -y to -i)
# - ✓ Choosing -er/-est vs more/most correctly
# - ✓ Including 'than' in comparatives
# - ✓ Including 'the' in superlatives
# - ✓ Using correct irregular forms
#
# **Remember:**
# - 1 syllable → -er/-est (tall, big, old)
# - 2 syllables ending in -y → -ier/-iest (happy, easy, busy)
# - 3+ syllables → more/most (expensive, comfortable, interesting)
# - Irregular → memorize (good/better/best, bad/worse/worst)

# %%
# Exercise Set 3: Gap Filling
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Gap Filling")
print("=" * 60)

# Quick reference for superlative adjectives
formation_guide = {
    "1_syllable": "add -er/-est",
    "2_syllable_y": "-y to -ier/-iest",
    "3+_syllables": "more/most",
    "irregular": "good→better→best, bad→worse→worst",
}

print("\nQuick Reference:")
for pattern, rule in formation_guide.items():
    print(f"  {pattern}: {rule}")

print("\n" + "=" * 60)
print(f"\nComplete 9 exercises below:")
print()

# 9 exercises with superlative adjectives
for i in range(1, 9 + 1):
    print(f"{i}. Exercise {i}: [Comparison exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation checklist:")
print("□ Correct spelling?")
print("□ Right form (-er/-est or more/most)?")
print("□ 'Than' in comparatives?")
print("□ 'The' in superlatives?")
print("□ Checked irregular forms?")

# %% [markdown]
# ## Exercise Set 4: Sentence Construction (9 exercises)
#
# **Focus:** Build complete comparative/superlative sentences
# **Comparison Type:** superlative adjectives
#
# ### Instructions:
# Complete all 9 exercises below. Pay attention to:
# - ✓ Correct spelling (double consonants, -y to -i)
# - ✓ Choosing -er/-est vs more/most correctly
# - ✓ Including 'than' in comparatives
# - ✓ Including 'the' in superlatives
# - ✓ Using correct irregular forms
#
# **Remember:**
# - 1 syllable → -er/-est (tall, big, old)
# - 2 syllables ending in -y → -ier/-iest (happy, easy, busy)
# - 3+ syllables → more/most (expensive, comfortable, interesting)
# - Irregular → memorize (good/better/best, bad/worse/worst)

# %%
# Exercise Set 4: Sentence Construction
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Sentence Construction")
print("=" * 60)

# Quick reference for superlative adjectives
formation_guide = {
    "1_syllable": "add -er/-est",
    "2_syllable_y": "-y to -ier/-iest",
    "3+_syllables": "more/most",
    "irregular": "good→better→best, bad→worse→worst",
}

print("\nQuick Reference:")
for pattern, rule in formation_guide.items():
    print(f"  {pattern}: {rule}")

print("\n" + "=" * 60)
print(f"\nComplete 9 exercises below:")
print()

# 9 exercises with superlative adjectives
for i in range(1, 9 + 1):
    print(f"{i}. Exercise {i}: [Comparison exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation checklist:")
print("□ Correct spelling?")
print("□ Right form (-er/-est or more/most)?")
print("□ 'Than' in comparatives?")
print("□ 'The' in superlatives?")
print("□ Checked irregular forms?")

# %% [markdown]
# ## Exercise Set 5: Error Correction (9 exercises)
#
# **Focus:** Find and fix mistakes
# **Comparison Type:** superlative adjectives
#
# ### Instructions:
# Complete all 9 exercises below. Pay attention to:
# - ✓ Correct spelling (double consonants, -y to -i)
# - ✓ Choosing -er/-est vs more/most correctly
# - ✓ Including 'than' in comparatives
# - ✓ Including 'the' in superlatives
# - ✓ Using correct irregular forms
#
# **Remember:**
# - 1 syllable → -er/-est (tall, big, old)
# - 2 syllables ending in -y → -ier/-iest (happy, easy, busy)
# - 3+ syllables → more/most (expensive, comfortable, interesting)
# - Irregular → memorize (good/better/best, bad/worse/worst)

# %%
# Exercise Set 5: Error Correction
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Error Correction")
print("=" * 60)

# Quick reference for superlative adjectives
formation_guide = {
    "1_syllable": "add -er/-est",
    "2_syllable_y": "-y to -ier/-iest",
    "3+_syllables": "more/most",
    "irregular": "good→better→best, bad→worse→worst",
}

print("\nQuick Reference:")
for pattern, rule in formation_guide.items():
    print(f"  {pattern}: {rule}")

print("\n" + "=" * 60)
print(f"\nComplete 9 exercises below:")
print()

# 9 exercises with superlative adjectives
for i in range(1, 9 + 1):
    print(f"{i}. Exercise {i}: [Comparison exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation checklist:")
print("□ Correct spelling?")
print("□ Right form (-er/-est or more/most)?")
print("□ 'Than' in comparatives?")
print("□ 'The' in superlatives?")
print("□ Checked irregular forms?")

# %% [markdown]
# ## Exercise Set 6: Transformation (8 exercises)
#
# **Focus:** Change between forms
# **Comparison Type:** superlative adjectives
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to:
# - ✓ Correct spelling (double consonants, -y to -i)
# - ✓ Choosing -er/-est vs more/most correctly
# - ✓ Including 'than' in comparatives
# - ✓ Including 'the' in superlatives
# - ✓ Using correct irregular forms
#
# **Remember:**
# - 1 syllable → -er/-est (tall, big, old)
# - 2 syllables ending in -y → -ier/-iest (happy, easy, busy)
# - 3+ syllables → more/most (expensive, comfortable, interesting)
# - Irregular → memorize (good/better/best, bad/worse/worst)

# %%
# Exercise Set 6: Transformation
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Transformation")
print("=" * 60)

# Quick reference for superlative adjectives
formation_guide = {
    "1_syllable": "add -er/-est",
    "2_syllable_y": "-y to -ier/-iest",
    "3+_syllables": "more/most",
    "irregular": "good→better→best, bad→worse→worst",
}

print("\nQuick Reference:")
for pattern, rule in formation_guide.items():
    print(f"  {pattern}: {rule}")

print("\n" + "=" * 60)
print(f"\nComplete 8 exercises below:")
print()

# 8 exercises with superlative adjectives
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Comparison exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation checklist:")
print("□ Correct spelling?")
print("□ Right form (-er/-est or more/most)?")
print("□ 'Than' in comparatives?")
print("□ 'The' in superlatives?")
print("□ Checked irregular forms?")

# %% [markdown]
# ## Exercise Set 7: Context Matching (8 exercises)
#
# **Focus:** Choose appropriate form for context
# **Comparison Type:** superlative adjectives
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to:
# - ✓ Correct spelling (double consonants, -y to -i)
# - ✓ Choosing -er/-est vs more/most correctly
# - ✓ Including 'than' in comparatives
# - ✓ Including 'the' in superlatives
# - ✓ Using correct irregular forms
#
# **Remember:**
# - 1 syllable → -er/-est (tall, big, old)
# - 2 syllables ending in -y → -ier/-iest (happy, easy, busy)
# - 3+ syllables → more/most (expensive, comfortable, interesting)
# - Irregular → memorize (good/better/best, bad/worse/worst)

# %%
# Exercise Set 7: Context Matching
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Context Matching")
print("=" * 60)

# Quick reference for superlative adjectives
formation_guide = {
    "1_syllable": "add -er/-est",
    "2_syllable_y": "-y to -ier/-iest",
    "3+_syllables": "more/most",
    "irregular": "good→better→best, bad→worse→worst",
}

print("\nQuick Reference:")
for pattern, rule in formation_guide.items():
    print(f"  {pattern}: {rule}")

print("\n" + "=" * 60)
print(f"\nComplete 8 exercises below:")
print()

# 8 exercises with superlative adjectives
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Comparison exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation checklist:")
print("□ Correct spelling?")
print("□ Right form (-er/-est or more/most)?")
print("□ 'Than' in comparatives?")
print("□ 'The' in superlatives?")
print("□ Checked irregular forms?")

# %% [markdown]
# ## Exercise Set 8: Question Formation (8 exercises)
#
# **Focus:** Create comparative/superlative questions
# **Comparison Type:** superlative adjectives
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to:
# - ✓ Correct spelling (double consonants, -y to -i)
# - ✓ Choosing -er/-est vs more/most correctly
# - ✓ Including 'than' in comparatives
# - ✓ Including 'the' in superlatives
# - ✓ Using correct irregular forms
#
# **Remember:**
# - 1 syllable → -er/-est (tall, big, old)
# - 2 syllables ending in -y → -ier/-iest (happy, easy, busy)
# - 3+ syllables → more/most (expensive, comfortable, interesting)
# - Irregular → memorize (good/better/best, bad/worse/worst)

# %%
# Exercise Set 8: Question Formation
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Question Formation")
print("=" * 60)

# Quick reference for superlative adjectives
formation_guide = {
    "1_syllable": "add -er/-est",
    "2_syllable_y": "-y to -ier/-iest",
    "3+_syllables": "more/most",
    "irregular": "good→better→best, bad→worse→worst",
}

print("\nQuick Reference:")
for pattern, rule in formation_guide.items():
    print(f"  {pattern}: {rule}")

print("\n" + "=" * 60)
print(f"\nComplete 8 exercises below:")
print()

# 8 exercises with superlative adjectives
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Comparison exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation checklist:")
print("□ Correct spelling?")
print("□ Right form (-er/-est or more/most)?")
print("□ 'Than' in comparatives?")
print("□ 'The' in superlatives?")
print("□ Checked irregular forms?")

# %% [markdown]
# ## Exercise Set 9: Short Answers (8 exercises)
#
# **Focus:** Respond appropriately
# **Comparison Type:** superlative adjectives
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to:
# - ✓ Correct spelling (double consonants, -y to -i)
# - ✓ Choosing -er/-est vs more/most correctly
# - ✓ Including 'than' in comparatives
# - ✓ Including 'the' in superlatives
# - ✓ Using correct irregular forms
#
# **Remember:**
# - 1 syllable → -er/-est (tall, big, old)
# - 2 syllables ending in -y → -ier/-iest (happy, easy, busy)
# - 3+ syllables → more/most (expensive, comfortable, interesting)
# - Irregular → memorize (good/better/best, bad/worse/worst)

# %%
# Exercise Set 9: Short Answers
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Short Answers")
print("=" * 60)

# Quick reference for superlative adjectives
formation_guide = {
    "1_syllable": "add -er/-est",
    "2_syllable_y": "-y to -ier/-iest",
    "3+_syllables": "more/most",
    "irregular": "good→better→best, bad→worse→worst",
}

print("\nQuick Reference:")
for pattern, rule in formation_guide.items():
    print(f"  {pattern}: {rule}")

print("\n" + "=" * 60)
print(f"\nComplete 8 exercises below:")
print()

# 8 exercises with superlative adjectives
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Comparison exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation checklist:")
print("□ Correct spelling?")
print("□ Right form (-er/-est or more/most)?")
print("□ 'Than' in comparatives?")
print("□ 'The' in superlatives?")
print("□ Checked irregular forms?")

# %% [markdown]
# ## Exercise Set 10: Mixed Practice (8 exercises)
#
# **Focus:** Apply all skills together
# **Comparison Type:** superlative adjectives
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to:
# - ✓ Correct spelling (double consonants, -y to -i)
# - ✓ Choosing -er/-est vs more/most correctly
# - ✓ Including 'than' in comparatives
# - ✓ Including 'the' in superlatives
# - ✓ Using correct irregular forms
#
# **Remember:**
# - 1 syllable → -er/-est (tall, big, old)
# - 2 syllables ending in -y → -ier/-iest (happy, easy, busy)
# - 3+ syllables → more/most (expensive, comfortable, interesting)
# - Irregular → memorize (good/better/best, bad/worse/worst)

# %%
# Exercise Set 10: Mixed Practice
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Mixed Practice")
print("=" * 60)

# Quick reference for superlative adjectives
formation_guide = {
    "1_syllable": "add -er/-est",
    "2_syllable_y": "-y to -ier/-iest",
    "3+_syllables": "more/most",
    "irregular": "good→better→best, bad→worse→worst",
}

print("\nQuick Reference:")
for pattern, rule in formation_guide.items():
    print(f"  {pattern}: {rule}")

print("\n" + "=" * 60)
print(f"\nComplete 8 exercises below:")
print()

# 8 exercises with superlative adjectives
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Comparison exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation checklist:")
print("□ Correct spelling?")
print("□ Right form (-er/-est or more/most)?")
print("□ 'Than' in comparatives?")
print("□ 'The' in superlatives?")
print("□ Checked irregular forms?")
