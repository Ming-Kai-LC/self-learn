# %% [markdown]
# # Module 17: Superlative Adjectives - The Best, The Biggest, The Most - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks focusing on superlative adjectives

# %% [markdown]
# ## Task 1: Creating a Top 10 List and Presenting
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use superlative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use superlative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 1: Creating a Top 10 List and Presenting
print("Creating a Top 10 List and Presenting")
print("=" * 60)
print(f"\nUse superlative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: Superlatives Quiz Game
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use superlative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use superlative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 2: Superlatives Quiz Game
print("Superlatives Quiz Game")
print("=" * 60)
print(f"\nUse superlative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: The Best Place in Our City - Presentation
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use superlative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use superlative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 3: The Best Place in Our City - Presentation
print("The Best Place in Our City - Presentation")
print("=" * 60)
print(f"\nUse superlative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Class Survey - Finding Our Superlatives
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use superlative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use superlative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 4: Class Survey - Finding Our Superlatives
print("Class Survey - Finding Our Superlatives")
print("=" * 60)
print(f"\nUse superlative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: World Records Research and Presentation
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use superlative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use superlative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 5: World Records Research and Presentation
print("World Records Research and Presentation")
print("=" * 60)
print(f"\nUse superlative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: Ranking and Explaining Choices
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use superlative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use superlative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 6: Ranking and Explaining Choices
print("Ranking and Explaining Choices")
print("=" * 60)
print(f"\nUse superlative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Creating Award Categories
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use superlative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use superlative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 7: Creating Award Categories
print("Creating Award Categories")
print("=" * 60)
print(f"\nUse superlative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Debate: What's the Most Important...?
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use superlative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use superlative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 8: Debate: What's the Most Important...?
print("Debate: What's the Most Important...?")
print("=" * 60)
print(f"\nUse superlative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")
