# %% [markdown]
# # Module 13: Don't Have To vs Mustn't - No Obligation vs Prohibition - Phase 1: Introduction
#
# ## Learning Objectives
# - Understand don't have to = not necessary (no obligation)
# - Understand mustn't = prohibited (not allowed)
# - Recognize the critical meaning difference between the two
# - Use the correct form based on context (rules vs freedom)
# - Form sentences expressing lack of obligation vs prohibition
#
# **Target Level:** A2
# **Estimated Time:** 4-5 hours
# **Modal Focus:** don't have to/mustn't
#
# ## Important Modal Verb Rules
#
# All modal verbs share these characteristics:
# - No -s in third person (he should, NOT he shoulds)
# - Followed by base verb (should go, NOT should to go)
# - No 'to' before the modal (NOT to should)
# - Questions: Modal + subject + base verb
# - Negatives: Modal + not + base verb

# %% [markdown]
# ## 1. Introduction - The Critical Difference
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Introduction - The Critical Difference - Practice
print("Introduction - The Critical Difference")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 2. Don't Have To = Not Necessary (No Obligation)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Don't Have To = Not Necessary (No Obligation) - Practice
print("Don't Have To = Not Necessary (No Obligation)")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 3. Mustn't = Prohibited (Not Allowed)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Mustn't = Prohibited (Not Allowed) - Practice
print("Mustn't = Prohibited (Not Allowed)")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 4. Formation - Don't/Doesn't have to
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Don't/Doesn't have to - Practice
print("Formation - Don't/Doesn't have to")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 5. Formation - Must not / Mustn't
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Must not / Mustn't - Practice
print("Formation - Must not / Mustn't")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 6. Meaning Contrast - Freedom vs Prohibition
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Meaning Contrast - Freedom vs Prohibition - Practice
print("Meaning Contrast - Freedom vs Prohibition")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 7. Context Clues - Which One to Use?
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Context Clues - Which One to Use? - Practice
print("Context Clues - Which One to Use?")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 8. Common Situations - No Obligation
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Situations - No Obligation - Practice
print("Common Situations - No Obligation")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 9. Common Situations - Prohibition
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Situations - Prohibition - Practice
print("Common Situations - Prohibition")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 10. Pronunciation and Contractions
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Pronunciation and Contractions - Practice
print("Pronunciation and Contractions")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 11. Common Mistakes and Confusions
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Mistakes and Confusions - Practice
print("Common Mistakes and Confusions")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 12. Practice with Rules and Signs
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Practice with Rules and Signs - Practice
print("Practice with Rules and Signs")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 13. Comparison Chart - Summary
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Comparison Chart - Summary - Practice
print("Comparison Chart - Summary")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 14. Practice Conversations - Rules at School/Work
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with don't have to/mustn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** don't have to/mustn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Practice Conversations - Rules at School/Work - Practice
print("Practice Conversations - Rules at School/Work")
print("=" * 60)

examples = [
    "Example sentence 1 with don't have to/mustn't",
    "Example sentence 2 with don't have to/mustn't",
    "Example sentence 3 with don't have to/mustn't",
    "Example sentence 4 with don't have to/mustn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using don't have to/mustn't")
print("Remember: don't have to/mustn't + base verb (no 'to', no -s)")
