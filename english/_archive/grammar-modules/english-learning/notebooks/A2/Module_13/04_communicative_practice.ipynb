# %% [markdown]
# # Module 13: Don't Have To vs Mustn't - No Obligation vs Prohibition - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks focusing on no obligation, prohibition, not necessary, not allowed

# %% [markdown]
# ## Task 1: Creating Signs and Rules
#
# **Modal Focus:** don't have to/mustn't
# **Communicative Goal:** prohibition
#
# ### Instructions:
# - Work in pairs or small groups
# - Use don't have to/mustn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use don't have to/mustn't for prohibition
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 1: Creating Signs and Rules
print("Creating Signs and Rules")
print("=" * 60)
print(f"\nCommunicative Goal: prohibition")
print(f"\nUseful don't have to/mustn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: Prohibition vs Freedom Debate
#
# **Modal Focus:** don't have to/mustn't
# **Communicative Goal:** not necessary
#
# ### Instructions:
# - Work in pairs or small groups
# - Use don't have to/mustn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use don't have to/mustn't for not necessary
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 2: Prohibition vs Freedom Debate
print("Prohibition vs Freedom Debate")
print("=" * 60)
print(f"\nCommunicative Goal: not necessary")
print(f"\nUseful don't have to/mustn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: Rules Review - What's Fair?
#
# **Modal Focus:** don't have to/mustn't
# **Communicative Goal:** not allowed
#
# ### Instructions:
# - Work in pairs or small groups
# - Use don't have to/mustn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use don't have to/mustn't for not allowed
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 3: Rules Review - What's Fair?
print("Rules Review - What's Fair?")
print("=" * 60)
print(f"\nCommunicative Goal: not allowed")
print(f"\nUseful don't have to/mustn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Designing Classroom Rules
#
# **Modal Focus:** don't have to/mustn't
# **Communicative Goal:** no obligation
#
# ### Instructions:
# - Work in pairs or small groups
# - Use don't have to/mustn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use don't have to/mustn't for no obligation
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 4: Designing Classroom Rules
print("Designing Classroom Rules")
print("=" * 60)
print(f"\nCommunicative Goal: no obligation")
print(f"\nUseful don't have to/mustn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: Understanding Legal Requirements
#
# **Modal Focus:** don't have to/mustn't
# **Communicative Goal:** prohibition
#
# ### Instructions:
# - Work in pairs or small groups
# - Use don't have to/mustn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use don't have to/mustn't for prohibition
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 5: Understanding Legal Requirements
print("Understanding Legal Requirements")
print("=" * 60)
print(f"\nCommunicative Goal: prohibition")
print(f"\nUseful don't have to/mustn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: Cultural Prohibitions Presentation
#
# **Modal Focus:** don't have to/mustn't
# **Communicative Goal:** not necessary
#
# ### Instructions:
# - Work in pairs or small groups
# - Use don't have to/mustn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use don't have to/mustn't for not necessary
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 6: Cultural Prohibitions Presentation
print("Cultural Prohibitions Presentation")
print("=" * 60)
print(f"\nCommunicative Goal: not necessary")
print(f"\nUseful don't have to/mustn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Rule Sorting Game
#
# **Modal Focus:** don't have to/mustn't
# **Communicative Goal:** not allowed
#
# ### Instructions:
# - Work in pairs or small groups
# - Use don't have to/mustn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use don't have to/mustn't for not allowed
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 7: Rule Sorting Game
print("Rule Sorting Game")
print("=" * 60)
print(f"\nCommunicative Goal: not allowed")
print(f"\nUseful don't have to/mustn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Policy Making Activity
#
# **Modal Focus:** don't have to/mustn't
# **Communicative Goal:** no obligation
#
# ### Instructions:
# - Work in pairs or small groups
# - Use don't have to/mustn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use don't have to/mustn't for no obligation
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 8: Policy Making Activity
print("Policy Making Activity")
print("=" * 60)
print(f"\nCommunicative Goal: no obligation")
print(f"\nUseful don't have to/mustn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")
