# %% [markdown]
# # Module 19: Adverbs of Manner and Comparison - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using adverbs of manner in real contexts

# %% [markdown]
# ## Activity 1: How Do You Do Things? - Adverb Self-Description
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# 1. Write 8-10 sentences using adverbs of manner
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using adverbs of manner to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 1: How Do You Do Things? - Adverb Self-Description
print("How Do You Do Things? - Adverb Self-Description")
print("=" * 60)
print(f"\nUse adverbs of manner to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 2: Describing How Others Act
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# 1. Write 8-10 sentences using adverbs of manner
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using adverbs of manner to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 2: Describing How Others Act
print("Describing How Others Act")
print("=" * 60)
print(f"\nUse adverbs of manner to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 3: Then vs Now - How Things Have Changed
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# 1. Write 8-10 sentences using adverbs of manner
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using adverbs of manner to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 3: Then vs Now - How Things Have Changed
print("Then vs Now - How Things Have Changed")
print("=" * 60)
print(f"\nUse adverbs of manner to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 4: Good Performance vs Poor Performance
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# 1. Write 8-10 sentences using adverbs of manner
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using adverbs of manner to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 4: Good Performance vs Poor Performance
print("Good Performance vs Poor Performance")
print("=" * 60)
print(f"\nUse adverbs of manner to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 5: Cultural Differences in Behavior
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# 1. Write 8-10 sentences using adverbs of manner
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using adverbs of manner to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 5: Cultural Differences in Behavior
print("Cultural Differences in Behavior")
print("=" * 60)
print(f"\nUse adverbs of manner to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 6: How I Want to Improve
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# 1. Write 8-10 sentences using adverbs of manner
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using adverbs of manner to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 6: How I Want to Improve
print("How I Want to Improve")
print("=" * 60)
print(f"\nUse adverbs of manner to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 7: Fast vs Slow - Speed Comparisons
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# 1. Write 8-10 sentences using adverbs of manner
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using adverbs of manner to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 7: Fast vs Slow - Speed Comparisons
print("Fast vs Slow - Speed Comparisons")
print("=" * 60)
print(f"\nUse adverbs of manner to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 8: Careful vs Careless - Quality Descriptions
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# 1. Write 8-10 sentences using adverbs of manner
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using adverbs of manner to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 8: Careful vs Careless - Quality Descriptions
print("Careful vs Careless - Quality Descriptions")
print("=" * 60)
print(f"\nUse adverbs of manner to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 9: Well vs Badly - Skill Levels
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# 1. Write 8-10 sentences using adverbs of manner
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using adverbs of manner to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 9: Well vs Badly - Skill Levels
print("Well vs Badly - Skill Levels")
print("=" * 60)
print(f"\nUse adverbs of manner to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 10: Describing a Perfect Day - Using Manner Adverbs
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# 1. Write 8-10 sentences using adverbs of manner
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using adverbs of manner to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 10: Describing a Perfect Day - Using Manner Adverbs
print("Describing a Perfect Day - Using Manner Adverbs")
print("=" * 60)
print(f"\nUse adverbs of manner to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")
