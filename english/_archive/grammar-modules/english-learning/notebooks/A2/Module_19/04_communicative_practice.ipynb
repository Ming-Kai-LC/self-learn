# %% [markdown]
# # Module 19: Adverbs of Manner and Comparison - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks focusing on adverbs of manner

# %% [markdown]
# ## Task 1: How Do You...? - Manner Interview
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# - Work in pairs or small groups
# - Use adverbs of manner throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use adverbs of manner naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 1: How Do You...? - Manner Interview
print("How Do You...? - Manner Interview")
print("=" * 60)
print(f"\nUse adverbs of manner in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: Demonstrating and Describing Actions
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# - Work in pairs or small groups
# - Use adverbs of manner throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use adverbs of manner naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 2: Demonstrating and Describing Actions
print("Demonstrating and Describing Actions")
print("=" * 60)
print(f"\nUse adverbs of manner in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: Adverb Charades
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# - Work in pairs or small groups
# - Use adverbs of manner throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use adverbs of manner naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 3: Adverb Charades
print("Adverb Charades")
print("=" * 60)
print(f"\nUse adverbs of manner in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Describing Perfect Performance
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# - Work in pairs or small groups
# - Use adverbs of manner throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use adverbs of manner naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 4: Describing Perfect Performance
print("Describing Perfect Performance")
print("=" * 60)
print(f"\nUse adverbs of manner in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: Cultural Behavior Comparison
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# - Work in pairs or small groups
# - Use adverbs of manner throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use adverbs of manner naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 5: Cultural Behavior Comparison
print("Cultural Behavior Comparison")
print("=" * 60)
print(f"\nUse adverbs of manner in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: Improving Skills - Adverb Goals
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# - Work in pairs or small groups
# - Use adverbs of manner throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use adverbs of manner naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 6: Improving Skills - Adverb Goals
print("Improving Skills - Adverb Goals")
print("=" * 60)
print(f"\nUse adverbs of manner in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Story Retelling with Manner Adverbs
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# - Work in pairs or small groups
# - Use adverbs of manner throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use adverbs of manner naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 7: Story Retelling with Manner Adverbs
print("Story Retelling with Manner Adverbs")
print("=" * 60)
print(f"\nUse adverbs of manner in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Performance Review Role Play
#
# **Comparison Focus:** adverbs of manner
#
# ### Instructions:
# - Work in pairs or small groups
# - Use adverbs of manner throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use adverbs of manner naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 8: Performance Review Role Play
print("Performance Review Role Play")
print("=" * 60)
print(f"\nUse adverbs of manner in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")
