# %% [markdown]
# # Module 05: Present Perfect with Ever/Never - Phase 4: Communicative Practice

# %% [markdown]
# ## Section 1
#
# Content for Communicative Practice

# %%
# Section 1
print("Section 1")

# %% [markdown]
# ## Section 2
#
# Content for Communicative Practice

# %%
# Section 2
print("Section 2")

# %% [markdown]
# ## Section 3
#
# Content for Communicative Practice

# %%
# Section 3
print("Section 3")

# %% [markdown]
# ## Section 4
#
# Content for Communicative Practice

# %%
# Section 4
print("Section 4")

# %% [markdown]
# ## Section 5
#
# Content for Communicative Practice

# %%
# Section 5
print("Section 5")

# %% [markdown]
# ## Section 6
#
# Content for Communicative Practice

# %%
# Section 6
print("Section 6")

# %% [markdown]
# ## Section 7
#
# Content for Communicative Practice

# %%
# Section 7
print("Section 7")

# %% [markdown]
# ## Section 8
#
# Content for Communicative Practice

# %%
# Section 8
print("Section 8")
