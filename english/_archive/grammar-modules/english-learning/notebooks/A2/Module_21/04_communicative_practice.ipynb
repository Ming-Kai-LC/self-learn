# %% [markdown]
# # A2 Module 21: Zero and First Conditional - If Clauses and Real Possibilities
# ## Phase 4: Communicative Practice
#
# **Total Tasks:** 8
# **Focus:** Real-world communication with conditionals
#
# ---
#
# ## Welcome to Communicative Practice!
#
# In this final phase, you'll use conditionals in authentic communication scenarios.
#
# ### Task Philosophy
#
# - Focus on COMMUNICATION, not perfection
# - Use natural, conversational language
# - Mistakes are okay - fluency is the goal
# - Apply what you've learned naturally
#
# ### Task Structure
#
# Each task presents a real-world scenario where you need to communicate using the grammar you've learned.
#
# **Let's communicate!**
#
# ---

# %% [markdown]
# ## Task 1: Life Advice Column
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with conditionals
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the conditionals structures naturally

# %%
# Task 1: Life Advice Column

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 2: What Will Happen? - Predictions
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with conditionals
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the conditionals structures naturally

# %%
# Task 2: What Will Happen? - Predictions

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 3: Travel Conditions
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with conditionals
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the conditionals structures naturally

# %%
# Task 3: Travel Conditions

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 4: Health and Habits Discussion
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with conditionals
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the conditionals structures naturally

# %%
# Task 4: Health and Habits Discussion

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 5: Making Promises
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with conditionals
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the conditionals structures naturally

# %%
# Task 5: Making Promises

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 6: Problem Solving with Conditionals
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with conditionals
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the conditionals structures naturally

# %%
# Task 6: Problem Solving with Conditionals

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 7: Future Scenarios Role-Play
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with conditionals
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the conditionals structures naturally

# %%
# Task 7: Future Scenarios Role-Play

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 8: Conditional Conversations
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with conditionals
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the conditionals structures naturally

# %%
# Task 8: Conditional Conversations

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ---
#
# ## 🎉 Module 21 Complete!
#
# Congratulations! You've finished **Zero and First Conditional - If Clauses and Real Possibilities**!
#
# ### What You've Achieved
#
# [DONE] Completed 15 introduction sections
# [DONE] Practiced through 85 exercises
# [DONE] Created 10 personalized activities
# [DONE] Communicated in 8 real-world tasks
#
# ### Mastery Checklist
#
# Can you confidently:
# - [ ] Form zero conditional for general truths and scientific facts
# - [ ] Form first conditional for real future possibilities
# - [ ] Understand the difference between zero and first conditional
# - [ ] Use correct verb forms in if-clause and main clause
# - [ ] Avoid common error: using 'will' in the if-clause
#
# ### Time Investment
#
# You've invested approximately 5-6 hours in this module. Well done!
#
# ### Next Steps
#
# Continue to **Module 22: Connectors and Linking Words - Because, So, But, Although**
#
# ### Spaced Repetition
#
# Review this module after:
# - 1 day
# - 3 days
# - 7 days
# - 14 days
# - 30 days
#
# ---
#
# Progress: Module Complete! 4 of 4 phases done
