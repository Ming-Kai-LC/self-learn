# %% [markdown]
# # A2 Module 21: Zero and First Conditional - If Clauses and Real Possibilities
#
# ## Expressing Conditions and Future Possibilities
#
# **Estimated Time:** 5-6 hours
# **Level:** A2 (Elementary)
# **Focus:** Conditionals
#
# ---
#
# ## Module Overview
#
# Master zero and first conditional structures for general truths and real future possibilities
#
# ### What You'll Learn
#
# 1. Form zero conditional for general truths and scientific facts
# 2. Form first conditional for real future possibilities
# 3. Understand the difference between zero and first conditional
# 4. Use correct verb forms in if-clause and main clause
# 5. Avoid common error: using 'will' in the if-clause
#
# ### Module Structure
#
# This module follows the proven 4-phase learning approach:
#
# 1. **Phase 1: Introduction** (15 sections)
#    - Detailed grammar explanations with examples
#    - Formation rules and usage guidelines
#    - Common errors to avoid
#
# 2. **Phase 2: Controlled Practice** (85 exercises)
#    - Structured exercises with immediate feedback
#    - Progressive difficulty
#    - Integration with previous grammar
#
# 3. **Phase 3: Meaningful Practice** (10 activities)
#    - Personalized content creation
#    - Real-world application
#    - Your life, your examples
#
# 4. **Phase 4: Communicative Practice** (8 tasks)
#    - Authentic communication scenarios
#    - Free production
#    - Fluency development
#
# ---
#
# Let's begin!

# %% [markdown]
# ## 1. Introduction to Conditionals
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Introduction to Conditionals

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 2. Zero Conditional - Structure and Formation
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Zero Conditional - Structure and Formation

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 3. Zero Conditional - General Truths and Facts
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Zero Conditional - General Truths and Facts

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 4. Zero Conditional - Habits and Routines
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Zero Conditional - Habits and Routines

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 5. First Conditional - Structure and Formation
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: First Conditional - Structure and Formation

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 6. First Conditional - Real Future Possibilities
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: First Conditional - Real Future Possibilities

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 7. First Conditional - Predictions and Warnings
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: First Conditional - Predictions and Warnings

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 8. First Conditional - Promises and Offers
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: First Conditional - Promises and Offers

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 9. Zero vs First Conditional - Key Differences
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Zero vs First Conditional - Key Differences

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 10. Common Errors with Conditionals
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Common Errors with Conditionals

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 11. Conditionals in Questions
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Conditionals in Questions

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 12. Conditionals in Negatives
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Conditionals in Negatives

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 13. Unless = If not
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Unless = If not

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 14. Combining Conditionals with Other Grammar
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Combining Conditionals with Other Grammar

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ## 15. Practice Conversations with Conditionals
#
# [Content to be added: Detailed grammar explanation with examples]
#
# ### Key Points:
# - Zero conditional: If + present, present (general truths)
# - First conditional: If + present, will + base verb (real future possibilities)
# - Do NOT use 'will' in the if-clause
# - Use comma when if-clause comes first
#
# ### Formation:
# ```
# Zero: If you heat water, it boils.
# First: If it rains, I will stay home.
# ```

# %%
# Practice: Practice Conversations with Conditionals

# Example sentences will be provided here for practice
# Try to create your own examples following the patterns shown

print("Practice area - examples and exercises to be added")

# %% [markdown]
# ---
#
# ## Congratulations!
#
# You've completed Phase 1 of Module 21: **Zero and First Conditional - If Clauses and Real Possibilities**
#
# ### What You've Learned
#
# You now understand the fundamental concepts of conditionals!
#
# ### Next Steps
#
# Continue to **Phase 2: Controlled Practice** where you'll do 85 exercises to reinforce your learning.
#
# **Remember:** Understanding grammar is the first step. Practice makes it automatic!
#
# ---
#
# 📚 Progress: Phase 1 of 4 complete
