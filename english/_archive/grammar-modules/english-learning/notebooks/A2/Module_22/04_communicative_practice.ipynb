# %% [markdown]
# # A2 Module 22: Connectors and Linking Words - Because, So, But, Although
# ## Phase 4: Communicative Practice
#
# **Total Tasks:** 8
# **Focus:** Real-world communication with connectors
#
# ---
#
# ## Welcome to Communicative Practice!
#
# In this final phase, you'll use connectors in authentic communication scenarios.
#
# ### Task Philosophy
#
# - Focus on COMMUNICATION, not perfection
# - Use natural, conversational language
# - Mistakes are okay - fluency is the goal
# - Apply what you've learned naturally
#
# ### Task Structure
#
# Each task presents a real-world scenario where you need to communicate using the grammar you've learned.
#
# **Let's communicate!**
#
# ---

# %% [markdown]
# ## Task 1: Explaining Decisions
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with connectors
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the connectors structures naturally

# %%
# Task 1: Explaining Decisions

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 2: Cause and Effect Discussion
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with connectors
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the connectors structures naturally

# %%
# Task 2: Cause and Effect Discussion

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 3: Contrasting Opinions Debate
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with connectors
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the connectors structures naturally

# %%
# Task 3: Contrasting Opinions Debate

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 4: Story Telling with Connectors
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with connectors
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the connectors structures naturally

# %%
# Task 4: Story Telling with Connectors

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 5: Explaining Complex Situations
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with connectors
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the connectors structures naturally

# %%
# Task 5: Explaining Complex Situations

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 6: Paragraph Writing Practice
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with connectors
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the connectors structures naturally

# %%
# Task 6: Paragraph Writing Practice

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 7: Discussion: Reasons and Results
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with connectors
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the connectors structures naturally

# %%
# Task 7: Discussion: Reasons and Results

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ## Task 8: Logical Arguments
#
# **Duration:** 15-20 minutes
# **Skill Focus:** Speaking/Writing with connectors
#
# **Scenario:**
#
# [Real-world scenario description to be added]
#
# **Your Task:**
#
# [Task instructions to be added]
#
# **Tips:**
#
# - Use natural, conversational language
# - Don't worry about small mistakes
# - Focus on communication
# - Try to use the connectors structures naturally

# %%
# Task 8: Logical Arguments

# Use this space to prepare your ideas or write your response

# Notes:
# -
# -
# -

print("Task preparation area")

# %% [markdown]
# ---
#
# ## 🎉 Module 22 Complete!
#
# Congratulations! You've finished **Connectors and Linking Words - Because, So, But, Although**!
#
# ### What You've Achieved
#
# [DONE] Completed 14 introduction sections
# [DONE] Practiced through 84 exercises
# [DONE] Created 10 personalized activities
# [DONE] Communicated in 8 real-world tasks
#
# ### Mastery Checklist
#
# Can you confidently:
# - [ ] Use 'because' and 'so' to connect cause and result
# - [ ] Understand the difference between 'because' (reason) and 'so' (result)
# - [ ] Use 'but' to express contrast between ideas
# - [ ] Use 'although' for concession (despite contrast)
# - [ ] Apply correct punctuation with connectors
#
# ### Time Investment
#
# You've invested approximately 5-6 hours in this module. Well done!
#
# ### Next Steps
#
# Continue to **Module 23: Relative Clauses - Who, Which, That, Where**
#
# ### Spaced Repetition
#
# Review this module after:
# - 1 day
# - 3 days
# - 7 days
# - 14 days
# - 30 days
#
# ---
#
# Progress: Module Complete! 4 of 4 phases done
