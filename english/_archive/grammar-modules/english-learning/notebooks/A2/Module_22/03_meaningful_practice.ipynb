# %% [markdown]
# # A2 Module 22: Connectors and Linking Words - Because, So, But, Although
# ## Phase 3: Meaningful Practice
#
# **Total Activities:** 10
# **Focus:** Personal application of connectors
#
# ---
#
# ## Welcome to Meaningful Practice!
#
# In this phase, you'll create personal content using connectors.
#
# ### Why Meaningful Practice?
#
# Research shows that when you create sentences about YOUR life, you remember them better!
#
# ### Activity Structure
#
# Each activity asks you to:
# 1. Think about your own experiences
# 2. Create 8-10 sentences using the grammar structure
# 3. Make them true and meaningful for YOU
#
# **Let's make it personal!**
#
# ---

# %% [markdown]
# ## Activity 1: Why I Do Things - Because
#
# **Objective:** Apply connectors in a personal, meaningful context.
#
# **Instructions:**
#
# [Detailed instructions to be added based on activity type]
#
# **Your Turn:**
#
# Create 8-10 sentences about your own life using the connectors structure.

# %%
# Activity 1: Why I Do Things - Because

# Write your sentences here
# Example format:

sentences = [
    "1. [Your sentence here]",
    "2. [Your sentence here]",
    "3. [Your sentence here]",
    # Add 8-10 sentences total
]

for sentence in sentences:
    print(sentence)

# %% [markdown]
# ## Activity 2: Results of My Actions - So
#
# **Objective:** Apply connectors in a personal, meaningful context.
#
# **Instructions:**
#
# [Detailed instructions to be added based on activity type]
#
# **Your Turn:**
#
# Create 8-10 sentences about your own life using the connectors structure.

# %%
# Activity 2: Results of My Actions - So

# Write your sentences here
# Example format:

sentences = [
    "1. [Your sentence here]",
    "2. [Your sentence here]",
    "3. [Your sentence here]",
    # Add 8-10 sentences total
]

for sentence in sentences:
    print(sentence)

# %% [markdown]
# ## Activity 3: Contrasts in My Life - But
#
# **Objective:** Apply connectors in a personal, meaningful context.
#
# **Instructions:**
#
# [Detailed instructions to be added based on activity type]
#
# **Your Turn:**
#
# Create 8-10 sentences about your own life using the connectors structure.

# %%
# Activity 3: Contrasts in My Life - But

# Write your sentences here
# Example format:

sentences = [
    "1. [Your sentence here]",
    "2. [Your sentence here]",
    "3. [Your sentence here]",
    # Add 8-10 sentences total
]

for sentence in sentences:
    print(sentence)

# %% [markdown]
# ## Activity 4: Despite Difficulties - Although
#
# **Objective:** Apply connectors in a personal, meaningful context.
#
# **Instructions:**
#
# [Detailed instructions to be added based on activity type]
#
# **Your Turn:**
#
# Create 8-10 sentences about your own life using the connectors structure.

# %%
# Activity 4: Despite Difficulties - Although

# Write your sentences here
# Example format:

sentences = [
    "1. [Your sentence here]",
    "2. [Your sentence here]",
    "3. [Your sentence here]",
    # Add 8-10 sentences total
]

for sentence in sentences:
    print(sentence)

# %% [markdown]
# ## Activity 5: My Daily Life with Connectors
#
# **Objective:** Apply connectors in a personal, meaningful context.
#
# **Instructions:**
#
# [Detailed instructions to be added based on activity type]
#
# **Your Turn:**
#
# Create 8-10 sentences about your own life using the connectors structure.

# %%
# Activity 5: My Daily Life with Connectors

# Write your sentences here
# Example format:

sentences = [
    "1. [Your sentence here]",
    "2. [Your sentence here]",
    "3. [Your sentence here]",
    # Add 8-10 sentences total
]

for sentence in sentences:
    print(sentence)

# %% [markdown]
# ## Activity 6: Explaining My Choices
#
# **Objective:** Apply connectors in a personal, meaningful context.
#
# **Instructions:**
#
# [Detailed instructions to be added based on activity type]
#
# **Your Turn:**
#
# Create 8-10 sentences about your own life using the connectors structure.

# %%
# Activity 6: Explaining My Choices

# Write your sentences here
# Example format:

sentences = [
    "1. [Your sentence here]",
    "2. [Your sentence here]",
    "3. [Your sentence here]",
    # Add 8-10 sentences total
]

for sentence in sentences:
    print(sentence)

# %% [markdown]
# ## Activity 7: My Opinions with Reasons
#
# **Objective:** Apply connectors in a personal, meaningful context.
#
# **Instructions:**
#
# [Detailed instructions to be added based on activity type]
#
# **Your Turn:**
#
# Create 8-10 sentences about your own life using the connectors structure.

# %%
# Activity 7: My Opinions with Reasons

# Write your sentences here
# Example format:

sentences = [
    "1. [Your sentence here]",
    "2. [Your sentence here]",
    "3. [Your sentence here]",
    # Add 8-10 sentences total
]

for sentence in sentences:
    print(sentence)

# %% [markdown]
# ## Activity 8: Describing My Personality
#
# **Objective:** Apply connectors in a personal, meaningful context.
#
# **Instructions:**
#
# [Detailed instructions to be added based on activity type]
#
# **Your Turn:**
#
# Create 8-10 sentences about your own life using the connectors structure.

# %%
# Activity 8: Describing My Personality

# Write your sentences here
# Example format:

sentences = [
    "1. [Your sentence here]",
    "2. [Your sentence here]",
    "3. [Your sentence here]",
    # Add 8-10 sentences total
]

for sentence in sentences:
    print(sentence)

# %% [markdown]
# ## Activity 9: My Past Experiences with Connectors
#
# **Objective:** Apply connectors in a personal, meaningful context.
#
# **Instructions:**
#
# [Detailed instructions to be added based on activity type]
#
# **Your Turn:**
#
# Create 8-10 sentences about your own life using the connectors structure.

# %%
# Activity 9: My Past Experiences with Connectors

# Write your sentences here
# Example format:

sentences = [
    "1. [Your sentence here]",
    "2. [Your sentence here]",
    "3. [Your sentence here]",
    # Add 8-10 sentences total
]

for sentence in sentences:
    print(sentence)

# %% [markdown]
# ## Activity 10: My Future Plans with Logical Connections
#
# **Objective:** Apply connectors in a personal, meaningful context.
#
# **Instructions:**
#
# [Detailed instructions to be added based on activity type]
#
# **Your Turn:**
#
# Create 8-10 sentences about your own life using the connectors structure.

# %%
# Activity 10: My Future Plans with Logical Connections

# Write your sentences here
# Example format:

sentences = [
    "1. [Your sentence here]",
    "2. [Your sentence here]",
    "3. [Your sentence here]",
    # Add 8-10 sentences total
]

for sentence in sentences:
    print(sentence)

# %% [markdown]
# ---
#
# ## Fantastic!
#
# You've completed Phase 3 of Module 22 - all 10 meaningful activities!
#
# ### What You've Accomplished
#
# You've created personalized content using connectors - this is YOUR English!
#
# ### Next Steps
#
# Continue to **Phase 4: Communicative Practice** for real-world communication tasks.
#
# ---
#
# 📚 Progress: Phase 3 of 4 complete
