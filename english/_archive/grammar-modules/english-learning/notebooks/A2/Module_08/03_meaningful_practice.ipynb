# %% [markdown]
# # Module 08: Future Time Clauses (when, as soon as, until) - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using future time clauses (when, as soon as, until)

# %% [markdown]
# ## Activity 1: Personal Experience 1
#
# **Task:** [Description to be added]
#
# ### Instructions:
# 1. Write 8-10 sentences using the target grammar
# 2. Use affirmative, negative, and question forms
# 3. Include appropriate time expressions
# 4. Make it personal and specific
#
# **Example:**
# [Model answer to be added]

# %%
# Activity 1: Personal Experience 1
print("Personal Experience 1")
print("=" * 60)
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 2: Personal Experience 2
#
# **Task:** [Description to be added]
#
# ### Instructions:
# 1. Write 8-10 sentences using the target grammar
# 2. Use affirmative, negative, and question forms
# 3. Include appropriate time expressions
# 4. Make it personal and specific
#
# **Example:**
# [Model answer to be added]

# %%
# Activity 2: Personal Experience 2
print("Personal Experience 2")
print("=" * 60)
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 3: Daily Life Application
#
# **Task:** [Description to be added]
#
# ### Instructions:
# 1. Write 8-10 sentences using the target grammar
# 2. Use affirmative, negative, and question forms
# 3. Include appropriate time expressions
# 4. Make it personal and specific
#
# **Example:**
# [Model answer to be added]

# %%
# Activity 3: Daily Life Application
print("Daily Life Application")
print("=" * 60)
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 4: Future Plans
#
# **Task:** [Description to be added]
#
# ### Instructions:
# 1. Write 8-10 sentences using the target grammar
# 2. Use affirmative, negative, and question forms
# 3. Include appropriate time expressions
# 4. Make it personal and specific
#
# **Example:**
# [Model answer to be added]

# %%
# Activity 4: Future Plans
print("Future Plans")
print("=" * 60)
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 5: Past Events
#
# **Task:** [Description to be added]
#
# ### Instructions:
# 1. Write 8-10 sentences using the target grammar
# 2. Use affirmative, negative, and question forms
# 3. Include appropriate time expressions
# 4. Make it personal and specific
#
# **Example:**
# [Model answer to be added]

# %%
# Activity 5: Past Events
print("Past Events")
print("=" * 60)
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 6: Expressing Opinions
#
# **Task:** [Description to be added]
#
# ### Instructions:
# 1. Write 8-10 sentences using the target grammar
# 2. Use affirmative, negative, and question forms
# 3. Include appropriate time expressions
# 4. Make it personal and specific
#
# **Example:**
# [Model answer to be added]

# %%
# Activity 6: Expressing Opinions
print("Expressing Opinions")
print("=" * 60)
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 7: Describing Situations
#
# **Task:** [Description to be added]
#
# ### Instructions:
# 1. Write 8-10 sentences using the target grammar
# 2. Use affirmative, negative, and question forms
# 3. Include appropriate time expressions
# 4. Make it personal and specific
#
# **Example:**
# [Model answer to be added]

# %%
# Activity 7: Describing Situations
print("Describing Situations")
print("=" * 60)
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 8: Making Comparisons
#
# **Task:** [Description to be added]
#
# ### Instructions:
# 1. Write 8-10 sentences using the target grammar
# 2. Use affirmative, negative, and question forms
# 3. Include appropriate time expressions
# 4. Make it personal and specific
#
# **Example:**
# [Model answer to be added]

# %%
# Activity 8: Making Comparisons
print("Making Comparisons")
print("=" * 60)
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 9: Telling Stories
#
# **Task:** [Description to be added]
#
# ### Instructions:
# 1. Write 8-10 sentences using the target grammar
# 2. Use affirmative, negative, and question forms
# 3. Include appropriate time expressions
# 4. Make it personal and specific
#
# **Example:**
# [Model answer to be added]

# %%
# Activity 9: Telling Stories
print("Telling Stories")
print("=" * 60)
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 10: Creative Writing
#
# **Task:** [Description to be added]
#
# ### Instructions:
# 1. Write 8-10 sentences using the target grammar
# 2. Use affirmative, negative, and question forms
# 3. Include appropriate time expressions
# 4. Make it personal and specific
#
# **Example:**
# [Model answer to be added]

# %%
# Activity 10: Creative Writing
print("Creative Writing")
print("=" * 60)
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare!")
