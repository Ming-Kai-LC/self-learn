# %% [markdown]
# # Module 14: May/Might/Could - Possibility and Permission - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks focusing on possibility, permission, predictions, uncertainty

# %% [markdown]
# ## Task 1: Prediction Competition
#
# **Modal Focus:** may/might/could
# **Communicative Goal:** permission
#
# ### Instructions:
# - Work in pairs or small groups
# - Use may/might/could throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use may/might/could for permission
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 1: Prediction Competition
print("Prediction Competition")
print("=" * 60)
print(f"\nCommunicative Goal: permission")
print(f"\nUseful may/might/could questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: Permission Role-Plays
#
# **Modal Focus:** may/might/could
# **Communicative Goal:** predictions
#
# ### Instructions:
# - Work in pairs or small groups
# - Use may/might/could throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use may/might/could for predictions
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 2: Permission Role-Plays
print("Permission Role-Plays")
print("=" * 60)
print(f"\nCommunicative Goal: predictions")
print(f"\nUseful may/might/could questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: Mystery Situation Guessing Game
#
# **Modal Focus:** may/might/could
# **Communicative Goal:** uncertainty
#
# ### Instructions:
# - Work in pairs or small groups
# - Use may/might/could throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use may/might/could for uncertainty
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 3: Mystery Situation Guessing Game
print("Mystery Situation Guessing Game")
print("=" * 60)
print(f"\nCommunicative Goal: uncertainty")
print(f"\nUseful may/might/could questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Future Possibility Discussions
#
# **Modal Focus:** may/might/could
# **Communicative Goal:** possibility
#
# ### Instructions:
# - Work in pairs or small groups
# - Use may/might/could throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use may/might/could for possibility
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 4: Future Possibility Discussions
print("Future Possibility Discussions")
print("=" * 60)
print(f"\nCommunicative Goal: possibility")
print(f"\nUseful may/might/could questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: Polite Request Scenarios
#
# **Modal Focus:** may/might/could
# **Communicative Goal:** permission
#
# ### Instructions:
# - Work in pairs or small groups
# - Use may/might/could throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use may/might/could for permission
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 5: Polite Request Scenarios
print("Polite Request Scenarios")
print("=" * 60)
print(f"\nCommunicative Goal: permission")
print(f"\nUseful may/might/could questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: Weather Forecast Presentation
#
# **Modal Focus:** may/might/could
# **Communicative Goal:** predictions
#
# ### Instructions:
# - Work in pairs or small groups
# - Use may/might/could throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use may/might/could for predictions
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 6: Weather Forecast Presentation
print("Weather Forecast Presentation")
print("=" * 60)
print(f"\nCommunicative Goal: predictions")
print(f"\nUseful may/might/could questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Possibility Interview
#
# **Modal Focus:** may/might/could
# **Communicative Goal:** uncertainty
#
# ### Instructions:
# - Work in pairs or small groups
# - Use may/might/could throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use may/might/could for uncertainty
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 7: Possibility Interview
print("Possibility Interview")
print("=" * 60)
print(f"\nCommunicative Goal: uncertainty")
print(f"\nUseful may/might/could questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Formal Permission Letters
#
# **Modal Focus:** may/might/could
# **Communicative Goal:** possibility
#
# ### Instructions:
# - Work in pairs or small groups
# - Use may/might/could throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use may/might/could for possibility
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 8: Formal Permission Letters
print("Formal Permission Letters")
print("=" * 60)
print(f"\nCommunicative Goal: possibility")
print(f"\nUseful may/might/could questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")
