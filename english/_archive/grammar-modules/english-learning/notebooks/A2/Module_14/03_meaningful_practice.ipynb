# %% [markdown]
# # Module 14: May/Might/Could - Possibility and Permission - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using may/might/could in real contexts

# %% [markdown]
# ## Activity 1: Making Predictions about Your Future
#
# **Modal Focus:** may/might/could
# **Context:** permission
#
# ### Instructions:
# 1. Write 8-10 sentences using may/might/could
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using may/might/could to be added]

# %%
# Activity 1: Making Predictions about Your Future
print("Making Predictions about Your Future")
print("=" * 60)
print(f"\nUse may/might/could to talk about: permission")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: may/might/could + base verb!")

# %% [markdown]
# ## Activity 2: Uncertain Situations
#
# **Modal Focus:** may/might/could
# **Context:** predictions
#
# ### Instructions:
# 1. Write 8-10 sentences using may/might/could
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using may/might/could to be added]

# %%
# Activity 2: Uncertain Situations
print("Uncertain Situations")
print("=" * 60)
print(f"\nUse may/might/could to talk about: predictions")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: may/might/could + base verb!")

# %% [markdown]
# ## Activity 3: Possibility of Events Happening
#
# **Modal Focus:** may/might/could
# **Context:** uncertainty
#
# ### Instructions:
# 1. Write 8-10 sentences using may/might/could
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using may/might/could to be added]

# %%
# Activity 3: Possibility of Events Happening
print("Possibility of Events Happening")
print("=" * 60)
print(f"\nUse may/might/could to talk about: uncertainty")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: may/might/could + base verb!")

# %% [markdown]
# ## Activity 4: Asking Permission Politely
#
# **Modal Focus:** may/might/could
# **Context:** possibility
#
# ### Instructions:
# 1. Write 8-10 sentences using may/might/could
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using may/might/could to be added]

# %%
# Activity 4: Asking Permission Politely
print("Asking Permission Politely")
print("=" * 60)
print(f"\nUse may/might/could to talk about: possibility")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: may/might/could + base verb!")

# %% [markdown]
# ## Activity 5: Weather Predictions
#
# **Modal Focus:** may/might/could
# **Context:** permission
#
# ### Instructions:
# 1. Write 8-10 sentences using may/might/could
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using may/might/could to be added]

# %%
# Activity 5: Weather Predictions
print("Weather Predictions")
print("=" * 60)
print(f"\nUse may/might/could to talk about: permission")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: may/might/could + base verb!")

# %% [markdown]
# ## Activity 6: Guessing Games with May/Might
#
# **Modal Focus:** may/might/could
# **Context:** predictions
#
# ### Instructions:
# 1. Write 8-10 sentences using may/might/could
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using may/might/could to be added]

# %%
# Activity 6: Guessing Games with May/Might
print("Guessing Games with May/Might")
print("=" * 60)
print(f"\nUse may/might/could to talk about: predictions")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: may/might/could + base verb!")

# %% [markdown]
# ## Activity 7: Mystery Situations
#
# **Modal Focus:** may/might/could
# **Context:** uncertainty
#
# ### Instructions:
# 1. Write 8-10 sentences using may/might/could
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using may/might/could to be added]

# %%
# Activity 7: Mystery Situations
print("Mystery Situations")
print("=" * 60)
print(f"\nUse may/might/could to talk about: uncertainty")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: may/might/could + base verb!")

# %% [markdown]
# ## Activity 8: Future Possibilities
#
# **Modal Focus:** may/might/could
# **Context:** possibility
#
# ### Instructions:
# 1. Write 8-10 sentences using may/might/could
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using may/might/could to be added]

# %%
# Activity 8: Future Possibilities
print("Future Possibilities")
print("=" * 60)
print(f"\nUse may/might/could to talk about: possibility")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: may/might/could + base verb!")

# %% [markdown]
# ## Activity 9: Polite Requests in Different Contexts
#
# **Modal Focus:** may/might/could
# **Context:** permission
#
# ### Instructions:
# 1. Write 8-10 sentences using may/might/could
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using may/might/could to be added]

# %%
# Activity 9: Polite Requests in Different Contexts
print("Polite Requests in Different Contexts")
print("=" * 60)
print(f"\nUse may/might/could to talk about: permission")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: may/might/could + base verb!")

# %% [markdown]
# ## Activity 10: Probability Discussions
#
# **Modal Focus:** may/might/could
# **Context:** predictions
#
# ### Instructions:
# 1. Write 8-10 sentences using may/might/could
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using may/might/could to be added]

# %%
# Activity 10: Probability Discussions
print("Probability Discussions")
print("=" * 60)
print(f"\nUse may/might/could to talk about: predictions")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: may/might/could + base verb!")
