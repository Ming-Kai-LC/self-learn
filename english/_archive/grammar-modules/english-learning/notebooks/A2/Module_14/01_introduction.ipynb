# %% [markdown]
# # Module 14: May/Might/Could - Possibility and Permission - Phase 1: Introduction
#
# ## Learning Objectives
# - Express possibility and uncertainty with may/might/could
# - Use may and could for polite permission requests
# - Understand the subtle differences between may/might/could
# - Make predictions about present and future situations
# - Form questions and negatives appropriately
#
# **Target Level:** A2
# **Estimated Time:** 5-6 hours
# **Modal Focus:** may/might/could
#
# ## Important Modal Verb Rules
#
# All modal verbs share these characteristics:
# - No -s in third person (he should, NOT he shoulds)
# - Followed by base verb (should go, NOT should to go)
# - No 'to' before the modal (NOT to should)
# - Questions: Modal + subject + base verb
# - Negatives: Modal + not + base verb

# %% [markdown]
# ## 1. Introduction to May/Might/Could
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Introduction to May/Might/Could - Practice
print("Introduction to May/Might/Could")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 2. Formation - Affirmative (may/might/could + base verb)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Affirmative (may/might/could + base verb) - Practice
print("Formation - Affirmative (may/might/could + base verb)")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 3. Formation - Negative (may not/might not/couldn't)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Negative (may not/might not/couldn't) - Practice
print("Formation - Negative (may not/might not/couldn't)")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 4. Expressing Possibility (50-50 chance)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Expressing Possibility (50-50 chance) - Practice
print("Expressing Possibility (50-50 chance)")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 5. Making Predictions about Present
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Making Predictions about Present - Practice
print("Making Predictions about Present")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 6. Making Predictions about Future
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Making Predictions about Future - Practice
print("Making Predictions about Future")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 7. Asking Permission - May I / Could I?
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Asking Permission - May I / Could I? - Practice
print("Asking Permission - May I / Could I?")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 8. Giving Permission - You may / You can
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Giving Permission - You may / You can - Practice
print("Giving Permission - You may / You can")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 9. Subtle Differences - May vs Might vs Could
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Subtle Differences - May vs Might vs Could - Practice
print("Subtle Differences - May vs Might vs Could")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 10. Certainty Scale (must → may/might/could → can't)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Certainty Scale (must → may/might/could → can't) - Practice
print("Certainty Scale (must → may/might/could → can't)")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 11. Common Collocations
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Collocations - Practice
print("Common Collocations")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 12. Pronunciation
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Pronunciation - Practice
print("Pronunciation")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 13. Common Mistakes
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Mistakes - Practice
print("Common Mistakes")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 14. Register - Formality Levels
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Register - Formality Levels - Practice
print("Register - Formality Levels")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")

# %% [markdown]
# ## 15. Practice Conversations - Possibilities and Permission
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with may/might/could:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** may/might/could + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Practice Conversations - Possibilities and Permission - Practice
print("Practice Conversations - Possibilities and Permission")
print("=" * 60)

examples = [
    "Example sentence 1 with may/might/could",
    "Example sentence 2 with may/might/could",
    "Example sentence 3 with may/might/could",
    "Example sentence 4 with may/might/could",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using may/might/could")
print("Remember: may/might/could + base verb (no 'to', no -s)")
