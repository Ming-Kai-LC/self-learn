# %% [markdown]
# # Module 11: Should/Shouldn't - Advice and Recommendations - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using should/shouldn't in real contexts

# %% [markdown]
# ## Activity 1: Give Advice to a Friend
#
# **Modal Focus:** should/shouldn't
# **Context:** recommendations
#
# ### Instructions:
# 1. Write 8-10 sentences using should/shouldn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using should/shouldn't to be added]

# %%
# Activity 1: Give Advice to a Friend
print("Give Advice to a Friend")
print("=" * 60)
print(f"\nUse should/shouldn't to talk about: recommendations")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: should/shouldn't + base verb!")

# %% [markdown]
# ## Activity 2: Health and Lifestyle Recommendations
#
# **Modal Focus:** should/shouldn't
# **Context:** opinions
#
# ### Instructions:
# 1. Write 8-10 sentences using should/shouldn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using should/shouldn't to be added]

# %%
# Activity 2: Health and Lifestyle Recommendations
print("Health and Lifestyle Recommendations")
print("=" * 60)
print(f"\nUse should/shouldn't to talk about: opinions")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: should/shouldn't + base verb!")

# %% [markdown]
# ## Activity 3: Study Tips and Suggestions
#
# **Modal Focus:** should/shouldn't
# **Context:** suggestions
#
# ### Instructions:
# 1. Write 8-10 sentences using should/shouldn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using should/shouldn't to be added]

# %%
# Activity 3: Study Tips and Suggestions
print("Study Tips and Suggestions")
print("=" * 60)
print(f"\nUse should/shouldn't to talk about: suggestions")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: should/shouldn't + base verb!")

# %% [markdown]
# ## Activity 4: Travel Advice
#
# **Modal Focus:** should/shouldn't
# **Context:** advice
#
# ### Instructions:
# 1. Write 8-10 sentences using should/shouldn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using should/shouldn't to be added]

# %%
# Activity 4: Travel Advice
print("Travel Advice")
print("=" * 60)
print(f"\nUse should/shouldn't to talk about: advice")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: should/shouldn't + base verb!")

# %% [markdown]
# ## Activity 5: Career Recommendations
#
# **Modal Focus:** should/shouldn't
# **Context:** recommendations
#
# ### Instructions:
# 1. Write 8-10 sentences using should/shouldn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using should/shouldn't to be added]

# %%
# Activity 5: Career Recommendations
print("Career Recommendations")
print("=" * 60)
print(f"\nUse should/shouldn't to talk about: recommendations")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: should/shouldn't + base verb!")

# %% [markdown]
# ## Activity 6: Should I or Shouldn't I? - Personal Decisions
#
# **Modal Focus:** should/shouldn't
# **Context:** opinions
#
# ### Instructions:
# 1. Write 8-10 sentences using should/shouldn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using should/shouldn't to be added]

# %%
# Activity 6: Should I or Shouldn't I? - Personal Decisions
print("Should I or Shouldn't I? - Personal Decisions")
print("=" * 60)
print(f"\nUse should/shouldn't to talk about: opinions")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: should/shouldn't + base verb!")

# %% [markdown]
# ## Activity 7: Advice Column
#
# **Modal Focus:** should/shouldn't
# **Context:** suggestions
#
# ### Instructions:
# 1. Write 8-10 sentences using should/shouldn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using should/shouldn't to be added]

# %%
# Activity 7: Advice Column
print("Advice Column")
print("=" * 60)
print(f"\nUse should/shouldn't to talk about: suggestions")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: should/shouldn't + base verb!")

# %% [markdown]
# ## Activity 8: Environmental Suggestions
#
# **Modal Focus:** should/shouldn't
# **Context:** advice
#
# ### Instructions:
# 1. Write 8-10 sentences using should/shouldn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using should/shouldn't to be added]

# %%
# Activity 8: Environmental Suggestions
print("Environmental Suggestions")
print("=" * 60)
print(f"\nUse should/shouldn't to talk about: advice")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: should/shouldn't + base verb!")

# %% [markdown]
# ## Activity 9: Friendship Advice
#
# **Modal Focus:** should/shouldn't
# **Context:** recommendations
#
# ### Instructions:
# 1. Write 8-10 sentences using should/shouldn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using should/shouldn't to be added]

# %%
# Activity 9: Friendship Advice
print("Friendship Advice")
print("=" * 60)
print(f"\nUse should/shouldn't to talk about: recommendations")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: should/shouldn't + base verb!")

# %% [markdown]
# ## Activity 10: Self-Improvement Goals
#
# **Modal Focus:** should/shouldn't
# **Context:** opinions
#
# ### Instructions:
# 1. Write 8-10 sentences using should/shouldn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using should/shouldn't to be added]

# %%
# Activity 10: Self-Improvement Goals
print("Self-Improvement Goals")
print("=" * 60)
print(f"\nUse should/shouldn't to talk about: opinions")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: should/shouldn't + base verb!")
