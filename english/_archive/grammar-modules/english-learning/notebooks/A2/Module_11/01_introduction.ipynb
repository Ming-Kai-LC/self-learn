# %% [markdown]
# # Module 11: Should/Shouldn't - Advice and Recommendations - Phase 1: Introduction
#
# ## Learning Objectives
# - Form affirmative and negative sentences with should/shouldn't
# - Use should/shouldn't to give advice and recommendations
# - Form questions with should and give appropriate responses
# - Express opinions about what is right or wrong
# - Distinguish between strong obligation (must) and advice (should)
#
# **Target Level:** A2
# **Estimated Time:** 4-5 hours
# **Modal Focus:** should/shouldn't
#
# ## Important Modal Verb Rules
#
# All modal verbs share these characteristics:
# - No -s in third person (he should, NOT he shoulds)
# - Followed by base verb (should go, NOT should to go)
# - No 'to' before the modal (NOT to should)
# - Questions: Modal + subject + base verb
# - Negatives: Modal + not + base verb

# %% [markdown]
# ## 1. Introduction to Should/Shouldn't
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Introduction to Should/Shouldn't - Practice
print("Introduction to Should/Shouldn't")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 2. Formation - Affirmative (should + base verb)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Affirmative (should + base verb) - Practice
print("Formation - Affirmative (should + base verb)")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 3. Formation - Negative (shouldn't + base verb)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Negative (shouldn't + base verb) - Practice
print("Formation - Negative (shouldn't + base verb)")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 4. Formation - Questions (Should + subject + base verb?)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Questions (Should + subject + base verb?) - Practice
print("Formation - Questions (Should + subject + base verb?)")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 5. Short Answers (Yes, I should / No, I shouldn't)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Short Answers (Yes, I should / No, I shouldn't) - Practice
print("Short Answers (Yes, I should / No, I shouldn't)")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 6. Giving Advice and Recommendations
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Giving Advice and Recommendations - Practice
print("Giving Advice and Recommendations")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 7. Expressing Opinions (I think you should...)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Expressing Opinions (I think you should...) - Practice
print("Expressing Opinions (I think you should...)")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 8. Making Suggestions (We should...)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Making Suggestions (We should...) - Practice
print("Making Suggestions (We should...)")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 9. Should vs Must - Advice vs Obligation
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Should vs Must - Advice vs Obligation - Practice
print("Should vs Must - Advice vs Obligation")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 10. Common Collocations with Should
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Collocations with Should - Practice
print("Common Collocations with Should")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 11. Pronunciation and Contractions
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Pronunciation and Contractions - Practice
print("Pronunciation and Contractions")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 12. Common Mistakes with Should
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Mistakes with Should - Practice
print("Common Mistakes with Should")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")

# %% [markdown]
# ## 13. Practice Conversations - Giving Advice
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with should/shouldn't:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** should/shouldn't + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Practice Conversations - Giving Advice - Practice
print("Practice Conversations - Giving Advice")
print("=" * 60)

examples = [
    "Example sentence 1 with should/shouldn't",
    "Example sentence 2 with should/shouldn't",
    "Example sentence 3 with should/shouldn't",
    "Example sentence 4 with should/shouldn't",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using should/shouldn't")
print("Remember: should/shouldn't + base verb (no 'to', no -s)")
