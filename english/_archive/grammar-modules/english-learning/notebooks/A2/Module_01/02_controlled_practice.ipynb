# %% [markdown]
# # Module 01: Past Continuous Formation - Phase 2: Controlled Practice
#
# ## Overview
# 80 exercises to master past continuous formation
#
# **Exercise Types:**
# - Formation - Affirmative (10)
# - Formation - Negative (10)
# - Formation - Questions (10)
# - Short Answers (10)
# - Spelling -ing Forms (10)
# - Error Correction (10)
# - Gap Filling (10)
# - Time Expressions (5)
# - Was/Were Selection (10)
# - Mixed Forms (5)
#
# **Total: 80 exercises** *(Enhanced for stronger grammar foundation)*

# %% [markdown]
# ## Exercise Set: Formation - Affirmative (10 exercises)
#
# **Focus:** Form affirmative past continuous sentences
#
# ### Instructions:
# Complete all 10 exercises below. Check your answers at the end.

# %%
# Formation - Affirmative Exercises
from projects.english_learning.utils.feedback_system import ExerciseValidator

print("Formation - Affirmative")
print("=" * 60)

# Sample exercises (replace with actual exercises)
exercises = []
for i in range(1, 10 + 1):
    exercises.append(
        {"question": f"Exercise {i}: [Grammar exercise]", "answer": "[correct answer]"}
    )

for i, ex in enumerate(exercises, 1):
    print(f"{i}. {ex['question']}")

print("\n[Answers and explanations provided at end of notebook]")

# %% [markdown]
# ## Exercise Set: Formation - Negative (10 exercises)
#
# **Focus:** Form negative past continuous sentences
#
# ### Instructions:
# Complete all 10 exercises below. Check your answers at the end.

# %%
# Formation - Negative Exercises
from projects.english_learning.utils.feedback_system import ExerciseValidator

print("Formation - Negative")
print("=" * 60)

# Sample exercises (replace with actual exercises)
exercises = []
for i in range(1, 10 + 1):
    exercises.append(
        {"question": f"Exercise {i}: [Grammar exercise]", "answer": "[correct answer]"}
    )

for i, ex in enumerate(exercises, 1):
    print(f"{i}. {ex['question']}")

print("\n[Answers and explanations provided at end of notebook]")

# %% [markdown]
# ## Exercise Set: Formation - Questions (10 exercises)
#
# **Focus:** Form yes/no questions in past continuous
#
# ### Instructions:
# Complete all 10 exercises below. Check your answers at the end.

# %%
# Formation - Questions Exercises
from projects.english_learning.utils.feedback_system import ExerciseValidator

print("Formation - Questions")
print("=" * 60)

# Sample exercises (replace with actual exercises)
exercises = []
for i in range(1, 10 + 1):
    exercises.append(
        {"question": f"Exercise {i}: [Grammar exercise]", "answer": "[correct answer]"}
    )

for i, ex in enumerate(exercises, 1):
    print(f"{i}. {ex['question']}")

print("\n[Answers and explanations provided at end of notebook]")

# %% [markdown]
# ## Exercise Set: Short Answers (10 exercises)
#
# **Focus:** Give appropriate short answers
#
# ### Instructions:
# Complete all 10 exercises below. Check your answers at the end.

# %%
# Short Answers Exercises
from projects.english_learning.utils.feedback_system import ExerciseValidator

print("Short Answers")
print("=" * 60)

# Sample exercises (replace with actual exercises)
exercises = []
for i in range(1, 10 + 1):
    exercises.append(
        {"question": f"Exercise {i}: [Grammar exercise]", "answer": "[correct answer]"}
    )

for i, ex in enumerate(exercises, 1):
    print(f"{i}. {ex['question']}")

print("\n[Answers and explanations provided at end of notebook]")

# %% [markdown]
# ## Exercise Set: Spelling -ing Forms (10 exercises)
#
# **Focus:** Write correct -ing forms
#
# ### Instructions:
# Complete all 10 exercises below. Check your answers at the end.

# %%
# Spelling -ing Forms Exercises
from projects.english_learning.utils.feedback_system import ExerciseValidator

print("Spelling -ing Forms")
print("=" * 60)

# Sample exercises (replace with actual exercises)
exercises = []
for i in range(1, 10 + 1):
    exercises.append(
        {"question": f"Exercise {i}: [Grammar exercise]", "answer": "[correct answer]"}
    )

for i, ex in enumerate(exercises, 1):
    print(f"{i}. {ex['question']}")

print("\n[Answers and explanations provided at end of notebook]")

# %% [markdown]
# ## Exercise Set: Error Correction (10 exercises)
#
# **Focus:** Find and correct mistakes in past continuous
#
# ### Instructions:
# Complete all 10 exercises below. Check your answers at the end.

# %%
# Error Correction Exercises
from projects.english_learning.utils.feedback_system import ExerciseValidator

print("Error Correction")
print("=" * 60)

# Sample exercises (replace with actual exercises)
exercises = []
for i in range(1, 10 + 1):
    exercises.append(
        {"question": f"Exercise {i}: [Grammar exercise]", "answer": "[correct answer]"}
    )

for i, ex in enumerate(exercises, 1):
    print(f"{i}. {ex['question']}")

print("\n[Answers and explanations provided at end of notebook]")

# %% [markdown]
# ## Exercise Set: Gap Filling (10 exercises)
#
# **Focus:** Complete sentences with was/were + verb-ing
#
# ### Instructions:
# Complete all 10 exercises below. Check your answers at the end.

# %%
# Gap Filling Exercises
from projects.english_learning.utils.feedback_system import ExerciseValidator

print("Gap Filling")
print("=" * 60)

# Sample exercises (replace with actual exercises)
exercises = []
for i in range(1, 10 + 1):
    exercises.append(
        {"question": f"Exercise {i}: [Grammar exercise]", "answer": "[correct answer]"}
    )

for i, ex in enumerate(exercises, 1):
    print(f"{i}. {ex['question']}")

print("\n[Answers and explanations provided at end of notebook]")

# %% [markdown]
# ## Exercise Set: Time Expressions (5 exercises)
#
# **Focus:** Add appropriate time expressions
#
# ### Instructions:
# Complete all 5 exercises below. Check your answers at the end.

# %%
# Time Expressions Exercises
from projects.english_learning.utils.feedback_system import ExerciseValidator

print("Time Expressions")
print("=" * 60)

# Sample exercises (replace with actual exercises)
exercises = []
for i in range(1, 5 + 1):
    exercises.append(
        {"question": f"Exercise {i}: [Grammar exercise]", "answer": "[correct answer]"}
    )

for i, ex in enumerate(exercises, 1):
    print(f"{i}. {ex['question']}")

print("\n[Answers and explanations provided at end of notebook]")

# %% [markdown]
# ## Exercise Set: Was/Were Selection (10 exercises)
#
# **Focus:** Choose correct form of 'be'
#
# ### Instructions:
# Complete all 10 exercises below. Check your answers at the end.

# %%
# Was/Were Selection Exercises
from projects.english_learning.utils.feedback_system import ExerciseValidator

print("Was/Were Selection")
print("=" * 60)

# Sample exercises (replace with actual exercises)
exercises = []
for i in range(1, 10 + 1):
    exercises.append(
        {"question": f"Exercise {i}: [Grammar exercise]", "answer": "[correct answer]"}
    )

for i, ex in enumerate(exercises, 1):
    print(f"{i}. {ex['question']}")

print("\n[Answers and explanations provided at end of notebook]")

# %% [markdown]
# ## Exercise Set: Mixed Forms (5 exercises)
#
# **Focus:** Convert between affirmative, negative, and questions
#
# ### Instructions:
# Complete all 5 exercises below. Check your answers at the end.

# %%
# Mixed Forms Exercises
from projects.english_learning.utils.feedback_system import ExerciseValidator

print("Mixed Forms")
print("=" * 60)

# Sample exercises (replace with actual exercises)
exercises = []
for i in range(1, 5 + 1):
    exercises.append(
        {"question": f"Exercise {i}: [Grammar exercise]", "answer": "[correct answer]"}
    )

for i, ex in enumerate(exercises, 1):
    print(f"{i}. {ex['question']}")

print("\n[Answers and explanations provided at end of notebook]")
