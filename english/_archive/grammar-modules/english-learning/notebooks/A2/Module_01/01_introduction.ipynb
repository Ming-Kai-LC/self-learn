# %% [markdown]
# # Module 01: Past Continuous Formation - Phase 1: Introduction
#
# ## Learning Objectives
# - Understand the past continuous tense structure
# - Form affirmative, negative, and question sentences
# - Use past continuous for actions in progress in the past
# - Apply time expressions correctly
#
# **Target Level:** A2
# **Estimated Time:** 120-150 minutes

# %% [markdown]
# ## 1. Introduction to Past Continuous
#
# The past continuous describes actions that were in progress at a specific time in the past.
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 1. Introduction to Past Continuous - Practice
print("1. Introduction to Past Continuous")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 2. Formation - Affirmative
#
# Structure: Subject + was/were + verb-ing
# I/he/she/it was working
# You/we/they were working
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 2. Formation - Affirmative - Practice
print("2. Formation - Affirmative")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 3. Formation - Negative
#
# Structure: Subject + wasn't/weren't + verb-ing
# I wasn't sleeping
# They weren't studying
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 3. Formation - Negative - Practice
print("3. Formation - Negative")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 4. Formation - Questions
#
# Structure: Was/Were + subject + verb-ing?
# Was she cooking?
# Were they playing?
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 4. Formation - Questions - Practice
print("4. Formation - Questions")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 5. Short Answers
#
# Yes, I was. / No, I wasn't.
# Yes, they were. / No, they weren't.
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 5. Short Answers - Practice
print("5. Short Answers")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 6. Spelling Rules for -ing
#
# Regular: work → working
# Drop -e: make → making
# Double consonant: run → running
# Change -ie to -y: lie → lying
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 6. Spelling Rules for -ing - Practice
print("6. Spelling Rules for -ing")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 7. Time Expressions
#
# at 8 o'clock yesterday, this time last week, at that moment, while, when, all morning/afternoon/evening/night/day
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 7. Time Expressions - Practice
print("7. Time Expressions")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 8. Uses - Actions in Progress
#
# I was reading at 9 PM yesterday.
# They were sleeping when you called.
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 8. Uses - Actions in Progress - Practice
print("8. Uses - Actions in Progress")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 9. Uses - Parallel Actions
#
# While I was cooking, he was cleaning.
# She was studying while her brother was watching TV.
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 9. Uses - Parallel Actions - Practice
print("9. Uses - Parallel Actions")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 10. Uses - Background in Stories
#
# It was raining. People were walking quickly.
# The sun was shining and birds were singing.
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 10. Uses - Background in Stories - Practice
print("10. Uses - Background in Stories")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 11. Common Mistakes
#
# ❌ I was work (missing -ing)
# ❌ They was playing (wrong 'be' form)
# ❌ I were watching (wrong 'be' form)
# ✓ I was working
# ✓ They were playing
# ✓ I was watching
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 11. Common Mistakes - Practice
print("11. Common Mistakes")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 12. Contractions
#
# I was → I was (no contraction in affirmative)
# I was not → I wasn't
# We were not → We weren't
# Note: Contractions mainly in negative forms
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 12. Contractions - Practice
print("12. Contractions")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")

# %% [markdown]
# ## 13. Practice Conversations
#
# A: What were you doing at 8 PM yesterday?
# B: I was watching a movie.
# A: Were you alone?
# B: No, I wasn't. My friend was with me.
#
# ### Examples:
# - I was studying English at 7 PM.
# - She was cooking when I arrived.
# - Were they working yesterday afternoon?
# - We weren't sleeping at midnight.
#
# ### Key Grammar Points:
# - Use was with: I, he, she, it
# - Use were with: you, we, they

# %%
# 13. Practice Conversations - Practice
print("13. Practice Conversations")
print("=" * 60)

examples = [
    "I was reading a book at 10 PM.",
    "She was working when you called.",
    "They were playing football all afternoon.",
    "We weren't watching TV at that time.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using past continuous")
