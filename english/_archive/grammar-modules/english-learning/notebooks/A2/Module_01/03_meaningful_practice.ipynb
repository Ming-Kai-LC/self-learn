# %% [markdown]
# # Module 01: Past Continuous Formation - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using past continuous
#
# **Activities:**
# 1. Yesterday at This Time
# 2. Last Weekend Activities
# 3. My Morning Routine Yesterday
# 4. What I Was Doing When...
# 5. A Memorable Evening
# 6. Parallel Activities
# 7. Weather and Actions
# 8. During My Last Vacation
# 9. Last Night at Home
# 10. Background for a Story

# %% [markdown]
# ## Activity 1: Yesterday at This Time
#
# **Task:** Describe what you were doing at specific times yesterday
#
# **Instructions:**
# 1. Write 8-10 sentences using past continuous
# 2. Use affirmative, negative, and question forms
# 3. Include time expressions
# 4. Make it personal and specific
#
# **Example:**
# Yesterday at 8 PM, I was watching a movie. My sister wasn't studying; she was cooking dinner...

# %%
# Activity 1: Yesterday at This Time
print("Yesterday at This Time")
print("=" * 60)
print("\nDescribe what you were doing at specific times yesterday")
print()
print("Write your sentences below:")
print()

for j in range(1, 9):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare your activities!")

# %% [markdown]
# ## Activity 2: Last Weekend Activities
#
# **Task:** Write about your activities in progress last weekend
#
# **Instructions:**
# 1. Write 8-10 sentences using past continuous
# 2. Use affirmative, negative, and question forms
# 3. Include time expressions
# 4. Make it personal and specific
#
# **Example:**
# Yesterday at 8 PM, I was watching a movie. My sister wasn't studying; she was cooking dinner...

# %%
# Activity 2: Last Weekend Activities
print("Last Weekend Activities")
print("=" * 60)
print("\nWrite about your activities in progress last weekend")
print()
print("Write your sentences below:")
print()

for j in range(1, 9):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare your activities!")

# %% [markdown]
# ## Activity 3: My Morning Routine Yesterday
#
# **Task:** Describe what you were doing during different parts of yesterday morning
#
# **Instructions:**
# 1. Write 8-10 sentences using past continuous
# 2. Use affirmative, negative, and question forms
# 3. Include time expressions
# 4. Make it personal and specific
#
# **Example:**
# Yesterday at 8 PM, I was watching a movie. My sister wasn't studying; she was cooking dinner...

# %%
# Activity 3: My Morning Routine Yesterday
print("My Morning Routine Yesterday")
print("=" * 60)
print("\nDescribe what you were doing during different parts of yesterday morning")
print()
print("Write your sentences below:")
print()

for j in range(1, 9):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare your activities!")

# %% [markdown]
# ## Activity 4: What I Was Doing When...
#
# **Task:** Describe what you were doing when something happened
#
# **Instructions:**
# 1. Write 8-10 sentences using past continuous
# 2. Use affirmative, negative, and question forms
# 3. Include time expressions
# 4. Make it personal and specific
#
# **Example:**
# Yesterday at 8 PM, I was watching a movie. My sister wasn't studying; she was cooking dinner...

# %%
# Activity 4: What I Was Doing When...
print("What I Was Doing When...")
print("=" * 60)
print("\nDescribe what you were doing when something happened")
print()
print("Write your sentences below:")
print()

for j in range(1, 9):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare your activities!")

# %% [markdown]
# ## Activity 5: A Memorable Evening
#
# **Task:** Write about an evening, describing ongoing actions
#
# **Instructions:**
# 1. Write 8-10 sentences using past continuous
# 2. Use affirmative, negative, and question forms
# 3. Include time expressions
# 4. Make it personal and specific
#
# **Example:**
# Yesterday at 8 PM, I was watching a movie. My sister wasn't studying; she was cooking dinner...

# %%
# Activity 5: A Memorable Evening
print("A Memorable Evening")
print("=" * 60)
print("\nWrite about an evening, describing ongoing actions")
print()
print("Write your sentences below:")
print()

for j in range(1, 9):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare your activities!")

# %% [markdown]
# ## Activity 6: Parallel Activities
#
# **Task:** Describe two or more things happening at the same time
#
# **Instructions:**
# 1. Write 8-10 sentences using past continuous
# 2. Use affirmative, negative, and question forms
# 3. Include time expressions
# 4. Make it personal and specific
#
# **Example:**
# Yesterday at 8 PM, I was watching a movie. My sister wasn't studying; she was cooking dinner...

# %%
# Activity 6: Parallel Activities
print("Parallel Activities")
print("=" * 60)
print("\nDescribe two or more things happening at the same time")
print()
print("Write your sentences below:")
print()

for j in range(1, 9):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare your activities!")

# %% [markdown]
# ## Activity 7: Weather and Actions
#
# **Task:** Describe what you were doing in different weather conditions
#
# **Instructions:**
# 1. Write 8-10 sentences using past continuous
# 2. Use affirmative, negative, and question forms
# 3. Include time expressions
# 4. Make it personal and specific
#
# **Example:**
# Yesterday at 8 PM, I was watching a movie. My sister wasn't studying; she was cooking dinner...

# %%
# Activity 7: Weather and Actions
print("Weather and Actions")
print("=" * 60)
print("\nDescribe what you were doing in different weather conditions")
print()
print("Write your sentences below:")
print()

for j in range(1, 9):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare your activities!")

# %% [markdown]
# ## Activity 8: During My Last Vacation
#
# **Task:** Write about activities in progress during your vacation
#
# **Instructions:**
# 1. Write 8-10 sentences using past continuous
# 2. Use affirmative, negative, and question forms
# 3. Include time expressions
# 4. Make it personal and specific
#
# **Example:**
# Yesterday at 8 PM, I was watching a movie. My sister wasn't studying; she was cooking dinner...

# %%
# Activity 8: During My Last Vacation
print("During My Last Vacation")
print("=" * 60)
print("\nWrite about activities in progress during your vacation")
print()
print("Write your sentences below:")
print()

for j in range(1, 9):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare your activities!")

# %% [markdown]
# ## Activity 9: Last Night at Home
#
# **Task:** Describe what family members/roommates were doing last night
#
# **Instructions:**
# 1. Write 8-10 sentences using past continuous
# 2. Use affirmative, negative, and question forms
# 3. Include time expressions
# 4. Make it personal and specific
#
# **Example:**
# Yesterday at 8 PM, I was watching a movie. My sister wasn't studying; she was cooking dinner...

# %%
# Activity 9: Last Night at Home
print("Last Night at Home")
print("=" * 60)
print("\nDescribe what family members/roommates were doing last night")
print()
print("Write your sentences below:")
print()

for j in range(1, 9):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare your activities!")

# %% [markdown]
# ## Activity 10: Background for a Story
#
# **Task:** Create a story background using past continuous
#
# **Instructions:**
# 1. Write 8-10 sentences using past continuous
# 2. Use affirmative, negative, and question forms
# 3. Include time expressions
# 4. Make it personal and specific
#
# **Example:**
# Yesterday at 8 PM, I was watching a movie. My sister wasn't studying; she was cooking dinner...

# %%
# Activity 10: Background for a Story
print("Background for a Story")
print("=" * 60)
print("\nCreate a story background using past continuous")
print()
print("Write your sentences below:")
print()

for j in range(1, 9):
    print(f"{j}. _________________________________")

print("\nShare with a partner and compare your activities!")
