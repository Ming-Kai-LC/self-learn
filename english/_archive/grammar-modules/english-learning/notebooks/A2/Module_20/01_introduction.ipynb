# %% [markdown]
# # Module 20: Intensifiers and Descriptive Language - Phase 1: Introduction
#
# ## Learning Objectives
# - Use very/really/quite to intensify adjectives and adverbs
# - Understand 'too' for excessive degree (too expensive, too difficult)
# - Use 'enough' correctly (adjective + enough, enough + noun)
# - Distinguish between very (neutral) and too (negative implication)
# - Combine intensifiers with comparatives for emphasis
#
# **Target Level:** A2
# **Estimated Time:** 4-5 hours
# **Comparison Focus:** intensifiers
#
# ## Important Formation Rules
#
# - very/really/quite + adj/adv
# - too + adj
# - adj + enough
# - enough + noun
#
# ### Common Errors to Avoid:
# - ❌ more better → ✅ better
# - ❌ more taller → ✅ taller
# - ❌ She is taller her brother → ✅ She is taller than her brother

# %% [markdown]
# ## 1. Introduction to Intensifiers
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Introduction to Intensifiers - Practice
print("Introduction to Intensifiers")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 2. Very + Adjective/Adverb
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Very + Adjective/Adverb - Practice
print("Very + Adjective/Adverb")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 3. Really + Adjective/Adverb
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Really + Adjective/Adverb - Practice
print("Really + Adjective/Adverb")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 4. Quite + Adjective (British vs American usage)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Quite + Adjective (British vs American usage) - Practice
print("Quite + Adjective (British vs American usage)")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 5. Too + Adjective (excessive/negative)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Too + Adjective (excessive/negative) - Practice
print("Too + Adjective (excessive/negative)")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 6. Adjective/Adverb + Enough
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Adjective/Adverb + Enough - Practice
print("Adjective/Adverb + Enough")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 7. Enough + Noun
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Enough + Noun - Practice
print("Enough + Noun")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 8. Position Rules (very/too before, enough after)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Position Rules (very/too before, enough after) - Practice
print("Position Rules (very/too before, enough after)")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 9. Very vs Too - Understanding the Difference
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Very vs Too - Understanding the Difference - Practice
print("Very vs Too - Understanding the Difference")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 10. Combining Intensifiers with Comparatives
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Combining Intensifiers with Comparatives - Practice
print("Combining Intensifiers with Comparatives")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 11. Gradable vs Non-Gradable Adjectives
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Gradable vs Non-Gradable Adjectives - Practice
print("Gradable vs Non-Gradable Adjectives")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 12. Common Mistakes with Intensifiers
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Common Mistakes with Intensifiers - Practice
print("Common Mistakes with Intensifiers")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 13. Practice Conversations - Adding Emphasis
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with intensifiers:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Practice Conversations - Adding Emphasis - Practice
print("Practice Conversations - Adding Emphasis")
print("=" * 60)

# Formation reminder for intensifiers
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with intensifiers",
    "Example sentence 2 with intensifiers",
    "Example sentence 3 with intensifiers",
    "Example sentence 4 with intensifiers",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using intensifiers")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)
