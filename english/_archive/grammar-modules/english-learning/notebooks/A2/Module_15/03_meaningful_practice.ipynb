# %% [markdown]
# # Module 15: Would Like - Polite Requests and Preferences - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using would like in real contexts

# %% [markdown]
# ## Activity 1: Ordering at a Restaurant Politely
#
# **Modal Focus:** would like
# **Context:** preferences
#
# ### Instructions:
# 1. Write 8-10 sentences using would like
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using would like to be added]

# %%
# Activity 1: Ordering at a Restaurant Politely
print("Ordering at a Restaurant Politely")
print("=" * 60)
print(f"\nUse would like to talk about: preferences")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: would like + base verb!")

# %% [markdown]
# ## Activity 2: Making Travel Arrangements
#
# **Modal Focus:** would like
# **Context:** offers
#
# ### Instructions:
# 1. Write 8-10 sentences using would like
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using would like to be added]

# %%
# Activity 2: Making Travel Arrangements
print("Making Travel Arrangements")
print("=" * 60)
print(f"\nUse would like to talk about: offers")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: would like + base verb!")

# %% [markdown]
# ## Activity 3: Expressing Preferences
#
# **Modal Focus:** would like
# **Context:** invitations
#
# ### Instructions:
# 1. Write 8-10 sentences using would like
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using would like to be added]

# %%
# Activity 3: Expressing Preferences
print("Expressing Preferences")
print("=" * 60)
print(f"\nUse would like to talk about: invitations")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: would like + base verb!")

# %% [markdown]
# ## Activity 4: Party Planning and Invitations
#
# **Modal Focus:** would like
# **Context:** polite requests
#
# ### Instructions:
# 1. Write 8-10 sentences using would like
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using would like to be added]

# %%
# Activity 4: Party Planning and Invitations
print("Party Planning and Invitations")
print("=" * 60)
print(f"\nUse would like to talk about: polite requests")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: would like + base verb!")

# %% [markdown]
# ## Activity 5: Shopping Politely
#
# **Modal Focus:** would like
# **Context:** preferences
#
# ### Instructions:
# 1. Write 8-10 sentences using would like
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using would like to be added]

# %%
# Activity 5: Shopping Politely
print("Shopping Politely")
print("=" * 60)
print(f"\nUse would like to talk about: preferences")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: would like + base verb!")

# %% [markdown]
# ## Activity 6: Would Like vs Want - Politeness Practice
#
# **Modal Focus:** would like
# **Context:** offers
#
# ### Instructions:
# 1. Write 8-10 sentences using would like
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using would like to be added]

# %%
# Activity 6: Would Like vs Want - Politeness Practice
print("Would Like vs Want - Politeness Practice")
print("=" * 60)
print(f"\nUse would like to talk about: offers")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: would like + base verb!")

# %% [markdown]
# ## Activity 7: Making Offers to Help
#
# **Modal Focus:** would like
# **Context:** invitations
#
# ### Instructions:
# 1. Write 8-10 sentences using would like
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using would like to be added]

# %%
# Activity 7: Making Offers to Help
print("Making Offers to Help")
print("=" * 60)
print(f"\nUse would like to talk about: invitations")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: would like + base verb!")

# %% [markdown]
# ## Activity 8: Future Wishes and Desires
#
# **Modal Focus:** would like
# **Context:** polite requests
#
# ### Instructions:
# 1. Write 8-10 sentences using would like
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using would like to be added]

# %%
# Activity 8: Future Wishes and Desires
print("Future Wishes and Desires")
print("=" * 60)
print(f"\nUse would like to talk about: polite requests")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: would like + base verb!")

# %% [markdown]
# ## Activity 9: Formal Email Requests
#
# **Modal Focus:** would like
# **Context:** preferences
#
# ### Instructions:
# 1. Write 8-10 sentences using would like
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using would like to be added]

# %%
# Activity 9: Formal Email Requests
print("Formal Email Requests")
print("=" * 60)
print(f"\nUse would like to talk about: preferences")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: would like + base verb!")

# %% [markdown]
# ## Activity 10: Interview Situations
#
# **Modal Focus:** would like
# **Context:** offers
#
# ### Instructions:
# 1. Write 8-10 sentences using would like
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using would like to be added]

# %%
# Activity 10: Interview Situations
print("Interview Situations")
print("=" * 60)
print(f"\nUse would like to talk about: offers")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: would like + base verb!")
