# %% [markdown]
# # Module 15: Would Like - Polite Requests and Preferences - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks focusing on polite requests, preferences, offers, invitations

# %% [markdown]
# ## Task 1: Restaurant Role-Play
#
# **Modal Focus:** would like
# **Communicative Goal:** preferences
#
# ### Instructions:
# - Work in pairs or small groups
# - Use would like throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use would like for preferences
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 1: Restaurant Role-Play
print("Restaurant Role-Play")
print("=" * 60)
print(f"\nCommunicative Goal: preferences")
print(f"\nUseful would like questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: Planning a Party - Offers and Preferences
#
# **Modal Focus:** would like
# **Communicative Goal:** offers
#
# ### Instructions:
# - Work in pairs or small groups
# - Use would like throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use would like for offers
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 2: Planning a Party - Offers and Preferences
print("Planning a Party - Offers and Preferences")
print("=" * 60)
print(f"\nCommunicative Goal: offers")
print(f"\nUseful would like questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: Polite Customer Service Scenarios
#
# **Modal Focus:** would like
# **Communicative Goal:** invitations
#
# ### Instructions:
# - Work in pairs or small groups
# - Use would like throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use would like for invitations
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 3: Polite Customer Service Scenarios
print("Polite Customer Service Scenarios")
print("=" * 60)
print(f"\nCommunicative Goal: invitations")
print(f"\nUseful would like questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Making Invitations
#
# **Modal Focus:** would like
# **Communicative Goal:** polite requests
#
# ### Instructions:
# - Work in pairs or small groups
# - Use would like throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use would like for polite requests
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 4: Making Invitations
print("Making Invitations")
print("=" * 60)
print(f"\nCommunicative Goal: polite requests")
print(f"\nUseful would like questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: Shopping Role-Plays
#
# **Modal Focus:** would like
# **Communicative Goal:** preferences
#
# ### Instructions:
# - Work in pairs or small groups
# - Use would like throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use would like for preferences
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 5: Shopping Role-Plays
print("Shopping Role-Plays")
print("=" * 60)
print(f"\nCommunicative Goal: preferences")
print(f"\nUseful would like questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: Formal Meeting - Would Like Requests
#
# **Modal Focus:** would like
# **Communicative Goal:** offers
#
# ### Instructions:
# - Work in pairs or small groups
# - Use would like throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use would like for offers
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 6: Formal Meeting - Would Like Requests
print("Formal Meeting - Would Like Requests")
print("=" * 60)
print(f"\nCommunicative Goal: offers")
print(f"\nUseful would like questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Preference Survey and Presentation
#
# **Modal Focus:** would like
# **Communicative Goal:** invitations
#
# ### Instructions:
# - Work in pairs or small groups
# - Use would like throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use would like for invitations
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 7: Preference Survey and Presentation
print("Preference Survey and Presentation")
print("=" * 60)
print(f"\nCommunicative Goal: invitations")
print(f"\nUseful would like questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Polite Decline Practice
#
# **Modal Focus:** would like
# **Communicative Goal:** polite requests
#
# ### Instructions:
# - Work in pairs or small groups
# - Use would like throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use would like for polite requests
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 8: Polite Decline Practice
print("Polite Decline Practice")
print("=" * 60)
print(f"\nCommunicative Goal: polite requests")
print(f"\nUseful would like questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")
