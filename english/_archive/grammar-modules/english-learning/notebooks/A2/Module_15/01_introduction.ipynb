# %% [markdown]
# # Module 15: Would Like - Polite Requests and Preferences - Phase 1: Introduction
#
# ## Learning Objectives
# - Form sentences with would like + noun and would like to + verb
# - Distinguish between would like (polite) and want (direct)
# - Make polite offers and invitations using would like
# - Form questions: Would you like...? / What would you like?
# - Use contractions: I'd like, you'd like, he'd like
#
# **Target Level:** A2
# **Estimated Time:** 4-5 hours
# **Modal Focus:** would like
#
# ## Important Modal Verb Rules
#
# All modal verbs share these characteristics:
# - No -s in third person (he should, NOT he shoulds)
# - Followed by base verb (should go, NOT should to go)
# - No 'to' before the modal (NOT to should)
# - Questions: Modal + subject + base verb
# - Negatives: Modal + not + base verb

# %% [markdown]
# ## 1. Introduction to Would Like
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Introduction to Would Like - Practice
print("Introduction to Would Like")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 2. Formation - Would like + noun
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Would like + noun - Practice
print("Formation - Would like + noun")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 3. Formation - Would like to + verb
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Formation - Would like to + verb - Practice
print("Formation - Would like to + verb")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 4. Contractions - I'd like, you'd like, he'd like
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Contractions - I'd like, you'd like, he'd like - Practice
print("Contractions - I'd like, you'd like, he'd like")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 5. Questions - Would you like...?
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Questions - Would you like...? - Practice
print("Questions - Would you like...?")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 6. Questions - What would you like?
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Questions - What would you like? - Practice
print("Questions - What would you like?")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 7. Short Answers
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Short Answers - Practice
print("Short Answers")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 8. Would Like vs Want - Politeness
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Would Like vs Want - Politeness - Practice
print("Would Like vs Want - Politeness")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 9. Making Polite Requests
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Making Polite Requests - Practice
print("Making Polite Requests")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 10. Making Offers and Invitations
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Making Offers and Invitations - Practice
print("Making Offers and Invitations")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 11. Responding to Offers
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Responding to Offers - Practice
print("Responding to Offers")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 12. Common Collocations
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Collocations - Practice
print("Common Collocations")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")

# %% [markdown]
# ## 13. Common Mistakes
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples with would like:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Short answer]
#
# ### Key Grammar Points:
# - **Formation:** would like + base verb (NO 'to', NO -s)
# - **Meaning:** [Specific use to be added]
# - **Context:** [When to use this modal]
#
# ### Common Mistakes to Avoid:
# - ❌ WRONG: [Common error example]
# - ✅ CORRECT: [Corrected version]

# %%
# Common Mistakes - Practice
print("Common Mistakes")
print("=" * 60)

examples = [
    "Example sentence 1 with would like",
    "Example sentence 2 with would like",
    "Example sentence 3 with would like",
    "Example sentence 4 with would like",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using would like")
print("Remember: would like + base verb (no 'to', no -s)")
