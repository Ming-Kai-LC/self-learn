# %% [markdown]
# # Module 16: Comparative Adjectives - Formation and Use - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks focusing on comparative adjectives

# %% [markdown]
# ## Task 1: Comparison Shopping - Which One to Buy?
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use comparative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use comparative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 1: Comparison Shopping - Which One to Buy?
print("Comparison Shopping - Which One to Buy?")
print("=" * 60)
print(f"\nUse comparative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: Debate: City Life vs Country Life
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use comparative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use comparative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 2: Debate: City Life vs Country Life
print("Debate: City Life vs Country Life")
print("=" * 60)
print(f"\nUse comparative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: Comparing Two Tourist Destinations
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use comparative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use comparative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 3: Comparing Two Tourist Destinations
print("Comparing Two Tourist Destinations")
print("=" * 60)
print(f"\nUse comparative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Then vs Now - Interview Activity
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use comparative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use comparative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 4: Then vs Now - Interview Activity
print("Then vs Now - Interview Activity")
print("=" * 60)
print(f"\nUse comparative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: Product Comparison Presentation
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use comparative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use comparative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 5: Product Comparison Presentation
print("Product Comparison Presentation")
print("=" * 60)
print(f"\nUse comparative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: Comparing Different Solutions to a Problem
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use comparative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use comparative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 6: Comparing Different Solutions to a Problem
print("Comparing Different Solutions to a Problem")
print("=" * 60)
print(f"\nUse comparative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Two Options Decision-Making Role Play
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use comparative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use comparative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 7: Two Options Decision-Making Role Play
print("Two Options Decision-Making Role Play")
print("=" * 60)
print(f"\nUse comparative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Comparing Learning Strategies
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# - Work in pairs or small groups
# - Use comparative adjectives throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use comparative adjectives naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 8: Comparing Learning Strategies
print("Comparing Learning Strategies")
print("=" * 60)
print(f"\nUse comparative adjectives in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")
