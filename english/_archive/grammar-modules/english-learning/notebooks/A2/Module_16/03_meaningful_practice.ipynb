# %% [markdown]
# # Module 16: Comparative Adjectives - Formation and Use - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using comparative adjectives in real contexts

# %% [markdown]
# ## Activity 1: Compare Yourself to Family Members
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using comparative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using comparative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 1: Compare Yourself to Family Members
print("Compare Yourself to Family Members")
print("=" * 60)
print(f"\nUse comparative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 2: My City vs Another City
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using comparative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using comparative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 2: My City vs Another City
print("My City vs Another City")
print("=" * 60)
print(f"\nUse comparative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 3: This Year vs Last Year
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using comparative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using comparative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 3: This Year vs Last Year
print("This Year vs Last Year")
print("=" * 60)
print(f"\nUse comparative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 4: Comparing Two Favorite Things
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using comparative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using comparative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 4: Comparing Two Favorite Things
print("Comparing Two Favorite Things")
print("=" * 60)
print(f"\nUse comparative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 5: Before and After - Personal Changes
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using comparative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using comparative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 5: Before and After - Personal Changes
print("Before and After - Personal Changes")
print("=" * 60)
print(f"\nUse comparative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 6: Comparing Two Friends or Classmates
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using comparative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using comparative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 6: Comparing Two Friends or Classmates
print("Comparing Two Friends or Classmates")
print("=" * 60)
print(f"\nUse comparative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 7: Old Phone vs New Phone
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using comparative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using comparative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 7: Old Phone vs New Phone
print("Old Phone vs New Phone")
print("=" * 60)
print(f"\nUse comparative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 8: Comparing Weather in Different Seasons
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using comparative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using comparative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 8: Comparing Weather in Different Seasons
print("Comparing Weather in Different Seasons")
print("=" * 60)
print(f"\nUse comparative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 9: Comparing Two Jobs or Careers
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using comparative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using comparative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 9: Comparing Two Jobs or Careers
print("Comparing Two Jobs or Careers")
print("=" * 60)
print(f"\nUse comparative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 10: Comparing Learning Methods
#
# **Comparison Focus:** comparative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using comparative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using comparative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 10: Comparing Learning Methods
print("Comparing Learning Methods")
print("=" * 60)
print(f"\nUse comparative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")
