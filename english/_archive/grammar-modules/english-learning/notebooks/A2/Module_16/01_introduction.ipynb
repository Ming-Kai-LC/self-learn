# %% [markdown]
# # Module 16: Comparative Adjectives - Formation and Use - Phase 1: Introduction
#
# ## Learning Objectives
# - Form comparatives correctly: -er, more + adjective, irregular forms
# - Apply spelling rules when adding -er (double consonants, -y to -i)
# - Use 'than' correctly in comparative sentences
# - Distinguish between short adjective + -er and long adjective + more
# - Use irregular comparatives: better, worse, farther
#
# **Target Level:** A2
# **Estimated Time:** 5-6 hours
# **Comparison Focus:** comparative adjectives
#
# ## Important Formation Rules
#
# - adjective + -er + than
# - more + adjective + than
# - irregular forms
#
# ### Common Errors to Avoid:
# - ❌ more better → ✅ better
# - ❌ more taller → ✅ taller
# - ❌ She is taller her brother → ✅ She is taller than her brother

# %% [markdown]
# ## 1. Introduction to Comparative Adjectives
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Introduction to Comparative Adjectives - Practice
print("Introduction to Comparative Adjectives")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 2. Formation - Short Adjectives (adjective + -er)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Formation - Short Adjectives (adjective + -er) - Practice
print("Formation - Short Adjectives (adjective + -er)")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 3. Formation - Long Adjectives (more + adjective)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Formation - Long Adjectives (more + adjective) - Practice
print("Formation - Long Adjectives (more + adjective)")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 4. Formation - Two-Syllable Adjectives Ending in -y
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Formation - Two-Syllable Adjectives Ending in -y - Practice
print("Formation - Two-Syllable Adjectives Ending in -y")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 5. Spelling Rules - Doubling Consonants (big → bigger)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Spelling Rules - Doubling Consonants (big → bigger) - Practice
print("Spelling Rules - Doubling Consonants (big → bigger)")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 6. Spelling Rules - Dropping -e (nice → nicer)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Spelling Rules - Dropping -e (nice → nicer) - Practice
print("Spelling Rules - Dropping -e (nice → nicer)")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 7. Spelling Rules - Changing -y to -i (happy → happier)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Spelling Rules - Changing -y to -i (happy → happier) - Practice
print("Spelling Rules - Changing -y to -i (happy → happier)")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 8. Using 'Than' in Comparative Sentences
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Using 'Than' in Comparative Sentences - Practice
print("Using 'Than' in Comparative Sentences")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 9. Irregular Comparatives (good → better, bad → worse)
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Irregular Comparatives (good → better, bad → worse) - Practice
print("Irregular Comparatives (good → better, bad → worse)")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 10. Comparing People - Height, Age, Personality
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Comparing People - Height, Age, Personality - Practice
print("Comparing People - Height, Age, Personality")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 11. Comparing Things - Size, Price, Quality
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Comparing Things - Size, Price, Quality - Practice
print("Comparing Things - Size, Price, Quality")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 12. Comparing Places - Beauty, Size, Population
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Comparing Places - Beauty, Size, Population - Practice
print("Comparing Places - Beauty, Size, Population")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 13. Common Mistakes with Comparatives
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Common Mistakes with Comparatives - Practice
print("Common Mistakes with Comparatives")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 14. Pronunciation of -er Endings
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Pronunciation of -er Endings - Practice
print("Pronunciation of -er Endings")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)

# %% [markdown]
# ## 15. Practice Conversations - Making Comparisons
#
# [Content to be added: Detailed grammar explanation]
#
# ### Formation Rules:
# - **Short adjectives (1 syllable):** Add -er/-est (tall → taller → tallest)
# - **Long adjectives (3+ syllables):** Use more/most (beautiful → more beautiful → most beautiful)
# - **Two-syllable -y adjectives:** Change -y to -ier/-iest (happy → happier → happiest)
# - **Irregular forms:** Learn by heart (good → better → best, bad → worse → worst)
#
# ### Spelling Rules:
# 1. Double final consonant for CVC: big → bigger, hot → hotter
# 2. Drop final -e: nice → nicer, large → largest
# 3. Change -y to -i: easy → easier, pretty → prettier
#
# ### Examples with comparative adjectives:
# - Example 1: [Affirmative sentence]
# - Example 2: [Negative sentence]
# - Example 3: [Question]
# - Example 4: [Complex sentence]
#
# ### Common Mistakes:
# - ❌ WRONG: [Error example]
# - ✅ CORRECT: [Corrected version]
#
# ### Key Grammar Points:
# - Point 1: [Specific use to be added]
# - Point 2: [Context when to use]
# - Point 3: [Integration with other grammar]

# %%
# Practice Conversations - Making Comparisons - Practice
print("Practice Conversations - Making Comparisons")
print("=" * 60)

# Formation reminder for comparative adjectives
print("\nREMEMBER:")
print("- Short adjectives: add -er/-est")
print("- Long adjectives: use more/most")
print("- Irregular: good→better→best, bad→worse→worst")
print("\n" + "=" * 60)

examples = [
    "Example sentence 1 with comparative adjectives",
    "Example sentence 2 with comparative adjectives",
    "Example sentence 3 with comparative adjectives",
    "Example sentence 4 with comparative adjectives",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using comparative adjectives")
print(
    "Check: Correct spelling? Right form (-er/more)? 'Than' if comparative? 'The' if superlative?"
)
