# %% [markdown]
# # Module 11: Question Words - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Welcome to the final practice phase! Here you'll use question words in **realistic situations** and **creative tasks**.
#
# ### What You'll Do:
# - ✅ Conduct interviews using question words
# - ✅ Write email inquiries and information requests
# - ✅ Create dialogues and conversations
# - ✅ Complete real-world communication tasks
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from IPython.display import display, HTML
from spaced_repetition import SpacedRepetitionScheduler

# Initialize spaced repetition scheduler
scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Ready for real communication practice!")

# %% [markdown]
# ---
#
# ## Task 1: Job Interview Role-Play 💼
#
# ### Scenario:
# You're interviewing someone for a position at your company. Prepare and conduct the interview.
#
# ### Instructions:
# 1. Write 15 interview questions using different question words
# 2. Write the candidate's answers
# 3. Make it realistic!
#
# ### Include questions about:
# - Background (What, Where, When)
# - Experience (What, How long, Why)
# - Skills (How, What)
# - Motivation (Why)
#
# ### Minimum: 15 question-answer exchanges
#
# ---

# %% [markdown]
# ### Your Interview:
#
# **Position:** _______________ (e.g., Marketing Manager, Software Developer)
#
# **Interviewer (You):** Good morning! Thank you for coming. What is your name?
#
# **Candidate:** _______________________________________________
#
# **Interviewer:** _______________________________________________?
#
# **Candidate:** _______________________________________________
#
# **Interviewer:** _______________________________________________?
#
# **Candidate:** _______________________________________________
#
# _(Continue for at least 15 exchanges)_
#
# **Interviewer:** Thank you for your time. We'll contact you soon.
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 2: Write an Email Requesting Information ✉️
#
# ### Scenario:
# You want to enroll in a language school. Write an email asking for information.
#
# ### Include questions about:
# - Course details (What courses? What levels?)
# - Schedule (When do classes start? How long?)
# - Location (Where is the school?)
# - Cost (How much? What's included?)
# - Teachers (Who are the teachers? How experienced?)
# - Requirements (What do I need?)
#
# ### Minimum: 10 questions in your email
#
# ---

# %% [markdown]
# ### Your Email:
#
# **Subject:** Inquiry about English Courses
#
# Dear Sir/Madam,
#
# I am interested in enrolling in your English language school and would like to request some information.
#
# _______________________________________________?
#
# _______________________________________________?
#
# _______________________________________________?
#
# _______________________________________________?
#
# _______________________________________________?
#
# _______________________________________________?
#
# _______________________________________________?
#
# _______________________________________________?
#
# _______________________________________________?
#
# _______________________________________________?
#
# I look forward to your response.
#
# Best regards,
#
# [Your name]
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 3: First Day at University/Work Conversation 🎓
#
# ### Scenario:
# It's your first day at a new university or workplace. You meet someone and want to know more about them and the place.
#
# ### Instructions:
# Write a conversation where you:
# - Introduce yourself
# - Ask about the other person
# - Ask about the place (facilities, schedule, people)
# - Get practical information
#
# ### Use ALL question words (What, Where, Who, When, Why, How)
#
# ### Minimum: 16 exchanges
#
# ---

# %% [markdown]
# ### Your Conversation:
#
# **You:** Hi! I'm new here. This is my first day. What's your name?
#
# **Colleague:** _______________________________________________
#
# **You:** _______________________________________________?
#
# **Colleague:** _______________________________________________
#
# **You:** _______________________________________________?
#
# **Colleague:** _______________________________________________
#
# _(Continue for at least 16 exchanges)_
#
# **You:** Thank you so much for your help!
#
# **Colleague:** No problem! Welcome!
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 4: Plan a Trip Together 🗺️
#
# ### Scenario:
# You and a friend are planning a trip. Discuss the details by asking and answering questions.
#
# ### Discuss:
# - Destination (Where?)
# - Dates (When? How long?)
# - Activities (What will we do?)
# - Transportation (How will we get there?)
# - Accommodation (Where will we stay?)
# - Budget (How much?)
# - Companions (Who else is coming?)
# - Reasons (Why this destination?)
#
# ### Minimum: 14 exchanges
#
# ---

# %% [markdown]
# ### Your Planning Conversation:
#
# **You:** Let's plan our trip! Where do you want to go?
#
# **Friend:** _______________________________________________
#
# **You:** _______________________________________________?
#
# **Friend:** _______________________________________________
#
# **You:** _______________________________________________?
#
# **Friend:** _______________________________________________
#
# _(Continue for at least 14 exchanges)_
#
# **You:** Great! Let's book it!
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 5: Newspaper/Blog Interview 📰
#
# ### Scenario:
# You're a journalist interviewing someone interesting (a local hero, artist, business owner, athlete, etc.)
#
# ### Instructions:
# Write a complete interview for publication.
#
# ### Include:
# - Introduction (Who is this person? Why interview them?)
# - 12 interview questions covering their:
#   - Background and origin
#   - Current work/activities
#   - Motivations and reasons
#   - Future plans
#   - Advice for others
#
# ### Minimum: 12 question-answer pairs + introduction
#
# ---

# %% [markdown]
# ### Your Interview Article:
#
# **Title:** Interview with _______________ (person's name/role)
#
# **Introduction:**
#
# _Example: Today we speak with Maria Rodriguez, a local chef who opened her own restaurant last year..._
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **Interview:**
#
# **Journalist:** _______________________________________________?
#
# **Interviewee:** _______________________________________________
#
# **Journalist:** _______________________________________________?
#
# **Interviewee:** _______________________________________________
#
# _(Continue for at least 12 question-answer pairs)_
#
# ---
#
# **Conclusion:**
#
# _______________________________________________
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 6: Problem-Solving Conversation 💡
#
# ### Scenario:
# Your friend is having a problem (lost their phone, failed an exam, had a fight with family, etc.). Help them by asking questions to understand the situation.
#
# ### Use questions to:
# - Understand what happened (What? When? Where?)
# - Identify who was involved (Who?)
# - Understand the reasons (Why?)
# - Explore solutions (How? What can you do?)
#
# ### Minimum: 12 exchanges
#
# ---

# %% [markdown]
# ### Your Conversation:
#
# **Problem:** _______________ (describe the problem)
#
# **You:** Hey, you look upset. What's wrong?
#
# **Friend:** _______________________________________________
#
# **You:** Oh no! _______________________________________________?
#
# **Friend:** _______________________________________________
#
# **You:** _______________________________________________?
#
# **Friend:** _______________________________________________
#
# _(Continue for at least 12 exchanges)_
#
# **You:** Don't worry, we'll figure this out together!
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 7: Design a Survey 📊
#
# ### Scenario:
# You're conducting a survey about people's habits, preferences, or opinions.
#
# ### Instructions:
# 1. Choose a topic (e.g., "Daily Exercise Habits", "Social Media Use", "Food Preferences", "Work-Life Balance")
# 2. Write 20 survey questions using different question words
# 3. Answer the survey yourself
#
# ### Topic areas to cover:
# - Frequency and timing (When? How often?)
# - Reasons and motivations (Why?)
# - Methods and approaches (How?)
# - Preferences and choices (What? Which?)
# - People and influences (Who?)
# - Locations and places (Where?)
#
# ---

# %% [markdown]
# ### Your Survey:
#
# **Survey Topic:** _______________________________________________
#
# **Survey Questions and Your Answers:**
#
# 1. _______________________________________________?
#
#    Your answer: _______________________________________________
#
# 2. _______________________________________________?
#
#    Your answer: _______________________________________________
#
# 3. _______________________________________________?
#
#    Your answer: _______________________________________________
#
# _(Continue for 20 questions total)_
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 8: Meeting a Stranger - Complete Dialogue 🤝
#
# ### Scenario:
# You're at a social event (party, conference, gym, coffee shop). You start a conversation with someone you've never met.
#
# ### Instructions:
# Write a complete natural conversation that:
# - Starts with small talk
# - Progresses to getting to know each other
# - Includes finding common interests
# - Ends with exchanging contact information
#
# ### Requirements:
# - Minimum 18 exchanges
# - Use ALL question words naturally
# - Make it sound realistic
# - Show progression from strangers to potential friends
#
# ---

# %% [markdown]
# ### Your Complete Dialogue:
#
# **Setting:** _______________ (Where does this conversation happen?)
#
# **You:** Hi! _______________________________________________
#
# **Stranger:** _______________________________________________
#
# **You:** _______________________________________________?
#
# **Stranger:** _______________________________________________
#
# _(Continue for at least 18 exchanges)_
#
# **You:** It was nice meeting you! Let's stay in touch.
#
# **Stranger:** Definitely! What's your phone number?
#
# **You:** _______________________________________________
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## 🎓 Module Completion Assessment
#
# ### Self-Evaluation Checklist:
#
# Check ✅ if you can do these things confidently:
#
# - [ ] I can use WHAT questions to ask for information
# - [ ] I can use WHERE questions to ask about location
# - [ ] I can use WHO questions to ask about people
# - [ ] I can use WHEN questions to ask about time
# - [ ] I can use WHY questions and answer with BECAUSE
# - [ ] I can use HOW questions in different contexts
# - [ ] I know the correct word order for questions
# - [ ] I can mix different question words naturally in conversation
# - [ ] I can conduct an interview using various question words
# - [ ] I can write information requests using questions
#
# ### Reflection:
#
# **What did you learn from this module?**
#
# _______________________________________________
#
# **Which question word was most useful for you?**
#
# _______________________________________________
#
# **How confident do you feel with question words? (1-10)**
#
# ___/10
#
# **What will you practice more?**
#
# _______________________________________________
#
# ---

# %%
# Mark this module as complete and schedule review
# Uncomment and run when you've completed all tasks

# scheduler.mark_module_complete(
#     module_id="A1_Module_11",
#     module_name="Question Words",
#     score=85.0  # Enter your self-assessed score (0-100)
# )

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### Congratulations! 🎉
#
# You've completed **Module 11: Question Words**!
#
# ### Key Skills Mastered:
# - ✅ **WHAT** - Asking about things and information
# - ✅ **WHERE** - Asking about places and locations
# - ✅ **WHO** - Asking about people
# - ✅ **WHEN** - Asking about time
# - ✅ **WHY** - Asking for reasons (with BECAUSE)
# - ✅ **HOW** - Asking about method and condition
# - ✅ Correct question word order
# - ✅ Natural use in conversations
#
# ### Next Steps:
#
# 1. **Take a break!** ☕ Great job!
#
# 2. **Review**: Your first review is scheduled. Check the progress tracker.
#
# 3. **Continue Learning**: Move to **Module 12: Can/Can't**
#
# 4. **Practice Daily**: Use question words naturally in your conversations!
#
# ---
#
# ## 📊 Spaced Repetition Reminder
#
# Remember to review this module:
# - **Day 1**: Tomorrow
# - **Day 2**: In 2 days
# - **Day 4**: In 4 days
# - **Week 1**: In 7 days
# - **Week 2**: In 14 days
#
# Regular review ensures you **retain** what you learned!
#
# ---
#
# ## 🌟 Final Message
#
# **Excellent work!** You've mastered question words through:
# - ✅ Understanding all 6 question words
# - ✅ 68 controlled practice exercises
# - ✅ Personal meaningful practice
# - ✅ Real-world communicative tasks
#
# **You can now ask questions confidently!** 🚀
#
# See you in Module 12!
