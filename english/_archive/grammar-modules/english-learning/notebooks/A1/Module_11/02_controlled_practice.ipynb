# %% [markdown]
# # Module 11: Question Words - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Welcome to the practice phase! Here you'll complete exercises with **immediate feedback** to master question words.
#
# ### What You'll Do:
# - ✅ Choose correct question words
# - ✅ Form proper questions with each word
# - ✅ Match questions with appropriate answers
# - ✅ Correct common mistakes
# - ✅ Use question words in context
#
# ⏱️ **Estimated time:** 90-120 minutes
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise, create_progress_bar
from IPython.display import display, HTML

# Initialize validator and exercise system
validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("✅ Ready to practice! Complete all exercises below.")

# %% [markdown]
# ---
#
# ## Exercise Set 1: Choose the Correct Question Word
#
# Complete each question with the correct question word.
#
# ### Instructions:
# Type: What, Where, Who, When, Why, or How
#
# ---

# %%
# Exercise 1.1
exercise.create_fill_in_blank("1. ___ is your name?", "What")

# %%
# Exercise 1.2
exercise.create_fill_in_blank("2. ___ do you live?", "Where")

# %%
# Exercise 1.3
exercise.create_fill_in_blank("3. ___ is your teacher?", "Who")

# %%
# Exercise 1.4
exercise.create_fill_in_blank("4. ___ is your birthday?", "When")

# %%
# Exercise 1.5
exercise.create_fill_in_blank("5. ___ are you sad? (asking for reason)", "Why")

# %%
# Exercise 1.6
exercise.create_fill_in_blank("6. ___ are you? (asking about health)", "How")

# %%
# Exercise 1.7
exercise.create_fill_in_blank("7. ___ time is it?", "What")

# %%
# Exercise 1.8
exercise.create_fill_in_blank("8. ___ is the post office? (asking for location)", "Where")

# %%
# Exercise 1.9
exercise.create_fill_in_blank("9. ___ does the class start?", "When")

# %%
# Exercise 1.10
exercise.create_fill_in_blank("10. ___ do you go to work? (asking about method)", "How")

# %% [markdown]
# ---
#
# ## Exercise Set 2: Complete Questions with WHAT
#
# Complete these questions using WHAT.
#
# ---

# %%
# Exercise 2.1
exercise.create_fill_in_blank("1. ___ is this? (pointing at an object)", "What")

# %%
# Exercise 2.2
exercise.create_fill_in_blank("2. ___ do you do? (asking about job)", "What")

# %%
# Exercise 2.3
exercise.create_fill_in_blank("3. ___ color do you like?", "What")

# %%
# Exercise 2.4
exercise.create_fill_in_blank("4. ___ does she want?", "What")

# %%
# Exercise 2.5
exercise.create_fill_in_blank("5. ___ are you doing?", "What")

# %%
# Exercise 2.6
exercise.create_fill_in_blank("6. ___ is your favorite food?", "What")

# %% [markdown]
# ---
#
# ## Exercise Set 3: Complete Questions with WHERE
#
# Complete these questions using WHERE.
#
# ---

# %%
# Exercise 3.1
exercise.create_fill_in_blank("1. ___ are you from?", "Where")

# %%
# Exercise 3.2
exercise.create_fill_in_blank("2. ___ does she work?", "Where")

# %%
# Exercise 3.3
exercise.create_fill_in_blank("3. ___ is the bathroom?", "Where")

# %%
# Exercise 3.4
exercise.create_fill_in_blank("4. ___ do they live?", "Where")

# %%
# Exercise 3.5
exercise.create_fill_in_blank("5. ___ can I find a good restaurant?", "Where")

# %%
# Exercise 3.6
exercise.create_fill_in_blank("6. ___ is your car?", "Where")

# %% [markdown]
# ---
#
# ## Exercise Set 4: Complete Questions with WHO
#
# Complete these questions using WHO.
#
# ---

# %%
# Exercise 4.1
exercise.create_fill_in_blank("1. ___ is that woman?", "Who")

# %%
# Exercise 4.2
exercise.create_fill_in_blank("2. ___ is your best friend?", "Who")

# %%
# Exercise 4.3
exercise.create_fill_in_blank("3. ___ lives in this house?", "Who")

# %%
# Exercise 4.4
exercise.create_fill_in_blank("4. ___ wants ice cream?", "Who")

# %%
# Exercise 4.5
exercise.create_fill_in_blank("5. ___ are those people?", "Who")

# %%
# Exercise 4.6
exercise.create_fill_in_blank("6. ___ did you meet yesterday?", "Who")

# %% [markdown]
# ---
#
# ## Exercise Set 5: Complete Questions with WHEN
#
# Complete these questions using WHEN.
#
# ---

# %%
# Exercise 5.1
exercise.create_fill_in_blank("1. ___ is the party?", "When")

# %%
# Exercise 5.2
exercise.create_fill_in_blank("2. ___ do you start work?", "When")

# %%
# Exercise 5.3
exercise.create_fill_in_blank("3. ___ does the train leave?", "When")

# %%
# Exercise 5.4
exercise.create_fill_in_blank("4. ___ did you arrive?", "When")

# %%
# Exercise 5.5
exercise.create_fill_in_blank("5. ___ is your appointment?", "When")

# %%
# Exercise 5.6
exercise.create_fill_in_blank("6. ___ does the store close?", "When")

# %% [markdown]
# ---
#
# ## Exercise Set 6: Complete Questions with WHY (Answer with BECAUSE)
#
# Complete these questions using WHY.
#
# ---

# %%
# Exercise 6.1
exercise.create_fill_in_blank("1. ___ are you happy?", "Why")

# %%
# Exercise 6.2
exercise.create_fill_in_blank("2. ___ do you study English?", "Why")

# %%
# Exercise 6.3
exercise.create_fill_in_blank("3. ___ is she crying?", "Why")

# %%
# Exercise 6.4
exercise.create_fill_in_blank("4. ___ doesn't he eat meat?", "Why")

# %%
# Exercise 6.5
exercise.create_fill_in_blank("5. ___ did you call me?", "Why")

# %%
# Exercise 6.6
exercise.create_fill_in_blank("6. ___ are they late?", "Why")

# %% [markdown]
# ---
#
# ## Exercise Set 7: Complete Questions with HOW
#
# Complete these questions using HOW.
#
# ---

# %%
# Exercise 7.1
exercise.create_fill_in_blank("1. ___ are you today?", "How")

# %%
# Exercise 7.2
exercise.create_fill_in_blank("2. ___ do you go to school?", "How")

# %%
# Exercise 7.3
exercise.create_fill_in_blank("3. ___ old are you?", "How")

# %%
# Exercise 7.4
exercise.create_fill_in_blank("4. ___ much does it cost?", "How")

# %%
# Exercise 7.5
exercise.create_fill_in_blank("5. ___ many students are there?", "How")

# %%
# Exercise 7.6
exercise.create_fill_in_blank("6. ___ often do you exercise?", "How")

# %% [markdown]
# ---
#
# ## Exercise Set 8: Multiple Choice - Best Question Word
#
# Choose the best question word for each situation.
#
# ---

# %%
# Exercise 8.1
exercise.create_multiple_choice(
    "___ is your address? (You want to know the location)",
    {"A": "What", "B": "Where", "C": "How"},
    "A",
    "'What' is correct because we ask for specific information (the address itself), not just the location.",
)

# %%
# Exercise 8.2
exercise.create_multiple_choice(
    "___ are you from?",
    {"A": "What", "B": "Where", "C": "Who"},
    "B",
    "'Where' asks about place of origin.",
)

# %%
# Exercise 8.3
exercise.create_multiple_choice(
    "___ called you last night?",
    {"A": "What", "B": "Where", "C": "Who"},
    "C",
    "'Who' asks about the person.",
)

# %%
# Exercise 8.4
exercise.create_multiple_choice(
    "___ doesn't she come to the party?",
    {"A": "Why", "B": "When", "C": "How"},
    "A",
    "'Why' asks for the reason.",
)

# %%
# Exercise 8.5
exercise.create_multiple_choice(
    "___ is the meeting?",
    {"A": "Where", "B": "When", "C": "Both A and B"},
    "C",
    "Both work! 'Where is the meeting?' asks about location. 'When is the meeting?' asks about time.",
)

# %%
# Exercise 8.6
exercise.create_multiple_choice(
    "___ tall is your brother?",
    {"A": "What", "B": "How", "C": "Who"},
    "B",
    "'How' is used with adjectives like 'tall', 'old', 'big', etc.",
)

# %%
# Exercise 8.7
exercise.create_multiple_choice(
    "___ did you eat for breakfast?",
    {"A": "What", "B": "Where", "C": "When"},
    "A",
    "'What' asks about the food (thing).",
)

# %%
# Exercise 8.8
exercise.create_multiple_choice(
    "___ do you spell your name?",
    {"A": "What", "B": "How", "C": "Who"},
    "B",
    "'How' asks about the method/way of spelling.",
)

# %% [markdown]
# ---
#
# ## Exercise Set 9: Error Correction
#
# Find and correct the error in each question.
#
# ---

# %%
# Exercise 9.1
display(HTML("<p><strong>Incorrect:</strong> <u>What you are</u> doing?</p>"))
exercise.create_fill_in_blank("Corrected: ___ are you doing?", "What")

# %%
# Exercise 9.2
display(HTML("<p><strong>Incorrect:</strong> <u>When</u> is your name?</p>"))
exercise.create_fill_in_blank("Corrected: ___ is your name?", "What")

# %%
# Exercise 9.3
display(HTML("<p><strong>Incorrect:</strong> <u>What</u> are you from?</p>"))
exercise.create_fill_in_blank("Corrected: ___ are you from?", "Where")

# %%
# Exercise 9.4
display(HTML("<p><strong>Incorrect:</strong> Where <u>you live</u>?</p>"))
exercise.create_fill_in_blank("Corrected: Where ___ you live?", "do")

# %%
# Exercise 9.5
display(HTML("<p><strong>Incorrect:</strong> <u>Who does live</u> here?</p>"))
exercise.create_fill_in_blank("Corrected: Who ___ here?", "lives")

# %%
# Exercise 9.6
display(HTML("<p><strong>Incorrect:</strong> Why are you late? I <u>missed the bus</u>.</p>"))
exercise.create_fill_in_blank("Corrected: Why are you late? ___ I missed the bus.", "Because")

# %%
# Exercise 9.7
display(HTML("<p><strong>Incorrect:</strong> <u>How</u> time is it?</p>"))
exercise.create_fill_in_blank("Corrected: ___ time is it?", "What")

# %%
# Exercise 9.8
display(HTML("<p><strong>Incorrect:</strong> When <u>she starts</u> work?</p>"))
exercise.create_fill_in_blank("Corrected: When ___ she start work?", "does")

# %% [markdown]
# ---
#
# ## Exercise Set 10: Complete the Questions
#
# Complete each question with the appropriate question word and verb.
#
# ---

# %%
# Exercise 10.1
exercise.create_fill_in_blank("1. ___ is the capital of France? (asking about a place)", "What")

# %%
# Exercise 10.2
exercise.create_fill_in_blank("2. ___ does this bus go?", "Where")

# %%
# Exercise 10.3
exercise.create_fill_in_blank("3. ___ is knocking at the door?", "Who")

# %%
# Exercise 10.4
exercise.create_fill_in_blank("4. ___ did the accident happen?", "When")

# %%
# Exercise 10.5
exercise.create_fill_in_blank("5. ___ do you like this city? (asking for reason)", "Why")

# %%
# Exercise 10.6
exercise.create_fill_in_blank("6. ___ long does it take?", "How")

# %% [markdown]
# ---
#
# ## 📊 Your Score

# %%
# Display final score
validator.display_score()

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### If your score is:
# - **80%+**: Excellent! Move to **03_meaningful_practice.ipynb** ✅
# - **60-79%**: Good progress! Review the question word meanings, then continue 👍
# - **Below 60%**: Review **01_introduction.ipynb** and retry these exercises 📚
#
# ### Key Points to Remember:
# - **WHAT** = things, information
# - **WHERE** = places, locations
# - **WHO** = people
# - **WHEN** = time
# - **WHY** = reasons (answer with BECAUSE)
# - **HOW** = method, condition
# - Word order: **Wh-word + BE/DO/DOES + Subject**
# - Exception: WHO as subject doesn't need DO/DOES
#
# ---
#
# ### Continue to:
# **03_meaningful_practice.ipynb** - Ask and answer personal questions!
#
# ---
#
# **Great work!** 🌟 You've completed the controlled practice phase!
