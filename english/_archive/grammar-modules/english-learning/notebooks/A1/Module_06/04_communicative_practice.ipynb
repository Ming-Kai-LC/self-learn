# %% [markdown]
# # Module 6: Nouns and Plurals - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Welcome to the final practice phase! Here you'll use **plural nouns** in **realistic situations** and **creative tasks**.
#
# ### What You'll Do:
# - ✅ Describe busy scenes with many people and objects
# - ✅ Create inventory lists for real-world scenarios
# - ✅ Plan events and make lists of needed items
# - ✅ Write descriptions of places
# - ✅ Give recommendations using plurals
# - ✅ Solve practical problems using plural forms
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from IPython.display import display, HTML
from spaced_repetition import SpacedRepetitionScheduler

# Initialize spaced repetition scheduler
scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Ready for real communication practice!")

# %% [markdown]
# ---
#
# ## Task 1: Picture Description 📸
#
# ### Scenario:
# Imagine you're looking at a busy scene. Describe what you see using plural nouns.
#
# ### Choose ONE scene to describe:
# - **Option A:** A busy marketplace
# - **Option B:** A school playground during break time
# - **Option C:** A restaurant during lunch hour
# - **Option D:** A park on a sunny Sunday
#
# ### Instructions:
# Write a detailed description (150-200 words) including:
# - How many **people** are there? (Use men, women, children)
# - What **objects** can you see? (Use plurals)
# - What **actions** are happening?
# - What **sounds** can you hear?
#
# ### Example Start:
# "In the marketplace, there are many **people**. I can see five **women** selling vegetables, three **men** carrying boxes, and several **children** playing. There are dozens of **stalls** with colorful **fruits** and **vegetables**..."
#
# ---

# %% [markdown]
# ### Your Picture Description:
#
# **Scene I chose:** _______________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 2: Inventory Check 📋
#
# ### Scenario:
# You work at a store/office/school and need to create an inventory list. Count and list all items.
#
# ### Choose ONE location:
# - **Option A:** Electronics store
# - **Option B:** Classroom
# - **Option C:** Coffee shop
# - **Option D:** Gym/Fitness center
#
# ### Instructions:
# Create a detailed inventory with quantities. List at least 20 different items.
#
# ### Example (Coffee Shop):
# - 45 cups (small, medium, large)
# - 12 coffee machines
# - 30 plates
# - 50 spoons
# - 3 refrigerators
#
# ---

# %% [markdown]
# ### Your Inventory List:
#
# **Location:** _______________
#
# **INVENTORY CHECK - Date: _______________**
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# 5. _______________________________________________
#
# 6. _______________________________________________
#
# 7. _______________________________________________
#
# 8. _______________________________________________
#
# 9. _______________________________________________
#
# 10. _______________________________________________
#
# 11. _______________________________________________
#
# 12. _______________________________________________
#
# 13. _______________________________________________
#
# 14. _______________________________________________
#
# 15. _______________________________________________
#
# 16. _______________________________________________
#
# 17. _______________________________________________
#
# 18. _______________________________________________
#
# 19. _______________________________________________
#
# 20. _______________________________________________
#
# **Total number of items:** _______________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 3: Planning an Event 🎉
#
# ### Scenario:
# You're organizing an event and need to prepare a list of everything required.
#
# ### Choose ONE event:
# - **Option A:** Birthday party for 30 people
# - **Option B:** Office meeting for 15 people
# - **Option C:** Wedding reception for 100 people
# - **Option D:** School festival for 200 people
#
# ### Instructions:
# Create a complete list including:
# - Food and drinks (quantities)
# - Equipment needed
# - Decorations
# - People needed (staff, helpers)
# - Other supplies
#
# ---

# %% [markdown]
# ### Your Event Plan:
#
# **Event:** _______________
#
# **Number of guests:** _______________
#
# **Date:** _______________
#
# ---
#
# **FOOD & DRINKS:**
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# 5. _______________________________________________
#
# 6. _______________________________________________
#
# **EQUIPMENT:**
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# 5. _______________________________________________
#
# **DECORATIONS:**
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# **PEOPLE NEEDED:**
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# **OTHER SUPPLIES:**
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# 5. _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 4: Comparing Two Places 🔄
#
# ### Scenario:
# Compare two similar places. What are the differences in terms of quantities?
#
# ### Choose ONE comparison:
# - **Option A:** Your hometown vs the capital city
# - **Option B:** A small shop vs a supermarket
# - **Option C:** A public library vs a bookstore
# - **Option D:** A local gym vs a large fitness center
#
# ### Instructions:
# Write a comparison (150-200 words) focusing on quantities.
#
# ### Example:
# "My hometown has two schools, but the capital has hundreds of schools. In my hometown, there are only three hospitals, but the capital has more than fifty hospitals..."
#
# ---

# %% [markdown]
# ### Your Comparison:
#
# **Comparing:** _______________ and _______________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Conclusion:** Which one is better for you and why?
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 5: Travel Recommendations 🌍
#
# ### Scenario:
# A friend wants to visit your country/city. Give recommendations about places to visit, things to see, and foods to try.
#
# ### Instructions:
# Write a recommendation guide including:
# - Places to visit (how many museums, parks, etc.)
# - Foods to try (use plurals and uncountable nouns correctly)
# - Things to buy
# - Activities to do
#
# ### Minimum: 12 recommendations
#
# ---

# %% [markdown]
# ### Your Travel Guide:
#
# **Destination:** _______________
#
# **Best time to visit:** _______________
#
# ---
#
# **PLACES TO VISIT:**
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# **FOODS TO TRY:**
#
# 5. _______________________________________________
#
# 6. _______________________________________________
#
# 7. _______________________________________________
#
# 8. _______________________________________________
#
# **THINGS TO BUY:**
#
# 9. _______________________________________________
#
# 10. _______________________________________________
#
# 11. _______________________________________________
#
# **ACTIVITIES:**
#
# 12. _______________________________________________
#
# 13. _______________________________________________
#
# 14. _______________________________________________
#
# 15. _______________________________________________
#
# **Additional tips:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 6: Problem Solving - Lost and Found 🔍
#
# ### Scenario:
# You work at a Lost and Found office. Describe the items you have.
#
# ### Instructions:
# **Option A:** Write a list of lost items currently in the office (at least 25 items)
#
# **OR**
#
# **Option B:** Write a conversation between you and a person looking for lost items (minimum 16 exchanges)
#
# ### Use irregular plurals where possible:
# - keys, glasses, watches
# - children's toys
# - men's/women's accessories
#
# ---

# %% [markdown]
# ### Lost and Found:
#
# **OPTION A: Lost Items List**
#
# **LOST AND FOUND OFFICE - Current Items**
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# 5. _______________________________________________
#
# _(Continue to 25 items)_
#
# ---
#
# **OR**
#
# **OPTION B: Conversation**
#
# **You (Lost & Found):** Hello, how can I help you?
#
# **Customer:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Customer:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Customer:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Customer:** _______________________________________________
#
# _(Continue for at least 16 exchanges)_
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 7: Organizing a Space 🏠
#
# ### Scenario:
# You need to organize a messy space. Describe what you found and how you'll organize it.
#
# ### Choose ONE space:
# - **Option A:** A messy garage
# - **Option B:** A cluttered office
# - **Option C:** A disorganized kitchen
# - **Option D:** A chaotic storage room
#
# ### Instructions:
# Write a report (200-250 words) describing:
# 1. What items you found (use plurals!)
# 2. How many of each item
# 3. How you plan to organize them
# 4. What you will keep/throw away/donate
#
# ---

# %% [markdown]
# ### Your Organization Report:
#
# **Space:** _______________
#
# **BEFORE - What I Found:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **ORGANIZATION PLAN:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **ITEMS TO KEEP:**
#
# _______________________________________________
#
# _______________________________________________
#
# **ITEMS TO THROW AWAY:**
#
# _______________________________________________
#
# _______________________________________________
#
# **ITEMS TO DONATE:**
#
# _______________________________________________
#
# _______________________________________________
#
# **AFTER - How It's Organized:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 8: Create a Survey 📊
#
# ### Scenario:
# Create a survey asking people about quantities in their lives.
#
# ### Instructions:
# Write 15 survey questions asking about quantities. Use different question types.
#
# ### Example Questions:
# - How many books do you read per month?
# - How many cups of coffee do you drink daily?
# - How many people live in your home?
# - Do you have any children? How many?
#
# ### Categories to include:
# - Daily habits
# - Possessions
# - Work/Study
# - Food and drink
# - Free time
#
# ---

# %% [markdown]
# ### Your Survey:
#
# **SURVEY TITLE:** _______________
#
# **Purpose:** _______________________________________________
#
# ---
#
# **DAILY HABITS:**
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# **POSSESSIONS:**
#
# 4. _______________________________________________
#
# 5. _______________________________________________
#
# 6. _______________________________________________
#
# **WORK/STUDY:**
#
# 7. _______________________________________________
#
# 8. _______________________________________________
#
# 9. _______________________________________________
#
# **FOOD & DRINK:**
#
# 10. _______________________________________________
#
# 11. _______________________________________________
#
# 12. _______________________________________________
#
# **FREE TIME:**
#
# 13. _______________________________________________
#
# 14. _______________________________________________
#
# 15. _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ---
#
# ## 🎓 Module Completion Assessment
#
# ### Self-Evaluation Checklist:
#
# Check ✅ if you can do these things confidently:
#
# - [ ] I can form regular plurals by adding -s
# - [ ] I can add -es after s/x/z/ch/sh
# - [ ] I can change consonant + y to -ies
# - [ ] I know when to add -s after vowel + y
# - [ ] I can change f/fe to -ves correctly
# - [ ] I know irregular plurals (men, children, feet, teeth, etc.)
# - [ ] I know same-form plurals (sheep, deer, fish)
# - [ ] I understand countable vs uncountable nouns
# - [ ] I can use measure words with uncountable nouns
# - [ ] I can use plurals naturally in conversations
#
# ### Reflection:
#
# **What did you learn from this module?**
#
# _______________________________________________
#
# _______________________________________________
#
# **Which plural form is still most challenging?**
#
# _______________________________________________
#
# **How confident do you feel with plural nouns? (1-10)**
#
# ___/10
#
# **What's the most important rule to remember?**
#
# ⚠️ **Critical Rule:** _______________________________________________
#
# (Answer: Most plurals add -s, but watch for special cases! Irregular plurals must be memorized. Uncountable nouns have NO plural form.)
#
# ---

# %%
# Mark this module as complete and schedule review
# Uncomment and run when you've completed all tasks

# scheduler.mark_module_complete(
#     module_id="A1_Module_06",
#     module_name="Nouns and Plurals",
#     score=85.0  # Enter your self-assessed score (0-100)
# )

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### Congratulations! 🎉
#
# You've completed **Module 6: Nouns and Plurals**!
#
# ### Key Skills Mastered:
# - ✅ Regular plural formation (add -s)
# - ✅ Special plural endings (-es, -ies, -ves)
# - ✅ Irregular plurals (men, children, feet, teeth, mice)
# - ✅ Same-form plurals (sheep, deer, fish)
# - ✅ Countable vs uncountable nouns
# - ✅ Using measure words with uncountable nouns
# - ✅ Using plurals naturally in real communication
#
# ### Plural formation is essential! 📊
#
# You now know how to talk about quantities correctly. This is one of the most important skills in English!
#
# ### Next Steps:
#
# 1. **Take a break!** ☕ You've learned a lot about plurals!
#
# 2. **Review**: Your first review is scheduled. Check the progress tracker.
#
# 3. **Continue Learning**: Move to **Module 7: Possessives**
#
# 4. **Practice Daily**: Pay attention to plural forms when reading and listening to English!
#
# ---
#
# ## 📊 Spaced Repetition Reminder
#
# Remember to review this module:
# - **Day 1**: Tomorrow
# - **Day 2**: In 2 days
# - **Day 4**: In 4 days
# - **Week 1**: In 7 days
# - **Week 2**: In 14 days
#
# Regular review ensures you **retain** plural formation rules!
#
# ---
#
# ## 🌟 Final Message
#
# **Excellent work!** You've mastered plural nouns through:
# - ✅ Understanding 8 different plural formation rules
# - ✅ 65 controlled practice exercises
# - ✅ Meaningful practice with your personal life
# - ✅ Real-world communicative tasks
#
# **You can now use plural nouns correctly and naturally!** 🎊
#
# Ready for the next challenge? Let's continue to Module 7!
#
# ---
