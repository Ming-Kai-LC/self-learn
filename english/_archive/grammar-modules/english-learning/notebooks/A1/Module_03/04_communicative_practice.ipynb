# %% [markdown]
# # Module 3: Present Simple - Affirmative - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Welcome to the final practice phase! Here you'll use Present Simple in **realistic situations** and **creative tasks**.
#
# ### What You'll Do:
# - ✅ Role-play realistic conversations about daily routines
# - ✅ Interview people about their habits
# - ✅ Write emails and descriptions
# - ✅ Create stories using Present Simple
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from IPython.display import display, HTML
from spaced_repetition import SpacedRepetitionScheduler

# Initialize spaced repetition scheduler
scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Ready for real communication practice!")

# %% [markdown]
# ---
#
# ## Task 1: First Day at Work/School Role-Play 💼
#
# ### Scenario:
# It's your first day at a new job or school. You meet someone and talk about your daily routines.
#
# ### Instructions:
# Write a conversation where you:
# 1. Introduce yourself
# 2. Talk about your typical day
# 3. Ask about their routine
# 4. Discuss habits and hobbies
#
# ### Minimum: 12 exchanges
#
# ---

# %% [markdown]
# ### Write Your Conversation Here:
#
# **You:** Hi! I'm _______________. Nice to meet you.
#
# **New Colleague:** Nice to meet you too! I'm _______________.
#
# **You:** So, what time do you usually start work?
#
# **New Colleague:** _______________________________________________
#
# **You:** _______________________________________________
#
# **New Colleague:** _______________________________________________
#
# **You:** _______________________________________________
#
# **New Colleague:** _______________________________________________
#
# _(Continue for at least 12 exchanges)_
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 2: Interview a Friend or Family Member 🎤
#
# ### Scenario:
# You're writing an article about "A Day in the Life" of someone you know. Interview them!
#
# ### Instructions:
# 1. Write 10 interview questions using Present Simple
# 2. Write their answers (real or imagined)
# 3. Write a summary paragraph about their daily routine
#
# ---

# %% [markdown]
# ### Your Interview:
#
# **Person you're interviewing:** _______________ (name and relationship)
#
# **Question 1:** What time do you wake up?
#
# **Answer:** _______________________________________________
#
# **Question 2:** What do you eat for breakfast?
#
# **Answer:** _______________________________________________
#
# **Question 3:** Where do you work/study?
#
# **Answer:** _______________________________________________
#
# **Question 4:** What do you do in the evenings?
#
# **Answer:** _______________________________________________
#
# **Question 5:** How often do you exercise?
#
# **Answer:** _______________________________________________
#
# **Question 6:** What do you do on weekends?
#
# **Answer:** _______________________________________________
#
# **Question 7:** What hobbies do you have?
#
# **Answer:** _______________________________________________
#
# **Question 8:** Do you cook? What do you usually make?
#
# **Answer:** _______________________________________________
#
# **Question 9:** What time do you usually go to bed?
#
# **Answer:** _______________________________________________
#
# **Question 10:** What's your favorite part of the day?
#
# **Answer:** _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ### Summary Paragraph:
#
# Write a paragraph (8-10 sentences) summarizing their daily routine based on the interview.
#
# _Example: Maria wakes up at 6 AM every day. She has coffee and toast for breakfast. She works as a nurse at the city hospital..._
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 3: Write an Email to a Pen Pal ✉️
#
# ### Scenario:
# You have a new pen pal from another country. Write an email describing your daily life and routine.
#
# ### Include:
# - Your daily routine
# - Your work/study life
# - Your hobbies
# - What you do on weekends
# - Questions about their routine
#
# ### Minimum length: 15 sentences
#
# ---

# %% [markdown]
# ### Your Email:
#
# **Subject:** My Daily Life
#
# Dear [Pen Pal Name],
#
# Thank you for your email! I want to tell you about my daily life.
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# What about you? What does your typical day look like?
#
# Best wishes,
#
# [Your name]
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 4: Compare Two People's Routines 🔄
#
# ### Scenario:
# You're writing a comparison of two people with very different lifestyles.
#
# ### Instructions:
# Choose two people (real or imagined) and write about their daily routines, showing the differences and similarities.
#
# ### Examples of contrasts:
# - Early bird vs night owl
# - Office worker vs freelancer
# - Student vs professional
# - City dweller vs rural resident
#
# ### Minimum: 12-15 sentences
#
# ---

# %% [markdown]
# ### Your Comparison:
#
# **Person 1:** _______________ (name and description)
#
# **Person 2:** _______________ (name and description)
#
# _Example: Carlos is a teacher. He wakes up early every morning. Maria is a musician. She works late at night..._
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 5: Create Social Media Posts 📱
#
# ### Instructions:
# Write **6 social media posts** about daily routines, habits, or activities. Use Present Simple naturally.
#
# ### Each post: 2-3 sentences
#
# ---

# %% [markdown]
# ### Your Posts:
#
# **Post 1 (Morning routine):**
#
# Example: "I start every day with coffee and meditation. It helps me feel calm and ready. ☕🧘"
#
# Your post: _______________________________________________
#
# ---
#
# **Post 2 (Workout/exercise):**
#
# Your post: _______________________________________________
#
# ---
#
# **Post 3 (Work/study life):**
#
# Your post: _______________________________________________
#
# ---
#
# **Post 4 (Hobby/interest):**
#
# Your post: _______________________________________________
#
# ---
#
# **Post 5 (Weekend activities):**
#
# Your post: _______________________________________________
#
# ---
#
# **Post 6 (Evening routine):**
#
# Your post: _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 6: Job Advertisement - Describe the Position 💼
#
# ### Scenario:
# You're writing a job advertisement describing what the person does in this job.
#
# ### Instructions:
# Choose a job and describe the typical daily tasks and responsibilities using Present Simple.
#
# ### Example jobs:
# - Teacher, Doctor, Chef, Software Developer, Sales Manager, etc.
#
# ### Include:
# - What the person does every day
# - What skills they use
# - Work hours and schedule
#
# ---

# %% [markdown]
# ### Your Job Description:
#
# **Position:** _______________
#
# _Example: A restaurant chef works in a busy kitchen. He/she prepares meals for customers. The chef starts work at 10 AM and finishes late in the evening..._
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 7: Creative Writing - "A Perfect Day" 📖
#
# ### Instructions:
# Describe your ideal perfect day from morning to night. What do you do? Where do you go? Who do you see?
#
# ### Requirements:
# - Use Present Simple throughout
# - Write 200-250 words
# - Include specific details and times
# - Make it vivid and interesting
#
# ---

# %% [markdown]
# ### Your Story: "My Perfect Day"
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 8: Cultural Comparison 🌍
#
# ### Instructions:
# Compare daily routines in your culture with another culture you know about.
#
# ### Topics to compare:
# - Meal times
# - Work hours
# - Social activities
# - Weekend habits
# - Family time
#
# ### Minimum: 10-12 sentences
#
# ---

# %% [markdown]
# ### Your Cultural Comparison:
#
# **Comparing:** _______________ and _______________
#
# _Example: In Spain, people eat dinner very late. They usually have dinner at 9 or 10 PM. In the United States, people eat dinner much earlier..._
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## 🎓 Module Completion Assessment
#
# ### Self-Evaluation Checklist:
#
# Check ✅ if you can do these things confidently:
#
# - [ ] I can form Present Simple correctly for all persons
# - [ ] I can use third-person -s correctly (he/she/it)
# - [ ] I know all the spelling rules (-s/-es/-ies)
# - [ ] I can use adverbs of frequency correctly
# - [ ] I can talk about my daily routine
# - [ ] I can describe other people's routines
# - [ ] I can write about habits and facts
# - [ ] I can use Present Simple in conversations
#
# ### Reflection:
#
# **What did you learn from this module?**
#
# _______________________________________________
#
# **Which spelling rule was most challenging?**
#
# _______________________________________________
#
# **How confident do you feel with Present Simple? (1-10)**
#
# ___/10
#
# ---

# %%
# Mark this module as complete and schedule review
# Uncomment and run when you've completed all tasks

# scheduler.mark_module_complete(
#     module_id="A1_Module_03",
#     module_name="Present Simple - Affirmative",
#     score=85.0  # Enter your self-assessed score (0-100)
# )

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### Congratulations! 🎉
#
# You've completed **Module 3: Present Simple - Affirmative**!
#
# ### Key Skills Mastered:
# - ✅ Present Simple formation for all persons
# - ✅ Critical third-person -s (A1's most complex structure!)
# - ✅ Spelling rules: -s/-es/-ies
# - ✅ Adverbs of frequency
# - ✅ Talking about habits, routines, and facts
#
# ### Next Steps:
#
# 1. **Take a break!** ☕ This was a big module!
#
# 2. **Review**: Your first review is scheduled. Check the progress tracker.
#
# 3. **Continue Learning**: Move to **Module 4: Present Simple - Negatives and Questions**
#
# 4. **Practice Daily**: Use Present Simple when talking about your routine!
#
# ---
#
# ## 📊 Spaced Repetition Reminder
#
# Remember to review this module:
# - **Day 1**: Tomorrow
# - **Day 2**: In 2 days
# - **Day 4**: In 4 days
# - **Week 1**: In 7 days
# - **Week 2**: In 14 days
#
# Regular review ensures you **retain** the third-person -s rule!
#
# ---
#
# ## 🌟 Final Message
#
# **Excellent work!** You've mastered Present Simple affirmative through:
# - ✅ Understanding formation and spelling rules
# - ✅ 58 controlled practice exercises
# - ✅ Meaningful practice with your daily life
# - ✅ Real-world communicative tasks
#
# **This is A1's most important structure!** 🚀
#
# You're ready to learn negatives and questions in Module 4!
