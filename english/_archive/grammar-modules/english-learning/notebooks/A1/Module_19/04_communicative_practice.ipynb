# %% [markdown]
# # Module 19: Will Future - Phase 4: Communicative Practice
#
# 8 communicative tasks

# %% [markdown]
# ## Task 1
#
# Communicative task

# %%
# Task 1
print("Task 1")

# %% [markdown]
# ## Task 2
#
# Communicative task

# %%
# Task 2
print("Task 2")

# %% [markdown]
# ## Task 3
#
# Communicative task

# %%
# Task 3
print("Task 3")

# %% [markdown]
# ## Task 4
#
# Communicative task

# %%
# Task 4
print("Task 4")

# %% [markdown]
# ## Task 5
#
# Communicative task

# %%
# Task 5
print("Task 5")

# %% [markdown]
# ## Task 6
#
# Communicative task

# %%
# Task 6
print("Task 6")

# %% [markdown]
# ## Task 7
#
# Communicative task

# %%
# Task 7
print("Task 7")

# %% [markdown]
# ## Task 8
#
# Communicative task

# %%
# Task 8
print("Task 8")
