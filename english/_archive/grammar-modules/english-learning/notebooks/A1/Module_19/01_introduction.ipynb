# %% [markdown]
# # Module 19: Will Future - Phase 1: Introduction
#
# ## Learning Objectives
# - Use "will" for future predictions and spontaneous decisions
# - Form affirmative, negative, and question sentences
# - Distinguish between "will" and "going to"
# - Make promises and offers
#
# **Target Level:** A1
# **Estimated Time:** 90-120 minutes

# %% [markdown]
# ## 1. Introduction to Will
#
# Will expresses spontaneous decisions, promises, predictions, and offers.
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 1. Introduction to Will - Practice
print("1. Introduction to Will")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 2. Formation
#
# Structure: Subject + will + base verb (won't = will not)
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 2. Formation - Practice
print("2. Formation")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 3. Affirmative Sentences
#
# I will help. She will come. They will win.
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 3. Affirmative Sentences - Practice
print("3. Affirmative Sentences")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 4. Negative Sentences
#
# I won't go. She won't call. They won't forget.
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 4. Negative Sentences - Practice
print("4. Negative Sentences")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 5. Questions
#
# Will you help? Will she come? What will you do?
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 5. Questions - Practice
print("5. Questions")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 6. Short Answers
#
# Yes, I will. No, I won't. Yes, she will. No, she won't.
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 6. Short Answers - Practice
print("6. Short Answers")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 7. Uses of Will
#
# Spontaneous decisions, promises, predictions, offers
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 7. Uses of Will - Practice
print("7. Uses of Will")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 8. Will vs Going To
#
# will = spontaneous/general; going to = planned/evidence
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 8. Will vs Going To - Practice
print("8. Will vs Going To")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 9. Time Expressions
#
# tomorrow, next week, in the future, probably, maybe
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 9. Time Expressions - Practice
print("9. Time Expressions")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 10. Contractions
#
# I'll, you'll, he'll, she'll, we'll, they'll, won't
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 10. Contractions - Practice
print("10. Contractions")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 11. Common Mistakes
#
# Using will for plans, forgetting 'not' in negatives
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 11. Common Mistakes - Practice
print("11. Common Mistakes")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")

# %% [markdown]
# ## 12. Practice Dialogues
#
# Natural conversations using will
#
# ### Examples:
# - I'll help you with that.
# - She'll probably come to the party.
# - Will you be there tomorrow?
# - They won't forget about the meeting.
#
# ### Key Points:
# Use "will" for decisions made at the moment of speaking.

# %%
# 12. Practice Dialogues - Practice
print("12. Practice Dialogues")
print("=" * 60)

examples = [
    "I'll call you later.",
    "She'll love this gift!",
    "They won't be late.",
    "Will you help me?",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Create your own sentences with 'will'")
