# %% [markdown]
# # Module 19: Will Future - Phase 2: Controlled Practice
#
# 70+ exercises on "will" future

# %% [markdown]
# ## Exercise Set 1
#
# Practice exercises for "will" future

# %%
# Exercise set 1
print("Exercises 1-10")

# %% [markdown]
# ## Exercise Set 2
#
# Practice exercises for "will" future

# %%
# Exercise set 2
print("Exercises 11-20")

# %% [markdown]
# ## Exercise Set 3
#
# Practice exercises for "will" future

# %%
# Exercise set 3
print("Exercises 21-30")

# %% [markdown]
# ## Exercise Set 4
#
# Practice exercises for "will" future

# %%
# Exercise set 4
print("Exercises 31-40")

# %% [markdown]
# ## Exercise Set 5
#
# Practice exercises for "will" future

# %%
# Exercise set 5
print("Exercises 41-50")

# %% [markdown]
# ## Exercise Set 6
#
# Practice exercises for "will" future

# %%
# Exercise set 6
print("Exercises 51-60")

# %% [markdown]
# ## Exercise Set 7
#
# Practice exercises for "will" future

# %%
# Exercise set 7
print("Exercises 61-70")

# %% [markdown]
# ## Exercise Set 8
#
# Practice exercises for "will" future

# %%
# Exercise set 8
print("Exercises 71-80")
