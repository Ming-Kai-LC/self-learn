# %% [markdown]
# # Module 4: Present Simple - Negatives and Questions - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Welcome to the practice phase! Here you'll complete exercises with **immediate feedback** to master negatives and questions.
#
# ### What You'll Do:
# - ✅ Practice forming negatives with don't/doesn't
# - ✅ Form Yes/No questions correctly
# - ✅ Give appropriate short answers
# - ✅ Create Wh-questions
# - ✅ Fix common errors
#
# ⏱️ **Estimated time:** 90-120 minutes
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise, create_progress_bar
from IPython.display import display, HTML

# Initialize validator and exercise system
validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("✅ Ready to practice! Complete all exercises below.")

# %% [markdown]
# ---
#
# ## Exercise Set 1: Form Negatives
#
# Change these affirmative sentences to negatives.
#
# ### Instructions:
# Use don't or doesn't + base verb
#
# ---

# %%
# Exercise 1.1
display(HTML("<p><strong>Affirmative:</strong> I like coffee.</p>"))
exercise.create_fill_in_blank("Negative: I ___ like coffee.", "don't")

# %%
# Exercise 1.2
display(HTML("<p><strong>Affirmative:</strong> She works here.</p>"))
exercise.create_fill_in_blank("Negative: She ___ work here.", "doesn't")

# %%
# Exercise 1.3
display(HTML("<p><strong>Affirmative:</strong> They live in Paris.</p>"))
exercise.create_fill_in_blank("Negative: They ___ live in Paris.", "don't")

# %%
# Exercise 1.4
display(HTML("<p><strong>Affirmative:</strong> He speaks French.</p>"))
exercise.create_fill_in_blank("Negative: He ___ speak French.", "doesn't")

# %%
# Exercise 1.5
display(HTML("<p><strong>Affirmative:</strong> We eat meat.</p>"))
exercise.create_fill_in_blank("Negative: We ___ eat meat.", "don't")

# %%
# Exercise 1.6
display(HTML("<p><strong>Affirmative:</strong> It rains a lot.</p>"))
exercise.create_fill_in_blank("Negative: It ___ rain a lot.", "doesn't")

# %%
# Exercise 1.7
display(HTML("<p><strong>Affirmative:</strong> You understand.</p>"))
exercise.create_fill_in_blank("Negative: You ___ understand.", "don't")

# %%
# Exercise 1.8
display(HTML("<p><strong>Affirmative:</strong> My sister plays tennis.</p>"))
exercise.create_fill_in_blank("Negative: My sister ___ play tennis.", "doesn't")

# %% [markdown]
# ---
#
# ## Exercise Set 2: Complete Negative Sentences
#
# Fill in the blank with don't/doesn't + the verb in parentheses.
#
# ---

# %%
# Exercise 2.1
exercise.create_fill_in_blank("1. I ___ (like) spicy food.", "don't like")

# %%
# Exercise 2.2
exercise.create_fill_in_blank("2. She ___ (have) a car.", "doesn't have")

# %%
# Exercise 2.3
exercise.create_fill_in_blank("3. They ___ (watch) TV in the evening.", "don't watch")

# %%
# Exercise 2.4
exercise.create_fill_in_blank("4. He ___ (go) to the gym.", "doesn't go")

# %%
# Exercise 2.5
exercise.create_fill_in_blank("5. We ___ (work) on weekends.", "don't work")

# %%
# Exercise 2.6
exercise.create_fill_in_blank("6. My dog ___ (like) cats.", "doesn't like")

# %%
# Exercise 2.7
exercise.create_fill_in_blank("7. You ___ (need) a jacket today.", "don't need")

# %%
# Exercise 2.8
exercise.create_fill_in_blank("8. It ___ (cost) much.", "doesn't cost")

# %% [markdown]
# ---
#
# ## Exercise Set 3: Form Yes/No Questions
#
# Change these statements to questions.
#
# ---

# %%
# Exercise 3.1
display(HTML("<p><strong>Statement:</strong> You speak English.</p>"))
exercise.create_fill_in_blank("Question: ___ you speak English?", "Do")

# %%
# Exercise 3.2
display(HTML("<p><strong>Statement:</strong> She lives in Tokyo.</p>"))
exercise.create_fill_in_blank("Question: ___ she live in Tokyo?", "Does")

# %%
# Exercise 3.3
display(HTML("<p><strong>Statement:</strong> They work together.</p>"))
exercise.create_fill_in_blank("Question: ___ they work together?", "Do")

# %%
# Exercise 3.4
display(HTML("<p><strong>Statement:</strong> He likes pizza.</p>"))
exercise.create_fill_in_blank("Question: ___ he like pizza?", "Does")

# %%
# Exercise 3.5
display(HTML("<p><strong>Statement:</strong> We have time.</p>"))
exercise.create_fill_in_blank("Question: ___ we have time?", "Do")

# %%
# Exercise 3.6
display(HTML("<p><strong>Statement:</strong> It works well.</p>"))
exercise.create_fill_in_blank("Question: ___ it work well?", "Does")

# %% [markdown]
# ---
#
# ## Exercise Set 4: Short Answers
#
# Answer these questions with short answers.
#
# ---

# %%
# Exercise 4.1
display(HTML("<p><strong>Question:</strong> Do you like coffee? (Yes)</p>"))
exercise.create_fill_in_blank("Answer: Yes, I ___.", "do")

# %%
# Exercise 4.2
display(HTML("<p><strong>Question:</strong> Does she work here? (No)</p>"))
exercise.create_fill_in_blank("Answer: No, she ___.", "doesn't")

# %%
# Exercise 4.3
display(HTML("<p><strong>Question:</strong> Do they speak Spanish? (Yes)</p>"))
exercise.create_fill_in_blank("Answer: Yes, they ___.", "do")

# %%
# Exercise 4.4
display(HTML("<p><strong>Question:</strong> Does he live in Paris? (No)</p>"))
exercise.create_fill_in_blank("Answer: No, he ___.", "doesn't")

# %%
# Exercise 4.5
display(HTML("<p><strong>Question:</strong> Do you have a car? (No)</p>"))
exercise.create_fill_in_blank("Answer: No, I ___.", "don't")

# %%
# Exercise 4.6
display(HTML("<p><strong>Question:</strong> Does it rain a lot here? (Yes)</p>"))
exercise.create_fill_in_blank("Answer: Yes, it ___.", "does")

# %% [markdown]
# ---
#
# ## Exercise Set 5: Wh-Questions - What
#
# Complete the questions with "What do" or "What does".
#
# ---

# %%
# Exercise 5.1
exercise.create_fill_in_blank("1. ___ you do? (job)", "What do")

# %%
# Exercise 5.2
exercise.create_fill_in_blank("2. ___ she like to eat?", "What does")

# %%
# Exercise 5.3
exercise.create_fill_in_blank("3. ___ they want?", "What do")

# %%
# Exercise 5.4
exercise.create_fill_in_blank("4. ___ your brother do?", "What does")

# %%
# Exercise 5.5
exercise.create_fill_in_blank("5. ___ you think?", "What do")

# %% [markdown]
# ---
#
# ## Exercise Set 6: Wh-Questions - Where/When/How
#
# Complete with the correct Wh-word + do/does.
#
# ---

# %%
# Exercise 6.1
exercise.create_fill_in_blank("1. ___ do you live? (asking about place)", "Where")

# %%
# Exercise 6.2
exercise.create_fill_in_blank("2. ___ does she start work? (asking about time)", "When")

# %%
# Exercise 6.3
exercise.create_fill_in_blank("3. ___ do they get to work? (asking about method)", "How")

# %%
# Exercise 6.4
exercise.create_fill_in_blank("4. ___ does he study English? (asking about reason)", "Why")

# %%
# Exercise 6.5
exercise.create_fill_in_blank("5. ___ do you live with? (asking about people)", "Who")

# %% [markdown]
# ---
#
# ## Exercise Set 7: Error Correction - Negatives
#
# Find and correct the error.
#
# ---

# %%
# Exercise 7.1
display(HTML("<p><strong>Incorrect:</strong> She <u>doesn't likes</u> coffee.</p>"))
exercise.create_fill_in_blank("Corrected: She doesn't ___ coffee.", "like")

# %%
# Exercise 7.2
display(HTML("<p><strong>Incorrect:</strong> I <u>doesn't</u> work here.</p>"))
exercise.create_fill_in_blank("Corrected: I ___ work here.", "don't")

# %%
# Exercise 7.3
display(HTML("<p><strong>Incorrect:</strong> They <u>don't speaks</u> French.</p>"))
exercise.create_fill_in_blank("Corrected: They don't ___ French.", "speak")

# %%
# Exercise 7.4
display(HTML("<p><strong>Incorrect:</strong> He <u>don't</u> live here.</p>"))
exercise.create_fill_in_blank("Corrected: He ___ live here.", "doesn't")

# %%
# Exercise 7.5
display(HTML("<p><strong>Incorrect:</strong> We <u>doesn't</u> have time.</p>"))
exercise.create_fill_in_blank("Corrected: We ___ have time.", "don't")

# %% [markdown]
# ---
#
# ## Exercise Set 8: Error Correction - Questions
#
# Correct the word order or form.
#
# ---

# %%
# Exercise 8.1
display(HTML("<p><strong>Incorrect:</strong> <u>Does he works</u> here?</p>"))
exercise.create_fill_in_blank("Corrected: Does he ___ here?", "work")

# %%
# Exercise 8.2
display(HTML("<p><strong>Incorrect:</strong> <u>You speak</u> English? (question)</p>"))
exercise.create_fill_in_blank("Corrected: ___ you speak English?", "Do")

# %%
# Exercise 8.3
display(HTML("<p><strong>Incorrect:</strong> <u>Where she lives?</u></p>"))
exercise.create_fill_in_blank("Corrected: Where ___ she live?", "does")

# %%
# Exercise 8.4
display(HTML("<p><strong>Incorrect:</strong> <u>What you do?</u></p>"))
exercise.create_fill_in_blank("Corrected: What ___ you do?", "do")

# %%
# Exercise 8.5
display(HTML("<p><strong>Incorrect:</strong> <u>Are you like</u> pizza?</p>"))
exercise.create_fill_in_blank("Corrected: ___ you like pizza?", "Do")

# %% [markdown]
# ---
#
# ## Exercise Set 9: Mixed Practice - Questions and Negatives
#
# Complete the sentences.
#
# ---

# %%
# Exercise 9.1
exercise.create_fill_in_blank("1. ___ you work on Saturdays? (question)", "Do")

# %%
# Exercise 9.2
exercise.create_fill_in_blank("2. She ___ eat meat. She's vegetarian. (negative)", "doesn't")

# %%
# Exercise 9.3
exercise.create_fill_in_blank("3. Where ___ they live? (question)", "do")

# %%
# Exercise 9.4
exercise.create_fill_in_blank("4. We ___ have a car. (negative)", "don't")

# %%
# Exercise 9.5
exercise.create_fill_in_blank("5. ___ he speak Japanese? (question)", "Does")

# %% [markdown]
# ---
#
# ## Exercise Set 10: Complete the Dialogue
#
# Fill in the missing questions and answers.
#
# ---

# %%
# Exercise 10.1
display(HTML("<p><strong>A:</strong> Do you like coffee?</p>"))
exercise.create_fill_in_blank("B: Yes, I ___.", "do")

# %%
# Exercise 10.2
display(HTML("<p><strong>A:</strong> ___ (Does/Do) she work here?</p>"))
exercise.create_fill_in_blank("A: ___ she work here?", "Does")

# %%
# Exercise 10.3
display(
    HTML(
        "<p><strong>B:</strong> No, she doesn't.</p><p><strong>A:</strong> Where does she work?</p>"
    )
)
exercise.create_fill_in_blank("B: She ___ in the city center. (negative: work)", "doesn't work")

# %% [markdown]
# ---
#
# ## 📊 Your Score

# %%
# Display final score
validator.display_score()

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### If your score is:
# - **80%+**: Excellent! Move to **03_meaningful_practice.ipynb** ✅
# - **60-79%**: Good progress! Review negatives and questions, then continue 👍
# - **Below 60%**: Review **01_introduction.ipynb** and retry these exercises 📚
#
# ### Key Points to Remember:
# - don't/doesn't + BASE VERB (no -s!)
# - Do/Does + subject + BASE VERB?
# - Short answers: Yes, I do / No, I don't
# - Wh-word + do/does + subject + base verb?
#
# ---
#
# ### Continue to:
# **03_meaningful_practice.ipynb** - Write about things you don't do and ask questions!
#
# ---
#
# **Great work!** 🌟 You've completed the controlled practice phase!
