# %% [markdown]
# # Module 10: Prepositions - Controlled Practice
#
# ---
#
# ## 📚 Phase 2: Controlled Practice (20% of Learning Time)
#
# Welcome to the **Controlled Practice** phase! In this notebook, you'll complete **structured exercises** to build accuracy and confidence with prepositions.
#
# ### What You'll Practice:
# - ✅ **IN, ON, AT** for place
# - ✅ **IN, ON, AT** for time
# - ✅ Other prepositions of place
# - ✅ Choosing the correct preposition
# - ✅ Error correction
# - ✅ Transformation exercises
#
# ### Exercise Format:
# - **Multiple choice** questions
# - **Fill-in-the-blank** exercises
# - **Immediate feedback** on your answers
# - **Final score** to track progress
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise
from IPython.display import display, HTML

validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("✅ Exercise system ready!")
print("\n💡 Tip: Think about the meaning - IN (inside), ON (contact), AT (point)")

# %% [markdown]
# ---
#
# ## Set 1: IN, ON, AT for Place (8 exercises)
#
# Choose the correct preposition for each sentence.
#
# ---

# %%
display(HTML("<h3>Exercise 1</h3>"))
display(HTML("<p>I live ___ New York.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 2</h3>"))
display(HTML("<p>The book is ___ the table.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 3</h3>"))
display(HTML("<p>She's waiting ___ the bus stop.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 4</h3>"))
display(HTML("<p>The cat is sleeping ___ the sofa.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 5</h3>"))
display(HTML("<p>We're ___ the park.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 6</h3>"))
display(HTML("<p>I'll meet you ___ the restaurant.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 7</h3>"))
display(HTML("<p>There's a picture ___ the wall.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 8</h3>"))
display(HTML("<p>She works ___ an office.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %% [markdown]
# ---
#
# ## Set 2: IN, ON, AT for Time (8 exercises)
#
# Choose the correct preposition for time expressions.
#
# ---

# %%
display(HTML("<h3>Exercise 9</h3>"))
display(HTML("<p>I was born ___ 1995.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 10</h3>"))
display(HTML("<p>The meeting is ___ Monday.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 11</h3>"))
display(HTML("<p>I'll see you ___ 3 o'clock.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 12</h3>"))
display(HTML("<p>They got married ___ December 25th.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 13</h3>"))
display(HTML("<p>We go on vacation ___ summer.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 14</h3>"))
display(HTML("<p>I wake up ___ 7:00 AM.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 15</h3>"))
display(HTML("<p>She starts school ___ September.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 16</h3>"))
display(HTML("<p>We celebrate ___ New Year's Day.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %% [markdown]
# ---
#
# ## Set 3: Other Prepositions of Place (8 exercises)
#
# Choose the correct preposition: under, over, behind, in front of, next to, between.
#
# ---

# %%
display(HTML("<h3>Exercise 17</h3>"))
display(HTML("<p>The dog is ___ the table (below it).</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["under", "over", "next to"], "under")

# %%
display(HTML("<h3>Exercise 18</h3>"))
display(HTML("<p>The lamp is ___ the desk (above it).</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["under", "over", "behind"], "over")

# %%
display(HTML("<h3>Exercise 19</h3>"))
display(HTML("<p>The car is ___ the house (at the back).</p>"))
exercise.create_multiple_choice(
    "Choose the correct answer:", ["behind", "in front of", "next to"], "behind"
)

# %%
display(HTML("<h3>Exercise 20</h3>"))
display(HTML("<p>There's a garden ___ my house (at the front).</p>"))
exercise.create_multiple_choice(
    "Choose the correct answer:", ["behind", "in front of", "between"], "in front of"
)

# %%
display(HTML("<h3>Exercise 21</h3>"))
display(HTML("<p>I sit ___ my best friend (beside).</p>"))
exercise.create_multiple_choice(
    "Choose the correct answer:", ["next to", "between", "under"], "next to"
)

# %%
display(HTML("<h3>Exercise 22</h3>"))
display(HTML("<p>The bank is ___ the post office and the pharmacy.</p>"))
exercise.create_multiple_choice(
    "Choose the correct answer:", ["next to", "between", "in front of"], "between"
)

# %%
display(HTML("<h3>Exercise 23</h3>"))
display(HTML("<p>The cat is hiding ___ the bed.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["under", "over", "next to"], "under")

# %%
display(HTML("<h3>Exercise 24</h3>"))
display(HTML("<p>The clock is hanging ___ the door.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["behind", "over", "between"], "over")

# %% [markdown]
# ---
#
# ## Set 4: Mixed Place Prepositions (8 exercises)
#
# Complete the sentences with the correct preposition.
#
# ---

# %%
display(HTML("<h3>Exercise 25</h3>"))
display(HTML("<p>I'm sitting ___ a bus.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 26</h3>"))
display(HTML("<p>She lives ___ 42 Oak Street.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 27</h3>"))
display(HTML("<p>The children are playing ___ the garden.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 28</h3>"))
display(HTML("<p>There's a spider ___ the ceiling.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 29</h3>"))
display(HTML("<p>We met ___ the party.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 30</h3>"))
display(HTML("<p>The keys are ___ the drawer.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 31</h3>"))
display(HTML("<p>I saw it ___ TV.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 32</h3>"))
display(HTML("<p>She's waiting ___ home.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %% [markdown]
# ---
#
# ## Set 5: Mixed Time Prepositions (8 exercises)
#
# Complete the sentences with the correct time preposition.
#
# ---

# %%
display(HTML("<h3>Exercise 33</h3>"))
display(HTML("<p>I'll finish this ___ two weeks.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 34</h3>"))
display(HTML("<p>The store opens ___ 9:00 AM.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 35</h3>"))
display(HTML("<p>We don't work ___ weekends.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 36</h3>"))
display(HTML("<p>I was born ___ Friday.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 37</h3>"))
display(HTML("<p>They arrive ___ the morning.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 38</h3>"))
display(HTML("<p>The concert is ___ Saturday evening.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 39</h3>"))
display(HTML("<p>She graduated ___ 2020.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 40</h3>"))
display(HTML("<p>I go to bed ___ night.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %% [markdown]
# ---
#
# ## Set 6: Special Cases and Fixed Expressions (8 exercises)
#
# Choose the correct preposition for these special expressions.
#
# ---

# %%
display(HTML("<h3>Exercise 41</h3>"))
display(HTML("<p>I'm ___ work right now.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 42</h3>"))
display(HTML("<p>She's ___ the phone.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 43</h3>"))
display(HTML("<p>They're ___ vacation.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 44</h3>"))
display(HTML("<p>I read about it ___ the newspaper.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 45</h3>"))
display(HTML("<p>He's ___ the dentist.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 46</h3>"))
display(HTML("<p>We arrived ___ time.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 47</h3>"))
display(HTML("<p>She's interested ___ art. (Wait - this needs 'in'!)</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 48</h3>"))
display(HTML("<p>I'm ___ the second floor.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %% [markdown]
# ---
#
# ## Set 7: Error Correction (6 exercises)
#
# Identify and correct the preposition error in each sentence.
#
# ---

# %%
display(HTML("<h3>Exercise 49</h3>"))
display(HTML("<p>❌ I live <strong>at</strong> New York.</p>"))
display(HTML("<p>What is the correct preposition?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 50</h3>"))
display(HTML("<p>❌ The meeting is <strong>in</strong> Monday.</p>"))
display(HTML("<p>What is the correct preposition?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 51</h3>"))
display(HTML("<p>❌ I'll see you <strong>in</strong> 3 o'clock.</p>"))
display(HTML("<p>What is the correct preposition?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 52</h3>"))
display(HTML("<p>❌ The book is <strong>at</strong> the table.</p>"))
display(HTML("<p>What is the correct preposition?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 53</h3>"))
display(HTML("<p>❌ She's waiting <strong>in</strong> the bus stop.</p>"))
display(HTML("<p>What is the correct preposition?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 54</h3>"))
display(HTML("<p>❌ I was born <strong>at</strong> 1995.</p>"))
display(HTML("<p>What is the correct preposition?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %% [markdown]
# ---
#
# ## Set 8: Transformation Practice (6 exercises)
#
# Rewrite the sentences using a different preposition structure.
#
# ---

# %%
display(HTML("<h3>Exercise 55</h3>"))
display(HTML("<p>Original: The cat is <strong>inside</strong> the box.</p>"))
display(HTML("<p>Rewrite with a preposition: The cat is ___ the box.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 56</h3>"))
display(HTML("<p>Original: The picture is hanging <strong>above</strong> the fireplace.</p>"))
display(HTML("<p>Rewrite: The picture is ___ the fireplace.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["over", "under", "next to"], "over")

# %%
display(HTML("<h3>Exercise 57</h3>"))
display(HTML("<p>Original: The meeting starts <strong>when the clock shows</strong> 2:00 PM.</p>"))
display(HTML("<p>Rewrite: The meeting starts ___ 2:00 PM.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 58</h3>"))
display(HTML("<p>Original: The pharmacy is <strong>beside</strong> the bank.</p>"))
display(HTML("<p>Rewrite: The pharmacy is ___ the bank.</p>"))
exercise.create_multiple_choice(
    "Choose the correct answer:", ["next to", "between", "behind"], "next to"
)

# %%
display(HTML("<h3>Exercise 59</h3>"))
display(HTML("<p>Original: I was born <strong>during the month of</strong> July.</p>"))
display(HTML("<p>Rewrite: I was born ___ July.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 60</h3>"))
display(
    HTML("<p>Original: The store is <strong>located at the address</strong> 15 Main Street.</p>")
)
display(HTML("<p>Rewrite: The store is ___ 15 Main Street.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %% [markdown]
# ---
#
# ## Set 9: Mixed Comprehensive Practice (6 exercises)
#
# Final mixed practice covering all preposition types.
#
# ---

# %%
display(HTML("<h3>Exercise 61</h3>"))
display(
    HTML(
        "<p>Complete: I'll meet you ___ the coffee shop ___ Main Street ___ 3:00 PM ___ Saturday.</p>"
    )
)
display(HTML("<p>Which preposition goes in the FIRST blank (location)?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "at")

# %%
display(HTML("<h3>Exercise 62</h3>"))
display(
    HTML(
        "<p>Complete: I'll meet you at the coffee shop ___ Main Street at 3:00 PM on Saturday.</p>"
    )
)
display(HTML("<p>Which preposition goes in the SECOND blank (street name)?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 63</h3>"))
display(
    HTML("<p>Complete: The books are ___ the shelf, ___ the dictionary and the encyclopedia.</p>")
)
display(HTML("<p>Which preposition goes in the FIRST blank (location on surface)?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %%
display(HTML("<h3>Exercise 64</h3>"))
display(
    HTML("<p>Complete: The books are on the shelf, ___ the dictionary and the encyclopedia.</p>")
)
display(HTML("<p>Which preposition goes in the SECOND blank (position between two items)?</p>"))
exercise.create_multiple_choice(
    "Choose the correct answer:", ["next to", "between", "behind"], "between"
)

# %%
display(HTML("<h3>Exercise 65</h3>"))
display(HTML("<p>Complete: ___ winter, we usually travel ___ vacation ___ January.</p>"))
display(HTML("<p>Which preposition goes in the FIRST blank (season)?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "in")

# %%
display(HTML("<h3>Exercise 66</h3>"))
display(HTML("<p>Complete: In winter, we usually travel ___ vacation in January.</p>"))
display(HTML("<p>Which preposition goes in the blank (fixed expression)?</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["in", "on", "at"], "on")

# %% [markdown]
# ---
#
# ## 📊 Check Your Score
#
# Run the cell below to see your final score!
#
# ---

# %%
# Display final score
validator.display_score()

print("\n" + "=" * 50)
print("🎯 EXERCISE SUMMARY")
print("=" * 50)
print("\nTotal Exercises: 66")
print("\nExercise Sets:")
print("  • Set 1: IN, ON, AT for Place (8)")
print("  • Set 2: IN, ON, AT for Time (8)")
print("  • Set 3: Other Prepositions of Place (8)")
print("  • Set 4: Mixed Place Prepositions (8)")
print("  • Set 5: Mixed Time Prepositions (8)")
print("  • Set 6: Special Cases and Fixed Expressions (8)")
print("  • Set 7: Error Correction (6)")
print("  • Set 8: Transformation Practice (6)")
print("  • Set 9: Mixed Comprehensive Practice (6)")
print("\n" + "=" * 50)
print("\n💡 Remember:")
print("   • IN = INSIDE (enclosed spaces, cities, long periods)")
print("   • ON = CONTACT (surfaces, days, dates)")
print("   • AT = POINT (specific locations, exact times)")
print("\n📌 Next: Move to Meaningful Practice to personalize your learning!")

# %% [markdown]
# ---
#
# ## 🎉 Excellent Work!
#
# You've completed **66 controlled practice exercises** on prepositions!
#
# ### What You Practiced:
# ✅ **IN, ON, AT** for place and time
# ✅ **Other prepositions** (under, over, behind, next to, between)
# ✅ **Special expressions** and fixed phrases
# ✅ **Error correction** and transformation
# ✅ **Mixed comprehensive** practice
#
# ### 📈 Next Steps:
# 1. **Review mistakes** - Which exercises were challenging?
# 2. **Practice weak areas** - Focus on your incorrect answers
# 3. **Move to Phase 3** - Meaningful Practice (personalize prepositions to your life)
# 4. **Keep practicing** - Prepositions take time to master!
#
# ---
#
# **Ready for Meaningful Practice?** → Open `03_meaningful_practice.ipynb`
#
# ---
