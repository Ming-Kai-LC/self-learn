# %% [markdown]
# # Module 10: Prepositions - Communicative Practice
#
# ---
#
# ## 💬 Phase 4: Communicative Practice (30% of Learning Time)
#
# Welcome to **Communicative Practice** - the final phase! Now you'll use prepositions in **real-world communication tasks**.
#
# ### What is Communicative Practice?
# - ✅ **Authentic tasks** - Real situations you might face
# - ✅ **Purpose-driven** - Communication with a specific goal
# - ✅ **Creative freedom** - Multiple correct answers
# - ✅ **Practical application** - Skills you can use immediately
#
# ### How to Complete Tasks:
# 1. **Read** the scenario and task carefully
# 2. **Plan** what you want to communicate
# 3. **Write** naturally, focusing on the message
# 4. **Use** prepositions correctly but don't obsess over them
# 5. **Review** - Does your message make sense?
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from spaced_repetition import SpacedRepetitionScheduler
from IPython.display import display, HTML

scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Ready for communicative practice!")
print("\n💡 Tip: Focus on communicating your message clearly!")

# %% [markdown]
# ---
#
# ## Task 1: Giving Directions to Your Home
#
# **Scenario:** A friend is visiting you for the first time. Write clear directions from a nearby landmark to your home.
#
# ### Your Task:
# Write directions using place prepositions. Include:
#
# **Starting Point:**
# - Start at... (landmark - train station, bus stop, metro station, etc.)
# - This is located at... / on... / in...
#
# **Step-by-Step Directions:**
# - Walk on... (street name)
# - Turn... at... (intersection/landmark)
# - You'll see... on your... (left/right)
# - Continue... (in/on) ... until you reach...
# - The building is... (next to / between / in front of / behind)
#
# **Final Location:**
# - My apartment/house is at... (address)
# - It's on the... (floor)
# - Ring the bell at... (location)
#
# **Time Information:**
# - Come on... (day) at... (time)
# - The walk takes about... minutes
#
# **Example:**
# > "Start at the Central Train Station on Main Street. Walk on Main Street towards the north for about 5 minutes. At the big clock, turn right onto Oak Avenue. Continue on Oak Avenue until you see a pharmacy on your left. My building is next to the pharmacy, between the pharmacy and a small café. I live at 42 Oak Avenue on the third floor. Ring the bell at the entrance - my name is on the buzzer. Come on Saturday at 2:00 PM!"
#
# ---
#
# **Double-click to edit and write YOUR directions:**

# %% [markdown]
# **Directions to My Home:**
#
# [Write clear directions to YOUR home here]
#
# ---

# %% [markdown]
# ---
#
# ## Task 2: Planning a Meeting
#
# **Scenario:** You need to plan a meeting with colleagues or friends. Send an email with all the details.
#
# ### Your Task:
# Write an email invitation with specific time and place information:
#
# **Subject Line:**
# - Meeting on... (date) - ... (topic)
#
# **Greeting and Purpose:**
# - Hi everyone,
# - I'd like to organize a meeting to discuss...
#
# **Date and Time:**
# - The meeting will be on... (day and date)
# - We'll meet at... (exact time)
# - It will finish at... (time)
# - Please arrive on time / at... (time)
#
# **Location:**
# - We'll meet at... (place name)
# - It's located at... (address)
# - The venue is on... (street/floor)
# - It's... (next to / behind / in front of) ...
# - We'll be in... (room/area)
#
# **Additional Details:**
# - Parking is available... (in the basement / behind the building)
# - The entrance is... (on Main Street / at the back)
# - If you're coming by bus, get off at...
#
# **Call to Action:**
# - Please confirm by... (date)
# - See you on... (day)!
#
# **Example:**
# > "Subject: Team Meeting on March 15th - Project Planning
# >
# > Hi everyone,
# >
# > I'd like to organize a meeting to discuss our new project. The meeting will be on Friday, March 15th at 10:00 AM. It will finish at 12:00 PM, so please plan for 2 hours.
# >
# > We'll meet at the Innovation Hub, located at 123 Tech Street on the 5th floor. The building is next to the Central Library, between the library and a coffee shop. We'll be in Conference Room B at the end of the hall.
# >
# > If you're driving, parking is available in the basement. Enter from Tech Street. If you're taking public transport, get off at Central Station and walk on Main Street for 5 minutes.
# >
# > Please confirm by March 10th. See you on Friday!"
#
# ---
#
# **Double-click to edit and write YOUR meeting invitation:**

# %% [markdown]
# **Meeting Invitation Email:**
#
# [Write YOUR meeting invitation here]
#
# ---

# %% [markdown]
# ---
#
# ## Task 3: Describing Your Dream Vacation
#
# **Scenario:** You're applying for a travel writing competition. Describe your dream vacation with specific details.
#
# ### Your Task:
# Write a detailed description (200-300 words) including:
#
# **Destination:**
# - I want to travel to... in... (country)
# - It's in the... (north/south) of...
# - It's located on... / in... / at...
#
# **When:**
# - I want to go in... (month/season/year)
# - I'll leave on... (date) and return on... (date)
# - The trip will last for... days
# - The best time to visit is in... because...
#
# **Where I'll Stay:**
# - I'll stay at/in... (hotel/hostel/apartment)
# - It's located... (in the city center / on the beach / in the mountains)
# - My room will be on the... floor
# - From my window, I'll see...
#
# **Daily Schedule:**
# - I'll wake up at... in the morning
# - At..., I'll visit...
# - In the afternoon, I'll...
# - On... (day), I plan to...
#
# **Places to Visit:**
# - There's a famous... at... / on... / in...
# - I want to see... (landmark) - it's located...
# - People say the best restaurant is on...
#
# **Why:**
# - I want to go in... (season) because...
# - I'm interested in... and in this place...
#
# ---
#
# **Double-click to edit and describe YOUR dream vacation:**

# %% [markdown]
# **My Dream Vacation:**
#
# [Write YOUR dream vacation description here - aim for 200-300 words]
#
# ---

# %% [markdown]
# ---
#
# ## Task 4: Event Announcement
#
# **Scenario:** You're organizing an event (party, workshop, concert, etc.). Create a social media post or flyer with all the details.
#
# ### Your Task:
# Create 3 different event announcements:
#
# ---
#
# ### Event 1: _____________ (your event name)
#
# **What:**
# - Join us for... (type of event)
# - We're celebrating/learning/enjoying...
#
# **When:**
# - Date: On... (day and date)
# - Time: From... to... / At... (time)
# - Doors open at...
#
# **Where:**
# - Location: At... (venue name)
# - Address: ... (full address)
# - It's located... (next to / between / on)
# - ... (floor/room) if applicable
#
# **How to Get There:**
# - By bus: Get off at...
# - By car: Park in... / at...
# - Entrance on... (street)
#
# **Additional Info:**
# - Tickets available at... / on...
# - Registration opens at...
# - More info on... (website) / at... (phone)
#
# **Example:**
# > "🎉 SUMMER MUSIC FESTIVAL 🎉
# >
# > Join us for an amazing evening of live music!
# >
# > 📅 When: Saturday, June 21st from 6:00 PM to 11:00 PM
# > Doors open at 5:30 PM
# >
# > 📍 Where: Riverside Park
# > Located at 50 River Road, next to the Old Bridge
# > On the east side of the city
# >
# > 🚗 Getting There:
# > - By bus: Line 5, get off at River Stop
# > - By car: Free parking behind the park, entrance on Oak Street
# >
# > 🎫 Tickets available online at www.summermusic.com
# > Registration opens at 5:00 PM at the main gate
# >
# > See you on Saturday! 🎵"
#
# ---
#
# **Double-click to edit and write YOUR 3 event announcements:**

# %% [markdown]
# **Event 1:**
#
# [Write event announcement 1]
#
# ---
#
# **Event 2:**
#
# [Write event announcement 2]
#
# ---
#
# **Event 3:**
#
# [Write event announcement 3]
#
# ---

# %% [markdown]
# ---
#
# ## Task 5: Daily Routine for a Lifestyle Blog
#
# **Scenario:** You're writing for a lifestyle blog. Describe a "perfect day" routine that readers can follow.
#
# ### Your Task:
# Write a blog post (250-350 words) describing an ideal daily routine:
#
# **Blog Post Structure:**
#
# **Title:** "My Perfect [Season/Day Type] Routine"
#
# **Introduction:**
# - Opening sentence about routine importance
# - Brief overview of the day
#
# **Morning (6:00 AM - 12:00 PM):**
# - I wake up at...
# - At..., I...
# - In the morning, I always...
# - Breakfast is at... in... (location)
# - By..., I've already...
#
# **Afternoon (12:00 PM - 6:00 PM):**
# - Lunch at...
# - In the afternoon, I...
# - At..., I usually...
# - I work/study... (at home / in an office / at a café)
#
# **Evening (6:00 PM - 10:00 PM):**
# - I finish work at...
# - Dinner is at... with...
# - In the evening, I...
# - I like to... at... (specific location)
#
# **Night (10:00 PM - Midnight):**
# - At night, I...
# - I go to bed at...
# - I sleep in... (my bedroom / describe location)
#
# **Conclusion:**
# - Why this routine works
# - Encouragement for readers
#
# **Include:**
# - Specific times (at 7:00 AM, at noon)
# - Specific locations (in the kitchen, at the gym, on the balcony)
# - Days if applicable (on weekdays, on Saturdays)
#
# ---
#
# **Double-click to edit and write YOUR blog post:**

# %% [markdown]
# **My Perfect Day Blog Post:**
#
# [Write YOUR blog post here - aim for 250-350 words]
#
# ---

# %% [markdown]
# ---
#
# ## Task 6: Housing Search Description
#
# **Scenario:** You're looking for a new apartment/house. Write detailed requirements for a real estate agent.
#
# ### Your Task:
# Write an email to a real estate agent describing what you're looking for:
#
# **Email Structure:**
#
# **Subject:** Looking for [apartment/house] in [area]
#
# **Greeting:**
# - Dear [Agent Name] / Hello,
#
# **Introduction:**
# - I'm looking for... (type of property)
# - I need to move by... (date/month)
#
# **Location Requirements:**
# - I want to live in... (city/neighborhood)
# - Preferably in the... (north/south/east/west)
# - It should be on... (specific street/area)
# - Near... (school/work/transport) - located at...
# - NOT on... (busy street/noisy area)
#
# **Building/Property Details:**
# - I prefer a building... (on a quiet street / in a residential area)
# - Maximum floor: No higher than the... floor
# - Minimum floor: At least the... floor
# - Balcony/terrace... (facing south / with view of...)
#
# **Interior Requirements:**
# - Bedrooms: ... bedroom(s)
# - Kitchen: ... (in a separate room / open plan)
# - Living room: ... (with balcony / facing...)
# - Storage: ... (in the apartment / in the basement)
#
# **Nearby Facilities (within walking distance):**
# - Supermarket... (on the same street / at the corner)
# - Public transport... (at... / within... minutes)
# - Parking... (in the building / behind the building / on the street)
# - Park/green space... (in the neighborhood / next to...)
#
# **Timeline:**
# - I need to move in by... (date)
# - I can view properties on... (days) at... (times)
# - I'm available for viewings... (in the morning / at weekends)
#
# **Closing:**
# - Thank you for your help
# - Looking forward to hearing from you
# - Best regards
#
# ---
#
# **Double-click to edit and write YOUR housing requirements:**

# %% [markdown]
# **Housing Search Email:**
#
# [Write YOUR housing requirements email here]
#
# ---

# %% [markdown]
# ---
#
# ## Task 7: Travel Itinerary
#
# **Scenario:** You're planning a 3-day trip. Create a detailed day-by-day itinerary for yourself or to share with travel companions.
#
# ### Your Task:
# Create a complete 3-day travel itinerary:
#
# ---
#
# ### Trip to: _____________ (destination)
# **Dates:** From... to... (dates)
#
# ---
#
# ### Day 1 - [Date]
#
# **Morning:**
# - 7:00 AM - Depart from... (location)
# - 10:00 AM - Arrive at... (destination)
# - Check in at... (hotel name) on... (street) at... (time)
# - Hotel is located... (next to / in front of / in the center)
#
# **Afternoon:**
# - 12:00 PM - Lunch at... (restaurant name) on... (street)
# - 2:00 PM - Visit... (attraction) - it's at... / in... / on...
# - 4:00 PM - Walk... (in the park / on the beach / along...)
#
# **Evening:**
# - 7:00 PM - Dinner at... (location)
# - 9:00 PM - ... (activity) at... (place)
# - Return to hotel at...
#
# ---
#
# ### Day 2 - [Date]
#
# **Morning:**
# - Wake up at...
# - Breakfast at... in... (hotel restaurant / café)
# - 9:00 AM - Excursion to... (place)
# - Meet at... (meeting point) at... (time)
#
# **Afternoon:**
# - Visit...
# - Lunch...
# - Continue to...
#
# **Evening:**
# - Return to... at... (time)
# - Dinner and evening activities
#
# ---
#
# ### Day 3 - [Date]
#
# **Morning:**
# - Free morning to...
# - Breakfast at...
# - Last visit to...
#
# **Afternoon:**
# - Check out at... (time)
# - Lunch at... before departure
# - Depart at... (time) from... (location)
# - Arrive home at... (time)
#
# ---
#
# **Important Information:**
# - Hotel: ... at ... on ...
# - Emergency meeting point: ... (location)
# - Transportation: ...
#
# ---
#
# **Double-click to edit and write YOUR complete 3-day itinerary:**

# %% [markdown]
# **My 3-Day Travel Itinerary:**
#
# [Write YOUR complete itinerary here with all three days]
#
# ---

# %% [markdown]
# ---
#
# ## Task 8: Personal History Timeline
#
# **Scenario:** You're creating a personal biography or CV. Write a chronological timeline of your life's important events.
#
# ### Your Task:
# Write a detailed personal timeline (300-400 words):
#
# **Title:** "My Life Journey" or "My Story"
#
# **Birth and Early Years:**
# - I was born in... (year) in... (city/country)
# - I was born on... (date)
# - I grew up in... (location)
# - My family lived at... / on... / in...
#
# **Childhood (Ages 0-12):**
# - In... (year), I started school at... (name)
# - It was located... (describe location)
# - On weekdays, I...
# - On weekends, I...
# - In... (year), something important happened: ...
#
# **Teenage Years (Ages 13-18):**
# - In... (year), I moved to... / started... / began...
# - I studied at... (school/city) from... to... (years)
# - On... (date/year), I...
# - I graduated in... (year)
#
# **Young Adult (Ages 19-25):**
# - In... (year), I started university/work at...
# - I lived in... / at... / on...
# - On... (specific date), I... (important event)
# - I met... in... (year) at... (location)
# - I graduated/finished in... (year)
#
# **Adult Life (Ages 26+):**
# - In... (year), I moved to...
# - I started working at... in... (year/month)
# - I got married/had children on... (date) in... (year)
# - Major achievements: In... (year), I...
#
# **Present:**
# - Now, in... (current year), I live in...
# - I work at..., located at...
# - On weekdays, I...
# - On weekends, I...
# - I'm studying English at... / in... / on...
#
# **Future:**
# - In... (year), I plan to...
# - In... years, I hope to...
# - On my next birthday, I will...
#
# **Include:**
# - At least 10 specific dates (years, months, or exact dates)
# - At least 8 different locations with prepositions
# - Both time and place prepositions throughout
#
# ---
#
# **Double-click to edit and write YOUR life timeline:**

# %% [markdown]
# **My Life Journey:**
#
# [Write YOUR personal timeline here - aim for 300-400 words]
#
# ---

# %% [markdown]
# ---
#
# ## 🎉 Congratulations!
#
# You've completed **Module 10: Prepositions** - all 4 phases!
#
# ### What You Accomplished:
# ✅ **Phase 1** - Introduction: Learned IN, ON, AT and other prepositions
# ✅ **Phase 2** - Controlled Practice: Completed 66 exercises
# ✅ **Phase 3** - Meaningful Practice: 10 personalized activities
# ✅ **Phase 4** - Communicative Practice: 8 real-world tasks
#
# ### 💪 Key Skills Mastered:
# - Using **IN, ON, AT** for place correctly
# - Using **IN, ON, AT** for time correctly
# - Using other place prepositions: **under, over, behind, in front of, next to, between**
# - Writing directions and locations clearly
# - Describing schedules and routines
# - Planning events and trips
# - Creating detailed descriptions with prepositions
#
# ### 📊 Module 10 Statistics:
# - **Total Exercises:** 66 controlled practice exercises
# - **Personal Activities:** 10 meaningful practice activities
# - **Communication Tasks:** 8 real-world tasks
# - **Estimated Study Time:** 7-10 hours
#
# ### 🎯 You Can Now:
# - ✅ Give clear directions using place prepositions
# - ✅ Describe locations accurately
# - ✅ Talk about schedules and times
# - ✅ Plan events with specific details
# - ✅ Write about your life using correct prepositions
# - ✅ Communicate naturally in real situations
#
# ### 📈 Keep Practicing:
# - Use prepositions when giving directions
# - Pay attention to prepositions in signs and announcements
# - Practice describing locations in your daily life
# - Write about your schedule regularly
#
# ---
#
# ## 🌟 Module 10 Complete!
#
# This is the **final module** of your A1 English learning journey (Modules 2-10)!
#
# You've completed:
# - Module 2, 3, 4, 5, 6, 7, 8, 9, and 10 ✅
#
# **Congratulations on finishing the entire course!** 🎊
#
# ---

# %%
# Mark module complete (uncomment when finished)
# scheduler.mark_module_complete(
#     module_id="A1_Module_10",
#     module_name="Prepositions",
#     score=85.0
# )

print("=" * 50)
print("🎊 MODULE 10: PREPOSITIONS - COMPLETE! 🎊")
print("=" * 50)
print("\n✅ Phase 1: Introduction")
print("✅ Phase 2: Controlled Practice (66 exercises)")
print("✅ Phase 3: Meaningful Practice (10 activities)")
print("✅ Phase 4: Communicative Practice (8 tasks)")
print("\n" + "=" * 50)
print("\n🌟 CONGRATULATIONS! 🌟")
print("\nYou've completed ALL modules (2-10)!")
print("\nYou can now use prepositions confidently in English!")
print("\n" + "=" * 50)
print("\n🎯 Total Course Progress: 100%")
print("\n🏆 You've finished the A1 English Learning Course!")
print("\n📚 Keep practicing and using English every day!")
print("\n" + "=" * 50)
