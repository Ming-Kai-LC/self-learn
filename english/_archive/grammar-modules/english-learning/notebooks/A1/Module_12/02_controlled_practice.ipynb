# %% [markdown]
# # Module 12: Can/Can't - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Welcome to the practice phase! Here you'll complete exercises with **immediate feedback** to master CAN and CAN'T.
#
# ### What You'll Do:
# - ✅ Form sentences with CAN for ability
# - ✅ Make negatives with CAN'T
# - ✅ Ask questions with CAN
# - ✅ Give short answers
# - ✅ Use CAN for permission, requests, and offers
# - ✅ Correct common mistakes
#
# ⏱️ **Estimated time:** 90-120 minutes
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise, create_progress_bar
from IPython.display import display, HTML

# Initialize validator and exercise system
validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("✅ Ready to practice! Complete all exercises below.")

# %% [markdown]
# ---
#
# ## Exercise Set 1: CAN for Ability
#
# Complete each sentence with CAN and the correct verb.
#
# ### Instructions:
# Type: can + verb (e.g., "can swim")
#
# ---

# %%
# Exercise 1.1
exercise.create_fill_in_blank("1. I ___ English. (speak)", "can speak")

# %%
# Exercise 1.2
exercise.create_fill_in_blank("2. She ___ very well. (cook)", "can cook")

# %%
# Exercise 1.3
exercise.create_fill_in_blank("3. They ___ football. (play)", "can play")

# %%
# Exercise 1.4
exercise.create_fill_in_blank("4. He ___ the guitar. (play)", "can play")

# %%
# Exercise 1.5
exercise.create_fill_in_blank("5. We ___ computers. (use)", "can use")

# %%
# Exercise 1.6
exercise.create_fill_in_blank("6. My brother ___ fast. (run)", "can run")

# %%
# Exercise 1.7
exercise.create_fill_in_blank("7. I ___ 50 meters. (swim)", "can swim")

# %%
# Exercise 1.8
exercise.create_fill_in_blank("8. She ___ a bicycle. (ride)", "can ride")

# %%
# Exercise 1.9
exercise.create_fill_in_blank("9. They ___ math problems. (solve)", "can solve")

# %%
# Exercise 1.10
exercise.create_fill_in_blank("10. He ___ three languages. (speak)", "can speak")

# %% [markdown]
# ---
#
# ## Exercise Set 2: CAN'T for Inability
#
# Complete each sentence with CAN'T and the correct verb.
#
# ---

# %%
# Exercise 2.1
exercise.create_fill_in_blank("1. I ___ Chinese. (speak)", "can't speak")

# %%
# Exercise 2.2
exercise.create_fill_in_blank("2. She ___ a car. (drive)", "can't drive")

# %%
# Exercise 2.3
exercise.create_fill_in_blank("3. He ___ the piano. (play)", "can't play")

# %%
# Exercise 2.4
exercise.create_fill_in_blank("4. We ___ late tonight. (stay)", "can't stay")

# %%
# Exercise 2.5
exercise.create_fill_in_blank("5. They ___ the answer. (find)", "can't find")

# %%
# Exercise 2.6
exercise.create_fill_in_blank("6. I ___ without my glasses. (see)", "can't see")

# %%
# Exercise 2.7
exercise.create_fill_in_blank("7. She ___ to the party. (come)", "can't come")

# %%
# Exercise 2.8
exercise.create_fill_in_blank("8. He ___ meat. (eat)", "can't eat")

# %%
# Exercise 2.9
exercise.create_fill_in_blank("9. We ___ you tomorrow. (help)", "can't help")

# %%
# Exercise 2.10
exercise.create_fill_in_blank("10. They ___ chess. (play)", "can't play")

# %% [markdown]
# ---
#
# ## Exercise Set 3: Questions with CAN
#
# Make questions using CAN. Put the words in the correct order.
#
# ---

# %%
# Exercise 3.1
exercise.create_fill_in_blank("1. you / swim / can / ? → ___ you swim?", "Can")

# %%
# Exercise 3.2
exercise.create_fill_in_blank("2. she / drive / can / ? → ___ she drive?", "Can")

# %%
# Exercise 3.3
exercise.create_fill_in_blank("3. they / come / can / ? → ___ they come?", "Can")

# %%
# Exercise 3.4
exercise.create_fill_in_blank("4. he / speak / can / French / ? → ___ he speak French?", "Can")

# %%
# Exercise 3.5
exercise.create_fill_in_blank("5. you / help / can / me / ? → ___ you help me?", "Can")

# %%
# Exercise 3.6
exercise.create_fill_in_blank("6. I / use / can / phone / your / ? → ___ I use your phone?", "Can")

# %%
# Exercise 3.7
exercise.create_fill_in_blank("7. we / start / can / now / ? → ___ we start now?", "Can")

# %%
# Exercise 3.8
exercise.create_fill_in_blank("8. she / play / can / tennis / ? → ___ she play tennis?", "Can")

# %%
# Exercise 3.9
exercise.create_fill_in_blank(
    "9. you / cook / can / Italian food / ? → ___ you cook Italian food?", "Can"
)

# %%
# Exercise 3.10
exercise.create_fill_in_blank(
    "10. they / understand / can / English / ? → ___ they understand English?", "Can"
)

# %% [markdown]
# ---
#
# ## Exercise Set 4: Short Answers
#
# Answer the questions with short answers.
#
# ### Instructions:
# Answer with "Yes, [pronoun] can." or "No, [pronoun] can't."
#
# ---

# %%
# Exercise 4.1
exercise.create_fill_in_blank("1. Can you swim? (✅) → ___, I can.", "Yes")

# %%
# Exercise 4.2
exercise.create_fill_in_blank("2. Can she drive? (❌) → ___, she can't.", "No")

# %%
# Exercise 4.3
exercise.create_fill_in_blank("3. Can they come? (✅) → ___, they can.", "Yes")

# %%
# Exercise 4.4
exercise.create_fill_in_blank("4. Can he speak French? (❌) → ___, he can't.", "No")

# %%
# Exercise 4.5
exercise.create_fill_in_blank("5. Can we start now? (✅) → ___, we can.", "Yes")

# %%
# Exercise 4.6
exercise.create_fill_in_blank("6. Can you help me? (✅) → ___, I can.", "Yes")

# %%
# Exercise 4.7
exercise.create_fill_in_blank("7. Can she cook? (❌) → ___, she can't.", "No")

# %%
# Exercise 4.8
exercise.create_fill_in_blank("8. Can they play tennis? (✅) → ___, they can.", "Yes")

# %% [markdown]
# ---
#
# ## Exercise Set 5: CAN vs CAN'T
#
# Choose CAN or CAN'T based on the context.
#
# ---

# %%
# Exercise 5.1
exercise.create_fill_in_blank("1. I ___ fly. (Nobody can!)", "can't")

# %%
# Exercise 5.2
exercise.create_fill_in_blank("2. She ___ speak three languages. (She's multilingual)", "can")

# %%
# Exercise 5.3
exercise.create_fill_in_blank("3. He ___ come tomorrow. (He's busy)", "can't")

# %%
# Exercise 5.4
exercise.create_fill_in_blank("4. We ___ help you. (We have time)", "can")

# %%
# Exercise 5.5
exercise.create_fill_in_blank("5. They ___ hear you. (It's too noisy)", "can't")

# %%
# Exercise 5.6
exercise.create_fill_in_blank("6. I ___ see the board. (It's clear)", "can")

# %%
# Exercise 5.7
exercise.create_fill_in_blank("7. She ___ drive yet. (She's learning)", "can't")

# %%
# Exercise 5.8
exercise.create_fill_in_blank("8. He ___ play the guitar. (He's a musician)", "can")

# %% [markdown]
# ---
#
# ## Exercise Set 6: CAN for Permission
#
# Complete the permission requests with CAN I or CAN WE.
#
# ---

# %%
# Exercise 6.1
exercise.create_fill_in_blank("1. ___ use your phone? (one person asking)", "Can I")

# %%
# Exercise 6.2
exercise.create_fill_in_blank("2. ___ sit here? (one person asking)", "Can I")

# %%
# Exercise 6.3
exercise.create_fill_in_blank("3. ___ leave early? (two or more people asking)", "Can we")

# %%
# Exercise 6.4
exercise.create_fill_in_blank("4. ___ ask a question? (one person asking)", "Can I")

# %%
# Exercise 6.5
exercise.create_fill_in_blank("5. ___ open the window? (one person asking)", "Can I")

# %%
# Exercise 6.6
exercise.create_fill_in_blank("6. ___ take a break? (two or more people asking)", "Can we")

# %%
# Exercise 6.7
exercise.create_fill_in_blank("7. ___ borrow your pen? (one person asking)", "Can I")

# %%
# Exercise 6.8
exercise.create_fill_in_blank("8. ___ start eating? (two or more people asking)", "Can we")

# %% [markdown]
# ---
#
# ## Exercise Set 7: CAN for Requests
#
# Complete the requests with CAN YOU.
#
# ---

# %%
# Exercise 7.1
exercise.create_fill_in_blank("1. ___ help me? (making a request)", "Can you")

# %%
# Exercise 7.2
exercise.create_fill_in_blank("2. ___ close the door? (making a request)", "Can you")

# %%
# Exercise 7.3
exercise.create_fill_in_blank("3. ___ speak more slowly? (making a request)", "Can you")

# %%
# Exercise 7.4
exercise.create_fill_in_blank("4. ___ pass the salt? (making a request)", "Can you")

# %%
# Exercise 7.5
exercise.create_fill_in_blank("5. ___ tell me the time? (making a request)", "Can you")

# %%
# Exercise 7.6
exercise.create_fill_in_blank("6. ___ wait a moment? (making a request)", "Can you")

# %%
# Exercise 7.7
exercise.create_fill_in_blank("7. ___ explain this again? (making a request)", "Can you")

# %%
# Exercise 7.8
exercise.create_fill_in_blank("8. ___ turn down the music? (making a request)", "Can you")

# %% [markdown]
# ---
#
# ## Exercise Set 8: Error Correction
#
# Find and correct the error in each sentence.
#
# ---

# %%
# Exercise 8.1
exercise.create_fill_in_blank("Incorrect: He cans swim. → Corrected: He ___ swim.", "can")

# %%
# Exercise 8.2
exercise.create_fill_in_blank("Incorrect: I can to drive. → Corrected: I can ___.", "drive")

# %%
# Exercise 8.3
exercise.create_fill_in_blank("Incorrect: Do you can help me? → Corrected: ___ you help me?", "Can")

# %%
# Exercise 8.4
exercise.create_fill_in_blank(
    "Incorrect: She doesn't can speak French. → Corrected: She ___ speak French.", "can't"
)

# %%
# Exercise 8.5
exercise.create_fill_in_blank("Incorrect: Can you swimming? → Corrected: Can you ___?", "swim")

# %%
# Exercise 8.6
exercise.create_fill_in_blank("Incorrect: I no can come. → Corrected: I ___ come.", "can't")

# %%
# Exercise 8.7
exercise.create_fill_in_blank(
    "Incorrect: Can he plays guitar? → Corrected: Can he ___ guitar?", "play"
)

# %%
# Exercise 8.8
exercise.create_fill_in_blank("Incorrect: They cans't drive. → Corrected: They ___ drive.", "can't")

# %% [markdown]
# ---
#
# ## Exercise Set 9: Multiple Choice
#
# Choose the correct answer.
#
# ---

# %%
# Exercise 9.1
exercise.create_multiple_choice(
    "___ you speak English?",
    {"A": "Do", "B": "Can", "C": "Are"},
    "B",
    "'Can' is correct for asking about ability.",
)

# %%
# Exercise 9.2
exercise.create_multiple_choice(
    "She ___ drive a car.",
    {"A": "can", "B": "cans", "C": "can to"},
    "A",
    "'Can' never changes form.",
)

# %%
# Exercise 9.3
exercise.create_multiple_choice(
    "I ___ swim.",
    {"A": "no can", "B": "can't", "C": "don't can"},
    "B",
    "Use 'can't' for negative, not 'don't can'.",
)

# %%
# Exercise 9.4
exercise.create_multiple_choice(
    "___ I sit here?",
    {"A": "Am", "B": "Do", "C": "Can"},
    "C",
    "'Can I' is used to ask for permission.",
)

# %%
# Exercise 9.5
exercise.create_multiple_choice(
    "Can you help me? Yes, I ___.",
    {"A": "do", "B": "can", "C": "am"},
    "B",
    "Short answer uses 'can'.",
)

# %%
# Exercise 9.6
exercise.create_multiple_choice(
    "He ___ play tennis.",
    {"A": "can", "B": "can to", "C": "cans"},
    "A",
    "'Can' + base verb (no 'to').",
)

# %%
# Exercise 9.7
exercise.create_multiple_choice(
    "___ speak more slowly, please?",
    {"A": "You can", "B": "Can you", "C": "Do you can"},
    "B",
    "'Can you' makes a polite request.",
)

# %%
# Exercise 9.8
exercise.create_multiple_choice(
    "They ___ come tomorrow.",
    {"A": "no can", "B": "can not", "C": "can't"},
    "C",
    "'Can't' is the most common form.",
)

# %% [markdown]
# ---
#
# ## Exercise Set 10: Context Practice
#
# Complete the dialogues with CAN, CAN'T, or appropriate forms.
#
# ---

# %%
# Exercise 10.1
exercise.create_fill_in_blank("A: ___ you play the guitar? B: Yes, I can.", "Can")

# %%
# Exercise 10.2
exercise.create_fill_in_blank("A: I need help. B: I ___ help you now. I'm busy.", "can't")

# %%
# Exercise 10.3
exercise.create_fill_in_blank("A: ___ I open the window? B: Yes, of course!", "Can")

# %%
# Exercise 10.4
exercise.create_fill_in_blank(
    "A: She speaks five languages! B: Wow! That's amazing. I ___ speak only two.", "can"
)

# %%
# Exercise 10.5
exercise.create_fill_in_blank("A: ___ you close the door, please? B: Sure, no problem.", "Can")

# %%
# Exercise 10.6
exercise.create_fill_in_blank("A: Can he come to the party? B: No, he ___. He's sick.", "can't")

# %%
# Exercise 10.7
exercise.create_fill_in_blank(
    "A: I ___ swim 100 meters. B: That's great! I can only swim 50.", "can"
)

# %%
# Exercise 10.8
exercise.create_fill_in_blank("A: Can we leave early today? B: Yes, you ___.", "can")

# %% [markdown]
# ---
#
# ## 📊 Your Score

# %%
# Display final score
validator.display_score()

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### If your score is:
# - **80%+**: Excellent! Move to **03_meaningful_practice.ipynb** ✅
# - **60-79%**: Good progress! Review the CAN/CAN'T rules, then continue 👍
# - **Below 60%**: Review **01_introduction.ipynb** and retry these exercises 📚
#
# ### Key Points to Remember:
# - **CAN** expresses ability and permission
# - **CAN'T** expresses inability
# - CAN never changes form (no -s, no -ed)
# - Use base verb after CAN (no 'to')
# - Questions: **CAN + subject + verb?**
# - Don't use DO/DOES with CAN
# - Short answers: **Yes, I can** / **No, I can't**
#
# ---
#
# ### Continue to:
# **03_meaningful_practice.ipynb** - Write about your own abilities!
#
# ---
#
# **Great work!** 🌟 You've completed the controlled practice phase!
