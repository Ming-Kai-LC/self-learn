# %% [markdown]
# # Module 12: Can/Can't - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Welcome to the final practice phase! Here you'll use CAN and CAN'T in **realistic situations** and **creative tasks**.
#
# ### What You'll Do:
# - ✅ Create dialogues using CAN/CAN'T
# - ✅ Write requests and offers in real contexts
# - ✅ Role-play permission situations
# - ✅ Complete real-world communication tasks
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from IPython.display import display, HTML
from spaced_repetition import SpacedRepetitionScheduler

# Initialize spaced repetition scheduler
scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Ready for real communication practice!")

# %% [markdown]
# ---
#
# ## Task 1: Job Interview - Skills Assessment 💼
#
# ### Scenario:
# You're at a job interview. The interviewer asks about your abilities and skills.
#
# ### Instructions:
# 1. Write a conversation with 12-15 exchanges
# 2. The interviewer asks what you CAN and CAN'T do
# 3. You answer honestly about your skills
# 4. Include questions about ability, permission, and offers to help
#
# ### Include:
# - Technical skills (Can you use...?)
# - Language skills (Can you speak...?)
# - Soft skills (Can you work in a team?)
# - Availability (Can you start...?)
#
# ### Minimum: 12 exchanges
#
# ---

# %% [markdown]
# ### Your Interview:
#
# **Position:** _______________ (e.g., Customer Service, IT Support, Teacher)
#
# **Interviewer:** Good morning! Let's talk about your skills. Can you tell me what software programs you can use?
#
# **You:** _______________________________________________
#
# **Interviewer:** _______________________________________________?
#
# **You:** _______________________________________________
#
# **Interviewer:** _______________________________________________?
#
# **You:** _______________________________________________
#
# _(Continue for at least 12 exchanges)_
#
# **Interviewer:** Thank you for your time. We'll be in touch.
#
# **You:** Thank you for the opportunity. I can start anytime!
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 2: First Day at Work - Asking for Permission and Help 🏢
#
# ### Scenario:
# It's your first day at a new job. You need to ask for permission to do various things and request help from colleagues.
#
# ### Instructions:
# Write a series of short conversations (minimum 10 situations) where you:
# - Ask permission to use facilities
# - Request help with tasks
# - Offer to help others
# - Talk about what you can and can't do yet
#
# ### Situations to include:
# - Using the printer/computer
# - Taking a break
# - Asking for help
# - Offering to help
# - Attending meetings
#
# ---

# %% [markdown]
# ### Your First Day Conversations:
#
# **Situation 1: Using the printer**
#
# **You:** Excuse me, can I _______________________________________________?
#
# **Colleague:** _______________________________________________
#
# ---
#
# **Situation 2: Coffee break**
#
# **You:** Can I _______________________________________________?
#
# **Manager:** _______________________________________________
#
# ---
#
# **Situation 3: Asking for help**
#
# **You:** I can't _______________________________________________. Can you _______________________________________________?
#
# **Colleague:** _______________________________________________
#
# ---
#
# _(Continue for at least 10 different situations)_
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 3: Travel Agency Conversation - Making Arrangements ✈️
#
# ### Scenario:
# You're at a travel agency planning a trip. Discuss what you can and can't do, ask for permission, and request services.
#
# ### Instructions:
# Write a complete conversation covering:
# - Travel dates (When can you travel?)
# - Budget (What can you afford?)
# - Activities (What can/can't you do? Swimming, hiking, etc.)
# - Special requests (Can you arrange...?)
# - Modifications (Can we change...?)
#
# ### Minimum: 14 exchanges
#
# ---

# %% [markdown]
# ### Your Travel Conversation:
#
# **Agent:** Good morning! How can I help you today?
#
# **You:** I want to plan a trip. Can you help me find a good destination?
#
# **Agent:** _______________________________________________
#
# **You:** _______________________________________________?
#
# **Agent:** _______________________________________________
#
# **You:** I can't swim, so _______________________________________________.
#
# **Agent:** _______________________________________________
#
# _(Continue for at least 14 exchanges)_
#
# **You:** Perfect! Can I pay a deposit today?
#
# **Agent:** Yes, you can. Thank you!
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 4: Helping a Friend Move 🚚
#
# ### Scenario:
# Your friend is moving to a new apartment. You're organizing help from several people.
#
# ### Instructions:
# Write conversations where you:
# - Offer to help with various tasks
# - Ask friends if they can help
# - Discuss who can and can't do certain tasks
# - Make requests for specific help
# - Coordinate the moving day
#
# ### Minimum: 3 conversations with different people (10+ exchanges total)
#
# ---

# %% [markdown]
# ### Your Moving Day Conversations:
#
# **Conversation 1: With your friend (the one moving)**
#
# **You:** I can help you move on Saturday. What time can I come?
#
# **Friend:** _______________________________________________
#
# **You:** _______________________________________________?
#
# **Friend:** _______________________________________________
#
# ---
#
# **Conversation 2: Asking another friend for help**
#
# **You:** Hi! Can you help us move on Saturday?
#
# **Friend 2:** _______________________________________________
#
# **You:** Can you drive the truck? I can't drive large vehicles.
#
# **Friend 2:** _______________________________________________
#
# ---
#
# **Conversation 3: On moving day**
#
# **You:** Can you take this box? It's very heavy.
#
# **Friend:** _______________________________________________
#
# **You:** _______________________________________________
#
# ---
#
# _(Add more conversations)_
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 5: Parent-Teacher Conference 👨‍👩‍👧‍👦
#
# ### Scenario:
# You're a parent (or student) meeting with a teacher. Discuss abilities, challenges, and permissions.
#
# ### Instructions:
# Write a conversation covering:
# - Current abilities (What can the student do well?)
# - Challenges (What can't they do yet?)
# - Requests for extra help (Can you provide...?)
# - Permission for activities (Can they participate...?)
# - Offers to help (I can help with...)
#
# ### Minimum: 14 exchanges
#
# ---

# %% [markdown]
# ### Your Conference:
#
# **Teacher:** Thank you for coming. Let's discuss your child's progress.
#
# **You:** _______________________________________________
#
# **Teacher:** They can read very well, but _______________________________________________.
#
# **You:** _______________________________________________?
#
# **Teacher:** _______________________________________________
#
# _(Continue for at least 14 exchanges)_
#
# **You:** Thank you for your help. Can we meet again next month?
#
# **Teacher:** Of course! I can schedule it now.
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 6: Tech Support Phone Call 📞
#
# ### Scenario:
# You're calling technical support because you can't do something on your computer/phone.
#
# ### Instructions:
# Write a phone conversation where you:
# - Explain what you can't do
# - Ask if they can help you
# - Request permission to try solutions
# - Confirm what you can and can't see/do
# - Follow instructions
#
# ### Include:
# - Problem description
# - Troubleshooting steps
# - Confirmation of actions
# - Resolution
#
# ### Minimum: 14 exchanges
#
# ---

# %% [markdown]
# ### Your Tech Support Call:
#
# **Support:** Good afternoon, tech support. How can I help you?
#
# **You:** Hello. I can't _______________________________________________.
#
# **Support:** _______________________________________________?
#
# **You:** Yes, I can see that. But I can't _______________________________________________.
#
# **Support:** _______________________________________________
#
# **You:** _______________________________________________?
#
# **Support:** _______________________________________________
#
# _(Continue for at least 14 exchanges)_
#
# **You:** Great! It works now. Thank you for your help!
#
# **Support:** You're welcome. Can I help you with anything else?
#
# **You:** No, thank you. That's all.
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 7: Fitness Class - New Member Orientation 💪
#
# ### Scenario:
# You're joining a fitness class. The instructor asks about your abilities and limitations.
#
# ### Instructions:
# Write a conversation covering:
# - Your current fitness abilities
# - Physical limitations (injuries, conditions)
# - What you can and can't do
# - Permission to modify exercises
# - Instructor's offers to help
#
# ### Minimum: 12 exchanges
#
# ---

# %% [markdown]
# ### Your Fitness Conversation:
#
# **Instructor:** Welcome! Before we start, can you tell me about your fitness level?
#
# **You:** _______________________________________________
#
# **Instructor:** Good! Can you do push-ups?
#
# **You:** _______________________________________________
#
# **Instructor:** _______________________________________________?
#
# **You:** I can't _______________________________________________. I have a knee problem.
#
# **Instructor:** _______________________________________________
#
# _(Continue for at least 12 exchanges)_
#
# **Instructor:** Great! If you can't do any exercise, just let me know. I can show you modifications.
#
# **You:** Thank you! Can I start today?
#
# **Instructor:** Yes, you can! Let's begin.
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 8: Restaurant - Special Requests and Dietary Restrictions 🍽️
#
# ### Scenario:
# You're at a restaurant with dietary restrictions or preferences. You need to communicate what you can and can't eat.
#
# ### Instructions:
# Write a conversation with a waiter where you:
# - Ask what dishes you can order
# - Explain what you can't eat (allergies, diet, preferences)
# - Request modifications
# - Ask if they can prepare special dishes
# - Offer suggestions or alternatives
#
# ### Include:
# - Greetings and menu discussion
# - Questions about ingredients
# - Special requests
# - Order placement
# - Follow-up questions
#
# ### Minimum: 14 exchanges
#
# ---

# %% [markdown]
# ### Your Restaurant Conversation:
#
# **Waiter:** Good evening! Welcome to our restaurant. Can I get you something to drink?
#
# **You:** _______________________________________________
#
# **Waiter:** Certainly. Are you ready to order food?
#
# **You:** I have a question. Can you tell me _______________________________________________?
#
# **Waiter:** _______________________________________________
#
# **You:** I can't eat _______________________________________________ because _______________________________________________.
#
# **Waiter:** _______________________________________________
#
# **You:** _______________________________________________?
#
# **Waiter:** _______________________________________________
#
# _(Continue for at least 14 exchanges)_
#
# **You:** Perfect! Can I also order _______________________________________________?
#
# **Waiter:** Yes, you can. I'll place your order now.
#
# **You:** Thank you for your help!
#
# ---
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## 🎓 Module Completion Assessment
#
# ### Self-Evaluation Checklist:
#
# Check ✅ if you can do these things confidently:
#
# - [ ] I can use CAN to express ability
# - [ ] I can use CAN'T to express inability
# - [ ] I can ask questions with CAN
# - [ ] I can give short answers (Yes, I can / No, I can't)
# - [ ] I can use CAN to ask for permission
# - [ ] I can use CAN to make polite requests
# - [ ] I can use CAN to make offers
# - [ ] I can use CAN/CAN'T naturally in conversations
# - [ ] I know when to use CAN vs CAN'T
# - [ ] I can avoid common mistakes (cans, can to, do can, etc.)
#
# ### Reflection:
#
# **What did you learn from this module?**
#
# _______________________________________________
#
# **Which use of CAN was most useful for you?**
#
# _______________________________________________
#
# **How confident do you feel with CAN/CAN'T? (1-10)**
#
# ___/10
#
# **What will you practice more?**
#
# _______________________________________________
#
# ---

# %%
# Mark this module as complete and schedule review
# Uncomment and run when you've completed all tasks

# scheduler.mark_module_complete(
#     module_id="A1_Module_12",
#     module_name="Can/Can't",
#     score=85.0  # Enter your self-assessed score (0-100)
# )

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### Congratulations! 🎉
#
# You've completed **Module 12: Can/Can't**!
#
# ### Key Skills Mastered:
# - ✅ **CAN** for ability and permission
# - ✅ **CAN'T** for inability
# - ✅ Questions with CAN
# - ✅ Short answers (Yes, I can / No, I can't)
# - ✅ Requests (Can you...?)
# - ✅ Offers (I can... / Can I...?)
# - ✅ Permission (Can I...?)
# - ✅ Natural use in real situations
#
# ### Next Steps:
#
# 1. **Take a break!** ☕ Great job!
#
# 2. **Review**: Your first review is scheduled. Check the progress tracker.
#
# 3. **Continue Learning**: Move to **Module 13: This, That, These, Those - Deep Dive**
#
# 4. **Practice Daily**: Use CAN/CAN'T naturally in your conversations!
#
# ---
#
# ## 📊 Spaced Repetition Reminder
#
# Remember to review this module:
# - **Day 1**: Tomorrow
# - **Day 2**: In 2 days
# - **Day 4**: In 4 days
# - **Week 1**: In 7 days
# - **Week 2**: In 14 days
#
# Regular review ensures you **retain** what you learned!
#
# ---
#
# ## 🌟 Final Message
#
# **Excellent work!** You've mastered CAN/CAN'T through:
# - ✅ Understanding modal verb CAN
# - ✅ 80+ controlled practice exercises
# - ✅ Personal meaningful practice
# - ✅ Real-world communicative tasks
#
# **You can now express abilities, make requests, and ask for permission confidently!** 🚀
#
# See you in Module 13!
