# %% [markdown]
# # Module 18: Going To Future - Phase 4: Communicative Practice
#
# ## Overview
# 8 communicative tasks
#
# **Tasks:**
# 1. Future Plans Interview
# 2. Fortune Teller Role-Play
# 3. Weekend Discussion
# 4. Travel Agency
# 5. Problem Solving
# 6. Group Project Planning
# 7. Predictions Game
# 8. Future Plans Presentation

# %% [markdown]
# ## Task 1: Future Plans Interview
#
# **Objective:** Interview a partner about their plans
#
# **Instructions:**
# - Work in pairs/groups
# - Use "going to" throughout
# - Ask and answer questions
# - Share with the class
#
# **Time:** 15-20 minutes

# %%
# Task 1: Future Plans Interview
print("Future Plans Interview")
print("=" * 60)
print("\nInterview a partner about their plans")
print("\nUse these question stems:")
print("- What are you going to...?")
print("- When are you going to...?")
print("- Where are you going to...?")
print("- Who is going to...?")
print("- How are you going to...?")

# %% [markdown]
# ## Task 2: Fortune Teller Role-Play
#
# **Objective:** Make predictions about someone's future
#
# **Instructions:**
# - Work in pairs/groups
# - Use "going to" throughout
# - Ask and answer questions
# - Share with the class
#
# **Time:** 15-20 minutes

# %%
# Task 2: Fortune Teller Role-Play
print("Fortune Teller Role-Play")
print("=" * 60)
print("\nMake predictions about someone's future")
print("\nUse these question stems:")
print("- What are you going to...?")
print("- When are you going to...?")
print("- Where are you going to...?")
print("- Who is going to...?")
print("- How are you going to...?")

# %% [markdown]
# ## Task 3: Weekend Discussion
#
# **Objective:** Discuss and compare weekend plans
#
# **Instructions:**
# - Work in pairs/groups
# - Use "going to" throughout
# - Ask and answer questions
# - Share with the class
#
# **Time:** 15-20 minutes

# %%
# Task 3: Weekend Discussion
print("Weekend Discussion")
print("=" * 60)
print("\nDiscuss and compare weekend plans")
print("\nUse these question stems:")
print("- What are you going to...?")
print("- When are you going to...?")
print("- Where are you going to...?")
print("- Who is going to...?")
print("- How are you going to...?")

# %% [markdown]
# ## Task 4: Travel Agency
#
# **Objective:** Plan a vacation together
#
# **Instructions:**
# - Work in pairs/groups
# - Use "going to" throughout
# - Ask and answer questions
# - Share with the class
#
# **Time:** 15-20 minutes

# %%
# Task 4: Travel Agency
print("Travel Agency")
print("=" * 60)
print("\nPlan a vacation together")
print("\nUse these question stems:")
print("- What are you going to...?")
print("- When are you going to...?")
print("- Where are you going to...?")
print("- Who is going to...?")
print("- How are you going to...?")

# %% [markdown]
# ## Task 5: Problem Solving
#
# **Objective:** Discuss solutions to problems
#
# **Instructions:**
# - Work in pairs/groups
# - Use "going to" throughout
# - Ask and answer questions
# - Share with the class
#
# **Time:** 15-20 minutes

# %%
# Task 5: Problem Solving
print("Problem Solving")
print("=" * 60)
print("\nDiscuss solutions to problems")
print("\nUse these question stems:")
print("- What are you going to...?")
print("- When are you going to...?")
print("- Where are you going to...?")
print("- Who is going to...?")
print("- How are you going to...?")

# %% [markdown]
# ## Task 6: Group Project Planning
#
# **Objective:** Plan a project as a team
#
# **Instructions:**
# - Work in pairs/groups
# - Use "going to" throughout
# - Ask and answer questions
# - Share with the class
#
# **Time:** 15-20 minutes

# %%
# Task 6: Group Project Planning
print("Group Project Planning")
print("=" * 60)
print("\nPlan a project as a team")
print("\nUse these question stems:")
print("- What are you going to...?")
print("- When are you going to...?")
print("- Where are you going to...?")
print("- Who is going to...?")
print("- How are you going to...?")

# %% [markdown]
# ## Task 7: Predictions Game
#
# **Objective:** Make and discuss predictions
#
# **Instructions:**
# - Work in pairs/groups
# - Use "going to" throughout
# - Ask and answer questions
# - Share with the class
#
# **Time:** 15-20 minutes

# %%
# Task 7: Predictions Game
print("Predictions Game")
print("=" * 60)
print("\nMake and discuss predictions")
print("\nUse these question stems:")
print("- What are you going to...?")
print("- When are you going to...?")
print("- Where are you going to...?")
print("- Who is going to...?")
print("- How are you going to...?")

# %% [markdown]
# ## Task 8: Future Plans Presentation
#
# **Objective:** Present your future plans
#
# **Instructions:**
# - Work in pairs/groups
# - Use "going to" throughout
# - Ask and answer questions
# - Share with the class
#
# **Time:** 15-20 minutes

# %%
# Task 8: Future Plans Presentation
print("Future Plans Presentation")
print("=" * 60)
print("\nPresent your future plans")
print("\nUse these question stems:")
print("- What are you going to...?")
print("- When are you going to...?")
print("- Where are you going to...?")
print("- Who is going to...?")
print("- How are you going to...?")
