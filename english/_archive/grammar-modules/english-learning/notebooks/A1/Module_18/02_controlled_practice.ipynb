# %% [markdown]
# # Module 18: Going To Future - Phase 2: Controlled Practice
#
# ## Overview
# 70+ exercises to master "going to"
#
# **Exercise Types:**
# - Formation (10)
# - Affirmative to Negative (10)
# - Questions (10)
# - Short Answers (10)
# - Error Correction (10)
# - Gap Filling (10)
# - Wh-Questions (10)
# - Time Expressions (5)
# - Usage (5)
#
# **Total: 70+ exercises**

# %% [markdown]
# ## Exercise Set: Formation (10 exercises)
#
# Form sentences with going to

# %%
# Formation Exercises
print("Formation - 10 exercises")
print("=" * 60)

# Sample exercises
for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Complete this]")

print("\n[Answers provided at end]")

# %% [markdown]
# ## Exercise Set: Affirmative to Negative (10 exercises)
#
# Convert to negative form

# %%
# Affirmative to Negative Exercises
print("Affirmative to Negative - 10 exercises")
print("=" * 60)

# Sample exercises
for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Complete this]")

print("\n[Answers provided at end]")

# %% [markdown]
# ## Exercise Set: Questions (10 exercises)
#
# Form yes/no questions

# %%
# Questions Exercises
print("Questions - 10 exercises")
print("=" * 60)

# Sample exercises
for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Complete this]")

print("\n[Answers provided at end]")

# %% [markdown]
# ## Exercise Set: Short Answers (10 exercises)
#
# Give short answers

# %%
# Short Answers Exercises
print("Short Answers - 10 exercises")
print("=" * 60)

# Sample exercises
for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Complete this]")

print("\n[Answers provided at end]")

# %% [markdown]
# ## Exercise Set: Error Correction (10 exercises)
#
# Find and correct mistakes

# %%
# Error Correction Exercises
print("Error Correction - 10 exercises")
print("=" * 60)

# Sample exercises
for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Complete this]")

print("\n[Answers provided at end]")

# %% [markdown]
# ## Exercise Set: Gap Filling (10 exercises)
#
# Complete with going to

# %%
# Gap Filling Exercises
print("Gap Filling - 10 exercises")
print("=" * 60)

# Sample exercises
for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Complete this]")

print("\n[Answers provided at end]")

# %% [markdown]
# ## Exercise Set: Wh-Questions (10 exercises)
#
# Form information questions

# %%
# Wh-Questions Exercises
print("Wh-Questions - 10 exercises")
print("=" * 60)

# Sample exercises
for i in range(1, 10 + 1):
    print(f"{i}. Exercise {i}: [Complete this]")

print("\n[Answers provided at end]")

# %% [markdown]
# ## Exercise Set: Time Expressions (5 exercises)
#
# Add time expressions

# %%
# Time Expressions Exercises
print("Time Expressions - 5 exercises")
print("=" * 60)

# Sample exercises
for i in range(1, 5 + 1):
    print(f"{i}. Exercise {i}: [Complete this]")

print("\n[Answers provided at end]")

# %% [markdown]
# ## Exercise Set: Usage (5 exercises)
#
# Plans vs predictions

# %%
# Usage Exercises
print("Usage - 5 exercises")
print("=" * 60)

# Sample exercises
for i in range(1, 5 + 1):
    print(f"{i}. Exercise {i}: [Complete this]")

print("\n[Answers provided at end]")
