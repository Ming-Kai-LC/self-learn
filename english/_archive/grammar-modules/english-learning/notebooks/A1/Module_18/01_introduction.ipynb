# %% [markdown]
# # Module 18: Going To Future - Phase 1: Introduction
#
# ## Learning Objectives
# - Form sentences using "going to" for future plans
# - Express intentions and predictions
# - Use affirmative, negative, and question forms
# - Apply time expressions correctly
#
# **Target Level:** A1
# **Estimated Time:** 90-120 minutes

# %% [markdown]
# ## 1. Introduction to Going To
#
# The 'going to' future expresses plans, intentions, and predictions based on evidence.
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 1. Introduction to Going To - Practice
print("1. Introduction to Going To")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 2. Formation
#
# Structure: Subject + am/is/are + going to + base verb
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 2. Formation - Practice
print("2. Formation")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 3. Affirmative Sentences
#
# I'm going to study. She's going to visit. They're going to travel.
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 3. Affirmative Sentences - Practice
print("3. Affirmative Sentences")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 4. Negative Sentences
#
# I'm not going to work. She isn't going to come. They aren't going to buy.
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 4. Negative Sentences - Practice
print("4. Negative Sentences")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 5. Questions
#
# Are you going to study? Is she going to come? What are you going to do?
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 5. Questions - Practice
print("5. Questions")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 6. Short Answers
#
# Yes, I am. No, I'm not. Yes, she is. No, she isn't.
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 6. Short Answers - Practice
print("6. Short Answers")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 7. Uses of Going To
#
# Plans/Intentions and Predictions with Evidence
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 7. Uses of Going To - Practice
print("7. Uses of Going To")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 8. Time Expressions
#
# tonight, tomorrow, next week, soon, later, in + time
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 8. Time Expressions - Practice
print("8. Time Expressions")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 9. Going To vs Will
#
# going to = planned; will = spontaneous
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 9. Going To vs Will - Practice
print("9. Going To vs Will")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 10. Contractions
#
# I'm, you're, he's, she's, we're, they're + gonna (informal)
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 10. Contractions - Practice
print("10. Contractions")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 11. Common Mistakes
#
# Wrong verb form, missing 'to', wrong 'be' form
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 11. Common Mistakes - Practice
print("11. Common Mistakes")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")

# %% [markdown]
# ## 12. Practice Conversations
#
# Dialogues using going to naturally
#
# ### Examples:
# - I'm going to learn English next year.
# - She's going to start a new job soon.
# - Are you going to visit your family?
# - We're not going to be late.
#
# ### Practice:
# Complete these sentences with appropriate forms.

# %%
# 12. Practice Conversations - Practice
print("12. Practice Conversations")
print("=" * 60)

examples = [
    "I'm going to study for the exam.",
    "She's going to call you later.",
    "They're going to move to a new city.",
    "We're not going to miss the train.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create 5 sentences using 'going to'")
