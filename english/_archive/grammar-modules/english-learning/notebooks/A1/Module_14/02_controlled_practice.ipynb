# %% [markdown]
# # Module 14: Like, Love, Hate + -ing - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Welcome to the practice phase! Here you'll complete exercises with **immediate feedback** to master expressing preferences with -ing verbs.
#
# ### What You'll Do:
# - [OK] Add -ing to verbs correctly (spelling practice)
# - [OK] Use LIKE + -ing in sentences
# - [OK] Use LOVE + -ing in sentences
# - [OK] Use HATE + -ing in sentences
# - [OK] Practice with mixed preference verbs
# - [OK] Create negative sentences
# - [OK] Form questions correctly
# - [OK] Choose between preference verbs
# - [OK] Correct common errors
# - [OK] Complete sentences in context
#
# ⏱️ **Estimated time:** 90-120 minutes
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise, create_progress_bar
from IPython.display import display, HTML

# Initialize validator and exercise system
validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("[OK] Ready to practice! Complete all exercises below.")

# %% [markdown]
# ---
#
# ## Exercise Set 1: Add -ing to Verbs Correctly (Spelling Rules)
#
# Add -ing to each verb following the correct spelling rules.
#
# ### Instructions:
# - Apply the spelling rules from Phase 1
# - Type the complete -ing form (e.g., "reading", "running")
#
# ---

# %%
# Exercise 1.1
exercise.create_fill_in_blank("1. read → ___", "reading")

# %%
# Exercise 1.2
exercise.create_fill_in_blank("2. make → ___ (drop e)", "making")

# %%
# Exercise 1.3
exercise.create_fill_in_blank("3. run → ___ (double n)", "running")

# %%
# Exercise 1.4
exercise.create_fill_in_blank("4. watch → ___", "watching")

# %%
# Exercise 1.5
exercise.create_fill_in_blank("5. dance → ___ (drop e)", "dancing")

# %%
# Exercise 1.6
exercise.create_fill_in_blank("6. swim → ___ (double m)", "swimming")

# %%
# Exercise 1.7
exercise.create_fill_in_blank("7. play → ___", "playing")

# %%
# Exercise 1.8
exercise.create_fill_in_blank("8. write → ___ (drop e)", "writing")

# %%
# Exercise 1.9
exercise.create_fill_in_blank("9. sit → ___ (double t)", "sitting")

# %%
# Exercise 1.10
exercise.create_fill_in_blank("10. listen → ___", "listening")

# %% [markdown]
# ---
#
# ## Exercise Set 2: LIKE + -ing Sentences
#
# Complete each sentence with LIKE/LIKES + the -ing form of the verb in parentheses.
#
# ### Instructions:
# - Use "like" or "likes" depending on the subject
# - Add the verb in -ing form
# - Example: She ___ (read) books. → She likes reading books.
#
# ---

# %%
# Exercise 2.1
exercise.create_fill_in_blank("1. I ___ (watch) movies on weekends.", "like watching")

# %%
# Exercise 2.2
exercise.create_fill_in_blank("2. She ___ (read) mystery novels.", "likes reading")

# %%
# Exercise 2.3
exercise.create_fill_in_blank("3. They ___ (play) football after school.", "like playing")

# %%
# Exercise 2.4
exercise.create_fill_in_blank("4. He ___ (cook) Italian food.", "likes cooking")

# %%
# Exercise 2.5
exercise.create_fill_in_blank("5. We ___ (listen) to music in the car.", "like listening")

# %%
# Exercise 2.6
exercise.create_fill_in_blank("6. Sarah ___ (swim) in the ocean.", "likes swimming")

# %%
# Exercise 2.7
exercise.create_fill_in_blank("7. You ___ (spend) time with friends.", "like spending")

# %%
# Exercise 2.8
exercise.create_fill_in_blank("8. My brother ___ (play) video games.", "likes playing")

# %%
# Exercise 2.9
exercise.create_fill_in_blank("9. I ___ (walk) in the park.", "like walking")

# %%
# Exercise 2.10
exercise.create_fill_in_blank("10. My parents ___ (travel) abroad.", "like traveling")

# %% [markdown]
# ---
#
# ## Exercise Set 3: LOVE + -ing Sentences
#
# Complete each sentence with LOVE/LOVES + the -ing form of the verb.
#
# ### Instructions:
# - Use "love" or "loves" depending on the subject
# - Add the verb in -ing form
#
# ---

# %%
# Exercise 3.1
exercise.create_fill_in_blank("1. I ___ (dance) at parties!", "love dancing")

# %%
# Exercise 3.2
exercise.create_fill_in_blank("2. She ___ (sing) in the shower.", "loves singing")

# %%
# Exercise 3.3
exercise.create_fill_in_blank("3. They ___ (eat) at new restaurants.", "love eating")

# %%
# Exercise 3.4
exercise.create_fill_in_blank("4. He ___ (run) in the morning.", "loves running")

# %%
# Exercise 3.5
exercise.create_fill_in_blank("5. We ___ (watch) the sunset.", "love watching")

# %%
# Exercise 3.6
exercise.create_fill_in_blank("6. Maria ___ (paint) landscapes.", "loves painting")

# %%
# Exercise 3.7
exercise.create_fill_in_blank("7. I ___ (learn) new languages.", "love learning")

# %%
# Exercise 3.8
exercise.create_fill_in_blank("8. My sister ___ (bake) cakes.", "loves baking")

# %% [markdown]
# ---
#
# ## Exercise Set 4: HATE + -ing Sentences
#
# Complete each sentence with HATE/HATES + the -ing form of the verb.
#
# ### Instructions:
# - Use "hate" or "hates" depending on the subject
# - Add the verb in -ing form
#
# ---

# %%
# Exercise 4.1
exercise.create_fill_in_blank("1. I ___ (wait) in long lines.", "hate waiting")

# %%
# Exercise 4.2
exercise.create_fill_in_blank("2. She ___ (wake) up early on Mondays.", "hates waking")

# %%
# Exercise 4.3
exercise.create_fill_in_blank("3. They ___ (clean) the house.", "hate cleaning")

# %%
# Exercise 4.4
exercise.create_fill_in_blank("4. He ___ (do) homework.", "hates doing")

# %%
# Exercise 4.5
exercise.create_fill_in_blank("5. We ___ (be) late for meetings.", "hate being")

# %%
# Exercise 4.6
exercise.create_fill_in_blank("6. Tom ___ (wash) dishes.", "hates washing")

# %%
# Exercise 4.7
exercise.create_fill_in_blank("7. I ___ (sit) in traffic.", "hate sitting")

# %%
# Exercise 4.8
exercise.create_fill_in_blank("8. My roommate ___ (iron) clothes.", "hates ironing")

# %% [markdown]
# ---
#
# ## Exercise Set 5: Mixed Preference Verbs
#
# Complete with the correct form: ENJOY/ENJOYS, PREFER/PREFERS, or DON'T MIND/DOESN'T MIND + -ing.
#
# ### Instructions:
# - Read the context to choose the right verb
# - Use correct subject-verb agreement
# - Add -ing form
#
# ---

# %%
# Exercise 5.1
exercise.create_fill_in_blank(
    "1. I ___ (read) before bed. [neutral, willing]", "don't mind reading"
)

# %%
# Exercise 5.2
exercise.create_fill_in_blank("2. She ___ (swim) to running. [comparison]", "prefers swimming")

# %%
# Exercise 5.3
exercise.create_fill_in_blank("3. They ___ (cook) together. [active pleasure]", "enjoy cooking")

# %%
# Exercise 5.4
exercise.create_fill_in_blank("4. He ___ (help) with housework. [neutral]", "doesn't mind helping")

# %%
# Exercise 5.5
exercise.create_fill_in_blank("5. We ___ (walk) to driving. [comparison]", "prefer walking")

# %%
# Exercise 5.6
exercise.create_fill_in_blank("6. Sarah ___ (play) tennis. [active pleasure]", "enjoys playing")

# %%
# Exercise 5.7
exercise.create_fill_in_blank("7. I ___ (work) late occasionally. [neutral]", "don't mind working")

# %%
# Exercise 5.8
exercise.create_fill_in_blank(
    "8. My friends ___ (go) to concerts. [active pleasure]", "enjoy going"
)

# %%
# Exercise 5.9
exercise.create_fill_in_blank(
    "9. She ___ (stay) home to going out. [comparison]", "prefers staying"
)

# %%
# Exercise 5.10
exercise.create_fill_in_blank("10. They ___ (wait) a few minutes. [neutral]", "don't mind waiting")

# %% [markdown]
# ---
#
# ## Exercise Set 6: Negative Forms
#
# Rewrite each sentence in the negative form using DON'T or DOESN'T.
#
# ### Instructions:
# - Use don't/doesn't + verb + -ing
# - Keep the -ing form after the verb
#
# ---

# %%
# Exercise 6.1
exercise.create_fill_in_blank("1. I like running. → I ___ running.", "don't like")

# %%
# Exercise 6.2
exercise.create_fill_in_blank("2. She loves cooking. → She ___ cooking.", "doesn't love")

# %%
# Exercise 6.3
exercise.create_fill_in_blank("3. They enjoy swimming. → They ___ swimming.", "don't enjoy")

# %%
# Exercise 6.4
exercise.create_fill_in_blank("4. He likes waiting. → He ___ waiting.", "doesn't like")

# %%
# Exercise 6.5
exercise.create_fill_in_blank("5. We love dancing. → We ___ dancing.", "don't love")

# %%
# Exercise 6.6
exercise.create_fill_in_blank("6. Maria enjoys studying. → Maria ___ studying.", "doesn't enjoy")

# %%
# Exercise 6.7
exercise.create_fill_in_blank("7. I like cleaning. → I ___ cleaning.", "don't like")

# %%
# Exercise 6.8
exercise.create_fill_in_blank("8. They love shopping. → They ___ shopping.", "don't love")

# %% [markdown]
# ---
#
# ## Exercise Set 7: Questions Formation
#
# Form questions using the words provided.
#
# ### Instructions:
# - Start with Do or Does
# - Use correct word order
# - Keep -ing form
#
# ---

# %%
# Exercise 7.1
exercise.create_fill_in_blank("1. you / like / read / books? → ___", "Do you like reading books?")

# %%
# Exercise 7.2
exercise.create_fill_in_blank("2. she / love / dance? → ___", "Does she love dancing?")

# %%
# Exercise 7.3
exercise.create_fill_in_blank("3. they / enjoy / cook? → ___", "Do they enjoy cooking?")

# %%
# Exercise 7.4
exercise.create_fill_in_blank("4. he / hate / wait? → ___", "Does he hate waiting?")

# %%
# Exercise 7.5
exercise.create_fill_in_blank(
    "5. you / prefer / walk / or / drive? → ___", "Do you prefer walking or driving?"
)

# %%
# Exercise 7.6
exercise.create_fill_in_blank("6. she / like / swim? → ___", "Does she like swimming?")

# %%
# Exercise 7.7
exercise.create_fill_in_blank("7. they / mind / help? → ___", "Do they mind helping?")

# %%
# Exercise 7.8
exercise.create_fill_in_blank("8. he / enjoy / travel? → ___", "Does he enjoy traveling?")

# %% [markdown]
# ---
#
# ## Exercise Set 8: Choose the Correct Form
#
# Choose the correct preference verb for each situation.
#
# ### Instructions:
# - Read the context carefully
# - Choose: like, love, hate, enjoy, prefer, or don't mind
#
# ---

# %%
# Exercise 8.1
exercise.create_fill_in_blank(
    "1. I really, really enjoy this! I ___ doing it! [very strong positive]", "love"
)

# %%
# Exercise 8.2
exercise.create_fill_in_blank("2. It's okay with me. I ___ doing it. [neutral]", "don't mind")

# %%
# Exercise 8.3
exercise.create_fill_in_blank("3. I think it's nice. I ___ doing it. [positive]", "like")

# %%
# Exercise 8.4
exercise.create_fill_in_blank(
    "4. I really dislike this! I ___ doing it! [very strong negative]", "hate"
)

# %%
# Exercise 8.5
exercise.create_fill_in_blank(
    "5. I get active pleasure from this. I ___ doing it. [active enjoyment]", "enjoy"
)

# %%
# Exercise 8.6
exercise.create_fill_in_blank(
    "6. Between two options, I choose this one. I ___ this to that. [comparison]", "prefer"
)

# %%
# Exercise 8.7
exercise.create_fill_in_blank(
    "7. This is terrible! I absolutely ___ it! [extreme negative]", "hate"
)

# %%
# Exercise 8.8
exercise.create_fill_in_blank(
    "8. This is wonderful! I absolutely ___ it! [extreme positive]", "love"
)

# %% [markdown]
# ---
#
# ## Exercise Set 9: Error Correction
#
# Find and correct the error in each sentence. Write the corrected sentence.
#
# ### Instructions:
# - Identify what's wrong (missing -ing, wrong verb form, spelling, etc.)
# - Write the complete correct sentence
#
# ---

# %%
# Exercise 9.1
exercise.create_fill_in_blank("1. I like read books. → ___", "I like reading books.")

# %%
# Exercise 9.2
exercise.create_fill_in_blank("2. She loves to dancing. → ___", "She loves dancing.")

# %%
# Exercise 9.3
exercise.create_fill_in_blank("3. They enjoys cooking. → ___", "They enjoy cooking.")

# %%
# Exercise 9.4
exercise.create_fill_in_blank("4. He don't like waiting. → ___", "He doesn't like waiting.")

# %%
# Exercise 9.5
exercise.create_fill_in_blank("5. Does you love swimming? → ___", "Do you love swimming?")

# %%
# Exercise 9.6
exercise.create_fill_in_blank("6. I hate do homework. → ___", "I hate doing homework.")

# %%
# Exercise 9.7
exercise.create_fill_in_blank("7. She like playing tennis. → ___", "She likes playing tennis.")

# %%
# Exercise 9.8
exercise.create_fill_in_blank("8. We prefer walk to drive. → ___", "We prefer walking to driving.")

# %% [markdown]
# ---
#
# ## Exercise Set 10: Context Completion
#
# Complete the conversations with the correct preference verb + -ing form.
#
# ### Instructions:
# - Read the full context
# - Choose the appropriate preference verb
# - Use correct form with -ing
#
# ---

# %%
# Exercise 10.1
exercise.create_fill_in_blank(
    "1. A: What do you do for fun? B: I ___ (play) guitar. [hobby]", "like playing"
)

# %%
# Exercise 10.2
exercise.create_fill_in_blank(
    "2. A: Do you want to go shopping? B: Not really. I ___ (shop). [strong negative]",
    "hate shopping",
)

# %%
# Exercise 10.3
exercise.create_fill_in_blank(
    "3. A: Can you help me? B: Sure! I ___ (help) people. [neutral/willing]", "don't mind helping"
)

# %%
# Exercise 10.4
exercise.create_fill_in_blank(
    "4. A: What's your passion? B: I ___ (paint)! It's amazing! [strong positive]", "love painting"
)

# %%
# Exercise 10.5
exercise.create_fill_in_blank(
    "5. A: Do you like coffee or tea? B: I ___ (drink) tea. [comparison implied]", "prefer drinking"
)

# %%
# Exercise 10.6
exercise.create_fill_in_blank(
    "6. A: How do you relax? B: I ___ (read) novels. [active pleasure]", "enjoy reading"
)

# %%
# Exercise 10.7
exercise.create_fill_in_blank(
    "7. A: What's the worst chore? B: I absolutely ___ (clean) the bathroom! [extreme negative]",
    "hate cleaning",
)

# %%
# Exercise 10.8
exercise.create_fill_in_blank(
    "8. A: What do you do on weekends? B: I ___ (spend) time with family. [positive]",
    "like spending",
)

# %% [markdown]
# ---
#
# ## 📊 Your Score

# %%
# Display final score
validator.display_score()

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### If your score is:
# - **80%+**: Excellent! Move to **03_meaningful_practice.ipynb** [OK]
# - **60-79%**: Good progress! Review the rules, then continue 👍
# - **Below 60%**: Review **01_introduction.ipynb** and retry these exercises 📚
#
# ### Key Points to Remember:
# - **Always use -ing form** after preference verbs
# - **Spelling rules**: drop -e, double consonants for CVC patterns
# - **Subject-verb agreement**: I like / She likes
# - **Negatives**: don't/doesn't + verb + -ing
# - **Questions**: Do/Does + subject + verb + -ing?
# - **LOVE** = very positive, **LIKE** = positive, **HATE** = very negative
# - **ENJOY** = active pleasure, **PREFER** = comparison, **DON'T MIND** = neutral
# - **ENJOY** only takes -ing (never infinitive!)
#
# ---
#
# ### Continue to:
# **03_meaningful_practice.ipynb** - Personal activities about YOUR preferences and hobbies!
#
# ---
#
# **Great work!** 🌟 You've completed the controlled practice phase!
