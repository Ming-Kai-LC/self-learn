# %% [markdown]
# # Module 8: Adjectives - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Complete exercises with **immediate feedback** to master adjectives!
#
# ### What You'll Practice:
# - ✅ Adjectives before nouns
# - ✅ Adjectives after 'be'
# - ✅ Opposite adjectives
# - ✅ Color adjectives
# - ✅ Adjective order
# - ✅ Error correction
#
# ⏱️ **Estimated time:** 90-120 minutes
# 📊 **Total exercises:** 62
#
# ---

# %%
# Setup
import sys
sys.path.append('../../../utils')

from feedback_system import ExerciseValidator, InteractiveExercise
from IPython.display import display, HTML

validator = ExerciseValidator()
exercise = InteractiveExercise(validator)
print("✅ Ready to practice!")
print("\n💡 Tip: Read each question carefully and think before answering!")

# %% [markdown]
# ---
#
# ## Exercise Set 1: Adjectives BEFORE Nouns (8 exercises)
#
# **Pattern:** a/an/the + ADJECTIVE + NOUN
#
# Fill in the blank with the correct adjective in the correct position.
#
# ---

# %%
display(HTML('<h3>Exercise 1</h3>'))
display(HTML('<p>I have a ___ house. (big)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "big"
)

display(HTML('<h3>Exercise 2</h3>'))
display(HTML('<p>She drives a ___ car. (red)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "red"
)

display(HTML('<h3>Exercise 3</h3>'))
display(HTML('<p>They live in an ___ apartment. (expensive)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "expensive"
)

display(HTML('<h3>Exercise 4</h3>'))
display(HTML('<p>He has a ___ smile. (beautiful)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "beautiful"
)

display(HTML('<h3>Exercise 5</h3>'))
display(HTML('<p>We saw a ___ movie. (funny)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "funny"
)

display(HTML('<h3>Exercise 6</h3>'))
display(HTML('<p>I need a ___ phone. (new)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "new"
)

display(HTML('<h3>Exercise 7</h3>'))
display(HTML('<p>She bought a ___ dress. (green)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "green"
)

display(HTML('<h3>Exercise 8</h3>'))
display(HTML('<p>They have a ___ garden. (large)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "large"
)

# %% [markdown]
# ---
#
# ## Exercise Set 2: Adjectives AFTER 'Be' (8 exercises)
#
# **Pattern:** Subject + be + ADJECTIVE
#
# Complete the sentences using the adjective after 'be'.
#
# ---

# %%
display(HTML('<h3>Exercise 9</h3>'))
display(HTML('<p>The house ___ big. (is)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "is"
)

display(HTML('<h3>Exercise 10</h3>'))
display(HTML('<p>She ___ happy. (is/are)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "is"
)

display(HTML('<h3>Exercise 11</h3>'))
display(HTML('<p>The weather ___ cold. (is)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "is"
)

display(HTML('<h3>Exercise 12</h3>'))
display(HTML('<p>They ___ tired. (am/is/are)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "are"
)

display(HTML('<h3>Exercise 13</h3>'))
display(HTML('<p>I ___ ready. (am/is/are)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "am"
)

display(HTML('<h3>Exercise 14</h3>'))
display(HTML('<p>The car ___ fast. (is)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "is"
)

display(HTML('<h3>Exercise 15</h3>'))
display(HTML('<p>We ___ excited. (am/is/are)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "are"
)

display(HTML('<h3>Exercise 16</h3>'))
display(HTML('<p>The students ___ quiet. (is/are)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "are"
)

# %% [markdown]
# ---
#
# ## Exercise Set 3: Choosing the Correct Adjective (8 exercises)
#
# Choose the adjective that makes sense in context.
#
# ---

# %%
display(HTML('<h3>Exercise 17</h3>'))
display(HTML('<p>The sun is ___. (hot / cold)</p>'))
exercise.create_multiple_choice(
    "Choose: The sun is ___.",
    ["hot", "cold"],
    "hot"
)

display(HTML('<h3>Exercise 18</h3>'))
display(HTML('<p>Ice is ___. (hot / cold)</p>'))
exercise.create_multiple_choice(
    "Choose: Ice is ___.",
    ["hot", "cold"],
    "cold"
)

display(HTML('<h3>Exercise 19</h3>'))
display(HTML('<p>An elephant is ___. (big / small)</p>'))
exercise.create_multiple_choice(
    "Choose: An elephant is ___.",
    ["big", "small"],
    "big"
)

display(HTML('<h3>Exercise 20</h3>'))
display(HTML('<p>A mouse is ___. (big / small)</p>'))
exercise.create_multiple_choice(
    "Choose: A mouse is ___.",
    ["big", "small"],
    "small"
)

display(HTML('<h3>Exercise 21</h3>'))
display(HTML('<p>A baby is ___. (old / young)</p>'))
exercise.create_multiple_choice(
    "Choose: A baby is ___.",
    ["old", "young"],
    "young"
)

display(HTML('<h3>Exercise 22</h3>'))
display(HTML('<p>A new car is ___. (expensive / cheap)</p>'))
exercise.create_multiple_choice(
    "Choose: A new car is usually ___.",
    ["expensive", "cheap"],
    "expensive"
)

display(HTML('<h3>Exercise 23</h3>'))
display(HTML('<p>Snow is ___. (black / white)</p>'))
exercise.create_multiple_choice(
    "Choose: Snow is ___.",
    ["black", "white"],
    "white"
)

display(HTML('<h3>Exercise 24</h3>'))
display(HTML('<p>The sky is ___. (blue / red)</p>'))
exercise.create_multiple_choice(
    "Choose: The sky is ___.",
    ["blue", "red"],
    "blue"
)

# %% [markdown]
# ---
#
# ## Exercise Set 4: Opposite Adjectives (8 exercises)
#
# Write the opposite adjective.
#
# ---

# %%
display(HTML('<h3>Exercise 25</h3>'))
display(HTML('<p>Opposite of "big": ___</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "small"
)

display(HTML('<h3>Exercise 26</h3>'))
display(HTML('<p>Opposite of "hot": ___</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "cold"
)

display(HTML('<h3>Exercise 27</h3>'))
display(HTML('<p>Opposite of "good": ___</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "bad"
)

display(HTML('<h3>Exercise 28</h3>'))
display(HTML('<p>Opposite of "happy": ___</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "sad"
)

display(HTML('<h3>Exercise 29</h3>'))
display(HTML('<p>Opposite of "old": ___ (for things)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "new"
)

display(HTML('<h3>Exercise 30</h3>'))
display(HTML('<p>Opposite of "fast": ___</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "slow"
)

display(HTML('<h3>Exercise 31</h3>'))
display(HTML('<p>Opposite of "expensive": ___</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "cheap"
)

display(HTML('<h3>Exercise 32</h3>'))
display(HTML('<p>Opposite of "easy": ___</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "difficult"
)

# %% [markdown]
# ---
#
# ## Exercise Set 5: Color Adjectives (6 exercises)
#
# Complete the sentences with appropriate color adjectives.
#
# ---

# %%
display(HTML('<h3>Exercise 33</h3>'))
display(HTML('<p>The grass is ___. (color)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "green"
)

display(HTML('<h3>Exercise 34</h3>'))
display(HTML('<p>A banana is ___. (color)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "yellow"
)

display(HTML('<h3>Exercise 35</h3>'))
display(HTML('<p>An apple is ___. (color)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "red"
)

display(HTML('<h3>Exercise 36</h3>'))
display(HTML('<p>The ocean is ___. (color)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "blue"
)

display(HTML('<h3>Exercise 37</h3>'))
display(HTML('<p>Coal is ___. (color)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "black"
)

display(HTML('<h3>Exercise 38</h3>'))
display(HTML('<p>Clouds are ___. (color)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "white"
)

# %% [markdown]
# ---
#
# ## Exercise Set 6: Adjective Order (6 exercises)
#
# Put the adjectives in the correct order.
#
# **Remember: Opinion → Size → Age → Color**
#
# ---

# %%
display(HTML('<h3>Exercise 39</h3>'))
display(HTML('<p>a ___ ___ car (red, big)</p>'))
exercise.create_fill_in_blank(
    "Answer (two words, size first): ",
    "big red"
)

display(HTML('<h3>Exercise 40</h3>'))
display(HTML('<p>a ___ ___ house (big, nice)</p>'))
exercise.create_fill_in_blank(
    "Answer (two words, opinion first): ",
    "nice big"
)

display(HTML('<h3>Exercise 41</h3>'))
display(HTML('<p>an ___ ___ shirt (blue, old)</p>'))
exercise.create_fill_in_blank(
    "Answer (two words, age first): ",
    "old blue"
)

display(HTML('<h3>Exercise 42</h3>'))
display(HTML('<p>a ___ ___ phone (new, small)</p>'))
exercise.create_fill_in_blank(
    "Answer (two words, size first): ",
    "small new"
)

display(HTML('<h3>Exercise 43</h3>'))
display(HTML('<p>a ___ ___ dress (white, beautiful)</p>'))
exercise.create_fill_in_blank(
    "Answer (two words, opinion first): ",
    "beautiful white"
)

display(HTML('<h3>Exercise 44</h3>'))
display(HTML('<p>a ___ ___ bag (green, large)</p>'))
exercise.create_fill_in_blank(
    "Answer (two words, size first): ",
    "large green"
)

# %% [markdown]
# ---
#
# ## Exercise Set 7: Transformation (Before Noun ↔ After 'Be') (6 exercises)
#
# Rewrite the sentence changing the adjective position.
#
# ---

# %%
display(HTML('<h3>Exercise 45</h3>'))
display(HTML('<p>I have a big house. → My house ___.</p>'))
exercise.create_fill_in_blank(
    "Answer (two words): ",
    "is big"
)

display(HTML('<h3>Exercise 46</h3>'))
display(HTML('<p>The car is fast. → He drives a ___ car.</p>'))
exercise.create_fill_in_blank(
    "Answer (one word): ",
    "fast"
)

display(HTML('<h3>Exercise 47</h3>'))
display(HTML('<p>She has a beautiful garden. → Her garden ___.</p>'))
exercise.create_fill_in_blank(
    "Answer (two words): ",
    "is beautiful"
)

display(HTML('<h3>Exercise 48</h3>'))
display(HTML('<p>The weather is cold. → It's a ___ day.</p>'))
exercise.create_fill_in_blank(
    "Answer (one word): ",
    "cold"
)

display(HTML('<h3>Exercise 49</h3>'))
display(HTML('<p>They live in a small apartment. → Their apartment ___.</p>'))
exercise.create_fill_in_blank(
    "Answer (two words): ",
    "is small"
)

display(HTML('<h3>Exercise 50</h3>'))
display(HTML('<p>The book is interesting. → I'm reading an ___ book.</p>'))
exercise.create_fill_in_blank(
    "Answer (one word): ",
    "interesting"
)

# %% [markdown]
# ---
#
# ## Exercise Set 8: Error Correction (6 exercises)
#
# Find and correct the mistakes.
#
# ---

# %%
display(HTML('<h3>Exercise 51</h3>'))
display(HTML('<p>❌ a house big → ✅ ___</p>'))
exercise.create_fill_in_blank(
    "Correct: ",
    "a big house"
)

display(HTML('<h3>Exercise 52</h3>'))
display(HTML('<p>❌ reds cars → ✅ ___</p>'))
exercise.create_fill_in_blank(
    "Correct: ",
    "red cars"
)

display(HTML('<h3>Exercise 53</h3>'))
display(HTML('<p>❌ She happy. → ✅ ___</p>'))
exercise.create_fill_in_blank(
    "Correct (three words): ",
    "She is happy"
)

display(HTML('<h3>Exercise 54</h3>'))
display(HTML('<p>❌ a red big car → ✅ ___</p>'))
exercise.create_fill_in_blank(
    "Correct: ",
    "a big red car"
)

display(HTML('<h3>Exercise 55</h3>'))
display(HTML('<p>❌ beautifuls flowers → ✅ ___</p>'))
exercise.create_fill_in_blank(
    "Correct: ",
    "beautiful flowers"
)

display(HTML('<h3>Exercise 56</h3>'))
display(HTML('<p>❌ The car fast. → ✅ ___</p>'))
exercise.create_fill_in_blank(
    "Correct (four words): ",
    "The car is fast"
)

# %% [markdown]
# ---
#
# ## Exercise Set 9: Mixed Practice (8 exercises)
#
# Complete various types of exercises.
#
# ---

# %%
display(HTML('<h3>Exercise 57</h3>'))
display(HTML('<p>This coffee is very ___. (hot/cold - for coffee)</p>'))
exercise.create_multiple_choice(
    "Choose: This coffee is very ___.",
    ["hot", "cold"],
    "hot"
)

display(HTML('<h3>Exercise 58</h3>'))
display(HTML('<p>I want to buy a ___ ___ car. (new, expensive)</p>'))
exercise.create_fill_in_blank(
    "Answer (two words in correct order): ",
    "new expensive"
)

display(HTML('<h3>Exercise 59</h3>'))
display(HTML('<p>The students ___ very intelligent. (is/are)</p>'))
exercise.create_fill_in_blank(
    "Answer: ",
    "are"
)

display(HTML('<h3>Exercise 60</h3>'))
display(HTML('<p>She has ___ eyes. (blue/green - choose one)</p>'))
exercise.create_multiple_choice(
    "Choose a color for eyes:",
    ["blue", "green", "brown"],
    "blue"
)

display(HTML('<h3>Exercise 61</h3>'))
display(HTML('<p>My grandfather is very ___. (old/young)</p>'))
exercise.create_multiple_choice(
    "Choose: My grandfather is very ___.",
    ["old", "young"],
    "old"
)

display(HTML('<h3>Exercise 62</h3>'))
display(HTML('<p>I like ___ movies. (funny/boring)</p>'))
exercise.create_multiple_choice(
    "Choose: I like ___ movies.",
    ["funny", "boring"],
    "funny"
)

# %% [markdown]
# ---
#
# ## 🎉 Practice Complete!
#
# ### Check Your Progress:
#
# Run the cell below to see your final score.
#
# ---

# %%
# Display final score
validator.display_score()

print("\n📊 Total exercises completed: 62")
print("\n✅ Great work! You've practiced:")
print("   - Adjectives before nouns")
print("   - Adjectives after 'be'")
print("   - Choosing correct adjectives")
print("   - Opposite adjectives")
print("   - Color adjectives")
print("   - Adjective order")
print("   - Transformations")
print("   - Error correction")
print("   - Mixed practice")

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# Excellent work completing the controlled practice!
#
# ### Continue to:
# 🎨 **03_meaningful_practice.ipynb** for personalized practice with YOUR life!
#
# ### In the next notebook, you'll:
# - ✅ Describe people you know
# - ✅ Write about places you've been
# - ✅ Talk about things you own
# - ✅ Use adjectives to describe YOUR experiences
#
# **Keep practicing!** 🚀
#
# ---
