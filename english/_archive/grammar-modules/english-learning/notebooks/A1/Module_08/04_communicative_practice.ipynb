# %% [markdown]
# # Module 8: Adjectives - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Welcome to the final practice phase! Here you'll use **adjectives** in **realistic communication tasks**.
#
# ### What You'll Do:
# - ✅ Write product descriptions for selling items
# - ✅ Create restaurant and hotel reviews
# - ✅ Make recommendations to friends
# - ✅ Describe problems and solutions
# - ✅ Write advertisements
# - ✅ Use adjectives in real scenarios
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from IPython.display import display, HTML
from spaced_repetition import SpacedRepetitionScheduler

# Initialize spaced repetition scheduler
scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Ready for real communication practice!")

# %% [markdown]
# ---
#
# ## Task 1: Online Marketplace - Selling Your Items 🛒
#
# ### Scenario:
# You want to sell some of your possessions online. Write detailed product descriptions that will attract buyers.
#
# ### Instructions:
# Create listings for **8 items** you want to sell. Include:
# - Item name and category
# - Detailed description using many adjectives
# - Condition (new, used, etc.)
# - Price
# - Why someone should buy it
#
# ### Example:
# **FOR SALE: Beautiful Blue Mountain Bike**
#
# I'm selling my **beautiful blue** mountain bike. It's in **excellent** condition - only 2 years old! The bike has a **strong aluminum** frame and **comfortable wide** tires. Perfect for **outdoor** adventures! The bike is **fast** and **reliable**. The seat is **soft** and **adjustable**. I'm selling it because I bought a **new** one.
#
# **Price:** $300 (very **reasonable**!)
#
# This is a **great** deal for a **high-quality** bike!
#
# ---

# %% [markdown]
# ### Your Product Listings:
#
# **ITEM 1:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Price:** _______________
#
# ---
#
# **ITEM 2:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Price:** _______________
#
# ---
#
# **Continue for at least 8 items total...**
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 2: Restaurant and Hotel Reviews ⭐
#
# ### Scenario:
# Write reviews for places you've visited. Your reviews will help other people decide where to go.
#
# ### Instructions:
# Write **6 reviews** (3 restaurants + 3 hotels). Include:
# - Name and location
# - Overall rating (1-5 stars)
# - Description using adjectives
# - What was good
# - What was bad (if anything)
# - Would you recommend it?
#
# ### Example:
# **Restaurant Review: "Luigi's Italian Kitchen" - New York**
#
# ⭐⭐⭐⭐⭐ (5/5 stars)
#
# Luigi's is an **amazing** Italian restaurant! The atmosphere is **warm** and **romantic** - perfect for a **special** evening. The food is **absolutely delicious**. I had the **fresh** pasta with **homemade** tomato sauce - it was **perfect**! The portions are **generous** and the prices are **reasonable**. The staff is very **friendly** and **professional**. The restaurant is **clean** and **comfortable**. My only complaint: it can be **crowded** on weekends, so make a reservation!
#
# **Highly recommended!** This is the **best** Italian restaurant in the city!
#
# ---

# %% [markdown]
# ### Your Reviews:
#
# **RESTAURANT REVIEW 1:**
#
# Name: _______________________________________________
#
# Rating: ⭐ ___/5
#
# Review:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# Recommendation: _______________________________________________
#
# ---
#
# **RESTAURANT REVIEW 2:**
#
# Name: _______________________________________________
#
# Rating: ⭐ ___/5
#
# Review:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **Continue for 3 restaurants and 3 hotels...**
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 3: Travel Recommendations 🌍
#
# ### Scenario:
# Friends are asking you for travel advice. Write detailed recommendations.
#
# ### Instructions:
# Write recommendations for **3 different friend scenarios**:
# - A friend who wants a **relaxing** beach vacation
# - A friend who wants an **exciting** adventure trip
# - A friend who wants a **cultural** city experience
#
# Include for each:
# - Destination recommendation
# - Why it's perfect for them (use many adjectives!)
# - Best time to visit
# - Things to do
# - Where to stay
# - What to eat
#
# ---

# %% [markdown]
# ### Your Travel Recommendations:
#
# **RECOMMENDATION 1: Relaxing Beach Vacation**
#
# Dear friend,
#
# For a **relaxing** vacation, I recommend:
#
# Destination: _______________________________________________
#
# Why it's perfect:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# Best time: _______________________________________________
#
# Things to do:
#
# _______________________________________________
#
# _______________________________________________
#
# Where to stay: _______________________________________________
#
# Food: _______________________________________________
#
# ---
#
# **RECOMMENDATION 2: Adventure Trip**
#
# Destination: _______________________________________________
#
# Why it's perfect:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **RECOMMENDATION 3: Cultural City Experience**
#
# Destination: _______________________________________________
#
# Why it's perfect:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 4: Problem-Solution Scenarios 🔧
#
# ### Scenario:
# You're helping people solve problems. Describe the problems and suggest solutions.
#
# ### Instructions:
# Write **5 problem-solution scenarios**. For each:
# 1. Describe the problem using adjectives
# 2. Explain why it's a problem
# 3. Suggest a solution
# 4. Describe how the solution will help
#
# ### Example:
# **Problem:** My neighbor has a **very loud** dog. The dog barks all night. It's **extremely annoying** and I can't sleep. The situation is **terrible** - I'm **tired** every day at work because of the **noisy** dog.
#
# **Solution:** I will have a **friendly** conversation with my neighbor. I'll be **polite** and **calm**. I'll explain that the **constant** noise is a **serious** problem. Maybe the dog needs more exercise or **professional** training. I'll suggest some **helpful** solutions that are **good** for both of us.
#
# ---

# %% [markdown]
# ### Your Problem-Solution Scenarios:
#
# **SCENARIO 1:**
#
# **Problem:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Solution:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **Continue for 5 scenarios...**
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 5: Job Advertisements 💼
#
# ### Scenario:
# Your company needs to hire people. Write attractive job advertisements.
#
# ### Instructions:
# Create **4 job advertisements** for different positions. Include:
# - Job title
# - Company description
# - Job responsibilities
# - Required qualities (use adjectives!)
# - Benefits
# - Salary range
#
# ### Example:
# **WANTED: Creative Graphic Designer**
#
# **Exciting** opportunity at a **dynamic young** company!
#
# We're a **successful modern** advertising agency in the **beautiful** downtown area. We're looking for a **talented creative** designer to join our **friendly professional** team.
#
# **Requirements:**
# - **Strong artistic** skills
# - **Excellent** communication
# - **Positive energetic** attitude
# - Experience with **current** design software
#
# **We offer:**
# - **Competitive** salary ($50,000-70,000)
# - **Flexible** working hours
# - **Beautiful modern** office
# - **Great** team atmosphere
#
# If you're a **motivated creative** person, apply today!
#
# ---

# %% [markdown]
# ### Your Job Advertisements:
#
# **JOB AD 1:**
#
# **Position:** _______________________________________________
#
# **Company:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Requirements:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **We offer:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **Continue for 4 job ads...**
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 6: Dating Profile 💕
#
# ### Scenario:
# Create an attractive dating profile (or friendship profile) using descriptive adjectives.
#
# ### Instructions:
# Write a profile that includes:
# - About you (appearance and personality)
# - Your interests and hobbies
# - What you're looking for
# - Your ideal match
# - Your lifestyle
#
# Use many adjectives to make your profile interesting!
#
# ### Example:
# **About Me:**
#
# I'm a **friendly outgoing** person who loves life! I'm **active** and **adventurous** - I enjoy **outdoor** activities like hiking and cycling. I'm also **creative** and **artistic** - I paint in my **free** time. Friends say I'm **funny**, **kind**, and **reliable**. I work as a teacher, so I'm **patient** and **understanding**.
#
# **What I'm Looking For:**
#
# I'm looking for a **genuine honest** person who is **fun** and **easygoing**. Someone who enjoys **simple** things like **long** walks, **good** conversations, and **delicious** food. You should be **positive**, **active**, and have a **great** sense of humor!
#
# ---

# %% [markdown]
# ### Your Profile:
#
# **About Me:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **My Interests:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **What I'm Looking For:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **My Ideal Match:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **My Lifestyle:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 7: Movie and Book Descriptions 🎬
#
# ### Scenario:
# You're writing descriptions to help people choose entertainment.
#
# ### Instructions:
# Write descriptions for:
# - **3 movies** you've seen
# - **3 books** you've read
#
# For each, include:
# - Title and genre
# - Plot summary (using adjectives)
# - What makes it special
# - Who would enjoy it
# - Your rating
#
# ---

# %% [markdown]
# ### Your Descriptions:
#
# **MOVIE 1:**
#
# **Title:** _______________________________________________
#
# **Genre:** _______________________________________________
#
# **Description:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Who would enjoy it:** _______________________________________________
#
# **Rating:** ⭐ ___/5
#
# ---
#
# **Continue for 3 movies and 3 books...**
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 8: Complaint Letters and Solutions ✉️
#
# ### Scenario:
# Write formal complaint letters about problems, using adjectives to describe issues clearly.
#
# ### Instructions:
# Write **3 complaint letters** about:
# 1. A faulty product you bought
# 2. Poor service at a restaurant
# 3. A problem with your apartment
#
# For each letter:
# - Be polite but clear
# - Describe the problem with specific adjectives
# - Explain the impact
# - Request a solution
#
# ### Example:
# **To: Customer Service, TechStore**
#
# Dear Sir/Madam,
#
# I am writing to complain about a **defective** laptop I purchased from your **online** store last month.
#
# The laptop has **serious** problems. The battery life is **extremely short** - only 2 hours instead of the **advertised** 8 hours. The screen is **very dim** and **difficult** to see. The keyboard has **sticky** keys that don't work **properly**. This is **completely unacceptable** for a **new expensive** product.
#
# I am **very disappointed** with this **poor-quality** product. I have been a **loyal** customer for 5 years and this is a **terrible** experience.
#
# I request a **full** refund or a **complete** replacement with a **working** laptop as soon as possible.
#
# I look forward to your **prompt** response.
#
# Sincerely,
# [Your name]
#
# ---

# %% [markdown]
# ### Your Complaint Letters:
#
# **LETTER 1: Faulty Product**
#
# To: _______________________________________________
#
# Dear Sir/Madam,
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# Sincerely,
# [Your name]
#
# ---
#
# **LETTER 2: Poor Restaurant Service**
#
# To: _______________________________________________
#
# Dear Sir/Madam,
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **LETTER 3: Apartment Problem**
#
# To: _______________________________________________
#
# Dear Sir/Madam,
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ---
#
# ## 🎓 Module Completion Assessment
#
# ### Self-Evaluation Checklist:
#
# Check ✅ if you can do these things confidently:
#
# - [ ] I can use adjectives before nouns correctly
# - [ ] I can use adjectives after 'be' correctly
# - [ ] I know common opposite adjectives
# - [ ] I can use color adjectives correctly
# - [ ] I understand basic adjective order
# - [ ] I know that adjectives never change form
# - [ ] I can describe people accurately
# - [ ] I can describe places and things
# - [ ] I can express opinions with adjectives
# - [ ] I can use adjectives naturally in communication
#
# ### Reflection:
#
# **What did you learn from this module?**
#
# _______________________________________________
#
# _______________________________________________
#
# **Which type of adjective is most useful for you?**
#
# _______________________________________________
#
# **How confident do you feel with adjectives? (1-10)**
#
# ___/10
#
# **What's the most important rule to remember?**
#
# ⚠️ **Key Rule:** _______________________________________________
#
# (Answer: Adjectives never change form - no plural -s! They go BEFORE nouns or AFTER 'be'.)
#
# **Write a sentence using 3 adjectives:**
#
# _______________________________________________
#
# _______________________________________________
#
# ---

# %%
# Mark this module as complete and schedule review
# Uncomment and run when you've completed all tasks

# scheduler.mark_module_complete(
#     module_id="A1_Module_08",
#     module_name="Adjectives",
#     score=85.0  # Enter your self-assessed score (0-100)
# )

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### Congratulations! 🎉
#
# You've completed **Module 8: Adjectives**!
#
# ### Key Skills Mastered:
# - ✅ Using adjectives before nouns (a big house)
# - ✅ Using adjectives after 'be' (The house is big)
# - ✅ Common opposite adjectives (big/small, hot/cold)
# - ✅ Color adjectives (red, blue, green, etc.)
# - ✅ Basic adjective order (Opinion-Size-Age-Color-Origin-Material)
# - ✅ Adjectives never change form (no plural -s)
# - ✅ Describing people, places, and things accurately
#
# ### Adjectives make your English colorful! 🎨
#
# You can now describe the world around you with precision and detail!
#
# ### Next Steps:
#
# 1. **Take a break!** ☕ You've mastered adjectives!
#
# 2. **Review**: Your first review is scheduled. Check the progress tracker.
#
# 3. **Continue Learning**: Move to **Module 9: There Is/Are**
#
# 4. **Practice Daily**: Pay attention to adjectives when reading and listening to English!
#
# ---
#
# ## 📊 Spaced Repetition Reminder
#
# Remember to review this module:
# - **Day 1**: Tomorrow
# - **Day 2**: In 2 days
# - **Day 4**: In 4 days
# - **Week 1**: In 7 days
# - **Week 2**: In 14 days
#
# Regular review ensures you remember all the adjectives!
#
# ---
#
# ## 🌟 Final Message
#
# **Excellent work!** You've mastered adjectives through:
# - ✅ Understanding 11 comprehensive sections
# - ✅ 62 controlled practice exercises
# - ✅ 10 meaningful practice activities
# - ✅ 8 real-world communicative tasks
#
# **Your English is now much more descriptive and interesting!** 🎊
#
# Ready for the next challenge? Let's continue to Module 9!
#
# ---
