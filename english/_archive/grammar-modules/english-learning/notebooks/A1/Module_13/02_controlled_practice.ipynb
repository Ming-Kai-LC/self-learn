# %% [markdown]
# # Module 13: This, That, These, Those - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Welcome to the practice phase! Here you'll complete exercises with **immediate feedback** to master demonstratives.
#
# ### What You'll Do:
# - [OK] Choose between THIS and THAT (singular forms)
# - [OK] Choose between THESE and THOSE (plural forms)
# - [OK] Practice singular vs plural forms
# - [OK] Decide on near vs far distance
# - [OK] Complete sentences with correct demonstratives
# - [OK] Ask questions with demonstratives
# - [OK] Use time expressions correctly
# - [OK] Correct common mistakes
# - [OK] Apply demonstratives in context
#
# ⏱️ **Estimated time:** 90-120 minutes
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise, create_progress_bar
from IPython.display import display, HTML

# Initialize validator and exercise system
validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("[OK] Ready to practice! Complete all exercises below.")

# %% [markdown]
# ---
#
# ## Exercise Set 1: Choose THIS or THAT (Singular Forms)
#
# Complete each sentence with THIS or THAT based on the distance clue.
#
# ### Instructions:
# - Use THIS for things near you
# - Use THAT for things far from you
# - Type: this or that (lowercase)
#
# ---

# %%
# Exercise 1.1
exercise.create_fill_in_blank("1. ___ book in my hand is interesting. (in your hand)", "this")

# %%
# Exercise 1.2
exercise.create_fill_in_blank("2. ___ car over there is expensive. (across the street)", "that")

# %%
# Exercise 1.3
exercise.create_fill_in_blank("3. ___ pen I'm holding doesn't work. (holding it)", "this")

# %%
# Exercise 1.4
exercise.create_fill_in_blank("4. ___ building in the distance is tall. (far away)", "that")

# %%
# Exercise 1.5
exercise.create_fill_in_blank("5. ___ coffee I'm drinking is delicious. (drinking it now)", "this")

# %%
# Exercise 1.6
exercise.create_fill_in_blank(
    "6. ___ restaurant we went to yesterday was good. (past place)", "that"
)

# %%
# Exercise 1.7
exercise.create_fill_in_blank("7. ___ chair I'm sitting on is comfortable. (sitting on it)", "this")

# %%
# Exercise 1.8
exercise.create_fill_in_blank("8. ___ mountain far away is beautiful. (in the distance)", "that")

# %%
# Exercise 1.9
exercise.create_fill_in_blank("9. ___ phone in my pocket is new. (in your pocket)", "this")

# %%
# Exercise 1.10
exercise.create_fill_in_blank("10. ___ house on the hill is mine. (far away on a hill)", "that")

# %% [markdown]
# ---
#
# ## Exercise Set 2: Choose THESE or THOSE (Plural Forms)
#
# Complete each sentence with THESE or THOSE based on the distance clue.
#
# ### Instructions:
# - Use THESE for things near you (plural)
# - Use THOSE for things far from you (plural)
# - Type: these or those (lowercase)
#
# ---

# %%
# Exercise 2.1
exercise.create_fill_in_blank("1. ___ books on my desk are mine. (on your desk)", "these")

# %%
# Exercise 2.2
exercise.create_fill_in_blank("2. ___ cars in the parking lot are new. (far away)", "those")

# %%
# Exercise 2.3
exercise.create_fill_in_blank("3. ___ shoes I'm wearing are comfortable. (wearing them)", "these")

# %%
# Exercise 2.4
exercise.create_fill_in_blank("4. ___ people over there are tourists. (far away)", "those")

# %%
# Exercise 2.5
exercise.create_fill_in_blank("5. ___ cookies on this plate are delicious. (near you)", "these")

# %%
# Exercise 2.6
exercise.create_fill_in_blank("6. ___ buildings in the distance are tall. (far away)", "those")

# %%
# Exercise 2.7
exercise.create_fill_in_blank("7. ___ keys in my pocket are mine. (in your pocket)", "these")

# %%
# Exercise 2.8
exercise.create_fill_in_blank("8. ___ mountains we can see are beautiful. (distant)", "those")

# %%
# Exercise 2.9
exercise.create_fill_in_blank("9. ___ papers I'm holding are important. (holding them)", "these")

# %%
# Exercise 2.10
exercise.create_fill_in_blank("10. ___ houses on that street are old. (far street)", "those")

# %% [markdown]
# ---
#
# ## Exercise Set 3: Singular vs Plural Forms
#
# Change the demonstrative to match the number (singular ↔ plural).
#
# ### Instructions:
# - THIS → THESE (singular to plural, near)
# - THAT → THOSE (singular to plural, far)
# - THESE → THIS (plural to singular, near)
# - THOSE → THAT (plural to singular, far)
#
# ---

# %%
# Exercise 3.1
exercise.create_fill_in_blank("1. This book → ___ books", "These")

# %%
# Exercise 3.2
exercise.create_fill_in_blank("2. That car → ___ cars", "Those")

# %%
# Exercise 3.3
exercise.create_fill_in_blank("3. These pens → ___ pen", "This")

# %%
# Exercise 3.4
exercise.create_fill_in_blank("4. Those houses → ___ house", "That")

# %%
# Exercise 3.5
exercise.create_fill_in_blank("5. This apple → ___ apples", "These")

# %%
# Exercise 3.6
exercise.create_fill_in_blank("6. That student → ___ students", "Those")

# %%
# Exercise 3.7
exercise.create_fill_in_blank("7. These chairs → ___ chair", "This")

# %%
# Exercise 3.8
exercise.create_fill_in_blank("8. Those flowers → ___ flower", "That")

# %% [markdown]
# ---
#
# ## Exercise Set 4: Near vs Far Distance Decisions
#
# Read the context and choose the correct demonstrative.
#
# ### Instructions:
# Choose based on whether the object is near or far from the speaker.
#
# ---

# %%
# Exercise 4.1
exercise.create_fill_in_blank("1. (Pointing to a book in your hand) ___ book is mine.", "This")

# %%
# Exercise 4.2
exercise.create_fill_in_blank("2. (Pointing to a car across the street) ___ car is red.", "That")

# %%
# Exercise 4.3
exercise.create_fill_in_blank(
    "3. (Showing photos you're holding) ___ photos are beautiful.", "These"
)

# %%
# Exercise 4.4
exercise.create_fill_in_blank(
    "4. (Pointing to people in the distance) ___ people are waiting.", "Those"
)

# %%
# Exercise 4.5
exercise.create_fill_in_blank("5. (Holding a cup of coffee) ___ coffee is hot.", "This")

# %%
# Exercise 4.6
exercise.create_fill_in_blank(
    "6. (Looking at a distant building) ___ building is the hospital.", "That"
)

# %%
# Exercise 4.7
exercise.create_fill_in_blank("7. (Touching shoes you're wearing) ___ shoes are new.", "These")

# %%
# Exercise 4.8
exercise.create_fill_in_blank(
    "8. (Pointing to mountains far away) ___ mountains are high.", "Those"
)

# %% [markdown]
# ---
#
# ## Exercise Set 5: Complete with Correct Demonstrative
#
# Complete each sentence with THIS, THAT, THESE, or THOSE.
#
# ### Instructions:
# Consider both number (singular/plural) and distance (near/far).
#
# ---

# %%
# Exercise 5.1
exercise.create_fill_in_blank("1. ___ is my house. (pointing to a nearby house)", "This")

# %%
# Exercise 5.2
exercise.create_fill_in_blank("2. ___ are my keys. (holding them)", "These")

# %%
# Exercise 5.3
exercise.create_fill_in_blank("3. ___ was a great movie. (movie you watched yesterday)", "That")

# %%
# Exercise 5.4
exercise.create_fill_in_blank("4. ___ people over there are my friends. (far away)", "Those")

# %%
# Exercise 5.5
exercise.create_fill_in_blank("5. ___ pen doesn't work. (pen in your hand)", "This")

# %%
# Exercise 5.6
exercise.create_fill_in_blank("6. ___ were happy days. (talking about the past)", "Those")

# %%
# Exercise 5.7
exercise.create_fill_in_blank("7. ___ flowers smell nice. (flowers near you)", "These")

# %%
# Exercise 5.8
exercise.create_fill_in_blank("8. ___ building is very old. (building in the distance)", "That")

# %%
# Exercise 5.9
exercise.create_fill_in_blank(
    "9. ___ is my favorite restaurant. (pointing to nearby restaurant)", "This"
)

# %%
# Exercise 5.10
exercise.create_fill_in_blank("10. ___ cars in the parking lot are new. (far away)", "Those")

# %% [markdown]
# ---
#
# ## Exercise Set 6: Questions with Demonstratives
#
# Complete the questions with the correct demonstrative.
#
# ### Instructions:
# Use the context clue to choose THIS, THAT, THESE, or THOSE.
#
# ---

# %%
# Exercise 6.1
exercise.create_fill_in_blank("1. What is ___? (pointing to something in your hand)", "this")

# %%
# Exercise 6.2
exercise.create_fill_in_blank("2. What are ___? (pointing to things near you)", "these")

# %%
# Exercise 6.3
exercise.create_fill_in_blank("3. What is ___ over there? (pointing to something far)", "that")

# %%
# Exercise 6.4
exercise.create_fill_in_blank("4. Whose are ___ books? (books on your desk)", "these")

# %%
# Exercise 6.5
exercise.create_fill_in_blank("5. Whose is ___ car? (car in the distance)", "that")

# %%
# Exercise 6.6
exercise.create_fill_in_blank("6. What are ___ things? (things far away)", "those")

# %%
# Exercise 6.7
exercise.create_fill_in_blank("7. Is ___ your phone? (phone near you)", "this")

# %%
# Exercise 6.8
exercise.create_fill_in_blank("8. Are ___ your keys? (keys you're holding)", "these")

# %% [markdown]
# ---
#
# ## Exercise Set 7: Time Expressions
#
# Complete each sentence with THIS, THAT, THESE, or THOSE for time references.
#
# ### Instructions:
# - THIS/THESE for present/current time
# - THAT/THOSE for past time
#
# ---

# %%
# Exercise 7.1
exercise.create_fill_in_blank("1. I'm very busy ___ week. (current week)", "this")

# %%
# Exercise 7.2
exercise.create_fill_in_blank("2. ___ day was special. (a day in the past)", "That")

# %%
# Exercise 7.3
exercise.create_fill_in_blank("3. I woke up early ___ morning. (today's morning)", "this")

# %%
# Exercise 7.4
exercise.create_fill_in_blank("4. ___ were happy times. (period in the past)", "Those")

# %%
# Exercise 7.5
exercise.create_fill_in_blank("5. ___ days I feel great. (currently)", "These")

# %%
# Exercise 7.6
exercise.create_fill_in_blank("6. I remember ___ summer very well. (past summer)", "that")

# %%
# Exercise 7.7
exercise.create_fill_in_blank("7. I have a meeting ___ afternoon. (today's afternoon)", "this")

# %%
# Exercise 7.8
exercise.create_fill_in_blank("8. ___ year has been wonderful. (current year)", "This")

# %% [markdown]
# ---
#
# ## Exercise Set 8: Error Correction
#
# Find and correct the error in each sentence.
#
# ### Instructions:
# Identify the wrong demonstrative and write the correct one.
#
# ---

# %%
# Exercise 8.1
exercise.create_fill_in_blank(
    "1. Incorrect: This books are good. → Correct: ___ books are good.", "These"
)

# %%
# Exercise 8.2
exercise.create_fill_in_blank(
    "2. Incorrect: That cars are expensive. → Correct: ___ cars are expensive.", "Those"
)

# %%
# Exercise 8.3
exercise.create_fill_in_blank("3. Incorrect: These is my pen. → Correct: ___ is my pen.", "This")

# %%
# Exercise 8.4
exercise.create_fill_in_blank(
    "4. Incorrect: Those is interesting. → Correct: ___ is interesting.", "That"
)

# %%
# Exercise 8.5
exercise.create_fill_in_blank(
    "5. Incorrect: This morning (yesterday) was cold. → Correct: ___ morning was cold.", "That"
)

# %%
# Exercise 8.6
exercise.create_fill_in_blank(
    "6. Incorrect: Those day was fun. → Correct: ___ day was fun.", "That"
)

# %%
# Exercise 8.7
exercise.create_fill_in_blank(
    "7. Incorrect: This days I'm busy. → Correct: ___ days I'm busy.", "These"
)

# %%
# Exercise 8.8
exercise.create_fill_in_blank(
    "8. Incorrect: These book is mine. → Correct: ___ book is mine.", "This"
)

# %% [markdown]
# ---
#
# ## Exercise Set 9: Multiple Choice
#
# Choose the correct demonstrative for each situation.
#
# ---

# %%
# Exercise 9.1
exercise.create_multiple_choice(
    "___ book in my hand is interesting.",
    {"A": "This", "B": "That", "C": "These"},
    "A",
    "'This' is correct for a singular object near you.",
)

# %%
# Exercise 9.2
exercise.create_multiple_choice(
    "___ cars over there are expensive.",
    {"A": "This", "B": "That", "C": "Those"},
    "C",
    "'Those' is correct for plural objects far away.",
)

# %%
# Exercise 9.3
exercise.create_multiple_choice(
    "___ is my friend Sarah. (introducing someone next to you)",
    {"A": "This", "B": "That", "C": "These"},
    "A",
    "'This' is used for introductions.",
)

# %%
# Exercise 9.4
exercise.create_multiple_choice(
    "___ were happy days. (talking about the past)",
    {"A": "This", "B": "That", "C": "Those"},
    "C",
    "'Those' refers to plural past times.",
)

# %%
# Exercise 9.5
exercise.create_multiple_choice(
    "Hello, ___ is John speaking. (on the phone)",
    {"A": "this", "B": "that", "C": "I"},
    "A",
    "Use 'this' to identify yourself on the phone.",
)

# %%
# Exercise 9.6
exercise.create_multiple_choice(
    "___ week has been very busy. (current week)",
    {"A": "This", "B": "That", "C": "These"},
    "A",
    "'This' refers to the current time period.",
)

# %%
# Exercise 9.7
exercise.create_multiple_choice(
    "___ shoes I'm wearing are comfortable.",
    {"A": "This", "B": "These", "C": "Those"},
    "B",
    "'These' is correct for plural items you're wearing.",
)

# %%
# Exercise 9.8
exercise.create_multiple_choice(
    "___ mountain in the distance is beautiful.",
    {"A": "This", "B": "These", "C": "That"},
    "C",
    "'That' is correct for a singular object far away.",
)

# %% [markdown]
# ---
#
# ## Exercise Set 10: Context Practice
#
# Complete the dialogues with the correct demonstrative.
#
# ### Instructions:
# Read the full context before choosing your answer.
#
# ---

# %%
# Exercise 10.1
exercise.create_fill_in_blank("1. A: What is ___ in your hand? B: This is my new phone.", "this")

# %%
# Exercise 10.2
exercise.create_fill_in_blank(
    "2. A: Look at ___ mountains! (pointing far away) B: They're beautiful!", "those"
)

# %%
# Exercise 10.3
exercise.create_fill_in_blank(
    "3. A: Are ___ your keys? (keys on the table near you) B: Yes, they are.", "these"
)

# %%
# Exercise 10.4
exercise.create_fill_in_blank("4. A: ___ was a great party yesterday. B: Yes, it was fun!", "That")

# %%
# Exercise 10.5
exercise.create_fill_in_blank("5. A: Hello, ___ is Sarah speaking. B: Hi Sarah!", "this")

# %%
# Exercise 10.6
exercise.create_fill_in_blank(
    "6. A: ___ building over there is my office. B: It's very modern!", "That"
)

# %%
# Exercise 10.7
exercise.create_fill_in_blank(
    "7. A: ___ days I wake up early. B: That's good! (talking about currently)", "These"
)

# %%
# Exercise 10.8
exercise.create_fill_in_blank(
    "8. A: How much are ___ shoes? (shoes you're holding) B: They're fifty dollars.", "these"
)

# %% [markdown]
# ---
#
# ## 📊 Your Score

# %%
# Display final score
validator.display_score()

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### If your score is:
# - **80%+**: Excellent! Move to **03_meaningful_practice.ipynb** [OK]
# - **60-79%**: Good progress! Review the demonstratives rules, then continue 👍
# - **Below 60%**: Review **01_introduction.ipynb** and retry these exercises 📚
#
# ### Key Points to Remember:
# - **THIS** = singular, near (This book)
# - **THAT** = singular, far (That car)
# - **THESE** = plural, near (These books)
# - **THOSE** = plural, far (Those cars)
# - Ask yourself: **How many?** and **How far?**
# - **Time**: THIS/THESE = present, THAT/THOSE = past
# - **Phone**: Use THIS to identify yourself
# - **Verb agreement**: This/That IS, These/Those ARE
#
# ---
#
# ### Continue to:
# **03_meaningful_practice.ipynb** - Personal activities using demonstratives!
#
# ---
#
# **Great work!** 🌟 You've completed the controlled practice phase!
