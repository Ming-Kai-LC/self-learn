# %% [markdown]
# # Module 2: Personal Pronouns - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Welcome to the final practice phase! Here you'll use personal pronouns in **realistic situations** and **creative tasks**.
#
# ### What You'll Do:
# - ✅ Role-play realistic conversations
# - ✅ Write emails and messages about people
# - ✅ Create stories using pronouns
# - ✅ Complete real-world communication tasks
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from IPython.display import display, HTML
from spaced_repetition import SpacedRepetitionScheduler

# Initialize spaced repetition scheduler
scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Ready for real communication practice!")

# %% [markdown]
# ---
#
# ## Task 1: Introducing Friends Role-Play 🤝
#
# ### Scenario:
# You meet your friend Alex at a café, and your other friend Sam arrives. You need to introduce them to each other.
#
# ### Instructions:
# 1. Introduce Sam to Alex (use pronouns to describe Sam)
# 2. Introduce Alex to Sam (use pronouns to describe Alex)
# 3. Talk about what you all like to do together
#
# ### Focus:
# Use pronouns naturally: he/him, she/her, we/us, them
#
# ---

# %% [markdown]
# ### Write Your Conversation Here:
#
# **You:** Alex, this is my friend Sam. ___ is from _______________.
#
# **Alex:** Nice to meet you, Sam!
#
# **Sam:** Nice to meet you too!
#
# **You:** Sam, this is Alex. ___ works at _______________. I've known ___ for _______________.
#
# **Alex:** _______________________________________________
#
# **Sam:** _______________________________________________
#
# **You:** ___ and I _______________ together. Maybe ___ can join ___?
#
# _(Continue for at least 10 exchanges)_
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 2: Write a Text Message Conversation 📱
#
# ### Scenario:
# You're texting with a friend about meeting up. Your friend asks about bringing other people.
#
# ### Include:
# - Plans for meeting
# - Talking about other people who might come (use pronouns!)
# - Discussing what to do together
#
# ### Minimum: 12 text messages (6 from you, 6 from friend)
#
# ---

# %% [markdown]
# ### Your Text Conversation:
#
# **Friend:** Hey! Are you free on Saturday?
#
# **You:** _______________________________________________
#
# **Friend:** Great! Want to meet up? I can invite Maria too.
#
# **You:** ___ sounds good! I like ___. Does ___ want to come?
#
# **Friend:** _______________________________________________
#
# **You:** _______________________________________________
#
# _(Continue the conversation...)_
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 3: Write a Letter About Your Friends ✉️
#
# ### Scenario:
# Write a letter to a pen pal describing your closest friends. Use pronouns to avoid repetition.
#
# ### Include:
# - Introduce 2-3 friends
# - Describe each friend (what they're like, what they do)
# - Tell stories about them
# - Explain your relationship with them
#
# ### Minimum length: 12-15 sentences
# ### Focus: Use he/him, she/her, they/them naturally
#
# ---

# %% [markdown]
# ### Your Letter:
#
# Dear [Pen Pal Name],
#
# I want to tell you about my closest friends...
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# Best wishes,
#
# [Your name]
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 4: Problem-Solving Conversation 💡
#
# ### Scenario:
# Your friend Tom forgot his sister's birthday. Help Tom figure out what to do.
#
# ### Your role:
# - Ask Tom about his sister (use pronouns to talk about her)
# - Give Tom suggestions
# - Talk about what Tom can do
#
# ### Focus: Use correct pronouns throughout (he/him for Tom, she/her for sister)
#
# ### Minimum: 12 exchanges
#
# ---

# %% [markdown]
# ### Your Conversation:
#
# **Tom:** Oh no! I forgot my sister's birthday yesterday!
#
# **You:** Don't worry! Does ___ know you forgot?
#
# **Tom:** No, she doesn't. I need to do something for ___.
#
# **You:** _______________________________________________
#
# **Tom:** _______________________________________________
#
# **You:** _______________________________________________
#
# _(Continue the conversation...)_
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 5: Create Social Media Posts About People 📱
#
# ### Instructions:
# Write **5 social media posts** about different people in your life. Use pronouns to refer to them.
#
# ### Each post: 2-4 sentences
#
# ---

# %% [markdown]
# ### Your Posts:
#
# **Post 1 (About a family member):**
#
# Example: "Happy birthday to my sister! She is 25 today. I love her so much! 🎂"
#
# Your post: _______________________________________________
#
# ---
#
# **Post 2 (About a friend):**
#
# Your post: _______________________________________________
#
# ---
#
# **Post 3 (About multiple people):**
#
# Your post: _______________________________________________
#
# ---
#
# **Post 4 (About someone you met):**
#
# Your post: _______________________________________________
#
# ---
#
# **Post 5 (About you and others):**
#
# Your post: _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 6: Giving a Presentation About Your Team 💼
#
# ### Scenario:
# You're giving a short presentation about your work/study team or friend group.
#
# ### Include:
# - Introduce each person
# - Describe their roles or personalities
# - Explain how you work together
# - Use pronouns to connect your ideas
#
# ### Minimum: 10-12 sentences
#
# ---

# %% [markdown]
# ### Your Presentation:
#
# **Title: Meet My Team**
#
# Hello everyone. Today I want to introduce my team/group.
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# Thank you!
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 7: Creative Writing - "The People I Love" 📖
#
# ### Instructions:
# Write a short essay (200-250 words) about the important people in your life.
#
# ### Requirements:
# - Write about at least 3 different people
# - Use pronouns correctly and naturally
# - Avoid repeating names - use he/she/they/him/her/them
# - Show the relationships between people
#
# ---

# %% [markdown]
# ### Your Essay:
#
# **Title: The People I Love**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 8: Discussion Questions 🗣️
#
# ### Instructions:
# Answer these discussion questions with 4-5 sentences each. Focus on using pronouns correctly.
#
# ---

# %% [markdown]
# ### Question 1: Who is the most important person in your life? Why?
#
# Your answer (use pronouns he/him or she/her):
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# ### Question 2: Do you have a large family? Tell me about them.
#
# Your answer (use pronouns they/them):
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# ### Question 3: Who helps you when you have problems? How do they help you?
#
# Your answer (focus on using correct object pronouns):
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# ### Question 4: Tell me about your best memories with friends.
#
# Your answer (use we/us and they/them):
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## 🎓 Module Completion Assessment
#
# ### Self-Evaluation Checklist:
#
# Check ✅ if you can do these things confidently:
#
# - [ ] I can use subject pronouns correctly (I, you, he, she, it, we, they)
# - [ ] I can use object pronouns correctly (me, you, him, her, it, us, them)
# - [ ] I know when to use subject vs object pronouns
# - [ ] I can replace names with pronouns naturally
# - [ ] I can write about people without repeating their names
# - [ ] I can use pronouns in conversations
# - [ ] I can avoid common pronoun mistakes
#
# ### Reflection:
#
# **What did you learn from this module?**
#
# _______________________________________________
#
# **What will you practice more?**
#
# _______________________________________________
#
# **How confident do you feel with personal pronouns? (1-10)**
#
# ___/10
#
# ---

# %%
# Mark this module as complete and schedule review
# Uncomment and run when you've completed all tasks

# scheduler.mark_module_complete(
#     module_id="A1_Module_02",
#     module_name="Personal Pronouns",
#     score=85.0  # Enter your self-assessed score (0-100)
# )

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### Congratulations! 🎉
#
# You've completed **Module 2: Personal Pronouns**!
#
# ### Key Skills Mastered:
# - ✅ Subject pronouns (I, you, he, she, it, we, they)
# - ✅ Object pronouns (me, you, him, her, it, us, them)
# - ✅ When to use each type
# - ✅ Natural communication with pronouns
#
# ### Next Steps:
#
# 1. **Take a break!** ☕ Great job!
#
# 2. **Review**: Your first review is scheduled. Check the progress tracker.
#
# 3. **Continue Learning**: Move to **Module 3: Present Simple - Affirmative**
#
# 4. **Practice Daily**: Use pronouns naturally in your conversations!
#
# ---
#
# ## 📊 Spaced Repetition Reminder
#
# Remember to review this module:
# - **Day 1**: Tomorrow
# - **Day 2**: In 2 days
# - **Day 4**: In 4 days
# - **Week 1**: In 7 days
# - **Week 2**: In 14 days
#
# Regular review ensures you **retain** what you learned!
#
# ---
#
# ## 🌟 Final Message
#
# **Excellent work!** You've mastered personal pronouns through:
# - ✅ Understanding subject vs object
# - ✅ Controlled practice for accuracy
# - ✅ Meaningful practice with real people
# - ✅ Communicative tasks for fluency
#
# **Your English is improving!** 🚀
#
# See you in Module 3!
