# %% [markdown]
# # Module 7: Possessives - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Welcome to the final practice phase! Here you'll use **possessives** in **realistic situations** and **creative tasks**.
#
# ### What You'll Do:
# - ✅ Describe family trees and relationships
# - ✅ Create workplace and school directories
# - ✅ Write lost and found descriptions
# - ✅ Solve ownership problems and disputes
# - ✅ Plan events with responsibilities
# - ✅ Use possessives in realistic conversations
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from IPython.display import display, HTML
from spaced_repetition import SpacedRepetitionScheduler

# Initialize spaced repetition scheduler
scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Ready for real communication practice!")

# %% [markdown]
# ---
#
# ## Task 1: Extended Family Tree 👨‍👩‍👧‍👦
#
# ### Scenario:
# Create a detailed family tree with descriptions of each person and their relationships.
#
# ### Instructions:
# Write about at least **15 family members** including:
# - Their names and relationships (using possessive 's)
# - Their jobs or occupations
# - Where they live
# - Their family members (spouse, children)
#
# ### Example:
# "**My grandfather's name** is Robert. **Robert's wife** is my grandmother, Linda. They have three children: **my mother's name** is Susan, **my uncle's name** is Michael, and **my aunt's name** is Jennifer. **Susan's husband** is my father, David. **Their children** are my sister Emma and me. **Michael's family** lives in Boston. **His wife's name** is Rachel, and **their son's name** is Tom..."
#
# ---

# %% [markdown]
# ### Your Extended Family Tree:
#
# **Write a detailed description (250-300 words) of your extended family:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 2: Company/School Directory 📋
#
# ### Scenario:
# Create a directory for your company or school listing people, their positions, and contact information.
#
# ### Instructions:
# Create a directory with at least **12 people** including:
# - Names and positions
# - Office/room locations
# - Phone extensions or email addresses
# - Who they report to (manager's/supervisor's name)
# - Department information
#
# ### Example Format:
#
# **MARKETING DEPARTMENT**
#
# **Director:** Sarah Johnson
# - **Sarah's office:** Room 305
# - **The director's phone:** ext. 1001
# - **Email:** sarah.johnson@company.com
#
# **Marketing Manager:** David Lee
# - **David's office:** Room 302
# - **The manager's phone:** ext. 1005
# - **Reports to:** Sarah Johnson
#
# ---

# %% [markdown]
# ### Your Company/School Directory:
#
# **Organization name:** _______________________________________________
#
# ---
#
# **DEPARTMENT 1: _______________**
#
# **1. Name and position:**
#
# _______________________________________________
#
# - Office/Room: _______________________________________________
# - Contact: _______________________________________________
# - Reports to: _______________________________________________
#
# **2. Name and position:**
#
# _______________________________________________
#
# - Office/Room: _______________________________________________
# - Contact: _______________________________________________
# - Reports to: _______________________________________________
#
# **3. Name and position:**
#
# _______________________________________________
#
# - Office/Room: _______________________________________________
# - Contact: _______________________________________________
# - Reports to: _______________________________________________
#
# **DEPARTMENT 2: _______________**
#
# **4. Name and position:**
#
# _______________________________________________
#
# - Office/Room: _______________________________________________
# - Contact: _______________________________________________
# - Reports to: _______________________________________________
#
# **5. Name and position:**
#
# _______________________________________________
#
# - Office/Room: _______________________________________________
# - Contact: _______________________________________________
# - Reports to: _______________________________________________
#
# **6. Name and position:**
#
# _______________________________________________
#
# - Office/Room: _______________________________________________
# - Contact: _______________________________________________
# - Reports to: _______________________________________________
#
# **Continue for at least 12 people total...**
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 3: Lost and Found Office 🔍
#
# ### Scenario:
# You work at a Lost and Found office. People come to claim their items or report lost items.
#
# ### Instructions:
# **Option A:** Write descriptions of **20 lost items** currently at the Lost and Found office. Use possessives to describe ownership.
#
# **OR**
#
# **Option B:** Write **3 conversations** (minimum 12 exchanges each) between you and people claiming lost items.
#
# ### Example (Conversation):
#
# **You:** Good morning! How can I help you?
#
# **Customer:** I lost my bag yesterday.
#
# **You:** Can you describe your bag's color and size?
#
# **Customer:** It's my wife's bag actually. It's a red leather bag.
#
# **You:** I see. What's inside the bag?
#
# **Customer:** There are her keys, her phone, and her wallet.
#
# ---

# %% [markdown]
# ### Lost and Found:
#
# **OPTION A: List of Lost Items**
#
# **LOST AND FOUND OFFICE - Current Items**
#
# **Date:** _______________
#
# 1. Item: _______________ Owner's name (if known): _______________
#
#    Description: _______________________________________________
#
# 2. Item: _______________ Owner's name (if known): _______________
#
#    Description: _______________________________________________
#
# 3. Item: _______________ Owner's name (if known): _______________
#
#    Description: _______________________________________________
#
# _(Continue to 20 items)_
#
# ---
#
# **OR**
#
# **OPTION B: Conversations**
#
# **Conversation 1:**
#
# **You:** _______________________________________________
#
# **Customer:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Customer:** _______________________________________________
#
# _(Continue for at least 12 exchanges)_
#
# ---
#
# **Conversation 2:**
#
# **You:** _______________________________________________
#
# **Customer:** _______________________________________________
#
# _(Continue for at least 12 exchanges)_
#
# ---
#
# **Conversation 3:**
#
# **You:** _______________________________________________
#
# **Customer:** _______________________________________________
#
# _(Continue for at least 12 exchanges)_
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 4: Ownership Dispute Resolution ⚖️
#
# ### Scenario:
# You're a mediator helping to resolve ownership disputes. Multiple people claim the same items.
#
# ### Instructions:
# Write **3 dispute cases** where you:
# 1. Describe the disputed item
# 2. List each person's claim (using possessives)
# 3. Present evidence from each side
# 4. Make a decision and explain why
#
# ### Example:
#
# **CASE 1: The Laptop**
#
# **Item:** Silver laptop, model XYZ
#
# **Claimant 1 - John's claim:**
# "This is my laptop. My name is on the laptop's case. I bought it last year at my company's store."
#
# **Claimant 2 - Sarah's claim:**
# "No, it's my sister's laptop. Her files are on it. The laptop's serial number matches her receipt."
#
# **Evidence:**
# - John's name is written on the case
# - Sarah has her sister's receipt with matching serial number
# - The laptop's files belong to Sarah's sister
#
# **Decision:** The laptop belongs to Sarah's sister because the receipt and files prove ownership.
#
# ---

# %% [markdown]
# ### Your Ownership Disputes:
#
# **CASE 1:**
#
# **Item:** _______________________________________________
#
# **Claimant 1's claim:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Claimant 2's claim:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Evidence:**
#
# - _______________________________________________
#
# - _______________________________________________
#
# - _______________________________________________
#
# **Decision:**
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **CASE 2:**
#
# **Item:** _______________________________________________
#
# **Claimant 1's claim:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Claimant 2's claim:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Evidence:**
#
# - _______________________________________________
#
# - _______________________________________________
#
# **Decision:**
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **CASE 3:**
#
# **Item:** _______________________________________________
#
# **Claimant 1's claim:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Claimant 2's claim:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Evidence:**
#
# - _______________________________________________
#
# - _______________________________________________
#
# **Decision:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 5: Event Planning with Responsibilities 🎉
#
# ### Scenario:
# You're organizing a large event. Create a detailed plan showing who is responsible for what.
#
# ### Choose ONE event:
# - **Option A:** Wedding reception for 150 guests
# - **Option B:** Company conference for 200 people
# - **Option C:** School festival for 500 students
# - **Option D:** Community charity event for 100 people
#
# ### Instructions:
# Create a plan that includes:
# - At least 15 people and their responsibilities
# - Use possessives to show ownership and responsibility
# - Include contact information
# - Show relationships between team members
#
# ### Example:
#
# **Sarah's role:** Event coordinator (main organizer)
# - **Sarah's responsibilities:** Overall planning and coordination
# - **Her team:** 5 people
# - **Her contact:** sarah@email.com
#
# **John's role:** Catering manager (reports to Sarah)
# - **John's responsibilities:** All food and beverages
# - **His team's tasks:** Menu planning, food preparation, service
#
# ---

# %% [markdown]
# ### Your Event Plan:
#
# **Event:** _______________________________________________
#
# **Date:** _______________ **Number of guests:** _______________
#
# **Budget:** _______________ **Venue:** _______________
#
# ---
#
# **ORGANIZATION CHART:**
#
# **1. Main Coordinator:**
#
# Name: _______________________________________________
#
# Role/Responsibilities: _______________________________________________
#
# Contact: _______________________________________________
#
# Team size: _______________________________________________
#
# **2. Person/Role:**
#
# Name: _______________________________________________
#
# Responsibilities: _______________________________________________
#
# Reports to: _______________________________________________
#
# Contact: _______________________________________________
#
# **3. Person/Role:**
#
# Name: _______________________________________________
#
# Responsibilities: _______________________________________________
#
# Reports to: _______________________________________________
#
# **Continue for at least 15 people...**
#
# ---
#
# **DETAILED RESPONSIBILITIES:**
#
# Write a paragraph (200-250 words) describing the event plan using possessives:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 6: Property and Belongings Inventory 🏠
#
# ### Scenario:
# Create a detailed inventory of property and belongings for insurance purposes.
#
# ### Instructions:
# Choose ONE scenario:
# - **Option A:** Your home inventory
# - **Option B:** A shared office inventory
# - **Option C:** A rental property inventory
#
# List at least **25 items** with:
# - Item description
# - Owner (using possessives)
# - Location
# - Estimated value
# - Purchase date/receipt holder
#
# ### Example:
#
# **Item 1:** Samsung TV, 55 inch
# - **Owner:** This is my husband's TV / Our family's TV
# - **Location:** The living room's main wall
# - **Value:** $800
# - **Receipt:** In my wife's filing cabinet
#
# ---

# %% [markdown]
# ### Your Property Inventory:
#
# **Inventory for:** _______________________________________________
#
# **Address:** _______________________________________________
#
# **Date:** _______________
#
# ---
#
# **ITEM 1:**
#
# Description: _______________________________________________
#
# Owner: _______________________________________________
#
# Location: _______________________________________________
#
# Value: _______________ Receipt holder: _______________
#
# **ITEM 2:**
#
# Description: _______________________________________________
#
# Owner: _______________________________________________
#
# Location: _______________________________________________
#
# Value: _______________ Receipt holder: _______________
#
# **ITEM 3:**
#
# Description: _______________________________________________
#
# Owner: _______________________________________________
#
# Location: _______________________________________________
#
# Value: _______________ Receipt holder: _______________
#
# **Continue for at least 25 items...**
#
# ---
#
# **SUMMARY:**
#
# Total number of items: _______________
#
# Total estimated value: _______________
#
# Most valuable item: _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 7: Biography Writing 📖
#
# ### Scenario:
# Write a detailed biography using possessives to describe relationships, possessions, and achievements.
#
# ### Instructions:
# Choose ONE option:
# - **Option A:** Write your own biography (300-400 words)
# - **Option B:** Write a family member's biography
# - **Option C:** Write a famous person's biography
#
# Include:
# - Family relationships (use possessive 's)
# - Education and career
# - Achievements and possessions
# - Important life events
# - Current situation
#
# ### Example Start:
# "**My grandfather's name** is Roberto Silva. **Roberto's childhood** was difficult. **His father's job** was farming, and **his mother's family** was very poor. Despite this, **Roberto's education** was important to him. **His teacher's encouragement** helped him continue studying. **My grandfather's first job** was at a small factory..."
#
# ---

# %% [markdown]
# ### Your Biography:
#
# **Biography of:** _______________________________________________
#
# **EARLY LIFE:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **FAMILY:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **EDUCATION AND CAREER:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **ACHIEVEMENTS:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **CURRENT LIFE:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **PERSONAL REFLECTION:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 8: Problem-Solving Scenarios 💡
#
# ### Scenario:
# Solve real-world problems that involve ownership and possessives.
#
# ### Instructions:
# Read each scenario and write a detailed solution (100-150 words each).
#
# ### Scenario 1: The Shared Apartment
# Four roommates share an apartment. They need to divide responsibilities and costs fairly. Create a plan showing:
# - Whose responsibility is each chore?
# - How much is each person's share of rent and bills?
# - Whose items are in shared spaces?
# - The house rules about guests and noise
#
# ### Scenario 2: The Family Business
# A family runs a restaurant together. Describe:
# - Each family member's role and responsibilities
# - Who owns what percentage of the business?
# - The employees' duties
# - The restaurant's schedule and management
#
# ### Scenario 3: The School Project
# Five students work on a group project. Explain:
# - Each student's tasks and deadlines
# - Whose materials and resources are needed?
# - The team's meeting schedule
# - How to divide the final presentation
#
# ---

# %% [markdown]
# ### Your Solutions:
#
# **SCENARIO 1: The Shared Apartment**
#
# **Roommate 1's responsibilities:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Roommate 2's responsibilities:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Roommate 3's responsibilities:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Roommate 4's responsibilities:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Each person's share of costs:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Shared items and rules:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **SCENARIO 2: The Family Business**
#
# **The owner's role:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Family member 2's role:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Family member 3's role:**
#
# _______________________________________________
#
# _______________________________________________
#
# **The employees' duties:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Ownership and management:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **SCENARIO 3: The School Project**
#
# **Student 1's tasks:**
#
# _______________________________________________
#
# **Student 2's tasks:**
#
# _______________________________________________
#
# **Student 3's tasks:**
#
# _______________________________________________
#
# **Student 4's tasks:**
#
# _______________________________________________
#
# **Student 5's tasks:**
#
# _______________________________________________
#
# **The team's schedule and resources:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Presentation division:**
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ---
#
# ## 🎓 Module Completion Assessment
#
# ### Self-Evaluation Checklist:
#
# Check ✅ if you can do these things confidently:
#
# - [ ] I can use possessive adjectives correctly (my, your, his, her, its, our, their)
# - [ ] I can form possessives with singular nouns (add 's)
# - [ ] I can form possessives with names ending in -s (James's or James')
# - [ ] I can form possessives with regular plural nouns (add ' only)
# - [ ] I can form possessives with irregular plural nouns (children's, men's)
# - [ ] I NEVER confuse its and it's
# - [ ] I can ask "Whose" questions correctly
# - [ ] I understand when to use apostrophes for possession
# - [ ] I can describe ownership relationships clearly
# - [ ] I can use possessives naturally in real communication
#
# ### Reflection:
#
# **What did you learn from this module?**
#
# _______________________________________________
#
# _______________________________________________
#
# **Which possessive form is still most challenging?**
#
# _______________________________________________
#
# **How confident do you feel with possessives? (1-10)**
#
# ___/10
#
# **What's the most important rule to remember?**
#
# ⚠️ **Critical Rule:** _______________________________________________
#
# (Answer: Never confuse its (possessive) and it's (it is/has)! Use apostrophe 's for singular nouns and irregular plurals, but only apostrophe for regular plural possessives.)
#
# **Write one complex sentence using multiple possessive forms:**
#
# _______________________________________________
#
# _______________________________________________
#
# ---

# %%
# Mark this module as complete and schedule review
# Uncomment and run when you've completed all tasks

# scheduler.mark_module_complete(
#     module_id="A1_Module_07",
#     module_name="Possessives",
#     score=85.0  # Enter your self-assessed score (0-100)
# )

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### Congratulations! 🎉
#
# You've completed **Module 7: Possessives**!
#
# ### Key Skills Mastered:
# - ✅ Possessive adjectives (my, your, his, her, its, our, their)
# - ✅ Possessive 's with singular nouns
# - ✅ Possessive forms with names ending in -s
# - ✅ Possessive forms with plural nouns (regular and irregular)
# - ✅ Asking "Whose" questions
# - ✅ The CRITICAL distinction between its and it's
# - ✅ Using possessives naturally in real communication
#
# ### Possessives are essential! 📊
#
# You now know how to show ownership and relationships correctly. This is crucial for clear communication!
#
# ### Next Steps:
#
# 1. **Take a break!** ☕ You've mastered possessives!
#
# 2. **Review**: Your first review is scheduled. Check the progress tracker.
#
# 3. **Continue Learning**: Move to **Module 8: Adjectives**
#
# 4. **Practice Daily**: Pay attention to possessive forms when reading and listening to English!
#
# ---
#
# ## 📊 Spaced Repetition Reminder
#
# Remember to review this module:
# - **Day 1**: Tomorrow
# - **Day 2**: In 2 days
# - **Day 4**: In 4 days
# - **Week 1**: In 7 days
# - **Week 2**: In 14 days
#
# Regular review ensures you **never confuse its and it's again**!
#
# ---
#
# ## 🌟 Final Message
#
# **Excellent work!** You've mastered possessives through:
# - ✅ Understanding 7 different possessive forms and rules
# - ✅ 64 controlled practice exercises
# - ✅ Meaningful practice with your personal life
# - ✅ Real-world communicative tasks
#
# **You can now use possessives correctly and naturally!** 🎊
#
# Ready for the next challenge? Let's continue to Module 8!
#
# ---
