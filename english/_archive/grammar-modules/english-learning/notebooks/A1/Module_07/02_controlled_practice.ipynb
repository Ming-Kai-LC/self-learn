# %% [markdown]
# # Module 7: Possessives - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Welcome to the controlled practice phase! Here you'll complete **62 exercises** with immediate feedback to master possessives.
#
# ### What You'll Practice:
# - ✅ Possessive adjectives (my, your, his, her, its, our, their)
# - ✅ Possessive 's with singular nouns
# - ✅ Names ending in -s
# - ✅ Possessive with regular plural nouns
# - ✅ Possessive with irregular plural nouns
# - ✅ Whose questions and answers
# - ✅ Its vs it's distinction
# - ✅ Mixed practice
# - ✅ Error correction
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise
from IPython.display import display, HTML

# Initialize the exercise system
validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("✅ Ready to practice possessives!")
print("📊 Your progress will be tracked automatically.")
print("\n💡 Tip: Pay attention to apostrophe placement!")

# %% [markdown]
# ---
#
# ## Exercise Set 1: Possessive Adjectives 👤
#
# **Rule**: Use possessive adjectives (my, your, his, her, its, our, their) before nouns.
#
# **Example**: This is **my** book.
#
# Complete the sentences with the correct possessive adjective.
#
# ---

# %%
# Exercise Set 1: Possessive Adjectives

display(HTML("<h3>Exercise 1</h3>"))
display(HTML("<p>This is ___ book. (I)</p>"))
exercise.create_fill_in_blank("Answer: This is ___ book.", "my")

display(HTML("<h3>Exercise 2</h3>"))
display(HTML("<p>Is that ___ pen? (you)</p>"))
exercise.create_fill_in_blank("Answer: Is that ___ pen?", "your")

display(HTML("<h3>Exercise 3</h3>"))
display(HTML("<p>That is ___ car. (he)</p>"))
exercise.create_fill_in_blank("Answer: That is ___ car.", "his")

display(HTML("<h3>Exercise 4</h3>"))
display(HTML("<p>I like ___ dress. (she)</p>"))
exercise.create_fill_in_blank("Answer: I like ___ dress.", "her")

display(HTML("<h3>Exercise 5</h3>"))
display(HTML("<p>The dog wagged ___ tail. (it)</p>"))
exercise.create_fill_in_blank("Answer: The dog wagged ___ tail.", "its")

display(HTML("<h3>Exercise 6</h3>"))
display(HTML("<p>This is ___ house. (we)</p>"))
exercise.create_fill_in_blank("Answer: This is ___ house.", "our")

display(HTML("<h3>Exercise 7</h3>"))
display(HTML("<p>Those are ___ books. (they)</p>"))
exercise.create_fill_in_blank("Answer: Those are ___ books.", "their")

display(HTML("<h3>Exercise 8</h3>"))
display(HTML("<p>___ name is Sarah. (she)</p>"))
exercise.create_fill_in_blank("Answer: ___ name is Sarah.", "Her")

print("\n✅ Exercise Set 1 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 2: Possessive 's (Singular Nouns) 📝
#
# **Rule**: Add **'s** to singular nouns to show possession.
#
# **Example**: John → John**'s** book
#
# Write the possessive form.
#
# ---

# %%
# Exercise Set 2: Possessive 's with Singular Nouns

display(HTML("<h3>Exercise 9</h3>"))
display(HTML("<p>This is ___ book. (John)</p>"))
exercise.create_fill_in_blank("Answer: This is ___ book.", "John's")

display(HTML("<h3>Exercise 10</h3>"))
display(HTML("<p>___ car is red. (Mary)</p>"))
exercise.create_fill_in_blank("Answer: ___ car is red.", "Mary's")

display(HTML("<h3>Exercise 11</h3>"))
display(HTML("<p>The ___ desk is big. (teacher)</p>"))
exercise.create_fill_in_blank("Answer: The ___ desk is big.", "teacher's")

display(HTML("<h3>Exercise 12</h3>"))
display(HTML("<p>My ___ name is Tom. (friend)</p>"))
exercise.create_fill_in_blank("Answer: My ___ name is Tom.", "friend's")

display(HTML("<h3>Exercise 13</h3>"))
display(HTML("<p>The ___ toy is here. (cat)</p>"))
exercise.create_fill_in_blank("Answer: The ___ toy is here.", "cat's")

display(HTML("<h3>Exercise 14</h3>"))
display(HTML("<p>I like ___ idea. (Sarah)</p>"))
exercise.create_fill_in_blank("Answer: I like ___ idea.", "Sarah's")

display(HTML("<h3>Exercise 15</h3>"))
display(HTML("<p>My ___ phone is new. (sister)</p>"))
exercise.create_fill_in_blank("Answer: My ___ phone is new.", "sister's")

print("\n✅ Exercise Set 2 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 3: Names Ending in -s ⚠️
#
# **Rule**: For names ending in -s, add **'s** OR **'** (both are correct).
#
# **Example**: James**'s** book OR James**'** book
#
# Write the possessive form (either form is accepted).
#
# ---

# %%
# Exercise Set 3: Names Ending in -s

display(HTML("<h3>Exercise 16</h3>"))
display(HTML("<p>This is ___ car. (James - add apostrophe)</p>"))
exercise.create_fill_in_blank("Answer: This is ___ car.", ["James's", "James'"])

display(HTML("<h3>Exercise 17</h3>"))
display(HTML("<p>I read ___ book. (Charles - add apostrophe)</p>"))
exercise.create_fill_in_blank("Answer: I read ___ book.", ["Charles's", "Charles'"])

display(HTML("<h3>Exercise 18</h3>"))
display(HTML("<p>___ idea is great. (Thomas - add apostrophe)</p>"))
exercise.create_fill_in_blank("Answer: ___ idea is great.", ["Thomas's", "Thomas'"])

display(HTML("<h3>Exercise 19</h3>"))
display(HTML("<p>___ house is big. (Jones - add apostrophe)</p>"))
exercise.create_fill_in_blank("Answer: ___ house is big.", ["Jones's", "Jones'"])

print("\n✅ Exercise Set 3 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 4: Plural Possessives (Regular) 👥
#
# **Rule**: For regular plural nouns (ending in -s), add only **'** (apostrophe).
#
# **Example**: students → students**'** books
#
# Write the possessive form.
#
# ---

# %%
# Exercise Set 4: Plural Possessives (Regular)

display(HTML("<h3>Exercise 20</h3>"))
display(HTML("<p>The ___ books are here. (students)</p>"))
exercise.create_fill_in_blank("Answer: The ___ books are here.", "students'")

display(HTML("<h3>Exercise 21</h3>"))
display(HTML("<p>The ___ room is upstairs. (teachers)</p>"))
exercise.create_fill_in_blank("Answer: The ___ room is upstairs.", "teachers'")

display(HTML("<h3>Exercise 22</h3>"))
display(HTML("<p>The ___ bowls are empty. (dogs)</p>"))
exercise.create_fill_in_blank("Answer: The ___ bowls are empty.", "dogs'")

display(HTML("<h3>Exercise 23</h3>"))
display(HTML("<p>The ___ toys are pink. (girls)</p>"))
exercise.create_fill_in_blank("Answer: The ___ toys are pink.", "girls'")

display(HTML("<h3>Exercise 24</h3>"))
display(HTML("<p>The ___ bikes are outside. (boys)</p>"))
exercise.create_fill_in_blank("Answer: The ___ bikes are outside.", "boys'")

display(HTML("<h3>Exercise 25</h3>"))
display(HTML("<p>My ___ houses are big. (friends)</p>"))
exercise.create_fill_in_blank("Answer: My ___ houses are big.", "friends'")

print("\n✅ Exercise Set 4 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 5: Plural Possessives (Irregular) 👶
#
# **Rule**: For irregular plural nouns (NOT ending in -s), add **'s**.
#
# **Example**: children → children**'s** toys
#
# Write the possessive form.
#
# ---

# %%
# Exercise Set 5: Plural Possessives (Irregular)

display(HTML("<h3>Exercise 26</h3>"))
display(HTML("<p>The ___ toys are colorful. (children)</p>"))
exercise.create_fill_in_blank("Answer: The ___ toys are colorful.", "children's")

display(HTML("<h3>Exercise 27</h3>"))
display(HTML("<p>The ___ room is downstairs. (men)</p>"))
exercise.create_fill_in_blank("Answer: The ___ room is downstairs.", "men's")

display(HTML("<h3>Exercise 28</h3>"))
display(HTML("<p>The ___ shoes are expensive. (women)</p>"))
exercise.create_fill_in_blank("Answer: The ___ shoes are expensive.", "women's")

display(HTML("<h3>Exercise 29</h3>"))
display(HTML("<p>The ___ choice is important. (people)</p>"))
exercise.create_fill_in_blank("Answer: The ___ choice is important.", "people's")

display(HTML("<h3>Exercise 30</h3>"))
display(HTML("<p>I saw the ___ parents. (children)</p>"))
exercise.create_fill_in_blank("Answer: I saw the ___ parents.", "children's")

print("\n✅ Exercise Set 5 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 6: Singular vs Plural Possessive 🔄
#
# **Challenge**: Decide if you need singular possessive ('s) or plural possessive (').
#
# Read carefully - is there ONE owner or MANY owners?
#
# ---

# %%
# Exercise Set 6: Singular vs Plural Possessive

display(HTML("<h3>Exercise 31</h3>"))
display(HTML("<p>The ___ book is red. (student - one student)</p>"))
exercise.create_fill_in_blank("Answer: The ___ book is red.", "student's")

display(HTML("<h3>Exercise 32</h3>"))
display(HTML("<p>The ___ books are red. (students - many students)</p>"))
exercise.create_fill_in_blank("Answer: The ___ books are red.", "students'")

display(HTML("<h3>Exercise 33</h3>"))
display(HTML("<p>My ___ car is new. (brother - one brother)</p>"))
exercise.create_fill_in_blank("Answer: My ___ car is new.", "brother's")

display(HTML("<h3>Exercise 34</h3>"))
display(HTML("<p>My ___ cars are new. (brothers - many brothers)</p>"))
exercise.create_fill_in_blank("Answer: My ___ cars are new.", "brothers'")

display(HTML("<h3>Exercise 35</h3>"))
display(HTML("<p>The ___ office is big. (doctor - one doctor)</p>"))
exercise.create_fill_in_blank("Answer: The ___ office is big.", "doctor's")

display(HTML("<h3>Exercise 36</h3>"))
display(HTML("<p>The ___ offices are big. (doctors - many doctors)</p>"))
exercise.create_fill_in_blank("Answer: The ___ offices are big.", "doctors'")

print("\n✅ Exercise Set 6 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 7: Whose Questions 🤔
#
# **Rule**: Use "Whose" to ask about ownership.
#
# **Example**: Whose book is this? → It's my book.
#
# Complete the questions and answers.
#
# ---

# %%
# Exercise Set 7: Whose Questions

display(HTML("<h3>Exercise 37</h3>"))
display(HTML("<p>___ book is this?</p>"))
exercise.create_fill_in_blank("Answer: ___ book is this?", "Whose")

display(HTML("<h3>Exercise 38</h3>"))
display(HTML("<p>Whose car is that? → It's ___ car. (I)</p>"))
exercise.create_fill_in_blank("Answer: It's ___ car.", "my")

display(HTML("<h3>Exercise 39</h3>"))
display(HTML("<p>___ keys are these?</p>"))
exercise.create_fill_in_blank("Answer: ___ keys are these?", "Whose")

display(HTML("<h3>Exercise 40</h3>"))
display(HTML("<p>Whose phone is this? → It's ___ phone. (John)</p>"))
exercise.create_fill_in_blank("Answer: It's ___ phone.", "John's")

display(HTML("<h3>Exercise 41</h3>"))
display(HTML("<p>Whose bag is that? → It's ___ bag. (she)</p>"))
exercise.create_fill_in_blank("Answer: It's ___ bag.", "her")

display(HTML("<h3>Exercise 42</h3>"))
display(HTML("<p>___ idea was it?</p>"))
exercise.create_fill_in_blank("Answer: ___ idea was it?", "Whose")

print("\n✅ Exercise Set 7 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 8: Its vs It's (CRITICAL!) ⚠️
#
# **Rule**:
# - **its** = possessive (NO apostrophe)
# - **it's** = it is / it has (WITH apostrophe)
#
# **Test**: Can you replace with "it is" or "it has"? → Use **it's**
#
# Choose the correct form.
#
# ---

# %%
# Exercise Set 8: Its vs It's

display(HTML("<h3>Exercise 43</h3>"))
display(HTML("<p>The dog wagged ___ tail. (its / it's)</p>"))
exercise.create_multiple_choice("Choose: The dog wagged ___ tail.", ["its", "it's"], "its")

display(HTML("<h3>Exercise 44</h3>"))
display(HTML("<p>___ raining today. (its / it's)</p>"))
exercise.create_multiple_choice("Choose: ___ raining today.", ["its", "it's"], "it's")

display(HTML("<h3>Exercise 45</h3>"))
display(HTML("<p>The company changed ___ logo. (its / it's)</p>"))
exercise.create_multiple_choice("Choose: The company changed ___ logo.", ["its", "it's"], "its")

display(HTML("<h3>Exercise 46</h3>"))
display(HTML("<p>___ my birthday! (its / it's)</p>"))
exercise.create_multiple_choice("Choose: ___ my birthday!", ["its", "it's"], "it's")

display(HTML("<h3>Exercise 47</h3>"))
display(HTML("<p>The bird built ___ nest. (its / it's)</p>"))
exercise.create_multiple_choice("Choose: The bird built ___ nest.", ["its", "it's"], "its")

display(HTML("<h3>Exercise 48</h3>"))
display(HTML("<p>___ been a long day. (its / it's)</p>"))
exercise.create_multiple_choice("Choose: ___ been a long day.", ["its", "it's"], "it's")

display(HTML("<h3>Exercise 49</h3>"))
display(HTML("<p>The car lost ___ wheel. (its / it's)</p>"))
exercise.create_multiple_choice("Choose: The car lost ___ wheel.", ["its", "it's"], "its")

display(HTML("<h3>Exercise 50</h3>"))
display(HTML("<p>___ time to go. (its / it's)</p>"))
exercise.create_multiple_choice("Choose: ___ time to go.", ["its", "it's"], "it's")

print("\n✅ Exercise Set 8 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 9: Mixed Practice 🔄
#
# **Challenge**: Mix of all possessive forms! Think carefully about which form to use.
#
# Complete the sentences.
#
# ---

# %%
# Exercise Set 9: Mixed Practice

display(HTML("<h3>Exercise 51</h3>"))
display(HTML("<p>This is ___ book. (I)</p>"))
exercise.create_fill_in_blank("Answer: This is ___ book.", "my")

display(HTML("<h3>Exercise 52</h3>"))
display(HTML("<p>___ house is big. (Peter)</p>"))
exercise.create_fill_in_blank("Answer: ___ house is big.", "Peter's")

display(HTML("<h3>Exercise 53</h3>"))
display(HTML("<p>The ___ classroom is clean. (students - many)</p>"))
exercise.create_fill_in_blank("Answer: The ___ classroom is clean.", "students'")

display(HTML("<h3>Exercise 54</h3>"))
display(HTML("<p>The ___ playground is big. (children)</p>"))
exercise.create_fill_in_blank("Answer: The ___ playground is big.", "children's")

display(HTML("<h3>Exercise 55</h3>"))
display(HTML("<p>___ a beautiful day. (it is)</p>"))
exercise.create_fill_in_blank("Answer: ___ a beautiful day.", "It's")

display(HTML("<h3>Exercise 56</h3>"))
display(HTML("<p>I like ___ sister. (he)</p>"))
exercise.create_fill_in_blank("Answer: I like ___ sister.", "his")

display(HTML("<h3>Exercise 57</h3>"))
display(HTML("<p>___ office is upstairs. (James)</p>"))
exercise.create_fill_in_blank("Answer: ___ office is upstairs.", ["James's", "James'"])

display(HTML("<h3>Exercise 58</h3>"))
display(HTML("<p>The cat licked ___ paws. (possessive)</p>"))
exercise.create_fill_in_blank("Answer: The cat licked ___ paws.", "its")

print("\n✅ Exercise Set 9 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 10: Error Correction ⚠️
#
# **Task**: Find and correct the possessive errors in these sentences.
#
# Write the correct form.
#
# ---

# %%
# Exercise Set 10: Error Correction

display(HTML("<h3>Exercise 59</h3>"))
display(HTML("<p>❌ This is Johns book.</p>"))
display(HTML("<p>✅ Correct: This is ___ book.</p>"))
exercise.create_fill_in_blank("Answer: This is ___ book.", "John's")

display(HTML("<h3>Exercise 60</h3>"))
display(HTML("<p>❌ The dog wagged it's tail.</p>"))
display(HTML("<p>✅ Correct: The dog wagged ___ tail.</p>"))
exercise.create_fill_in_blank("Answer: The dog wagged ___ tail.", "its")

display(HTML("<h3>Exercise 61</h3>"))
display(HTML("<p>❌ The students' book (one student).</p>"))
display(HTML("<p>✅ Correct: The ___ book.</p>"))
exercise.create_fill_in_blank("Answer: The ___ book.", "student's")

display(HTML("<h3>Exercise 62</h3>"))
display(HTML("<p>❌ The childrens' toys.</p>"))
display(HTML("<p>✅ Correct: The ___ toys.</p>"))
exercise.create_fill_in_blank("Answer: The ___ toys.", "children's")

display(HTML("<h3>Exercise 63</h3>"))
display(HTML("<p>❌ This book is my.</p>"))
display(HTML("<p>✅ Correct: This book is ___. (possessive pronoun)</p>"))
exercise.create_fill_in_blank("Answer: This book is ___.", "mine")

display(HTML("<h3>Exercise 64</h3>"))
display(HTML("<p>❌ Its raining today.</p>"))
display(HTML("<p>✅ Correct: ___ raining today.</p>"))
exercise.create_fill_in_blank("Answer: ___ raining today.", "It's")

print("\n✅ Exercise Set 10 complete!")

# %% [markdown]
# ---
#
# ## 📊 Your Final Score
#
# ---

# %%
# Display your final score
validator.display_score()

print("\n" + "=" * 50)
print("🎉 CONGRATULATIONS!")
print("=" * 50)
print("\nYou've completed all 64 exercises on possessives!")
print("\n📚 What you practiced:")
print("  ✅ Possessive adjectives (my, your, his, her, its, our, their)")
print("  ✅ Possessive 's with singular nouns")
print("  ✅ Names ending in -s")
print("  ✅ Plural possessives (regular and irregular)")
print("  ✅ Singular vs plural possessives")
print("  ✅ Whose questions")
print("  ✅ Its vs it's distinction")
print("  ✅ Mixed practice")
print("  ✅ Error correction")
print("\n💡 Key Rule: Apostrophes show POSSESSION, not plurals!")
print("   its = possessive | it's = it is/it has")

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# Great work on completing the controlled practice!
#
# ### Continue to:
# 📝 **03_meaningful_practice.ipynb** for personalized activities using possessives!
#
# ### In the next notebook, you'll:
# - ✅ Write about your family and friends using possessives
# - ✅ Describe ownership in your life
# - ✅ Use possessives to show relationships
# - ✅ Practice its vs it's in context
# - ✅ Apply possessives naturally
#
# **See you in the next notebook!** 🚀
#
# ---
