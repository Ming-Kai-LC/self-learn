# %% [markdown]
# # Module 20: Adverbs of Frequency - Extended - Phase 1: Introduction
#
# ## Learning Objectives
# - Use adverbs of frequency correctly
# - Understand position in sentences
# - Express frequency with percentages
# - Use frequency expressions
#
# **Target Level:** A1
# **Estimated Time:** 90-120 minutes

# %% [markdown]
# ## 1. Introduction
#
# Adverbs of frequency tell us how often something happens.
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 1. Introduction - Practice
print("1. Introduction")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 2. Common Adverbs
#
# always, usually, often, sometimes, rarely, never
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 2. Common Adverbs - Practice
print("2. Common Adverbs")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 3. Position in Sentence
#
# Before main verb, after 'be'
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 3. Position in Sentence - Practice
print("3. Position in Sentence")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 4. Percentage Scale
#
# always=100%, usually=80%, often=60%, sometimes=40%, rarely=20%, never=0%
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 4. Percentage Scale - Practice
print("4. Percentage Scale")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 5. Frequency Expressions
#
# once a week, twice a month, every day
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 5. Frequency Expressions - Practice
print("5. Frequency Expressions")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 6. Questions
#
# How often do you...?
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 6. Questions - Practice
print("6. Questions")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 7. Extended List
#
# 30+ frequency expressions
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 7. Extended List - Practice
print("7. Extended List")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 8. Time Frequency
#
# daily, weekly, monthly, annually
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 8. Time Frequency - Practice
print("8. Time Frequency")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 9. Collocations
#
# Common verb + frequency combinations
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 9. Collocations - Practice
print("9. Collocations")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 10. Position Variations
#
# For emphasis
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 10. Position Variations - Practice
print("10. Position Variations")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 11. Common Mistakes
#
# Wrong position, double negatives
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 11. Common Mistakes - Practice
print("11. Common Mistakes")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")

# %% [markdown]
# ## 12. Practice Conversations
#
# Natural use of frequency adverbs
#
# ### Examples:
# - I always brush my teeth.
# - She usually walks to work.
# - They sometimes eat out.
# - He never smokes.
#
# ### Practice:
# How often do you exercise?

# %%
# 12. Practice Conversations - Practice
print("12. Practice Conversations")
print("=" * 60)

examples = [
    "I always wake up early.",
    "She usually drinks coffee.",
    "We sometimes go to the cinema.",
    "They never eat fast food.",
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nPractice: Write about your routines")
