# %% [markdown]
# # Module 9: There Is / There Are - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Practice using **there is/are** with structured exercises and immediate feedback.
#
# ### What You'll Practice:
# - ✅ Choosing between there is and there are
# - ✅ Making negative sentences
# - ✅ Asking questions
# - ✅ Short answers
# - ✅ Using any with questions and negatives
# - ✅ How many questions
#
# ⏱️ **Estimated time:** 1.5-2 hours
#
# **Total exercises:** 62
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise
from IPython.display import display, HTML

validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("✅ Module 9: There Is/Are - Controlled Practice")
print("\n📝 Complete 62 exercises to master there is/are!")
print("\n💡 Tip: Pay attention to singular vs plural nouns!")

# %% [markdown]
# ---
#
# ## Exercise Set 1: There Is vs There Are (8 exercises)
#
# Choose the correct form: **there is** or **there are**
#
# **Remember:**
# - Use **there is** for singular and uncountable nouns
# - Use **there are** for plural nouns
#
# ---

# %%
display(HTML("<h3>Exercise 1</h3>"))
display(HTML("<p>___ a book on the table.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["There is", "There are"], "There is")

display(HTML("<h3>Exercise 2</h3>"))
display(HTML("<p>___ three students in the classroom.</p>"))
exercise.create_multiple_choice(
    "Choose the correct answer:", ["There is", "There are"], "There are"
)

display(HTML("<h3>Exercise 3</h3>"))
display(HTML("<p>___ milk in the fridge.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["There is", "There are"], "There is")

display(HTML("<h3>Exercise 4</h3>"))
display(HTML("<p>___ many cars in the parking lot.</p>"))
exercise.create_multiple_choice(
    "Choose the correct answer:", ["There is", "There are"], "There are"
)

display(HTML("<h3>Exercise 5</h3>"))
display(HTML("<p>___ a cat on the roof.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["There is", "There are"], "There is")

display(HTML("<h3>Exercise 6</h3>"))
display(HTML("<p>___ two apples in the basket.</p>"))
exercise.create_multiple_choice(
    "Choose the correct answer:", ["There is", "There are"], "There are"
)

display(HTML("<h3>Exercise 7</h3>"))
display(HTML("<p>___ water on the floor.</p>"))
exercise.create_multiple_choice("Choose the correct answer:", ["There is", "There are"], "There is")

display(HTML("<h3>Exercise 8</h3>"))
display(HTML("<p>___ five people in the room.</p>"))
exercise.create_multiple_choice(
    "Choose the correct answer:", ["There is", "There are"], "There are"
)

# %% [markdown]
# ---
#
# ## Exercise Set 2: Complete Sentences (8 exercises)
#
# Write the complete form: **there is** or **there are**
#
# ---

# %%
display(HTML("<h3>Exercise 9</h3>"))
display(HTML("<p>___ a bank near here.</p>"))
exercise.create_fill_in_blank("Answer: ", "there is")

display(HTML("<h3>Exercise 10</h3>"))
display(HTML("<p>___ many books in the library.</p>"))
exercise.create_fill_in_blank("Answer: ", "there are")

display(HTML("<h3>Exercise 11</h3>"))
display(HTML("<p>___ a problem with this computer.</p>"))
exercise.create_fill_in_blank("Answer: ", "there is")

display(HTML("<h3>Exercise 12</h3>"))
display(HTML("<p>___ ten students in my class.</p>"))
exercise.create_fill_in_blank("Answer: ", "there are")

display(HTML("<h3>Exercise 13</h3>"))
display(HTML("<p>___ coffee in the pot.</p>"))
exercise.create_fill_in_blank("Answer: ", "there is")

display(HTML("<h3>Exercise 14</h3>"))
display(HTML("<p>___ three restaurants on this street.</p>"))
exercise.create_fill_in_blank("Answer: ", "there are")

display(HTML("<h3>Exercise 15</h3>"))
display(HTML("<p>___ a beautiful park in the city.</p>"))
exercise.create_fill_in_blank("Answer: ", "there is")

display(HTML("<h3>Exercise 16</h3>"))
display(HTML("<p>___ some problems with the plan.</p>"))
exercise.create_fill_in_blank("Answer: ", "there are")

# %% [markdown]
# ---
#
# ## Exercise Set 3: Negative Sentences (8 exercises)
#
# Complete with **there isn't** or **there aren't**
#
# **Remember:** Use **any** in negative sentences!
#
# ---

# %%
display(HTML("<h3>Exercise 17</h3>"))
display(HTML("<p>___ a cat here.</p>"))
exercise.create_fill_in_blank("Answer: ", "there isn't")

display(HTML("<h3>Exercise 18</h3>"))
display(HTML("<p>___ any books on the shelf.</p>"))
exercise.create_fill_in_blank("Answer: ", "there aren't")

display(HTML("<h3>Exercise 19</h3>"))
display(HTML("<p>___ any milk in the fridge.</p>"))
exercise.create_fill_in_blank("Answer: ", "there isn't")

display(HTML("<h3>Exercise 20</h3>"))
display(HTML("<p>___ many students today.</p>"))
exercise.create_fill_in_blank("Answer: ", "there aren't")

display(HTML("<h3>Exercise 21</h3>"))
display(HTML("<p>___ a problem.</p>"))
exercise.create_fill_in_blank("Answer: ", "there isn't")

display(HTML("<h3>Exercise 22</h3>"))
display(HTML("<p>___ any chairs in the room.</p>"))
exercise.create_fill_in_blank("Answer: ", "there aren't")

display(HTML("<h3>Exercise 23</h3>"))
display(HTML("<p>___ enough time.</p>"))
exercise.create_fill_in_blank("Answer: ", "there isn't")

display(HTML("<h3>Exercise 24</h3>"))
display(HTML("<p>___ any apples.</p>"))
exercise.create_fill_in_blank("Answer: ", "there aren't")

# %% [markdown]
# ---
#
# ## Exercise Set 4: Questions (8 exercises)
#
# Complete with **Is there** or **Are there**
#
# ---

# %%
display(HTML("<h3>Exercise 25</h3>"))
display(HTML("<p>___ a bank near here?</p>"))
exercise.create_fill_in_blank("Answer: ", "is there")

display(HTML("<h3>Exercise 26</h3>"))
display(HTML("<p>___ any questions?</p>"))
exercise.create_fill_in_blank("Answer: ", "are there")

display(HTML("<h3>Exercise 27</h3>"))
display(HTML("<p>___ any milk in the fridge?</p>"))
exercise.create_fill_in_blank("Answer: ", "is there")

display(HTML("<h3>Exercise 28</h3>"))
display(HTML("<p>___ many people at the party?</p>"))
exercise.create_fill_in_blank("Answer: ", "are there")

display(HTML("<h3>Exercise 29</h3>"))
display(HTML("<p>___ a problem?</p>"))
exercise.create_fill_in_blank("Answer: ", "is there")

display(HTML("<h3>Exercise 30</h3>"))
display(HTML("<p>___ any good restaurants near here?</p>"))
exercise.create_fill_in_blank("Answer: ", "are there")

display(HTML("<h3>Exercise 31</h3>"))
display(HTML("<p>___ enough time?</p>"))
exercise.create_fill_in_blank("Answer: ", "is there")

display(HTML("<h3>Exercise 32</h3>"))
display(HTML("<p>___ any books in the library?</p>"))
exercise.create_fill_in_blank("Answer: ", "are there")

# %% [markdown]
# ---
#
# ## Exercise Set 5: Short Answers (8 exercises)
#
# Answer the questions with short answers.
#
# **Remember:**
# - Yes, there is. / No, there isn't.
# - Yes, there are. / No, there aren't.
#
# ---

# %%
display(HTML("<h3>Exercise 33</h3>"))
display(HTML("<p>Is there a bank near here? (✓)</p>"))
exercise.create_fill_in_blank("Answer: ", "yes, there is")

display(HTML("<h3>Exercise 34</h3>"))
display(HTML("<p>Are there any questions? (✗)</p>"))
exercise.create_fill_in_blank("Answer: ", "no, there aren't")

display(HTML("<h3>Exercise 35</h3>"))
display(HTML("<p>Is there any milk? (✗)</p>"))
exercise.create_fill_in_blank("Answer: ", "no, there isn't")

display(HTML("<h3>Exercise 36</h3>"))
display(HTML("<p>Are there many people? (✓)</p>"))
exercise.create_fill_in_blank("Answer: ", "yes, there are")

display(HTML("<h3>Exercise 37</h3>"))
display(HTML("<p>Is there a problem? (✓)</p>"))
exercise.create_fill_in_blank("Answer: ", "yes, there is")

display(HTML("<h3>Exercise 38</h3>"))
display(HTML("<p>Are there any apples? (✗)</p>"))
exercise.create_fill_in_blank("Answer: ", "no, there aren't")

display(HTML("<h3>Exercise 39</h3>"))
display(HTML("<p>Is there enough time? (✓)</p>"))
exercise.create_fill_in_blank("Answer: ", "yes, there is")

display(HTML("<h3>Exercise 40</h3>"))
display(HTML("<p>Are there any books? (✓)</p>"))
exercise.create_fill_in_blank("Answer: ", "yes, there are")

# %% [markdown]
# ---
#
# ## Exercise Set 6: How Many Questions (6 exercises)
#
# Complete the questions with **How many + noun + are there**
#
# ---

# %%
display(HTML("<h3>Exercise 41</h3>"))
display(HTML("<p>___ students ___ in the class?</p>"))
exercise.create_fill_in_blank("Answer: ", "how many students are there")

display(HTML("<h3>Exercise 42</h3>"))
display(HTML("<p>___ chairs ___ in the room?</p>"))
exercise.create_fill_in_blank("Answer: ", "how many chairs are there")

display(HTML("<h3>Exercise 43</h3>"))
display(HTML("<p>___ books ___ on the shelf?</p>"))
exercise.create_fill_in_blank("Answer: ", "how many books are there")

display(HTML("<h3>Exercise 44</h3>"))
display(HTML("<p>___ people ___ at the party?</p>"))
exercise.create_fill_in_blank("Answer: ", "how many people are there")

display(HTML("<h3>Exercise 45</h3>"))
display(HTML("<p>___ restaurants ___ in your city?</p>"))
exercise.create_fill_in_blank("Answer: ", "how many restaurants are there")

display(HTML("<h3>Exercise 46</h3>"))
display(HTML("<p>___ apples ___ in the basket?</p>"))
exercise.create_fill_in_blank("Answer: ", "how many apples are there")

# %% [markdown]
# ---
#
# ## Exercise Set 7: Transformation (Affirmative → Negative) (6 exercises)
#
# Transform the affirmative sentences into negative sentences.
#
# **Example:** There is a cat. → There isn't a cat.
#
# ---

# %%
display(HTML("<h3>Exercise 47</h3>"))
display(HTML("<p>There is a book on the table.</p>"))
exercise.create_fill_in_blank("Negative: ", "there isn't a book on the table")

display(HTML("<h3>Exercise 48</h3>"))
display(HTML("<p>There are some apples.</p>"))
exercise.create_fill_in_blank("Negative: ", "there aren't any apples")

display(HTML("<h3>Exercise 49</h3>"))
display(HTML("<p>There is milk in the fridge.</p>"))
exercise.create_fill_in_blank("Negative: ", "there isn't any milk in the fridge")

display(HTML("<h3>Exercise 50</h3>"))
display(HTML("<p>There are many people.</p>"))
exercise.create_fill_in_blank("Negative: ", "there aren't many people")

display(HTML("<h3>Exercise 51</h3>"))
display(HTML("<p>There is a problem.</p>"))
exercise.create_fill_in_blank("Negative: ", "there isn't a problem")

display(HTML("<h3>Exercise 52</h3>"))
display(HTML("<p>There are some chairs.</p>"))
exercise.create_fill_in_blank("Negative: ", "there aren't any chairs")

# %% [markdown]
# ---
#
# ## Exercise Set 8: Error Correction (6 exercises)
#
# Find and correct the mistake in each sentence.
#
# ---

# %%
display(HTML("<h3>Exercise 53</h3>"))
display(HTML("<p>❌ There is three books on the table.</p>"))
exercise.create_fill_in_blank("Corrected: ", "there are three books on the table")

display(HTML("<h3>Exercise 54</h3>"))
display(HTML("<p>❌ There are a cat in the garden.</p>"))
exercise.create_fill_in_blank("Corrected: ", "there is a cat in the garden")

display(HTML("<h3>Exercise 55</h3>"))
display(HTML("<p>❌ There are milk in the fridge.</p>"))
exercise.create_fill_in_blank("Corrected: ", "there is milk in the fridge")

display(HTML("<h3>Exercise 56</h3>"))
display(HTML("<p>❌ Is there any students?</p>"))
exercise.create_fill_in_blank("Corrected: ", "are there any students")

display(HTML("<h3>Exercise 57</h3>"))
display(HTML("<p>❌ There is many problems.</p>"))
exercise.create_fill_in_blank("Corrected: ", "there are many problems")

display(HTML("<h3>Exercise 58</h3>"))
display(HTML("<p>❌ There isn't any books.</p>"))
exercise.create_fill_in_blank("Corrected: ", "there aren't any books")

# %% [markdown]
# ---
#
# ## Exercise Set 9: Mixed Practice (4 exercises)
#
# Complete these sentences using the correct form.
#
# ---

# %%
display(HTML("<h3>Exercise 59</h3>"))
display(HTML("<p>___ a library on Main Street, but ___ any bookstores.</p>"))
exercise.create_fill_in_blank("Answer: ", "there is, there aren't")

display(HTML("<h3>Exercise 60</h3>"))
display(HTML("<p>___ many students in my class? Yes, ___.</p>"))
exercise.create_fill_in_blank("Answer: ", "are there, there are")

display(HTML("<h3>Exercise 61</h3>"))
display(HTML("<p>___ any milk? No, ___.</p>"))
exercise.create_fill_in_blank("Answer: ", "is there, there isn't")

display(HTML("<h3>Exercise 62</h3>"))
display(HTML("<p>___ people ___ at the meeting?</p>"))
exercise.create_fill_in_blank("Answer: ", "how many people are there")

# %% [markdown]
# ---
#
# ## 📊 Your Score
#
# ---

# %%
# Display final score
validator.display_score()

print("\n" + "=" * 50)
print("\n💡 Review Tips:")
print("\n1. Use THERE IS for singular and uncountable nouns")
print("2. Use THERE ARE for plural nouns")
print("3. Invert for questions: IS THERE / ARE THERE")
print("4. Use ANY in negatives and questions")
print("5. Don't confuse with IT IS / THEY ARE")
print("\n" + "=" * 50)

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# Great work on completing the controlled practice!
#
# ### Continue to:
# 📝 **03_meaningful_practice.ipynb** to use there is/are in real-life contexts!
#
# ### In the next notebook, you'll:
# - ✅ Describe your home and neighborhood
# - ✅ Talk about your city and places
# - ✅ Describe quantities and availability
# - ✅ Use there is/are with prepositions
#
# **Keep practicing!** 🚀
#
# ---
