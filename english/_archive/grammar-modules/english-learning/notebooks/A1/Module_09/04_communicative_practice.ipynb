# %% [markdown]
# # Module 9: There Is / There Are - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Welcome to communicative practice! Here you'll use **there is/are** in **real-world scenarios**.
#
# ### What You'll Do:
# - ✅ Give directions using there is/are
# - ✅ Write property advertisements
# - ✅ Describe tourist destinations
# - ✅ Report problems and suggest solutions
# - ✅ Create event information
# - ✅ Write neighborhood guides
# - ✅ Describe facilities and services
# - ✅ Make recommendations
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from spaced_repetition import SpacedRepetitionScheduler
from IPython.display import display, HTML

scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Module 9: There Is/Are - Communicative Practice")
print("\n💬 Use there is/are in real-world communication!")
print("\n🎯 Complete 8 realistic tasks!")

# %% [markdown]
# ---
#
# ## Task 1: Giving Directions 🗺️
#
# ### Scenario:
# You work at a hotel reception desk. Tourists ask you for directions to places in the city.
#
# ### Your Task:
# Write directions to 5 different places using **there is/are** to describe what they'll see.
#
# ### Example:
# **How do I get to the museum from here?**
#
# "Walk straight for two blocks. On the corner, there is a big bank. Turn left there. There are three cafés on that street. The museum is after the second café. There is a fountain in front of the museum. You can't miss it!"
#
# ### Your Directions:
#
# ---

# %% [markdown]
# ### Write Directions:
#
# **1. How do I get to the train station from the hotel?**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **2. Where's the nearest pharmacy?**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **3. How do I get to the park?**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **4. Where can I find a good restaurant?**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **5. How do I get to the shopping center?**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 2: Property Advertisements 🏡
#
# ### Scenario:
# You work for a real estate agency. You need to write attractive descriptions of properties for sale or rent.
#
# ### Your Task:
# Write 4 property advertisements using **there is/are** to describe features and location.
#
# ### Example:
# **Beautiful Apartment for Rent**
#
# "Lovely 2-bedroom apartment in the city center. There are two spacious bedrooms with built-in closets. There is a modern kitchen with all appliances. In the living room, there are large windows with great views. There is one bathroom with a bathtub. The building has an elevator, and there is secure parking in the basement. Near the apartment, there are many shops, restaurants, and a park. There is a metro station just 5 minutes away. Perfect location!"
#
# ### Your Advertisements:
#
# ---

# %% [markdown]
# ### Write Property Advertisements:
#
# **1. Apartment for Rent (describe a real or imaginary apartment):**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **2. House for Sale:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **3. Office Space for Rent:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **4. Vacation Rental:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 3: Tourist Guide - Destination Descriptions 🌍
#
# ### Scenario:
# You work for a tourism website. You need to write descriptions of tourist destinations.
#
# ### Your Task:
# Write descriptions of 3 cities or tourist destinations using **there is/are**.
#
# ### Example:
# **Visit Barcelona!**
#
# "Barcelona is an amazing city on the Mediterranean coast. There are beautiful beaches right in the city. There is incredible architecture by Gaudí, including the famous Sagrada Familia. In the old town, there are narrow streets with charming shops and cafés. There are many museums and art galleries. There is a vibrant food scene with excellent restaurants and markets. On Las Ramblas, there are street performers and flower stalls. There is great public transportation, including a metro system. Near the city, there are mountains for hiking. There is something for everyone in Barcelona!"
#
# ### Your Destination Descriptions:
#
# ---

# %% [markdown]
# ### Write Destination Descriptions:
#
# **1. City/Destination 1:** _______________________________________________
#
# Write a description (8-10 sentences):
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **2. City/Destination 2:** _______________________________________________
#
# Write a description (8-10 sentences):
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **3. City/Destination 3:** _______________________________________________
#
# Write a description (8-10 sentences):
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 4: Problem Reports and Solutions 🔧
#
# ### Scenario:
# You're a community member reporting problems to the city council and suggesting solutions.
#
# ### Your Task:
# Write 5 problem reports with solutions using **there is/are**.
#
# ### Example:
# **Problem Report: Parking Issue**
#
# "Dear City Council,
#
# I am writing to report a serious parking problem in our neighborhood. There are too many cars and not enough parking spaces. There is only one small parking lot for the entire street. There aren't any parking restrictions, so people park everywhere. There is often illegal parking on the sidewalks. There are many complaints from residents.
#
# I suggest the following solutions: There should be a new parking structure. There should be parking permits for residents. There should be clear parking rules with signs. There should be better public transportation so people don't need cars.
#
# Thank you for your attention to this matter."
#
# ### Your Problem Reports:
#
# ---

# %% [markdown]
# ### Write Problem Reports:
#
# **1. Problem:** _______________________________________________
#
# **Report and Solution:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **2. Problem:** _______________________________________________
#
# **Report and Solution:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **3. Problem:** _______________________________________________
#
# **Report and Solution:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **4. Problem:** _______________________________________________
#
# **Report and Solution:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **5. Problem:** _______________________________________________
#
# **Report and Solution:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 5: Event Information 🎉
#
# ### Scenario:
# You're organizing events and need to provide information about what's available at each event.
#
# ### Your Task:
# Write information sheets for 4 different events using **there is/are**.
#
# ### Example:
# **Summer Music Festival - Event Information**
#
# "Welcome to the Summer Music Festival!
#
# **What's Available:**
# - There are three stages with live music all day.
# - There is a food court with 20 different vendors.
# - There are restrooms near each stage.
# - There is a first aid tent near the main entrance.
# - There are ATM machines throughout the festival grounds.
# - There is free WiFi in designated areas.
# - There is a lost and found booth at the information center.
# - There are water stations - please bring your own bottle!
# - There is parking available ($10), but there isn't much space. We recommend public transportation.
#
# **Note:** There aren't any re-entry passes. Once you leave, you cannot come back."
#
# ### Your Event Information Sheets:
#
# ---

# %% [markdown]
# ### Write Event Information:
#
# **1. Event Type:** _______________________________________________
#
# **Event Name:** _______________________________________________
#
# **Information:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **2. Event Type:** _______________________________________________
#
# **Event Name:** _______________________________________________
#
# **Information:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **3. Event Type:** _______________________________________________
#
# **Event Name:** _______________________________________________
#
# **Information:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **4. Event Type:** _______________________________________________
#
# **Event Name:** _______________________________________________
#
# **Information:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 6: Neighborhood Guide for Newcomers 📍
#
# ### Scenario:
# A new neighbor is moving in. Write a helpful guide about the neighborhood.
#
# ### Your Task:
# Write 3 neighborhood guides for different areas using **there is/are**.
#
# ### Example:
# **Welcome to Riverside Neighborhood!**
#
# "Welcome! Here's what you need to know about our neighborhood.
#
# **Shopping:** There is a large supermarket on Main Street. There are also two convenience stores open 24/7. There is a farmers market every Saturday morning in the park.
#
# **Dining:** There are many restaurants nearby. There is an excellent Italian restaurant on the corner. There are three coffee shops within walking distance.
#
# **Healthcare:** There is a medical clinic two blocks away. There is a pharmacy next to the clinic. There is a hospital about 10 minutes by car.
#
# **Recreation:** There is a beautiful park with a playground. There are jogging trails along the river. There is a community center with a gym and swimming pool.
#
# **Transportation:** There is a bus stop right in front of the building. There are taxis available 24/7. There is a subway station five blocks north.
#
# **Important:** There isn't any street parking after 6 PM. There is a parking garage on Oak Street. There aren't any loud noise restrictions before 10 PM, but please be considerate of neighbors.
#
# Welcome to the neighborhood!"
#
# ### Your Neighborhood Guides:
#
# ---

# %% [markdown]
# ### Write Neighborhood Guides:
#
# **1. Neighborhood:** _______________________________________________
#
# **Guide:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **2. Neighborhood:** _______________________________________________
#
# **Guide:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **3. Neighborhood:** _______________________________________________
#
# **Guide:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 7: Facility Descriptions 🏫
#
# ### Scenario:
# You need to describe facilities for a brochure or website.
#
# ### Your Task:
# Write descriptions of 4 different facilities using **there is/are**.
#
# ### Example:
# **City Library - Visitor Information**
#
# "Welcome to the City Library!
#
# **Facilities:**
# There are three floors in the library. On the first floor, there is the main reception desk and a large reading room. There are computers available for public use (limit 1 hour). There is free WiFi throughout the building.
#
# On the second floor, there is a children's section with books and activities. There are study rooms you can reserve online. There is also a quiet reading area.
#
# On the third floor, there are research materials and archives. There is a special collections room (by appointment only).
#
# **Services:**
# There is a café on the ground floor. There are restrooms on each floor. There is an elevator and stairs. There is accessible parking in front of the building. There are bike racks near the entrance.
#
# **Note:** There isn't any food or drink allowed except in the café area. There aren't any phone calls allowed in the quiet zones."
#
# ### Your Facility Descriptions:
#
# ---

# %% [markdown]
# ### Write Facility Descriptions:
#
# **1. Facility Type:** _______________________________________________
#
# **Description:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **2. Facility Type:** _______________________________________________
#
# **Description:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **3. Facility Type:** _______________________________________________
#
# **Description:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **4. Facility Type:** _______________________________________________
#
# **Description:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 8: Recommendations and Reviews 🌟
#
# ### Scenario:
# Write recommendations for visitors or write reviews of places using **there is/are**.
#
# ### Your Task:
# Write 4 recommendations or reviews.
#
# ### Example:
# **Restaurant Review: La Bella Italia**
#
# "★★★★★ Excellent Italian Restaurant!
#
# I highly recommend La Bella Italia! The atmosphere is wonderful. There is a beautiful terrace for outdoor dining. Inside, there are cozy tables with candles. The decor is authentic Italian.
#
# The menu is extensive. There are many pasta dishes to choose from. There are also excellent pizzas from a wood-fired oven. There is a good selection of wines. There are vegetarian options, but there aren't many vegan choices.
#
# The service is great. There are friendly, attentive waiters. There is usually a wait on weekends (reservations recommended). There is parking behind the restaurant, but there aren't many spaces.
#
# Prices are reasonable. There is a lunch special on weekdays. There aren't any hidden charges.
#
# Overall, there is nothing not to like about this restaurant. It's perfect for a romantic dinner or family meal. There is something for everyone!"
#
# ### Your Recommendations/Reviews:
#
# ---

# %% [markdown]
# ### Write Recommendations or Reviews:
#
# **1. Place/Business:** _______________________________________________
#
# **Type:** (Restaurant/Hotel/Attraction/Shop/etc.) _______________________________________________
#
# **Review:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **2. Place/Business:** _______________________________________________
#
# **Type:** _______________________________________________
#
# **Review:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **3. Place/Business:** _______________________________________________
#
# **Type:** _______________________________________________
#
# **Review:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **4. Place/Business:** _______________________________________________
#
# **Type:** _______________________________________________
#
# **Review:**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ---
#
# ## 🎓 Module Complete!
#
# Congratulations! You've completed **Module 9: There Is/Are**!
#
# ### What You've Mastered:
#
# ✅ Using **there is** for singular and uncountable nouns
#
# ✅ Using **there are** for plural nouns
#
# ✅ Making negative sentences with **there isn't / there aren't**
#
# ✅ Asking questions with **Is there...? / Are there...?**
#
# ✅ Using **How many...?** questions
#
# ✅ Short answers with **Yes, there is/are** and **No, there isn't/aren't**
#
# ✅ Using **any** in questions and negatives
#
# ✅ Describing locations, quantities, and existence
#
# ✅ Using there is/are in real-world communication
#
# ### Practice Summary:
# - **Introduction:** 11 comprehensive sections
# - **Controlled Practice:** 62 exercises
# - **Meaningful Practice:** 10 personalized activities
# - **Communicative Practice:** 8 real-world tasks
#
# ---

# %%
# Mark module complete
# Uncomment the lines below when you've finished all activities

# scheduler.mark_module_complete(
#     module_id="A1_Module_09",
#     module_name="There Is/Are",
#     score=85.0
# )
# print("✅ Module 9 marked as complete!")
# print("\n📊 Check your progress in the spaced repetition system!")

print("\n" + "=" * 50)
print("\n🎉 Congratulations on completing Module 9!")
print("\n📚 Ready for Module 10: Prepositions?")
print("\n" + "=" * 50)

# %% [markdown]
# ---
#
# ## 🚀 What's Next?
#
# You're ready to move on to:
#
# ### **Module 10: Prepositions**
#
# In the next module, you'll learn:
# - Prepositions of place (in, on, at, under, etc.)
# - Prepositions of time
# - Common prepositional phrases
# - Using prepositions correctly
#
# **Keep up the great work!** 🌟
#
# ---
