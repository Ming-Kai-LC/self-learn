# %% [markdown]
# # Module 5: Articles and Demonstratives - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Welcome to the final practice phase! Here you'll use articles and demonstratives in **realistic situations** and **creative tasks**.
#
# ### What You'll Do:
# - ✅ Role-play shopping and giving directions
# - ✅ Write descriptions of places and things
# - ✅ Create advertisements and recommendations
# - ✅ Practice real conversations using articles and demonstratives naturally
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from IPython.display import display, HTML
from spaced_repetition import SpacedRepetitionScheduler

# Initialize spaced repetition scheduler
scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Ready for real communication practice!")

# %% [markdown]
# ---
#
# ## Task 1: Shopping Role-Play 🛍️
#
# ### Scenario:
# You're in a store looking for items. The salesperson helps you. Use **a/an, the, this/that/these/those** naturally.
#
# ### Instructions:
# Write a conversation where you:
# 1. Ask about items using articles
# 2. Point to things near and far using demonstratives
# 3. Discuss specific items using "the"
# 4. Make a final decision
#
# ### Minimum: 16 exchanges
#
# ---

# %% [markdown]
# ### Write Your Shopping Conversation:
#
# **You:** Hello! I'm looking for _______________ (use a/an)
#
# **Salesperson:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Salesperson:** _______________________________________________
#
# **You:** What about ___ over there? (use that/those)
#
# **Salesperson:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Salesperson:** _______________________________________________
#
# **You:** Can I see ___ one? (use this/that)
#
# **Salesperson:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Salesperson:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Salesperson:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Salesperson:** _______________________________________________
#
# _(Continue for at least 16 exchanges)_
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 2: Giving Directions 🗺️
#
# ### Scenario:
# Someone asks you for directions to a place. Use **the** for specific buildings/places and demonstratives for pointing.
#
# ### Instructions:
# Write directions to 3 different places in your city/town, using:
# - **the** for specific buildings (the bank, the library, the hospital)
# - **this/that** for streets or areas
# - **a/an** when first mentioning a place type
#
# ---

# %% [markdown]
# ### Your Directions:
#
# **Direction 1: To the nearest bank/post office/pharmacy**
#
# **Person:** Excuse me, where is ___ (place)?
#
# **You:** _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **Direction 2: To a restaurant/café/store**
#
# **Person:** Do you know where ___ is?
#
# **You:** _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# **Direction 3: To a tourist attraction/park/museum**
#
# **Person:** How do I get to ___?
#
# **You:** _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 3: Write an Advertisement 📢
#
# ### Scenario:
# Create an advertisement for a product, service, or place. Use articles correctly and demonstratives for emphasis.
#
# ### Instructions:
# Choose one topic and write an advertisement (150-200 words):
# - A new restaurant or café
# - A product for sale (phone, car, furniture, etc.)
# - A service (language school, gym, etc.)
# - A place to visit (hotel, tourist attraction)
#
# ### Include:
# - **a/an** when introducing features
# - **the** for specific/unique features
# - **this/these** for emphasis ("This is the best...")
#
# ---

# %% [markdown]
# ### Your Advertisement:
#
# **Product/Service/Place:** _______________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 4: Describe Your Neighborhood 🏘️
#
# ### Scenario:
# A friend wants to know about your neighborhood. Describe it using articles and demonstratives.
#
# ### Instructions:
# Write a description (200-250 words) including:
# - What places are there (using a/an and the)
# - What's near your home (using this/these)
# - What's farther away (using that/those)
# - Your favorite places (using the + superlatives)
#
# ---

# %% [markdown]
# ### Your Neighborhood Description:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 5: Recommendations List 📝
#
# ### Scenario:
# Create a list of recommendations for a visitor to your city. What should they see, do, eat?
#
# ### Instructions:
# Write 12 recommendations using articles correctly.
#
# ### Categories:
# - Places to visit (museums, parks, monuments)
# - Restaurants or cafés
# - Activities or experiences
# - Shopping areas
#
# ---

# %% [markdown]
# ### Your Recommendations:
#
# **Places to Visit:**
#
# 1. You should visit _______________. It's _______________.
#
# 2. You should see _______________. It's _______________.
#
# 3. You should go to _______________. It's _______________.
#
# **Restaurants/Cafés:**
#
# 4. You should try _______________. It's _______________.
#
# 5. You should eat at _______________. They have _______________.
#
# 6. You should visit _______________. The _______________ is excellent.
#
# **Activities:**
#
# 7. You should _______________. It's _______________.
#
# 8. You should _______________. It's _______________.
#
# 9. You should _______________. It's _______________.
#
# **Shopping:**
#
# 10. You should shop at _______________. It has _______________.
#
# 11. You should visit _______________. It's _______________.
#
# 12. You should buy _______________ from _______________.
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 6: Photo Description 📷
#
# ### Scenario:
# Imagine you're showing someone a photo. Describe what's in it using demonstratives to point.
#
# ### Instructions:
# Choose a photo topic and describe it (real or imagined):
# - A family photo
# - A vacation photo
# - A photo of your room/home
# - A photo of a special event
#
# Use **this/these** for things in the foreground and **that/those** for background.
#
# ### Minimum: 12-15 sentences
#
# ---

# %% [markdown]
# ### Your Photo Description:
#
# **Photo topic:** _______________
#
# _Example: This is a photo from my vacation. This is me in the center. These are my friends next to me. That building in the background is the hotel where we stayed..._
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 7: Comparing Two Things 🔄
#
# ### Scenario:
# Compare two similar items, places, or people. Help someone make a choice.
#
# ### Instructions:
# Choose one comparison topic:
# - Two restaurants/cafés
# - Two cities/neighborhoods
# - Two products (phones, laptops, cars)
# - Two jobs/careers
#
# Write a comparison (150-200 words) using articles and demonstratives correctly.
#
# ---

# %% [markdown]
# ### Your Comparison:
#
# **Comparing:** _______________ and _______________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Recommendation:** I think _______________ is better because _______________.
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 8: Lost and Found 🔍
#
# ### Scenario:
# You lost something. Write a notice or have a conversation describing what you lost.
#
# ### Instructions:
# Write either:
# - **Option A:** A "Lost" notice (100 words)
# - **Option B:** A conversation at the lost and found office (12+ exchanges)
#
# Use articles correctly when describing the item.
#
# ---

# %% [markdown]
# ### Option A: Lost Notice
#
# **LOST**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **OR**
#
# ### Option B: Lost and Found Conversation
#
# **You:** Excuse me, I lost _______________.
#
# **Officer:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Officer:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Officer:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Officer:** _______________________________________________
#
# _(Continue for at least 12 exchanges)_
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## 🎓 Module Completion Assessment
#
# ### Self-Evaluation Checklist:
#
# Check ✅ if you can do these things confidently:
#
# - [ ] I can choose between a and an based on sound
# - [ ] I can use "the" for specific things and second mentions
# - [ ] I know when to use zero article (no article)
# - [ ] I can use this/that for singular items near/far
# - [ ] I can use these/those for plural items near/far
# - [ ] I understand the difference between articles and demonstratives
# - [ ] I can use articles naturally in conversations
# - [ ] I don't combine articles with demonstratives
#
# ### Reflection:
#
# **What did you learn from this module?**
#
# _______________________________________________
#
# **Which article is still most challenging?**
#
# _______________________________________________
#
# **How confident do you feel with articles and demonstratives? (1-10)**
#
# ___/10
#
# **What's the most important rule to remember?**
#
# ⚠️ **Critical Rule:** _______________________________________________
#
# (Answer: Use AN before vowel SOUNDS, not letters / This/These = near, That/Those = far)
#
# ---

# %%
# Mark this module as complete and schedule review
# Uncomment and run when you've completed all tasks

# scheduler.mark_module_complete(
#     module_id="A1_Module_05",
#     module_name="Articles and Demonstratives",
#     score=85.0  # Enter your self-assessed score (0-100)
# )

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### Congratulations! 🎉
#
# You've completed **Module 5: Articles and Demonstratives**!
#
# ### Key Skills Mastered:
# - ✅ Using a/an correctly based on sound
# - ✅ Using the definite article "the" appropriately
# - ✅ Knowing when to use zero article
# - ✅ Using this/these for near items (singular/plural)
# - ✅ Using that/those for far items (singular/plural)
# - ✅ Understanding articles vs demonstratives
#
# ### These small words are HUGE! 🚀
#
# Articles and demonstratives are some of the most frequently used words in English. Mastering them makes your English sound much more natural!
#
# ### Next Steps:
#
# 1. **Take a break!** ☕ You've learned important grammar!
#
# 2. **Review**: Your first review is scheduled. Check the progress tracker.
#
# 3. **Continue Learning**: Move to **Module 6: Nouns and Plurals**
#
# 4. **Practice Daily**: Pay attention to articles when reading and listening to English!
#
# ---
#
# ## 📊 Spaced Repetition Reminder
#
# Remember to review this module:
# - **Day 1**: Tomorrow
# - **Day 2**: In 2 days
# - **Day 4**: In 4 days
# - **Week 1**: In 7 days
# - **Week 2**: In 14 days
#
# Regular review ensures you **retain** article and demonstrative usage!
#
# ---
#
# ## 🌟 Final Message
#
# **Excellent work!** You've mastered articles and demonstratives through:
# - ✅ Understanding the rules for a/an/the and zero article
# - ✅ 53 controlled practice exercises
# - ✅ Meaningful practice with your personal life
# - ✅ Real-world communicative tasks
#
# **You can now use articles and demonstratives naturally!** 🎊
#
# Ready for the next challenge? Let's continue to Module 6!
