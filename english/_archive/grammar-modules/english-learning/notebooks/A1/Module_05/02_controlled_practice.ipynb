# %% [markdown]
# # Module 5: Articles and Demonstratives - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Now it's time to practice! Complete exercises on articles (a/an/the) and demonstratives (this/that/these/those) with immediate feedback.
#
# ### What You'll Practice:
# - ✅ Choosing between a and an
# - ✅ Using the definite article "the"
# - ✅ Recognizing when to use zero article (no article)
# - ✅ Using this/that for singular items
# - ✅ Using these/those for plural items
# - ✅ Correcting common mistakes
#
# ⏱️ **Estimated time:** 90-120 minutes
#
# ---

# %%
# Setup
import sys
sys.path.append('../../../utils')

from feedback_system import ExerciseValidator, InteractiveExercise
from IPython.display import display, HTML

validator = ExerciseValidator()
exercise = InteractiveExercise(validator)
print("✅ Ready to practice!")

# %% [markdown]
# ---
#
# ## Exercise Set 1: A vs An (8 exercises)
#
# Choose the correct article: **a** or **an**
#
# **Remember:** Use **an** before vowel SOUNDS, **a** before consonant SOUNDS.
#
# ---

# %%
display(HTML('<p><strong>1.</strong> I have ___ book.</p>'))
exercise.create_fill_in_blank(
    "Answer: I have ___ book.",
    "a"
)

# %%
display(HTML('<p><strong>2.</strong> She eats ___ apple every day.</p>'))
exercise.create_fill_in_blank(
    "Answer: She eats ___ apple every day.",
    "an"
)

# %%
display(HTML('<p><strong>3.</strong> He is ___ university student.</p>'))
exercise.create_fill_in_blank(
    "Answer: He is ___ university student.",
    "a"
)

# %%
display(HTML('<p><strong>4.</strong> I waited for ___ hour.</p>'))
exercise.create_fill_in_blank(
    "Answer: I waited for ___ hour.",
    "an"
)

# %%
display(HTML('<p><strong>5.</strong> She is ___ honest person.</p>'))
exercise.create_fill_in_blank(
    "Answer: She is ___ honest person.",
    "an"
)

# %%
display(HTML('<p><strong>6.</strong> I need ___ umbrella.</p>'))
exercise.create_fill_in_blank(
    "Answer: I need ___ umbrella.",
    "an"
)

# %%
display(HTML('<p><strong>7.</strong> He lives in ___ European country.</p>'))
exercise.create_fill_in_blank(
    "Answer: He lives in ___ European country.",
    "a"
)

# %%
display(HTML('<p><strong>8.</strong> She is ___ engineer.</p>'))
exercise.create_fill_in_blank(
    "Answer: She is ___ engineer.",
    "an"
)

# %% [markdown]
# ---
#
# ## Exercise Set 2: Using A/An in Context (6 exercises)
#
# Complete the sentences with **a** or **an**.
#
# ---

# %%
display(HTML('<p><strong>1.</strong> My father is ___ teacher.</p>'))
exercise.create_fill_in_blank(
    "Answer: My father is ___ teacher.",
    "a"
)

# %%
display(HTML('<p><strong>2.</strong> I exercise three times ___ week.</p>'))
exercise.create_fill_in_blank(
    "Answer: I exercise three times ___ week.",
    "a"
)

# %%
display(HTML('<p><strong>3.</strong> What ___ beautiful day!</p>'))
exercise.create_fill_in_blank(
    "Answer: What ___ beautiful day!",
    "a"
)

# %%
display(HTML('<p><strong>4.</strong> She bought ___ orange and ___ banana.</p>'))
exercise.create_fill_in_blank(
    "Answer: She bought ___ orange and ___ banana.",
    "an, a"
)

# %%
display(HTML('<p><strong>5.</strong> I need ___ new phone.</p>'))
exercise.create_fill_in_blank(
    "Answer: I need ___ new phone.",
    "a"
)

# %%
display(HTML('<p><strong>6.</strong> He drives at 100 km ___ hour.</p>'))
exercise.create_fill_in_blank(
    "Answer: He drives at 100 km ___ hour.",
    "an"
)

# %% [markdown]
# ---
#
# ## Exercise Set 3: Using "The" (Definite Article) (7 exercises)
#
# Complete the sentences with **the** where needed. If no article is needed, write **Ø** (zero article).
#
# ---

# %%
display(HTML('<p><strong>1.</strong> ___ sun is shining.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ sun is shining.",
    "The"
)

# %%
display(HTML('<p><strong>2.</strong> Please close ___ door.</p>'))
exercise.create_fill_in_blank(
    "Answer: Please close ___ door.",
    "the"
)

# %%
display(HTML('<p><strong>3.</strong> She is ___ best student in the class.</p>'))
exercise.create_fill_in_blank(
    "Answer: She is ___ best student in the class.",
    "the"
)

# %%
display(HTML('<p><strong>4.</strong> I play ___ guitar.</p>'))
exercise.create_fill_in_blank(
    "Answer: I play ___ guitar.",
    "the"
)

# %%
display(HTML('<p><strong>5.</strong> I have a dog. ___ dog is very friendly.</p>'))
exercise.create_fill_in_blank(
    "Answer: I have a dog. ___ dog is very friendly.",
    "The"
)

# %%
display(HTML('<p><strong>6.</strong> ___ moon is beautiful tonight.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ moon is beautiful tonight.",
    "The"
)

# %%
display(HTML('<p><strong>7.</strong> She bought an umbrella. ___ umbrella is red.</p>'))
exercise.create_fill_in_blank(
    "Answer: She bought an umbrella. ___ umbrella is red.",
    "The"
)

# %% [markdown]
# ---
#
# ## Exercise Set 4: Zero Article (No Article) (6 exercises)
#
# Complete with **the** or leave blank for zero article (use **Ø** symbol).
#
# ---

# %%
display(HTML('<p><strong>1.</strong> I like ___ dogs. (in general)</p>'))
exercise.create_fill_in_blank(
    "Answer: I like ___ dogs.",
    "Ø"
)

# %%
display(HTML('<p><strong>2.</strong> I like ___ dogs in this park. (specific)</p>'))
exercise.create_fill_in_blank(
    "Answer: I like ___ dogs in this park.",
    "the"
)

# %%
display(HTML('<p><strong>3.</strong> I speak ___ English.</p>'))
exercise.create_fill_in_blank(
    "Answer: I speak ___ English.",
    "Ø"
)

# %%
display(HTML('<p><strong>4.</strong> I have ___ breakfast at 7 AM.</p>'))
exercise.create_fill_in_blank(
    "Answer: I have ___ breakfast at 7 AM.",
    "Ø"
)

# %%
display(HTML('<p><strong>5.</strong> ___ John is my friend.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ John is my friend.",
    "Ø"
)

# %%
display(HTML('<p><strong>6.</strong> I live in ___ Spain.</p>'))
exercise.create_fill_in_blank(
    "Answer: I live in ___ Spain.",
    "Ø"
)

# %% [markdown]
# ---
#
# ## Exercise Set 5: This vs That (Singular) (6 exercises)
#
# Choose **this** (near) or **that** (far).
#
# ---

# %%
display(HTML('<p><strong>1.</strong> ___ book (in my hand) is interesting.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ book is interesting.",
    "This"
)

# %%
display(HTML('<p><strong>2.</strong> ___ building (far away) is very tall.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ building is very tall.",
    "That"
)

# %%
display(HTML('<p><strong>3.</strong> ___ is my phone. (holding it)</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ is my phone.",
    "This"
)

# %%
display(HTML('<p><strong>4.</strong> Look at ___ bird! (in the distance)</p>'))
exercise.create_fill_in_blank(
    "Answer: Look at ___ bird!",
    "that"
)

# %%
display(HTML('<p><strong>5.</strong> I like ___ song. (playing now)</p>'))
exercise.create_fill_in_blank(
    "Answer: I like ___ song.",
    "this"
)

# %%
display(HTML('<p><strong>6.</strong> ___ car over there is mine.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ car over there is mine.",
    "That"
)

# %% [markdown]
# ---
#
# ## Exercise Set 6: These vs Those (Plural) (6 exercises)
#
# Choose **these** (near) or **those** (far).
#
# ---

# %%
display(HTML('<p><strong>1.</strong> ___ books (on my desk) are mine.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ books are mine.",
    "These"
)

# %%
display(HTML('<p><strong>2.</strong> ___ mountains (in the distance) are beautiful.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ mountains are beautiful.",
    "Those"
)

# %%
display(HTML('<p><strong>3.</strong> I love ___ shoes. (I'm wearing)</p>'))
exercise.create_fill_in_blank(
    "Answer: I love ___ shoes.",
    "these"
)

# %%
display(HTML('<p><strong>4.</strong> ___ are my friends. (with me)</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ are my friends.",
    "These"
)

# %%
display(HTML('<p><strong>5.</strong> ___ trees over there are very old.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ trees over there are very old.",
    "Those"
)

# %%
display(HTML('<p><strong>6.</strong> Look at ___ apples! (far away)</p>'))
exercise.create_fill_in_blank(
    "Answer: Look at ___ apples!",
    "those"
)

# %% [markdown]
# ---
#
# ## Exercise Set 7: Mixed Practice - Articles and Demonstratives (8 exercises)
#
# Choose the correct word: **a, an, the, this, that, these, those**, or **Ø** (zero article).
#
# ---

# %%
display(HTML('<p><strong>1.</strong> I have ___ cat. ___ cat is black.</p>'))
exercise.create_fill_in_blank(
    "Answer: I have ___ cat. ___ cat is black.",
    "a, The"
)

# %%
display(HTML('<p><strong>2.</strong> ___ pen (near me) is blue, but ___ pen (far) is red.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ pen is blue, but ___ pen is red.",
    "This, that"
)

# %%
display(HTML('<p><strong>3.</strong> She is ___ doctor. She works at ___ hospital.</p>'))
exercise.create_fill_in_blank(
    "Answer: She is ___ doctor. She works at ___ hospital.",
    "a, the"
)

# %%
display(HTML('<p><strong>4.</strong> I play ___ football every weekend.</p>'))
exercise.create_fill_in_blank(
    "Answer: I play ___ football every weekend.",
    "Ø"
)

# %%
display(HTML('<p><strong>5.</strong> ___ books (near me) are new, but ___ books (far) are old.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ books are new, but ___ books are old.",
    "These, those"
)

# %%
display(HTML('<p><strong>6.</strong> ___ earth goes around ___ sun.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ earth goes around ___ sun.",
    "The, the"
)

# %%
display(HTML('<p><strong>7.</strong> What ___ beautiful flowers! (near me)</p>'))
exercise.create_fill_in_blank(
    "Answer: What ___ beautiful flowers!",
    "Ø"
)

# %%
display(HTML('<p><strong>8.</strong> I bought ___ umbrella. ___ umbrella was expensive.</p>'))
exercise.create_fill_in_blank(
    "Answer: I bought ___ umbrella. ___ umbrella was expensive.",
    "an, The"
)

# %% [markdown]
# ---
#
# ## Exercise Set 8: Error Correction (6 exercises)
#
# Find and correct the mistake in each sentence.
#
# ---

# %%
display(HTML('<p><strong>1.</strong> She is <u>a</u> engineer.</p>'))
exercise.create_fill_in_blank(
    "Correction: She is ___ engineer.",
    "an"
)

# %%
display(HTML('<p><strong>2.</strong> I have a dog. <u>A</u> dog is very friendly.</p>'))
exercise.create_fill_in_blank(
    "Correction: I have a dog. ___ dog is very friendly.",
    "The"
)

# %%
display(HTML('<p><strong>3.</strong> <u>This</u> books are interesting. (holding them)</p>'))
exercise.create_fill_in_blank(
    "Correction: ___ books are interesting.",
    "These"
)

# %%
display(HTML('<p><strong>4.</strong> He is <u>an</u> university student.</p>'))
exercise.create_fill_in_blank(
    "Correction: He is ___ university student.",
    "a"
)

# %%
display(HTML('<p><strong>5.</strong> I live in <u>the</u> Spain.</p>'))
exercise.create_fill_in_blank(
    "Correction: I live in ___ Spain.",
    "Ø"
)

# %%
display(HTML('<p><strong>6.</strong> <u>That</u> is my new shoes. (wearing them)</p>'))
exercise.create_fill_in_blank(
    "Correction: ___ are my new shoes.",
    "These"
)

# %% [markdown]
# ---
#
# ## Exercise Set 9: Complete the Dialogue (5 exercises)
#
# Complete the dialogue with the correct articles or demonstratives.
#
# ---

# %%
display(HTML('<p><strong>Dialogue:</strong></p>'))
display(HTML('<p>A: Is ___ your book? (near speaker)</p>'))
exercise.create_fill_in_blank(
    "Answer: Is ___ your book?",
    "this"
)

# %%
display(HTML('<p>B: No, ___ is not mine. My book is over there.</p>'))
exercise.create_fill_in_blank(
    "Answer: No, ___ is not mine.",
    "that"
)

# %%
display(HTML('<p>A: Oh, I see it. It\'s ___ blue book, right?</p>'))
exercise.create_fill_in_blank(
    "Answer: It's ___ blue book, right?",
    "the"
)

# %%
display(HTML('<p>B: Yes! ___ blue one on ___ table.</p>'))
exercise.create_fill_in_blank(
    "Answer: ___ blue one on ___ table.",
    "The, the"
)

# %%
display(HTML('<p>A: Got it! And what are ___? (pointing to notebooks nearby)</p>'))
exercise.create_fill_in_blank(
    "Answer: And what are ___?",
    "these"
)

# %% [markdown]
# ---
#
# ## 📊 Check Your Progress
#
# Review your score below:
#
# ---

# %%
# Display final score
validator.display_score()

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# **Excellent work!** You've completed 53 exercises on articles and demonstratives!
#
# ### Continue to:
# **03_meaningful_practice.ipynb** - Use articles and demonstratives with your own information!
#
# ---
#
# ## 📌 Quick Review:
#
# ✅ **A** before consonant sounds (a book, a university)
#
# ✅ **An** before vowel sounds (an apple, an hour)
#
# ✅ **The** for specific things (second mention, unique things)
#
# ✅ **Zero article** for general plural/uncountable, names, countries, meals
#
# ✅ **This/These** for near (singular/plural)
#
# ✅ **That/Those** for far (singular/plural)
#
# ---
#
# **Great progress!** 🌟
