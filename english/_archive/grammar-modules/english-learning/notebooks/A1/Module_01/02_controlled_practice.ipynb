# %% [markdown]
# # Module 1: The Verb "To Be" - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Welcome to the practice phase! Here you'll complete exercises with **immediate feedback** to build accuracy.
#
# ### What You'll Do:
# - ✅ Fill-in-the-blank exercises
# - ✅ Multiple choice questions
# - ✅ Sentence transformations
# - ✅ Error correction
#
# ⏱️ **Estimated time:** 90-120 minutes
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise, create_progress_bar
from IPython.display import display, HTML

# Initialize validator and exercise system
validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("✅ Ready to practice! Complete all exercises below.")

# %% [markdown]
# ---
#
# ## Exercise Set 1: Fill in the Blank (Positive Statements)
#
# Complete each sentence with the correct form of "to be" (**am**, **is**, or **are**).
#
# ### Instructions:
# Type the correct form and click "Check Answer"
#
# ---

# %%
# Exercise 1.1
exercise.create_fill_in_blank("1. I ___ a student.", "am")

# %%
# Exercise 1.2
exercise.create_fill_in_blank("2. She ___ happy today.", "is")

# %%
# Exercise 1.3
exercise.create_fill_in_blank("3. They ___ my friends.", "are")

# %%
# Exercise 1.4
exercise.create_fill_in_blank("4. You ___ very kind.", "are")

# %%
# Exercise 1.5
exercise.create_fill_in_blank("5. He ___ from London.", "is")

# %%
# Exercise 1.6
exercise.create_fill_in_blank("6. We ___ at home.", "are")

# %%
# Exercise 1.7
exercise.create_fill_in_blank("7. It ___ cold today.", "is")

# %%
# Exercise 1.8
exercise.create_fill_in_blank("8. I ___ tired.", "am")

# %%
# Exercise 1.9
exercise.create_fill_in_blank("9. She ___ a doctor.", "is")

# %%
# Exercise 1.10
exercise.create_fill_in_blank("10. They ___ students.", "are")

# %% [markdown]
# ---
#
# ## Exercise Set 2: Multiple Choice (Questions)
#
# Choose the correct form to make a question.
#
# ---

# %%
# Exercise 2.1
exercise.create_multiple_choice(
    "___ you ready?",
    {"A": "Am", "B": "Is", "C": "Are"},
    "C",
    "'You' always takes 'are' in questions.",
)

# %%
# Exercise 2.2
exercise.create_multiple_choice(
    "___ she your teacher?",
    {"A": "Am", "B": "Is", "C": "Are"},
    "B",
    "'She' is singular, so we use 'is'.",
)

# %%
# Exercise 2.3
exercise.create_multiple_choice(
    "___ they from Spain?",
    {"A": "Am", "B": "Is", "C": "Are"},
    "C",
    "'They' is plural, so we use 'are'.",
)

# %%
# Exercise 2.4
exercise.create_multiple_choice(
    "___ I late?", {"A": "Am", "B": "Is", "C": "Are"}, "A", "'I' always takes 'am'."
)

# %%
# Exercise 2.5
exercise.create_multiple_choice(
    "___ it sunny today?",
    {"A": "Am", "B": "Is", "C": "Are"},
    "B",
    "'It' is singular, so we use 'is'.",
)

# %% [markdown]
# ---
#
# ## Exercise Set 3: Negatives
#
# Complete with the negative form (use contractions: isn't, aren't, or I'm not).
#
# ---

# %%
# Exercise 3.1
exercise.create_fill_in_blank("1. She ___ at home. (negative)", "isn't")

# %%
# Exercise 3.2
exercise.create_fill_in_blank("2. They ___ tired. (negative)", "aren't")

# %%
# Exercise 3.3
exercise.create_fill_in_blank("3. I ___ hungry. (negative)", "I'm not", "Type: I'm not")

# %%
# Exercise 3.4
exercise.create_fill_in_blank("4. You ___ late. (negative)", "aren't")

# %%
# Exercise 3.5
exercise.create_fill_in_blank("5. He ___ a teacher. (negative)", "isn't")

# %% [markdown]
# ---
#
# ## Exercise Set 4: Short Answers
#
# Answer the questions with short answers.
#
# ---

# %%
# Exercise 4.1
exercise.create_multiple_choice(
    "Are you happy? (Yes)",
    {"A": "Yes, I do.", "B": "Yes, I am.", "C": "Yes, you are."},
    "B",
    "Use 'Yes, I am' for positive short answers with 'I'.",
)

# %%
# Exercise 4.2
exercise.create_multiple_choice(
    "Is she a student? (No)",
    {"A": "No, she doesn't.", "B": "No, she isn't.", "C": "No, she not."},
    "B",
    "Use 'No, she isn't' for negative short answers.",
)

# %%
# Exercise 4.3
exercise.create_multiple_choice(
    "Are they ready? (Yes)",
    {"A": "Yes, they is.", "B": "Yes, they do.", "C": "Yes, they are."},
    "C",
    "'They' takes 'are' in short answers.",
)

# %% [markdown]
# ---
#
# ## Exercise Set 5: Error Correction
#
# Find and correct the error in each sentence.
#
# ---

# %%
# Exercise 5.1
display(HTML("<p><strong>Incorrect:</strong> I <u>is</u> a student.</p>"))
exercise.create_fill_in_blank("Corrected: I ___ a student.", "am")

# %%
# Exercise 5.2
display(HTML("<p><strong>Incorrect:</strong> She <u>are</u> happy.</p>"))
exercise.create_fill_in_blank("Corrected: She ___ happy.", "is")

# %%
# Exercise 5.3
display(HTML("<p><strong>Incorrect:</strong> They <u>is</u> students.</p>"))
exercise.create_fill_in_blank("Corrected: They ___ students.", "are")

# %%
# Exercise 5.4
display(HTML("<p><strong>Incorrect:</strong> You <u>is</u> late.</p>"))
exercise.create_fill_in_blank("Corrected: You ___ late.", "are")

# %%
# Exercise 5.5
display(HTML("<p><strong>Incorrect:</strong> He <u>am</u> tired.</p>"))
exercise.create_fill_in_blank("Corrected: He ___ tired.", "is")

# %% [markdown]
# ---
#
# ## Exercise Set 6: Sentence Transformation
#
# Transform the statements into questions.
#
# ---

# %%
# Exercise 6.1
display(HTML("<p><strong>Statement:</strong> You are happy.</p>"))
exercise.create_fill_in_blank("Question: ___ you happy?", "Are")

# %%
# Exercise 6.2
display(HTML("<p><strong>Statement:</strong> She is a teacher.</p>"))
exercise.create_fill_in_blank("Question: ___ she a teacher?", "Is")

# %%
# Exercise 6.3
display(HTML("<p><strong>Statement:</strong> They are from Italy.</p>"))
exercise.create_fill_in_blank("Question: ___ they from Italy?", "Are")

# %% [markdown]
# ---
#
# ## 📊 Your Score

# %%
# Display final score
validator.display_score()

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### If your score is:
# - **80%+**: Excellent! Move to **03_meaningful_practice.ipynb** ✅
# - **60-79%**: Good progress! Review mistakes, then continue to next phase 👍
# - **Below 60%**: Review **01_introduction.ipynb** and retry these exercises 📚
#
# ---
#
# ### Continue to:
# **03_meaningful_practice.ipynb** - Use "to be" with your own information!
#
# ---
#
# **Great work!** 🌟 You've completed the controlled practice phase!
