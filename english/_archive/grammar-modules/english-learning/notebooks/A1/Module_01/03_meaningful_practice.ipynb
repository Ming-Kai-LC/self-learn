# %% [markdown]
# # Module 1: The Verb "To Be" - Meaningful Practice
#
# ## 🎨 Phase 3: Meaningful Practice (25% of learning time)
#
# Now it's time to make it **personal**! Use "to be" to talk about **YOU** and your life.
#
# ### What You'll Do:
# - ✅ Write sentences about yourself
# - ✅ Describe people and places
# - ✅ Answer personal questions
# - ✅ Complete contextualized scenarios
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from IPython.display import display, HTML, Markdown
from feedback_system import display_hint

print("✅ Let's make learning personal!")

# %% [markdown]
# ---
#
# ## Activity 1: All About Me 👤
#
# Complete these sentences about **yourself**. Write your answers in the markdown cells below.
#
# ### Example:
# - I am **Maria**.
# - I am from **Mexico**.
# - I am **25 years old**.
#
# ---

# %% [markdown]
# ### Your Turn:
#
# 1. I am _______________. (your name)
#
# 2. I am from _______________. (your country/city)
#
# 3. I am _______________ years old.
#
# 4. I am a _______________. (your job or "student")
#
# 5. I am _______________ today. (how you feel: happy, tired, excited, etc.)
#
# ---
#
# **Double-click this cell to edit and write your answers!**

# %% [markdown]
# ---
#
# ## Activity 2: My Family and Friends 👨‍👩‍👧‍👦
#
# Write 5 sentences about your family or friends using "to be".
#
# ### Examples:
# - My mother **is** a teacher.
# - My brother **is** 18 years old.
# - My friends **are** very funny.
# - My sister **is** in university.
#
# ---

# %% [markdown]
# ### Your Sentences:
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# 5. _______________________________________________
#
# ---
#
# **Double-click to edit!**

# %% [markdown]
# ---
#
# ## Activity 3: Where Are They? 📍
#
# Look at the situations and complete the sentences.
#
# ---

# %% [markdown]
# ### Situation 1: At the Airport
#
# **Context:** John and Sarah are at the airport. They are waiting for their flight to Paris.
#
# Complete:
# 1. John and Sarah _______________ at the airport.
# 2. They _______________ at home.
# 3. Their flight _______________ to Paris.
# 4. They _______________ excited.
#
# **Double-click to write your answers!**

# %%
# Show hint if needed
display_hint("Remember: John and Sarah = 'they' (use 'are')")

# %% [markdown]
# ### Situation 2: First Day of Class
#
# **Context:** Today is the first day of English class. The teacher's name is Mr. Smith. He is from England.
#
# Complete:
# 1. Today _______________ the first day.
# 2. The teacher _______________ Mr. Smith.
# 3. He _______________ from England.
# 4. The students _______________ nervous.
#
# **Double-click to write your answers!**

# %% [markdown]
# ---
#
# ## Activity 4: Questions About You ❓
#
# Answer these personal questions with **short answers** and **full sentences**.
#
# ### Example:
# **Q:** Are you a student?
# **Short answer:** Yes, I am.
# **Full answer:** I am a student at the University of Madrid.
#
# ---

# %% [markdown]
# ### Answer These:
#
# 1. **Are you from the United States?**
#    - Short answer: _______________
#    - Full sentence: _______________
#
# 2. **Are you a teacher?**
#    - Short answer: _______________
#    - Full sentence: _______________
#
# 3. **Are you happy today?**
#    - Short answer: _______________
#    - Full sentence: _______________
#
# 4. **Are your friends in class with you?**
#    - Short answer: _______________
#    - Full sentence: _______________
#
# 5. **Is English difficult for you?**
#    - Short answer: _______________
#    - Full sentence: _______________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Activity 5: Describe a Picture 🖼️
#
# Imagine this scene:
#
# **A coffee shop on a rainy day**
# - 3 people are inside
# - One person is at the counter (the barista)
# - Two customers are at a table
# - The coffee shop is cozy and warm
# - It is raining outside
#
# Write 6-8 sentences describing this scene using "to be".
#
# ---

# %% [markdown]
# ### Your Description:
#
# Example first sentence: "It is a rainy day."
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# 5. _______________________________________________
#
# 6. _______________________________________________
#
# 7. _______________________________________________
#
# 8. _______________________________________________
#
# **Double-click to write!**

# %%
# Useful vocabulary hint
display_hint("Useful words: inside, outside, warm, cold, busy, quiet, at the table, at the counter")

# %% [markdown]
# ---
#
# ## Activity 6: Negative Sentences About Your Life ✖️
#
# Write 5 sentences about things that are **NOT** true about you.
#
# ### Examples:
# - I am **not** from China.
# - I am **not** a doctor.
# - My parents **aren't** in Australia.
#
# ---

# %% [markdown]
# ### Your Negative Sentences:
#
# 1. _______________________________________________
#
# 2. _______________________________________________
#
# 3. _______________________________________________
#
# 4. _______________________________________________
#
# 5. _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Activity 7: Interview a Classmate or Friend 🎤
#
# Write 8 questions to ask someone using "to be". Then find someone and ask them!
#
# ### Examples:
# - Are you from this city?
# - Is your family large?
# - Are you busy this week?
#
# ---

# %% [markdown]
# ### Your Questions:
#
# 1. _______________________________________________?
#
# 2. _______________________________________________?
#
# 3. _______________________________________________?
#
# 4. _______________________________________________?
#
# 5. _______________________________________________?
#
# 6. _______________________________________________?
#
# 7. _______________________________________________?
#
# 8. _______________________________________________?
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Activity 8: Your City/Town 🏙️
#
# Write a short paragraph (5-7 sentences) about your city or hometown using "to be".
#
# ### Things to describe:
# - Name of the city
# - Location (country, near the sea/mountains, etc.)
# - Size (big, small, medium)
# - Characteristics (beautiful, busy, quiet, old, modern)
# - Famous places or features
#
# ---

# %% [markdown]
# ### Your Paragraph:
#
# Example: "My city is Barcelona. It is in Spain..."
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## 🎯 Self-Reflection
#
# Before moving to the next phase, reflect on your learning:
#
# ### Rate your confidence (1-5):
# - I can use "am", "is", "are" correctly: ___/5
# - I can make questions with "to be": ___/5
# - I can make negative sentences: ___/5
# - I can write about my life using "to be": ___/5
#
# ### What was difficult?
# _Write your thoughts here..._
#
# ### What do you want to practice more?
# _Write your thoughts here..._
#
# ---

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# Excellent work completing the meaningful practice! You've used "to be" to talk about **real** things in your life.
#
# ### Continue to:
# **04_communicative_practice.ipynb** - Real-world conversations and creative writing!
#
# ---
#
# **You're making great progress!** 🌟
