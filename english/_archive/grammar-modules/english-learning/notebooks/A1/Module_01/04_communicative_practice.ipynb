# %% [markdown]
# # Module 1: The Verb "To Be" - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Welcome to the final practice phase! Here you'll use "to be" in **realistic situations** and **creative tasks**.
#
# ### What You'll Do:
# - ✅ Role-play realistic conversations
# - ✅ Write emails and messages
# - ✅ Create stories and descriptions
# - ✅ Complete real-world communication tasks
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../../utils")

from IPython.display import display, HTML
from spaced_repetition import SpacedRepetitionScheduler

# Initialize spaced repetition scheduler
scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")

print("✅ Ready for real communication practice!")

# %% [markdown]
# ---
#
# ## Task 1: First Meeting Role-Play 🤝
#
# ### Scenario:
# You meet someone new at a café. Have a conversation introducing yourselves.
#
# ### Instructions:
# 1. If you have a partner, practice this conversation together
# 2. If studying alone, write both parts and practice speaking out loud
#
# ### Conversation Prompts:
# - Greet each other
# - Introduce yourselves (names)
# - Say where you're from
# - Talk about your jobs/studies
# - Discuss how you feel today
# - Ask 2-3 questions each
#
# ---

# %% [markdown]
# ### Write Your Conversation Here:
#
# **You:** Hi! I'm _______________. What's your name?
#
# **New Friend:** _______________________________________________
#
# **You:** _______________________________________________
#
# **New Friend:** _______________________________________________
#
# **You:** _______________________________________________
#
# **New Friend:** _______________________________________________
#
# **You:** _______________________________________________
#
# **New Friend:** _______________________________________________
#
# **You:** _______________________________________________
#
# **New Friend:** _______________________________________________
#
# _(Continue for at least 10 exchanges)_
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 2: Write an Email Introduction ✉️
#
# ### Scenario:
# You're joining a new online language exchange group. Write an email introducing yourself to the group.
#
# ### Include:
# - Your name
# - Where you're from
# - Your occupation or studies
# - Your interests/hobbies
# - Why you're learning English
# - What you're looking for in the group
#
# ### Minimum length: 8-10 sentences
#
# ---

# %% [markdown]
# ### Your Email:
#
# **Subject:** Introduction - New Member
#
# Dear Language Exchange Group,
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# Best regards,
#
# [Your name]
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 3: Create Character Profiles 👥
#
# ### Instructions:
# Create profiles for **3 different characters**. Use your imagination!
#
# ### For each character, include:
# - Name and age
# - Nationality and current location
# - Occupation
# - Personality traits (happy, serious, funny, etc.)
# - Current situation or mood
#
# ### Use at least 6 sentences per character.
#
# ---

# %% [markdown]
# ### Character 1:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# ### Character 2:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# ### Character 3:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 4: Problem-Solving Conversation 💡
#
# ### Scenario:
# Your friend is feeling stressed and overwhelmed. Have a supportive conversation.
#
# ### Your role:
# - Ask how your friend is
# - Ask questions about the situation
# - Be supportive and understanding
# - Make suggestions
#
# ### Minimum: 12 exchanges
#
# ---

# %% [markdown]
# ### Your Conversation:
#
# **You:** Hi! How are you today?
#
# **Friend:** I'm not good. I'm really stressed.
#
# **You:** _______________________________________________
#
# **Friend:** _______________________________________________
#
# **You:** _______________________________________________
#
# **Friend:** _______________________________________________
#
# _(Continue the conversation...)_
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 5: Write Social Media Posts 📱
#
# ### Instructions:
# Write **5 social media posts** using "to be". Each post should be 2-3 sentences.
#
# ### Topics:
# 1. How you're feeling today
# 2. A place you're visiting or want to visit
# 3. Something about your friends or family
# 4. Your current activity or location
# 5. Your thoughts about something (weather, food, a movie, etc.)
#
# ---

# %% [markdown]
# ### Your Posts:
#
# **Post 1 (Feelings):**
#
# _______________________________________________
#
# ---
#
# **Post 2 (Place):**
#
# _______________________________________________
#
# ---
#
# **Post 3 (Friends/Family):**
#
# _______________________________________________
#
# ---
#
# **Post 4 (Current situation):**
#
# _______________________________________________
#
# ---
#
# **Post 5 (Thoughts/opinions):**
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 6: Job Interview Role-Play 💼
#
# ### Scenario:
# You're at a job interview. The interviewer asks you questions about yourself.
#
# ### Questions to answer:
# Focus on using "to be" in your answers.
#
# ---

# %% [markdown]
# ### Interview Questions:
#
# **Interviewer:** Tell me about yourself. Who are you?
#
# **You:** _______________________________________________
#
# **Interviewer:** Where are you from? Are you from this city?
#
# **You:** _______________________________________________
#
# **Interviewer:** What is your educational background?
#
# **You:** _______________________________________________
#
# **Interviewer:** Are you currently employed? What is your current situation?
#
# **You:** _______________________________________________
#
# **Interviewer:** Why are you interested in this position?
#
# **You:** _______________________________________________
#
# **Interviewer:** What are your strengths? What kind of person are you?
#
# **You:** _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 7: Creative Writing - "A Day in My Life" 📖
#
# ### Instructions:
# Write a short story (150-200 words) about a typical day in your life. Use "to be" as much as possible.
#
# ### Include:
# - How you are when you wake up
# - Where you are during the day
# - Who you are with
# - How you feel at different times
# - Where you are in the evening
#
# ---

# %% [markdown]
# ### Your Story:
#
# **Title: A Day in My Life**
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Task 8: Discussion Questions 🗣️
#
# ### Instructions:
# Answer these discussion questions with 3-4 sentences each. Speak your answers out loud, then write them down.
#
# ---

# %% [markdown]
# ### Question 1: What are the most important things in your life?
#
# Your answer:
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# ### Question 2: Who is your best friend? Why are they special?
#
# Your answer:
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# ### Question 3: Where is your favorite place to be? Why?
#
# Your answer:
#
# _______________________________________________
#
# _______________________________________________
#
# ---
#
# ### Question 4: What is difficult for you about learning English?
#
# Your answer:
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## 🎓 Module Completion Assessment
#
# ### Self-Evaluation Checklist:
#
# Check ✅ if you can do these things confidently:
#
# - [ ] I can introduce myself using "to be"
# - [ ] I can ask and answer questions about identity and location
# - [ ] I can describe people and places
# - [ ] I can write simple emails and messages
# - [ ] I can have basic conversations
# - [ ] I can use positive, negative, and question forms correctly
# - [ ] I can use "to be" naturally in communication
#
# ### Reflection:
#
# **What did you learn from this module?**
#
# _______________________________________________
#
# **What will you practice more?**
#
# _______________________________________________
#
# **How confident do you feel with "to be"? (1-10)**
#
# ___/10
#
# ---

# %%
# Mark this module as complete and schedule review
# Uncomment and run when you've completed all tasks

# scheduler.mark_module_complete(
#     module_id="A1_Module_01",
#     module_name="Verb To Be",
#     score=85.0  # Enter your self-assessed score (0-100)
# )

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### Congratulations! 🎉
#
# You've completed **Module 1: The Verb "To Be"**!
#
# ### Next Steps:
#
# 1. **Take a break!** ☕ You've earned it.
#
# 2. **Review**: Your first review is scheduled. Check the progress tracker for dates.
#
# 3. **Continue Learning**: Move to **Module 2: Personal Pronouns**
#
# 4. **Practice Daily**: Try to use "to be" in real conversations every day!
#
# ---
#
# ## 📊 Spaced Repetition Reminder
#
# Remember to review this module:
# - **Day 1**: Tomorrow
# - **Day 2**: In 2 days
# - **Day 4**: In 4 days
# - **Week 1**: In 7 days
# - **Week 2**: In 14 days
#
# Regular review ensures you **remember** what you learned!
#
# ---
#
# ## 🌟 Final Message
#
# **Excellent work!** You've completed your first grammar module with:
# - ✅ Clear understanding of "to be"
# - ✅ Controlled practice for accuracy
# - ✅ Meaningful practice with your life
# - ✅ Real communication tasks
#
# **You're on your way to English proficiency!** 🚀
#
# Keep up the great work and see you in Module 2!
