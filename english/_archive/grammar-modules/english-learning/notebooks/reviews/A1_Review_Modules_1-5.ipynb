# %% [markdown]
# # A1 Review: Modules 1-5 Consolidation
#
# ## 📚 Comprehensive Review and Integration
#
# Welcome to your first review session! This notebook consolidates everything you learned in **Modules 1-5**:
#
# 1. ✅ **Module 1**: Verb "To Be"
# 2. ✅ **Module 2**: Personal Pronouns
# 3. ✅ **Module 3**: Present Simple - Affirmative
# 4. ✅ **Module 4**: Present Simple - Negatives and Questions
# 5. ✅ **Module 5**: Articles and Demonstratives
#
# ### Why Review?
#
# Research shows that **spaced repetition** increases long-term retention by up to 200%! Regular review helps move knowledge from short-term to long-term memory.
#
# ### What You'll Do:
# - Mixed exercises combining all 5 modules
# - Real-world integration tasks
# - Self-assessment
# - Identify areas needing more practice
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys

sys.path.append("../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise, create_progress_bar
from spaced_repetition import SpacedRepetitionScheduler, create_review_reminder
from IPython.display import display, HTML

validator = ExerciseValidator()
exercise = InteractiveExercise(validator)
scheduler = SpacedRepetitionScheduler(data_file="../../data/progress.json")

print("✅ Review session ready!")

# %%
# Display spaced repetition reminder
create_review_reminder()

# %% [markdown]
# ---
#
# ## Part 1: Mixed Grammar Review (40%)
#
# These exercises combine grammar from all 5 modules.
#
# ---
#
# ### Section A: Complete the Sentences

# %%
# Exercise 1: Combining "to be" and pronouns
exercise.create_fill_in_blank("1. ___ am a student, and ___ is my teacher. (I/She)", "I, she")

# %%
# Exercise 2: Present Simple with articles
exercise.create_fill_in_blank("2. She ___ (work) in ___ office. (verb + article)", "works, an")

# %%
# Exercise 3: Negative with demonstrative
exercise.create_fill_in_blank(
    "3. ___ books are not mine. They belong to ___. (these/them)", "These, them"
)

# %% [markdown]
# ### Section B: Error Correction
#
# Find and correct the errors in these sentences.

# %%
display(HTML("<p><strong>Incorrect:</strong> She <u>don't</u> like coffee.</p>"))
exercise.create_fill_in_blank("Corrected: She ___ like coffee.", "doesn't")

# %%
display(HTML("<p><strong>Incorrect:</strong> I am <u>a</u> engineer.</p>"))
exercise.create_fill_in_blank("Corrected: I am ___ engineer.", "an")

# %%
display(HTML("<p><strong>Incorrect:</strong> They <u>works</u> in London.</p>"))
exercise.create_fill_in_blank("Corrected: They ___ in London.", "work")

# %% [markdown]
# ### Section C: Questions and Answers

# %%
# Question formation review
exercise.create_multiple_choice(
    "How do you form a question in Present Simple with 'he'?",
    {"A": "He does work?", "B": "Does he work?", "C": "Do he work?", "D": "Does he works?"},
    "B",
    "Use 'Does + subject + base verb' for he/she/it questions.",
)

# %% [markdown]
# ---
#
# ## Part 2: Integrated Communication Tasks (30%)
#
# Use all the grammar you've learned in realistic situations.
#
# ---
#
# ### Task 1: Introduce Your Best Friend
#
# Write a paragraph (8-10 sentences) introducing your best friend. Use:
# - "To be" for identity and description
# - Personal pronouns (he/she, him/her)
# - Present Simple for habits and routines
# - Articles (a/an/the)
# - Demonstratives if relevant
#
# **Example start:** "My best friend is Maria. She is from Mexico..."

# %% [markdown]
# ### Your Paragraph:
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ### Task 2: Daily Routine Interview
#
# Write 10 questions you would ask someone about their daily routine. Then provide your own answers.
#
# Use Present Simple questions (Do you...? Does he/she...?)

# %% [markdown]
# ### Questions and Answers:
#
# **Q1:** _______________________________________________?
#
# **A1:** _______________________________________________
#
# **Q2:** _______________________________________________?
#
# **A2:** _______________________________________________
#
# _(Continue for questions 3-10...)_
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ### Task 3: Describe a Typical Weekend
#
# Write about what you do on a typical weekend. Include:
# - What time you wake up
# - Where you go
# - What you do
# - Who you spend time with
# - What you don't do
#
# **Minimum:** 10 sentences

# %% [markdown]
# ### Your Weekend Description:
#
# _______________________________________________
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Part 3: Weak Areas Identification (15%)
#
# Identify which modules need more review.
#
# ---

# %%
# Self-assessment quiz
display(
    HTML(
        """
<h3>Rate your confidence (1-5) for each module:</h3>
<p>1 = Not confident, need to review | 5 = Very confident</p>
"""
    )
)

# You can create interactive sliders here or have students rate manually

# %% [markdown]
# ### Self-Assessment:
#
# **Module 1 - Verb "To Be":** ___/5
#
# **Module 2 - Personal Pronouns:** ___/5
#
# **Module 3 - Present Simple (Affirmative):** ___/5
#
# **Module 4 - Present Simple (Negative/Questions):** ___/5
#
# **Module 5 - Articles and Demonstratives:** ___/5
#
# ### Modules I need to review:
#
# _______________________________________________
#
# ### What is still confusing?
#
# _______________________________________________
#
# **Double-click to write!**

# %% [markdown]
# ---
#
# ## Part 4: Rapid Review Exercises (15%)
#
# Quick exercises to reinforce key concepts.
#
# ---

# %%
# Matching exercise: Pronouns
exercise.create_matching_exercise(
    [("I", "me"), ("he", "him"), ("she", "her"), ("they", "them"), ("we", "us")],
    instructions="Match subject pronouns with object pronouns:",
)

# %%
# Quick verb form drill
exercise.create_fill_in_blank("He ___ (play) football every day.", "plays")

# %%
exercise.create_fill_in_blank("They ___ (not/like) spicy food.", "don't like")

# %% [markdown]
# ---
#
# ## 📊 Review Score

# %%
# Display your score
validator.display_score()

# %%
# Mark reviews as complete for modules 1-5
# Uncomment and run when finished

# Enter your score from the exercises above
# review_score = 85.0  # Replace with your actual score

# for i in range(1, 6):
#     scheduler.mark_review_complete(f"A1_Module_{i:02d}", review_score)

# %% [markdown]
# ---
#
# ## 🎯 Next Steps
#
# ### Based on your score:
#
# **80%+ :** Excellent! Continue to Modules 6-10 ✅
#
# **60-79%:** Good work! Review weak areas identified above, then continue 👍
#
# **Below 60%:** Spend more time reviewing Modules 1-5 before moving forward 📚
#
# ### Action Plan:
#
# 1. Review any modules where you rated yourself below 3/5
# 2. Complete additional practice in your weak areas
# 3. Continue to Module 6 when ready
# 4. Schedule your next review session (see dates below)
#
# ---
#
# ## 📅 Your Next Review Schedule
#
# The system will remind you to review Modules 1-5 again at these intervals:
#
# - **Next review:** In 7 days
# - **Following review:** In 14 days
# - **Monthly review:** In 30 days
#
# Check the **Progress Tracker** notebook to see all scheduled reviews!
#
# ---
#
# ## 🌟 Great Job!
#
# You've completed your first comprehensive review! Regular review is the key to long-term retention.
#
# **Keep up the excellent work!** 🚀
#
# Ready to continue? Open **Module 6: Nouns and Plurals**
