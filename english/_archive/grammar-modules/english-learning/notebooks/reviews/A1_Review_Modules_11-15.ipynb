# %% [markdown]
# # A1 Review: Modules 11-15 Consolidation
#
# ## 📚 Review of Modules 11-15
#
# 1. ✅ Module 11: Question Words
# 2. ✅ Module 12: Can/Can't
# 3. ✅ Module 13: Demonstratives Deep Dive
# 4. ✅ Module 14: Like/Love/Hate + -ing
# 5. ✅ Module 15: Past Simple - Was/Were
#
# ⏱️ Time: 2-3 hours
#
# ---

# %%
import sys

sys.path.append("../../utils")
from feedback_system import ExerciseValidator, InteractiveExercise
from spaced_repetition import SpacedRepetitionScheduler

validator = ExerciseValidator()
exercise = InteractiveExercise(validator)
scheduler = SpacedRepetitionScheduler(data_file="../../data/progress.json")
print("Ready for review!")

# %% [markdown]
# ## Mixed Review
#
# Exercises combining all 5 modules...
#
# ---

# %% [markdown]
# ## Self-Assessment
#
# **Module 11:** ___/5
# **Module 12:** ___/5
# **Module 13:** ___/5
# **Module 14:** ___/5
# **Module 15:** ___/5
#
# ---

# %%
validator.display_score()

# %% [markdown]
# ## Complete!
#
# Continue to Module 16!
#
# ---
