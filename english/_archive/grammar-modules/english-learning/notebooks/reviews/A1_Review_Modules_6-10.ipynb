# %% [markdown]
# # A1 Review: Modules 6-10 Consolidation
#
# ## 📚 Comprehensive Review
#
# This review consolidates Modules 6-10:
#
# 1. ✅ Module 6: Nouns and Plurals
# 2. ✅ Module 7: Possessives
# 3. ✅ Module 8: Adjectives
# 4. ✅ Module 9: There Is/Are
# 5. ✅ Module 10: Prepositions
#
# ⏱️ Time: 2-3 hours
#
# ---

# %%
import sys

sys.path.append("../../utils")

from feedback_system import ExerciseValidator, InteractiveExercise
from spaced_repetition import SpacedRepetitionScheduler

validator = ExerciseValidator()
exercise = InteractiveExercise(validator)
scheduler = SpacedRepetitionScheduler(data_file="../../data/progress.json")

print("Ready for review!")

# %% [markdown]
# ## Part 1: Mixed Grammar Review
#
# Complete exercises combining all 5 modules...
#
# ---

# %% [markdown]
# ## Part 2: Integrated Tasks
#
# Communication tasks using grammar from Modules 6-10...
#
# ---

# %% [markdown]
# ## Self-Assessment
#
# **Module 6 - Nouns and Plurals:** ___/5
#
# **Module 7 - Possessives:** ___/5
#
# **Module 8 - Adjectives:** ___/5
#
# **Module 9 - There Is/Are:** ___/5
#
# **Module 10 - Prepositions:** ___/5
#
# ---

# %%
validator.display_score()

# %% [markdown]
# ## Complete!
#
# Continue to Module 11!
#
# ---
