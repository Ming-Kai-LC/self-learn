# %% [markdown]
# # A1 Review: Modules 16-20 Consolidation
#
# ## 📚 Final A1 Review
#
# 1. ✅ Module 16: Past Simple Regular Verbs
# 2. ✅ Module 17: Past Simple Irregular Verbs
# 3. ✅ Module 18: Going To Future
# 4. ✅ Module 19: Will Future
# 5. ✅ Module 20: Adverbs of Frequency
#
# ⏱️ Time: 2-3 hours
#
# ---

# %%
import sys

sys.path.append("../../utils")
from feedback_system import ExerciseValidator, InteractiveExercise
from spaced_repetition import SpacedRepetitionScheduler

validator = ExerciseValidator()
exercise = InteractiveExercise(validator)
scheduler = SpacedRepetitionScheduler(data_file="../../data/progress.json")
print("Ready for review!")

# %% [markdown]
# ## Mixed Review
#
# Exercises combining all 5 modules...
#
# ---

# %% [markdown]
# ## Self-Assessment
#
# **Module 16:** ___/5
# **Module 17:** ___/5
# **Module 18:** ___/5
# **Module 19:** ___/5
# **Module 20:** ___/5
#
# ---

# %%
validator.display_score()

# %% [markdown]
# ## 🎉 A1 Complete!
#
# Congratulations! You've finished all 20 A1 modules!
#
# ### Next Steps:
# - Continue to A2 Level
# - Review A1 materials regularly
# - Keep practicing!
#
# ---
