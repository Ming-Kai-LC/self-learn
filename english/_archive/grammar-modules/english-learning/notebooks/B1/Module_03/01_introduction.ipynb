# %% [markdown]
# # B1 Level - Module 3: Present Perfect Continuous - Duration and Process
#
# ## How Long Have You Been...?
#
# **Grammar Focus:** Present Perfect Continuous - Duration Emphasis
# **Estimated Time:** 5-6 hours
# **Difficulty:** ★★★★☆
#
# ---
#
# # Phase 1: Introduction

# %% [markdown]
# ## Introduction - A New Perfect Tense
#
# Present Perfect Continuous adds **duration and process emphasis** to Present Perfect.
#
# **Form:** have/has been + verb-ing
#
# **Main use:** How long something has been continuing up to NOW
