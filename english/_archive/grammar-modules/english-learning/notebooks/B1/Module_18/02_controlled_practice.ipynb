# %% [markdown]
# # B1 Level - Module 18: Relative Clauses - Object Relatives and Omission
#
# ## When You Can Leave Out the Relative Pronoun
#
# **Grammar Focus:** Advanced Relative Patterns
# **Estimated Time:** 5-6 hours
# **Difficulty:** ★★★★☆
#
# ---
#
# # Phase 2: Controlled Practice

# %% [markdown]
# ## Welcome to Phase 2: Controlled Practice
#
# In this phase, you'll complete **85 exercises**.
#
# **Remember:** Advanced Relative Patterns requires systematic practice!
#
# ---
#
# Let's begin!

# %% [markdown]
# ## Exercises (Total: 85)

# %% [markdown]
# ### Exercise Sets
#
# **Note:** Full exercises in production version.
