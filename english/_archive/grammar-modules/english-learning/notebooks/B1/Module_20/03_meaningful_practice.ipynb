# %% [markdown]
# # B1 Level - Module 20: Modal Verbs for Past Deduction
#
# ## Must Have, Can't Have, Might Have + PP
#
# **Grammar Focus:** Making Conclusions About Past Events
# **Estimated Time:** 6-7 hours
# **Difficulty:** ★★★★★
#
# ---
#
# # Phase 3: Meaningful Practice

# %% [markdown]
# ## Welcome to Phase 3: Meaningful Practice
#
# **Activities in this phase:** 10
#
# Make the grammar personally relevant!
#
# ---

# %% [markdown]
# ### Activity 1
#
# [Activity description]
#
# ---

# %% [markdown]
# ### Activity 2
#
# [Activity description]
#
# ---

# %% [markdown]
# ### Activity 3
#
# [Activity description]
#
# ---

# %% [markdown]
# ### Activity 4
#
# [Activity description]
#
# ---

# %% [markdown]
# ### Activity 5
#
# [Activity description]
#
# ---

# %% [markdown]
# ### Activity 6
#
# [Activity description]
#
# ---

# %% [markdown]
# ### Activity 7
#
# [Activity description]
#
# ---

# %% [markdown]
# ### Activity 8
#
# [Activity description]
#
# ---

# %% [markdown]
# ### Activity 9
#
# [Activity description]
#
# ---

# %% [markdown]
# ### Activity 10
#
# [Activity description]
#
# ---
