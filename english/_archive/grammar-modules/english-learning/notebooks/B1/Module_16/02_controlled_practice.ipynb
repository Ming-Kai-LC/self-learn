# %% [markdown]
# # B1 Level - Module 16: Defining vs Non-Defining Relative Clauses
#
# ## Essential vs Extra Information - Comma Usage
#
# **Grammar Focus:** Distinguishing Clause Types
# **Estimated Time:** 6-7 hours
# **Difficulty:** ★★★★☆
#
# ---
#
# # Phase 2: Controlled Practice

# %% [markdown]
# ## Welcome to Phase 2: Controlled Practice
#
# In this phase, you'll complete **95 exercises**.
#
# **Remember:** Distinguishing Clause Types requires systematic practice!
#
# ---
#
# Let's begin!

# %% [markdown]
# ## Exercises (Total: 95)

# %% [markdown]
# ### Exercise Sets
#
# **Note:** Full exercises in production version.
