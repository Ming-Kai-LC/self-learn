# %% [markdown]
# # A1 Writing 04: Family Members
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 20-25 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn:
#
# 1. Mother/father
# 2. Brother/sister
# 3. Family
# 4. My family
# 5. Simple descriptions

# %% [markdown]
# ## Family Members - A1 Writing
#
# Topics: Mother/father, Brother/sister, Family, My family, Simple descriptions
#
# ### What You Will Do
# Write about your family

# %%
# Family Members
print('A1 Writing: Family Members')
print('Level: Beginner - Very Easy!')

# %% [markdown]
# ## Let's Learn!
#
# ### Step 1: Look and Learn
#
# Today you will learn about mother/father. This is very easy!
#
# ### Step 2: Examples
#
# - **Mother/father**
# - **Brother/sister**
# - **Family**
#
# ### Step 3: Your Turn
#
# Now you try:
#
# 1. Write about mother/father
# 2. Practice brother/sister
# 3. Try family

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Writing 04',
    'topics': ['Mother/father', 'Brother/sister'],
    'my_notes': 'Write here what you learned'
}

print('Great! You are learning!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help from AI
#
# ### Ask ChatGPT:
#
# ```
# I am a beginner (A1 level). I am learning family members.
# Please:
# 1. Show me very easy examples
# 2. Use VERY simple English
# 3. Help me practice mother/father
# 4. Check my writing
# ```

# %% [markdown]
# ## Practice Tasks
#
# 1. Look at the examples
# 2. Copy and practice writing
# 3. Write your own mother/father
# 4. Show AI and ask for help
# 5. Practice again!
#
# ## What You Learned
#
# ✅ You can now: Mother/father, Brother/sister
#
# **Keep Going!** You are doing great! 🌟
