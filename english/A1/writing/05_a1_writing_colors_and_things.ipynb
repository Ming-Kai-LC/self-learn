# %% [markdown]
# # A1 Writing 05: Colors and Things
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 20-25 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn:
#
# 1. Basic colors
# 2. Objects
# 3. Adjectives
# 4. My favorite
# 5. Descriptions

# %% [markdown]
# ## Colors and Things - A1 Writing
#
# Topics: Basic colors, Objects, Adjectives, My favorite, Descriptions
#
# ### What You Will Do
# Describe things with colors

# %%
# Colors and Things
print('A1 Writing: Colors and Things')
print('Level: Beginner - Very Easy!')

# %% [markdown]
# ## Let's Learn!
#
# ### Step 1: Look and Learn
#
# Today you will learn about basic colors. This is very easy!
#
# ### Step 2: Examples
#
# - **Basic colors**
# - **Objects**
# - **Adjectives**
#
# ### Step 3: Your Turn
#
# Now you try:
#
# 1. Write about basic colors
# 2. Practice objects
# 3. Try adjectives

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Writing 05',
    'topics': ['Basic colors', 'Objects'],
    'my_notes': 'Write here what you learned'
}

print('Great! You are learning!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help from AI
#
# ### Ask ChatGPT:
#
# ```
# I am a beginner (A1 level). I am learning colors and things.
# Please:
# 1. Show me very easy examples
# 2. Use VERY simple English
# 3. Help me practice basic colors
# 4. Check my writing
# ```

# %% [markdown]
# ## Practice Tasks
#
# 1. Look at the examples
# 2. Copy and practice writing
# 3. Write your own basic colors
# 4. Show AI and ask for help
# 5. Practice again!
#
# ## What You Learned
#
# ✅ You can now: Basic colors, Objects
#
# **Keep Going!** You are doing great! 🌟
