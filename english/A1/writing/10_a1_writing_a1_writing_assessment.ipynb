# %% [markdown]
# # A1 Writing 10: A1 Writing Assessment
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 25-30 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn:
#
# 1. Writing test
# 2. Basic sentences
# 3. Progress check
# 4. Practice review
# 5. A2 readiness

# %% [markdown]
# ## A1 Writing Assessment - A1 Writing
#
# Topics: Writing test, Basic sentences, Progress check, Practice review, A2 readiness
#
# ### What You Will Do
# Test your A1 writing skills

# %%
# A1 Writing Assessment
print('A1 Writing: A1 Writing Assessment')
print('Level: Beginner - Very Easy!')

# %% [markdown]
# ## Let's Learn!
#
# ### Step 1: Look and Learn
#
# Today you will learn about writing test. This is very easy!
#
# ### Step 2: Examples
#
# - **Writing test**
# - **Basic sentences**
# - **Progress check**
#
# ### Step 3: Your Turn
#
# Now you try:
#
# 1. Write about writing test
# 2. Practice basic sentences
# 3. Try progress check

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Writing 10',
    'topics': ['Writing test', 'Basic sentences'],
    'my_notes': 'Write here what you learned'
}

print('Great! You are learning!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help from AI
#
# ### Ask ChatGPT:
#
# ```
# I am a beginner (A1 level). I am learning a1 writing assessment.
# Please:
# 1. Show me very easy examples
# 2. Use VERY simple English
# 3. Help me practice writing test
# 4. Check my writing
# ```

# %% [markdown]
# ## Practice Tasks
#
# 1. Look at the examples
# 2. Copy and practice writing
# 3. Write your own writing test
# 4. Show AI and ask for help
# 5. Practice again!
#
# ## What You Learned
#
# ✅ You can now: Writing test, Basic sentences
#
# **Keep Going!** You are doing great! 🌟
