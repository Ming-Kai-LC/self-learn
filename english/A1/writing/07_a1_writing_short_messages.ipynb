# %% [markdown]
# # A1 Writing 07: Short Messages
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn:
#
# 1. Hello
# 2. Thank you
# 3. Sorry
# 4. Please
# 5. Goodbye

# %% [markdown]
# ## Short Messages - A1 Writing
#
# Topics: Hello, Thank you, Sorry, Please, Goodbye
#
# ### What You Will Do
# Write very simple messages

# %%
# Short Messages
print('A1 Writing: Short Messages')
print('Level: Beginner - Very Easy!')

# %% [markdown]
# ## Let's Learn!
#
# ### Step 1: Look and Learn
#
# Today you will learn about hello. This is very easy!
#
# ### Step 2: Examples
#
# - **Hello**
# - **Thank you**
# - **Sorry**
#
# ### Step 3: Your Turn
#
# Now you try:
#
# 1. Write about hello
# 2. Practice thank you
# 3. Try sorry

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Writing 07',
    'topics': ['Hello', 'Thank you'],
    'my_notes': 'Write here what you learned'
}

print('Great! You are learning!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help from AI
#
# ### Ask ChatGPT:
#
# ```
# I am a beginner (A1 level). I am learning short messages.
# Please:
# 1. Show me very easy examples
# 2. Use VERY simple English
# 3. Help me practice hello
# 4. Check my writing
# ```

# %% [markdown]
# ## Practice Tasks
#
# 1. Look at the examples
# 2. Copy and practice writing
# 3. Write your own hello
# 4. Show AI and ask for help
# 5. Practice again!
#
# ## What You Learned
#
# ✅ You can now: Hello, Thank you
#
# **Keep Going!** You are doing great! 🌟
