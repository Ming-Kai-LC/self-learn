# %% [markdown]
# # A1 Writing 01: The Alphabet and Your Name
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn:
#
# 1. Letters A-Z
# 2. Writing your name
# 3. Capital letters
# 4. Small letters
# 5. Practice

# %% [markdown]
# ## The Alphabet and Your Name - A1 Writing
#
# Topics: Letters A-Z, Writing your name, Capital letters, Small letters, Practice
#
# ### What You Will Do
# Write the alphabet and your name

# %%
# The Alphabet and Your Name
print('A1 Writing: The Alphabet and Your Name')
print('Level: Beginner - Very Easy!')

# %% [markdown]
# ## Let's Learn!
#
# ### Step 1: Look and Learn
#
# Today you will learn about letters a-z. This is very easy!
#
# ### Step 2: Examples
#
# - **Letters A-Z**
# - **Writing your name**
# - **Capital letters**
#
# ### Step 3: Your Turn
#
# Now you try:
#
# 1. Write about letters a-z
# 2. Practice writing your name
# 3. Try capital letters

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Writing 01',
    'topics': ['Letters A-Z', 'Writing your name'],
    'my_notes': 'Write here what you learned'
}

print('Great! You are learning!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help from AI
#
# ### Ask ChatGPT:
#
# ```
# I am a beginner (A1 level). I am learning the alphabet and your name.
# Please:
# 1. Show me very easy examples
# 2. Use VERY simple English
# 3. Help me practice letters a-z
# 4. Check my writing
# ```

# %% [markdown]
# ## Practice Tasks
#
# 1. Look at the examples
# 2. Copy and practice writing
# 3. Write your own letters a-z
# 4. Show AI and ask for help
# 5. Practice again!
#
# ## What You Learned
#
# ✅ You can now: Letters A-Z, Writing your name
#
# **Keep Going!** You are doing great! 🌟
