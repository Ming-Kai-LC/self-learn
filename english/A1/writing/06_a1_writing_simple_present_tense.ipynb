# %% [markdown]
# # A1 Writing 06: Simple Present Tense
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 20-25 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn:
#
# 1. I like
# 2. I have
# 3. I want
# 4. Simple verbs
# 5. Daily actions

# %% [markdown]
# ## Simple Present Tense - A1 Writing
#
# Topics: I like, I have, I want, Simple verbs, Daily actions
#
# ### What You Will Do
# Write simple present sentences

# %%
# Simple Present Tense
print('A1 Writing: Simple Present Tense')
print('Level: Beginner - Very Easy!')

# %% [markdown]
# ## Let's Learn!
#
# ### Step 1: Look and Learn
#
# Today you will learn about i like. This is very easy!
#
# ### Step 2: Examples
#
# - **I like**
# - **I have**
# - **I want**
#
# ### Step 3: Your Turn
#
# Now you try:
#
# 1. Write about i like
# 2. Practice i have
# 3. Try i want

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Writing 06',
    'topics': ['I like', 'I have'],
    'my_notes': 'Write here what you learned'
}

print('Great! You are learning!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help from AI
#
# ### Ask ChatGPT:
#
# ```
# I am a beginner (A1 level). I am learning simple present tense.
# Please:
# 1. Show me very easy examples
# 2. Use VERY simple English
# 3. Help me practice i like
# 4. Check my writing
# ```

# %% [markdown]
# ## Practice Tasks
#
# 1. Look at the examples
# 2. Copy and practice writing
# 3. Write your own i like
# 4. Show AI and ask for help
# 5. Practice again!
#
# ## What You Learned
#
# ✅ You can now: I like, I have
#
# **Keep Going!** You are doing great! 🌟
