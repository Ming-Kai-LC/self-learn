# %% [markdown]
# # A1 Writing 09: Basic Questions
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 20-25 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn:
#
# 1. What is
# 2. Where is
# 3. Who is
# 4. Question marks
# 5. Simple questions

# %% [markdown]
# ## Basic Questions - A1 Writing
#
# Topics: What is, Where is, Who is, Question marks, Simple questions
#
# ### What You Will Do
# Write simple questions

# %%
# Basic Questions
print('A1 Writing: Basic Questions')
print('Level: Beginner - Very Easy!')

# %% [markdown]
# ## Let's Learn!
#
# ### Step 1: Look and Learn
#
# Today you will learn about what is. This is very easy!
#
# ### Step 2: Examples
#
# - **What is**
# - **Where is**
# - **Who is**
#
# ### Step 3: Your Turn
#
# Now you try:
#
# 1. Write about what is
# 2. Practice where is
# 3. Try who is

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Writing 09',
    'topics': ['What is', 'Where is'],
    'my_notes': 'Write here what you learned'
}

print('Great! You are learning!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help from AI
#
# ### Ask ChatGPT:
#
# ```
# I am a beginner (A1 level). I am learning basic questions.
# Please:
# 1. Show me very easy examples
# 2. Use VERY simple English
# 3. Help me practice what is
# 4. Check my writing
# ```

# %% [markdown]
# ## Practice Tasks
#
# 1. Look at the examples
# 2. Copy and practice writing
# 3. Write your own what is
# 4. Show AI and ask for help
# 5. Practice again!
#
# ## What You Learned
#
# ✅ You can now: What is, Where is
#
# **Keep Going!** You are doing great! 🌟
