# %% [markdown]
# # A1 Writing 08: Lists and Forms
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 20-25 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn:
#
# 1. Shopping lists
# 2. To-do lists
# 3. Simple forms
# 4. Name/age/address
# 5. Fill in blanks

# %% [markdown]
# ## Lists and Forms - A1 Writing
#
# Topics: Shopping lists, To-do lists, Simple forms, Name/age/address, Fill in blanks
#
# ### What You Will Do
# Make simple lists and forms

# %%
# Lists and Forms
print('A1 Writing: Lists and Forms')
print('Level: Beginner - Very Easy!')

# %% [markdown]
# ## Let's Learn!
#
# ### Step 1: Look and Learn
#
# Today you will learn about shopping lists. This is very easy!
#
# ### Step 2: Examples
#
# - **Shopping lists**
# - **To-do lists**
# - **Simple forms**
#
# ### Step 3: Your Turn
#
# Now you try:
#
# 1. Write about shopping lists
# 2. Practice to-do lists
# 3. Try simple forms

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Writing 08',
    'topics': ['Shopping lists', 'To-do lists'],
    'my_notes': 'Write here what you learned'
}

print('Great! You are learning!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help from AI
#
# ### Ask ChatGPT:
#
# ```
# I am a beginner (A1 level). I am learning lists and forms.
# Please:
# 1. Show me very easy examples
# 2. Use VERY simple English
# 3. Help me practice shopping lists
# 4. Check my writing
# ```

# %% [markdown]
# ## Practice Tasks
#
# 1. Look at the examples
# 2. Copy and practice writing
# 3. Write your own shopping lists
# 4. Show AI and ask for help
# 5. Practice again!
#
# ## What You Learned
#
# ✅ You can now: Shopping lists, To-do lists
#
# **Keep Going!** You are doing great! 🌟
