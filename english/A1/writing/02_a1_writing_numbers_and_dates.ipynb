# %% [markdown]
# # A1 Writing 02: Numbers and Dates
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn:
#
# 1. Numbers 1-100
# 2. Your age
# 3. Dates
# 4. Your birthday
# 5. Writing numbers

# %% [markdown]
# ## Numbers and Dates - A1 Writing
#
# Topics: Numbers 1-100, Your age, Dates, Your birthday, Writing numbers
#
# ### What You Will Do
# Write numbers and dates correctly

# %%
# Numbers and Dates
print('A1 Writing: Numbers and Dates')
print('Level: Beginner - Very Easy!')

# %% [markdown]
# ## Let's Learn!
#
# ### Step 1: Look and Learn
#
# Today you will learn about numbers 1-100. This is very easy!
#
# ### Step 2: Examples
#
# - **Numbers 1-100**
# - **Your age**
# - **Dates**
#
# ### Step 3: Your Turn
#
# Now you try:
#
# 1. Write about numbers 1-100
# 2. Practice your age
# 3. Try dates

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Writing 02',
    'topics': ['Numbers 1-100', 'Your age'],
    'my_notes': 'Write here what you learned'
}

print('Great! You are learning!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help from AI
#
# ### Ask ChatGPT:
#
# ```
# I am a beginner (A1 level). I am learning numbers and dates.
# Please:
# 1. Show me very easy examples
# 2. Use VERY simple English
# 3. Help me practice numbers 1-100
# 4. Check my writing
# ```

# %% [markdown]
# ## Practice Tasks
#
# 1. Look at the examples
# 2. Copy and practice writing
# 3. Write your own numbers 1-100
# 4. Show AI and ask for help
# 5. Practice again!
#
# ## What You Learned
#
# ✅ You can now: Numbers 1-100, Your age
#
# **Keep Going!** You are doing great! 🌟
