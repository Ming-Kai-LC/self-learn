# %% [markdown]
# # A1 Writing 03: Simple Sentences About You
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 20-25 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn:
#
# 1. I am
# 2. My name is
# 3. I live in
# 4. I am from
# 5. Simple facts

# %% [markdown]
# ## Simple Sentences About You - A1 Writing
#
# Topics: I am, My name is, I live in, I am from, Simple facts
#
# ### What You Will Do
# Write basic sentences about yourself

# %%
# Simple Sentences About You
print('A1 Writing: Simple Sentences About You')
print('Level: Beginner - Very Easy!')

# %% [markdown]
# ## Let's Learn!
#
# ### Step 1: Look and Learn
#
# Today you will learn about i am. This is very easy!
#
# ### Step 2: Examples
#
# - **I am**
# - **My name is**
# - **I live in**
#
# ### Step 3: Your Turn
#
# Now you try:
#
# 1. Write about i am
# 2. Practice my name is
# 3. Try i live in

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Writing 03',
    'topics': ['I am', 'My name is'],
    'my_notes': 'Write here what you learned'
}

print('Great! You are learning!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help from AI
#
# ### Ask ChatGPT:
#
# ```
# I am a beginner (A1 level). I am learning simple sentences about you.
# Please:
# 1. Show me very easy examples
# 2. Use VERY simple English
# 3. Help me practice i am
# 4. Check my writing
# ```

# %% [markdown]
# ## Practice Tasks
#
# 1. Look at the examples
# 2. Copy and practice writing
# 3. Write your own i am
# 4. Show AI and ask for help
# 5. Practice again!
#
# ## What You Learned
#
# ✅ You can now: I am, My name is
#
# **Keep Going!** You are doing great! 🌟
