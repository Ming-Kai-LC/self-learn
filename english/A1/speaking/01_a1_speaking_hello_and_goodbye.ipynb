# %% [markdown]
# # A1 Speaking 01: Hello and Goodbye
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to say:
#
# 1. Hello
# 2. Hi
# 3. Good morning
# 4. Goodbye
# 5. See you

# %% [markdown]
# ## Hello and Goodbye - A1 Speaking
#
# Topics: Hello, Hi, Good morning, Goodbye, See you
#
# ### What You Will Do
# Say hello and goodbye

# %%
# Hello and Goodbye
print('A1 Speaking: Hello and Goodbye')
print('Level: Beginner - You can do this!')

# %% [markdown]
# ## Let's Practice!
#
# ### Step 1: Listen
#
# First, listen to: Hello
#
# ### Step 2: Repeat
#
# Say these words:
# - Hello
# - Hi
# - Good morning
#
# ### Step 3: Practice
#
# Now try speaking:
#
# 1. Say Hello
# 2. Practice Hi
# 3. Try with a friend or AI

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Speaking 01',
    'what_i_said': 'Hello',
    'minutes': 0,
    'notes': 'How did it go?'
}

print('Good job! Keep speaking!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Practice with AI
#
# ### Use Gliglish AI or ChatGPT Voice:
#
# ```
# I am a beginner (A1). I want to practice hello and goodbye.
# Please:
# 1. Speak very slowly
# 2. Use very easy words
# 3. Help me say Hello
# 4. Be patient with me
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Listen to examples
# 2. Repeat many times
# 3. Say Hello yourself
# 4. Practice with AI
# 5. Speak every day!
#
# ## What You Learned
#
# ✅ You can now say: Hello, Hi
#
# **Great Work!** Speaking gets easier! 🌟
