# %% [markdown]
# # A1 Speaking 09: Thank You and Please
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to say:
#
# 1. Thank you
# 2. Please
# 3. Sorry
# 4. Excuse me
# 5. Polite words

# %% [markdown]
# ## Thank You and Please - A1 Speaking
#
# Topics: Thank you, Please, Sorry, Excuse me, Polite words
#
# ### What You Will Do
# Be polite in English

# %%
# Thank You and Please
print('A1 Speaking: Thank You and Please')
print('Level: Beginner - You can do this!')

# %% [markdown]
# ## Let's Practice!
#
# ### Step 1: Listen
#
# First, listen to: Thank you
#
# ### Step 2: Repeat
#
# Say these words:
# - Thank you
# - Please
# - Sorry
#
# ### Step 3: Practice
#
# Now try speaking:
#
# 1. Say Thank you
# 2. Practice Please
# 3. Try with a friend or AI

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Speaking 09',
    'what_i_said': 'Thank you',
    'minutes': 0,
    'notes': 'How did it go?'
}

print('Good job! Keep speaking!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Practice with AI
#
# ### Use Gliglish AI or ChatGPT Voice:
#
# ```
# I am a beginner (A1). I want to practice thank you and please.
# Please:
# 1. Speak very slowly
# 2. Use very easy words
# 3. Help me say Thank you
# 4. Be patient with me
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Listen to examples
# 2. Repeat many times
# 3. Say Thank you yourself
# 4. Practice with AI
# 5. Speak every day!
#
# ## What You Learned
#
# ✅ You can now say: Thank you, Please
#
# **Great Work!** Speaking gets easier! 🌟
