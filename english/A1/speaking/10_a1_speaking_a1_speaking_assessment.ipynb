# %% [markdown]
# # A1 Speaking 10: A1 Speaking Assessment
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 20-25 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to say:
#
# 1. Speaking test
# 2. Introduction
# 3. Simple questions
# 4. Practice check
# 5. A2 readiness

# %% [markdown]
# ## A1 Speaking Assessment - A1 Speaking
#
# Topics: Speaking test, Introduction, Simple questions, Practice check, A2 readiness
#
# ### What You Will Do
# Test your A1 speaking

# %%
# A1 Speaking Assessment
print('A1 Speaking: A1 Speaking Assessment')
print('Level: Beginner - You can do this!')

# %% [markdown]
# ## Let's Practice!
#
# ### Step 1: Listen
#
# First, listen to: Speaking test
#
# ### Step 2: Repeat
#
# Say these words:
# - Speaking test
# - Introduction
# - Simple questions
#
# ### Step 3: Practice
#
# Now try speaking:
#
# 1. Say Speaking test
# 2. Practice Introduction
# 3. Try with a friend or AI

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Speaking 10',
    'what_i_said': 'Speaking test',
    'minutes': 0,
    'notes': 'How did it go?'
}

print('Good job! Keep speaking!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Practice with AI
#
# ### Use Gliglish AI or ChatGPT Voice:
#
# ```
# I am a beginner (A1). I want to practice a1 speaking assessment.
# Please:
# 1. Speak very slowly
# 2. Use very easy words
# 3. Help me say Speaking test
# 4. Be patient with me
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Listen to examples
# 2. Repeat many times
# 3. Say Speaking test yourself
# 4. Practice with AI
# 5. Speak every day!
#
# ## What You Learned
#
# ✅ You can now say: Speaking test, Introduction
#
# **Great Work!** Speaking gets easier! 🌟
