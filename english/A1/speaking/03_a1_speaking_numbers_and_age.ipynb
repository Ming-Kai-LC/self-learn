# %% [markdown]
# # A1 Speaking 03: Numbers and Age
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to say:
#
# 1. Numbers 1-20
# 2. How old are you
# 3. I am X years old
# 4. Counting
# 5. Age

# %% [markdown]
# ## Numbers and Age - A1 Speaking
#
# Topics: Numbers 1-20, How old are you, I am X years old, Counting, Age
#
# ### What You Will Do
# Say numbers and your age

# %%
# Numbers and Age
print('A1 Speaking: Numbers and Age')
print('Level: Beginner - You can do this!')

# %% [markdown]
# ## Let's Practice!
#
# ### Step 1: Listen
#
# First, listen to: Numbers 1-20
#
# ### Step 2: Repeat
#
# Say these words:
# - Numbers 1-20
# - How old are you
# - I am X years old
#
# ### Step 3: Practice
#
# Now try speaking:
#
# 1. Say Numbers 1-20
# 2. Practice How old are you
# 3. Try with a friend or AI

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Speaking 03',
    'what_i_said': 'Numbers 1-20',
    'minutes': 0,
    'notes': 'How did it go?'
}

print('Good job! Keep speaking!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Practice with AI
#
# ### Use Gliglish AI or ChatGPT Voice:
#
# ```
# I am a beginner (A1). I want to practice numbers and age.
# Please:
# 1. Speak very slowly
# 2. Use very easy words
# 3. Help me say Numbers 1-20
# 4. Be patient with me
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Listen to examples
# 2. Repeat many times
# 3. Say Numbers 1-20 yourself
# 4. Practice with AI
# 5. Speak every day!
#
# ## What You Learned
#
# ✅ You can now say: Numbers 1-20, How old are you
#
# **Great Work!** Speaking gets easier! 🌟
