# %% [markdown]
# # A1 Speaking 08: Colors and Objects
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to say:
#
# 1. Red/blue/green
# 2. What color
# 3. This/that
# 4. Objects
# 5. Describing

# %% [markdown]
# ## Colors and Objects - A1 Speaking
#
# Topics: Red/blue/green, What color, This/that, Objects, Describing
#
# ### What You Will Do
# Name colors and things

# %%
# Colors and Objects
print('A1 Speaking: Colors and Objects')
print('Level: Beginner - You can do this!')

# %% [markdown]
# ## Let's Practice!
#
# ### Step 1: Listen
#
# First, listen to: Red/blue/green
#
# ### Step 2: Repeat
#
# Say these words:
# - Red/blue/green
# - What color
# - This/that
#
# ### Step 3: Practice
#
# Now try speaking:
#
# 1. Say Red/blue/green
# 2. Practice What color
# 3. Try with a friend or AI

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Speaking 08',
    'what_i_said': 'Red/blue/green',
    'minutes': 0,
    'notes': 'How did it go?'
}

print('Good job! Keep speaking!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Practice with AI
#
# ### Use Gliglish AI or ChatGPT Voice:
#
# ```
# I am a beginner (A1). I want to practice colors and objects.
# Please:
# 1. Speak very slowly
# 2. Use very easy words
# 3. Help me say Red/blue/green
# 4. Be patient with me
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Listen to examples
# 2. Repeat many times
# 3. Say Red/blue/green yourself
# 4. Practice with AI
# 5. Speak every day!
#
# ## What You Learned
#
# ✅ You can now say: Red/blue/green, What color
#
# **Great Work!** Speaking gets easier! 🌟
