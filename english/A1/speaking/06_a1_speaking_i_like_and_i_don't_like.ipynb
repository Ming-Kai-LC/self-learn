# %% [markdown]
# # A1 Speaking 06: I Like and I Don't Like
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to say:
#
# 1. I like
# 2. I don't like
# 3. Do you like
# 4. Yes/No
# 5. Preferences

# %% [markdown]
# ## I Like and I Don't Like - A1 Speaking
#
# Topics: I like, I don't like, Do you like, Yes/No, Preferences
#
# ### What You Will Do
# Say what you like

# %%
# I Like and I Don't Like
print('A1 Speaking: I Like and I Don't Like')
print('Level: Beginner - You can do this!')

# %% [markdown]
# ## Let's Practice!
#
# ### Step 1: Listen
#
# First, listen to: I like
#
# ### Step 2: Repeat
#
# Say these words:
# - I like
# - I don't like
# - Do you like
#
# ### Step 3: Practice
#
# Now try speaking:
#
# 1. Say I like
# 2. Practice I don't like
# 3. Try with a friend or AI

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Speaking 06',
    'what_i_said': 'I like',
    'minutes': 0,
    'notes': 'How did it go?'
}

print('Good job! Keep speaking!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Practice with AI
#
# ### Use Gliglish AI or ChatGPT Voice:
#
# ```
# I am a beginner (A1). I want to practice i like and i don't like.
# Please:
# 1. Speak very slowly
# 2. Use very easy words
# 3. Help me say I like
# 4. Be patient with me
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Listen to examples
# 2. Repeat many times
# 3. Say I like yourself
# 4. Practice with AI
# 5. Speak every day!
#
# ## What You Learned
#
# ✅ You can now say: I like, I don't like
#
# **Great Work!** Speaking gets easier! 🌟
