# %% [markdown]
# # A1 Speaking 02: My Name Is
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to say:
#
# 1. My name is
# 2. What's your name
# 3. Nice to meet you
# 4. Introductions
# 5. Names

# %% [markdown]
# ## My Name Is - A1 Speaking
#
# Topics: My name is, What's your name, Nice to meet you, Introductions, Names
#
# ### What You Will Do
# Introduce yourself

# %%
# My Name Is
print('A1 Speaking: My Name Is')
print('Level: Beginner - You can do this!')

# %% [markdown]
# ## Let's Practice!
#
# ### Step 1: Listen
#
# First, listen to: My name is
#
# ### Step 2: Repeat
#
# Say these words:
# - My name is
# - What's your name
# - Nice to meet you
#
# ### Step 3: Practice
#
# Now try speaking:
#
# 1. Say My name is
# 2. Practice What's your name
# 3. Try with a friend or AI

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Speaking 02',
    'what_i_said': 'My name is',
    'minutes': 0,
    'notes': 'How did it go?'
}

print('Good job! Keep speaking!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Practice with AI
#
# ### Use Gliglish AI or ChatGPT Voice:
#
# ```
# I am a beginner (A1). I want to practice my name is.
# Please:
# 1. Speak very slowly
# 2. Use very easy words
# 3. Help me say My name is
# 4. Be patient with me
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Listen to examples
# 2. Repeat many times
# 3. Say My name is yourself
# 4. Practice with AI
# 5. Speak every day!
#
# ## What You Learned
#
# ✅ You can now say: My name is, What's your name
#
# **Great Work!** Speaking gets easier! 🌟
