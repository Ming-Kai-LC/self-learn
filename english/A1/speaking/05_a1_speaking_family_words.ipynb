# %% [markdown]
# # A1 Speaking 05: Family Words
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to say:
#
# 1. Mother/father
# 2. Sister/brother
# 3. My family
# 4. This is my
# 5. Family members

# %% [markdown]
# ## Family Words - A1 Speaking
#
# Topics: Mother/father, Sister/brother, My family, This is my, Family members
#
# ### What You Will Do
# Talk about your family

# %%
# Family Words
print('A1 Speaking: Family Words')
print('Level: Beginner - You can do this!')

# %% [markdown]
# ## Let's Practice!
#
# ### Step 1: Listen
#
# First, listen to: Mother/father
#
# ### Step 2: Repeat
#
# Say these words:
# - Mother/father
# - Sister/brother
# - My family
#
# ### Step 3: Practice
#
# Now try speaking:
#
# 1. Say Mother/father
# 2. Practice Sister/brother
# 3. Try with a friend or AI

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Speaking 05',
    'what_i_said': 'Mother/father',
    'minutes': 0,
    'notes': 'How did it go?'
}

print('Good job! Keep speaking!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Practice with AI
#
# ### Use Gliglish AI or ChatGPT Voice:
#
# ```
# I am a beginner (A1). I want to practice family words.
# Please:
# 1. Speak very slowly
# 2. Use very easy words
# 3. Help me say Mother/father
# 4. Be patient with me
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Listen to examples
# 2. Repeat many times
# 3. Say Mother/father yourself
# 4. Practice with AI
# 5. Speak every day!
#
# ## What You Learned
#
# ✅ You can now say: Mother/father, Sister/brother
#
# **Great Work!** Speaking gets easier! 🌟
