# %% [markdown]
# # A1 Speaking 07: Simple Questions
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to say:
#
# 1. What is this
# 2. Where is
# 3. How are you
# 4. Yes/No
# 5. Basic questions

# %% [markdown]
# ## Simple Questions - A1 Speaking
#
# Topics: What is this, Where is, How are you, Yes/No, Basic questions
#
# ### What You Will Do
# Ask very simple questions

# %%
# Simple Questions
print('A1 Speaking: Simple Questions')
print('Level: Beginner - You can do this!')

# %% [markdown]
# ## Let's Practice!
#
# ### Step 1: Listen
#
# First, listen to: What is this
#
# ### Step 2: Repeat
#
# Say these words:
# - What is this
# - Where is
# - How are you
#
# ### Step 3: Practice
#
# Now try speaking:
#
# 1. Say What is this
# 2. Practice Where is
# 3. Try with a friend or AI

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Speaking 07',
    'what_i_said': 'What is this',
    'minutes': 0,
    'notes': 'How did it go?'
}

print('Good job! Keep speaking!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Practice with AI
#
# ### Use Gliglish AI or ChatGPT Voice:
#
# ```
# I am a beginner (A1). I want to practice simple questions.
# Please:
# 1. Speak very slowly
# 2. Use very easy words
# 3. Help me say What is this
# 4. Be patient with me
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Listen to examples
# 2. Repeat many times
# 3. Say What is this yourself
# 4. Practice with AI
# 5. Speak every day!
#
# ## What You Learned
#
# ✅ You can now say: What is this, Where is
#
# **Great Work!** Speaking gets easier! 🌟
