# %% [markdown]
# # A1 Reading 08: Family and Friends
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to read:
#
# 1. Mother/father
# 2. Sister/brother
# 3. Friend
# 4. Family words
# 5. People

# %% [markdown]
# ## Family and Friends - A1 Reading
#
# Topics: Mother/father, Sister/brother, Friend, Family words, People
#
# ### What You Will Do
# Read about family

# %%
# Family and Friends
print('A1 Reading: Family and Friends')
print('Level: Beginner - Let\'s read!')

# %% [markdown]
# ## Let's Read!
#
# ### Step 1: Look
#
# Today you will read: Mother/father
#
# ### Step 2: Examples
#
# Look at these:
# - Mother/father
# - Sister/brother
# - Friend
#
# ### Step 3: Practice Reading
#
# Now you try:
#
# 1. Read Mother/father
# 2. Look at Sister/brother
# 3. Practice many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Reading 08',
    'what_i_read': 'Mother/father',
    'new_words': 'Write new words here',
    'notes': 'What did you learn?'
}

print('Good reading!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I am learning to read family and friends.
# Please:
# 1. Show me very easy examples
# 2. Use only simple words
# 3. Help me read Mother/father
# 4. Explain in easy English
# ```
#
# ### Good websites:
# - British Council Kids
# - Starfall (for beginners)
# - Very easy English websites

# %% [markdown]
# ## Your Tasks
#
# 1. Look at the examples
# 2. Read Mother/father slowly
# 3. Say the words out loud
# 4. Read again and again
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now read: Mother/father, Sister/brother
#
# **Excellent!** Reading is fun! 🌟
