# %% [markdown]
# # A1 Reading 05: Very Short Sentences
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to read:
#
# 1. I am
# 2. This is
# 3. My name is
# 4. Simple sentences
# 5. Basic grammar

# %% [markdown]
# ## Very Short Sentences - A1 Reading
#
# Topics: I am, This is, My name is, Simple sentences, Basic grammar
#
# ### What You Will Do
# Read simple sentences

# %%
# Very Short Sentences
print('A1 Reading: Very Short Sentences')
print('Level: Beginner - Let\'s read!')

# %% [markdown]
# ## Let's Read!
#
# ### Step 1: Look
#
# Today you will read: I am
#
# ### Step 2: Examples
#
# Look at these:
# - I am
# - This is
# - My name is
#
# ### Step 3: Practice Reading
#
# Now you try:
#
# 1. Read I am
# 2. Look at This is
# 3. Practice many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Reading 05',
    'what_i_read': 'I am',
    'new_words': 'Write new words here',
    'notes': 'What did you learn?'
}

print('Good reading!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I am learning to read very short sentences.
# Please:
# 1. Show me very easy examples
# 2. Use only simple words
# 3. Help me read I am
# 4. Explain in easy English
# ```
#
# ### Good websites:
# - British Council Kids
# - Starfall (for beginners)
# - Very easy English websites

# %% [markdown]
# ## Your Tasks
#
# 1. Look at the examples
# 2. Read I am slowly
# 3. Say the words out loud
# 4. Read again and again
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now read: I am, This is
#
# **Excellent!** Reading is fun! 🌟
