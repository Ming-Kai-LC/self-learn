# %% [markdown]
# # A1 Reading 10: A1 Reading Assessment
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 20-25 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to read:
#
# 1. Reading test
# 2. Words and sentences
# 3. Progress check
# 4. Understanding
# 5. A2 readiness

# %% [markdown]
# ## A1 Reading Assessment - A1 Reading
#
# Topics: Reading test, Words and sentences, Progress check, Understanding, A2 readiness
#
# ### What You Will Do
# Test your A1 reading

# %%
# A1 Reading Assessment
print('A1 Reading: A1 Reading Assessment')
print('Level: Beginner - Let\'s read!')

# %% [markdown]
# ## Let's Read!
#
# ### Step 1: Look
#
# Today you will read: Reading test
#
# ### Step 2: Examples
#
# Look at these:
# - Reading test
# - Words and sentences
# - Progress check
#
# ### Step 3: Practice Reading
#
# Now you try:
#
# 1. Read Reading test
# 2. Look at Words and sentences
# 3. Practice many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Reading 10',
    'what_i_read': 'Reading test',
    'new_words': 'Write new words here',
    'notes': 'What did you learn?'
}

print('Good reading!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I am learning to read a1 reading assessment.
# Please:
# 1. Show me very easy examples
# 2. Use only simple words
# 3. Help me read Reading test
# 4. Explain in easy English
# ```
#
# ### Good websites:
# - British Council Kids
# - Starfall (for beginners)
# - Very easy English websites

# %% [markdown]
# ## Your Tasks
#
# 1. Look at the examples
# 2. Read Reading test slowly
# 3. Say the words out loud
# 4. Read again and again
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now read: Reading test, Words and sentences
#
# **Excellent!** Reading is fun! 🌟
