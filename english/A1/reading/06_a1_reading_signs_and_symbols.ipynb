# %% [markdown]
# # A1 Reading 06: Signs and Symbols
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to read:
#
# 1. Exit
# 2. Stop
# 3. Open/Closed
# 4. Public signs
# 5. Important words

# %% [markdown]
# ## Signs and Symbols - A1 Reading
#
# Topics: Exit, Stop, Open/Closed, Public signs, Important words
#
# ### What You Will Do
# Understand basic signs

# %%
# Signs and Symbols
print('A1 Reading: Signs and Symbols')
print('Level: Beginner - Let\'s read!')

# %% [markdown]
# ## Let's Read!
#
# ### Step 1: Look
#
# Today you will read: Exit
#
# ### Step 2: Examples
#
# Look at these:
# - Exit
# - Stop
# - Open/Closed
#
# ### Step 3: Practice Reading
#
# Now you try:
#
# 1. Read Exit
# 2. Look at Stop
# 3. Practice many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Reading 06',
    'what_i_read': 'Exit',
    'new_words': 'Write new words here',
    'notes': 'What did you learn?'
}

print('Good reading!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I am learning to read signs and symbols.
# Please:
# 1. Show me very easy examples
# 2. Use only simple words
# 3. Help me read Exit
# 4. Explain in easy English
# ```
#
# ### Good websites:
# - British Council Kids
# - Starfall (for beginners)
# - Very easy English websites

# %% [markdown]
# ## Your Tasks
#
# 1. Look at the examples
# 2. Read Exit slowly
# 3. Say the words out loud
# 4. Read again and again
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now read: Exit, Stop
#
# **Excellent!** Reading is fun! 🌟
