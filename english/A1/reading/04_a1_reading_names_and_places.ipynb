# %% [markdown]
# # A1 Reading 04: Names and Places
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to read:
#
# 1. People's names
# 2. Countries
# 3. Cities
# 4. Street names
# 5. Capital letters

# %% [markdown]
# ## Names and Places - A1 Reading
#
# Topics: People's names, Countries, Cities, Street names, Capital letters
#
# ### What You Will Do
# Read names and places

# %%
# Names and Places
print('A1 Reading: Names and Places')
print('Level: Beginner - Let\'s read!')

# %% [markdown]
# ## Let's Read!
#
# ### Step 1: Look
#
# Today you will read: People's names
#
# ### Step 2: Examples
#
# Look at these:
# - People's names
# - Countries
# - Cities
#
# ### Step 3: Practice Reading
#
# Now you try:
#
# 1. Read People's names
# 2. Look at Countries
# 3. Practice many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Reading 04',
    'what_i_read': 'People's names',
    'new_words': 'Write new words here',
    'notes': 'What did you learn?'
}

print('Good reading!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I am learning to read names and places.
# Please:
# 1. Show me very easy examples
# 2. Use only simple words
# 3. Help me read People's names
# 4. Explain in easy English
# ```
#
# ### Good websites:
# - British Council Kids
# - Starfall (for beginners)
# - Very easy English websites

# %% [markdown]
# ## Your Tasks
#
# 1. Look at the examples
# 2. Read People's names slowly
# 3. Say the words out loud
# 4. Read again and again
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now read: People's names, Countries
#
# **Excellent!** Reading is fun! 🌟
