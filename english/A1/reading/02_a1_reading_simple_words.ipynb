# %% [markdown]
# # A1 Reading 02: Simple Words
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to read:
#
# 1. Cat/dog
# 2. Mom/dad
# 3. Easy words
# 4. Common words
# 5. 3-letter words

# %% [markdown]
# ## Simple Words - A1 Reading
#
# Topics: Cat/dog, Mom/dad, Easy words, Common words, 3-letter words
#
# ### What You Will Do
# Read very simple words

# %%
# Simple Words
print('A1 Reading: Simple Words')
print('Level: Beginner - Let\'s read!')

# %% [markdown]
# ## Let's Read!
#
# ### Step 1: Look
#
# Today you will read: Cat/dog
#
# ### Step 2: Examples
#
# Look at these:
# - Cat/dog
# - Mom/dad
# - Easy words
#
# ### Step 3: Practice Reading
#
# Now you try:
#
# 1. Read Cat/dog
# 2. Look at Mom/dad
# 3. Practice many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Reading 02',
    'what_i_read': 'Cat/dog',
    'new_words': 'Write new words here',
    'notes': 'What did you learn?'
}

print('Good reading!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I am learning to read simple words.
# Please:
# 1. Show me very easy examples
# 2. Use only simple words
# 3. Help me read Cat/dog
# 4. Explain in easy English
# ```
#
# ### Good websites:
# - British Council Kids
# - Starfall (for beginners)
# - Very easy English websites

# %% [markdown]
# ## Your Tasks
#
# 1. Look at the examples
# 2. Read Cat/dog slowly
# 3. Say the words out loud
# 4. Read again and again
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now read: Cat/dog, Mom/dad
#
# **Excellent!** Reading is fun! 🌟
