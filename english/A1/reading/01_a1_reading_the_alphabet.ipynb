# %% [markdown]
# # A1 Reading 01: The Alphabet
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to read:
#
# 1. A-Z
# 2. Capital letters
# 3. Small letters
# 4. Letter names
# 5. Reading letters

# %% [markdown]
# ## The Alphabet - A1 Reading
#
# Topics: A-Z, Capital letters, Small letters, Letter names, Reading letters
#
# ### What You Will Do
# Read and recognize all letters

# %%
# The Alphabet
print('A1 Reading: The Alphabet')
print('Level: Beginner - Let\'s read!')

# %% [markdown]
# ## Let's Read!
#
# ### Step 1: Look
#
# Today you will read: A-Z
#
# ### Step 2: Examples
#
# Look at these:
# - A-Z
# - Capital letters
# - Small letters
#
# ### Step 3: Practice Reading
#
# Now you try:
#
# 1. Read A-Z
# 2. Look at Capital letters
# 3. Practice many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Reading 01',
    'what_i_read': 'A-Z',
    'new_words': 'Write new words here',
    'notes': 'What did you learn?'
}

print('Good reading!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I am learning to read the alphabet.
# Please:
# 1. Show me very easy examples
# 2. Use only simple words
# 3. Help me read A-Z
# 4. Explain in easy English
# ```
#
# ### Good websites:
# - British Council Kids
# - Starfall (for beginners)
# - Very easy English websites

# %% [markdown]
# ## Your Tasks
#
# 1. Look at the examples
# 2. Read A-Z slowly
# 3. Say the words out loud
# 4. Read again and again
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now read: A-Z, Capital letters
#
# **Excellent!** Reading is fun! 🌟
