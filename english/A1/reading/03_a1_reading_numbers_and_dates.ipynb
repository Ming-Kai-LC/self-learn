# %% [markdown]
# # A1 Reading 03: Numbers and Dates
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to read:
#
# 1. Numbers 1-20
# 2. Dates
# 3. Days
# 4. Months
# 5. Reading numbers

# %% [markdown]
# ## Numbers and Dates - A1 Reading
#
# Topics: Numbers 1-20, Dates, Days, Months, Reading numbers
#
# ### What You Will Do
# Read numbers and dates

# %%
# Numbers and Dates
print('A1 Reading: Numbers and Dates')
print('Level: Beginner - Let\'s read!')

# %% [markdown]
# ## Let's Read!
#
# ### Step 1: Look
#
# Today you will read: Numbers 1-20
#
# ### Step 2: Examples
#
# Look at these:
# - Numbers 1-20
# - Dates
# - Days
#
# ### Step 3: Practice Reading
#
# Now you try:
#
# 1. Read Numbers 1-20
# 2. Look at Dates
# 3. Practice many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Reading 03',
    'what_i_read': 'Numbers 1-20',
    'new_words': 'Write new words here',
    'notes': 'What did you learn?'
}

print('Good reading!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Get Help
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I am learning to read numbers and dates.
# Please:
# 1. Show me very easy examples
# 2. Use only simple words
# 3. Help me read Numbers 1-20
# 4. Explain in easy English
# ```
#
# ### Good websites:
# - British Council Kids
# - Starfall (for beginners)
# - Very easy English websites

# %% [markdown]
# ## Your Tasks
#
# 1. Look at the examples
# 2. Read Numbers 1-20 slowly
# 3. Say the words out loud
# 4. Read again and again
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now read: Numbers 1-20, Dates
#
# **Excellent!** Reading is fun! 🌟
