# %% [markdown]
# # A1 Listening 02: Names and Introductions
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to hear:
#
# 1. My name is
# 2. What's your name
# 3. Names
# 4. Introductions
# 5. Listening for names

# %% [markdown]
# ## Names and Introductions - A1 Listening
#
# Topics: My name is, What's your name, Names, Introductions, Listening for names
#
# ### What You Will Do
# Understand people's names

# %%
# Names and Introductions
print('A1 Listening: Names and Introductions')
print('Level: Beginner - Listen carefully!')

# %% [markdown]
# ## Let's Listen!
#
# ### Step 1: Get Ready
#
# Today you will listen for: My name is
#
# ### Step 2: What to Listen For
#
# - My name is
# - What's your name
# - Names
#
# ### Step 3: Listen and Practice
#
# Listen carefully:
#
# 1. Listen for My name is
# 2. Try to hear What's your name
# 3. Listen many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Listening 02',
    'listened_for': 'My name is',
    'did_i_understand': 'Yes/No',
    'notes': 'What was difficult?'
}

print('Good listening!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Find Easy Audio
#
# ### Good websites for A1:
#
# ```
# - YouTube: "English for Beginners"
# - Voice of America: Learning English
# - BBC Learning English: The English We Speak
# - Slow, clear English only!
# ```
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I need very easy listening about names and introductions.
# Please:
# 1. Speak VERY slowly
# 2. Use only simple words
# 3. Say words about My name is
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Find easy audio
# 2. Listen for My name is
# 3. Listen again and again
# 4. Don't worry if you don't understand everything
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now hear: My name is, What's your name
#
# **Keep Listening!** It gets easier! 🌟
