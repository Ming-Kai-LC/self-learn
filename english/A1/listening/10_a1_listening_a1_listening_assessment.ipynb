# %% [markdown]
# # A1 Listening 10: A1 Listening Assessment
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 20-25 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to hear:
#
# 1. Listening test
# 2. Understanding
# 3. Progress check
# 4. Basic sounds
# 5. A2 readiness

# %% [markdown]
# ## A1 Listening Assessment - A1 Listening
#
# Topics: Listening test, Understanding, Progress check, Basic sounds, A2 readiness
#
# ### What You Will Do
# Test your A1 listening

# %%
# A1 Listening Assessment
print('A1 Listening: A1 Listening Assessment')
print('Level: Beginner - Listen carefully!')

# %% [markdown]
# ## Let's Listen!
#
# ### Step 1: Get Ready
#
# Today you will listen for: Listening test
#
# ### Step 2: What to Listen For
#
# - Listening test
# - Understanding
# - Progress check
#
# ### Step 3: Listen and Practice
#
# Listen carefully:
#
# 1. Listen for Listening test
# 2. Try to hear Understanding
# 3. Listen many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Listening 10',
    'listened_for': 'Listening test',
    'did_i_understand': 'Yes/No',
    'notes': 'What was difficult?'
}

print('Good listening!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Find Easy Audio
#
# ### Good websites for A1:
#
# ```
# - YouTube: "English for Beginners"
# - Voice of America: Learning English
# - BBC Learning English: The English We Speak
# - Slow, clear English only!
# ```
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I need very easy listening about a1 listening assessment.
# Please:
# 1. Speak VERY slowly
# 2. Use only simple words
# 3. Say words about Listening test
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Find easy audio
# 2. Listen for Listening test
# 3. Listen again and again
# 4. Don't worry if you don't understand everything
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now hear: Listening test, Understanding
#
# **Keep Listening!** It gets easier! 🌟
