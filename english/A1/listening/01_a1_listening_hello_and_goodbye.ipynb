# %% [markdown]
# # A1 Listening 01: Hello and Goodbye
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to hear:
#
# 1. Greetings
# 2. Hello/Hi
# 3. Goodbye/Bye
# 4. Good morning
# 5. Simple sounds

# %% [markdown]
# ## Hello and Goodbye - A1 Listening
#
# Topics: Greetings, Hello/Hi, Goodbye/Bye, Good morning, Simple sounds
#
# ### What You Will Do
# Hear and understand greetings

# %%
# Hello and Goodbye
print('A1 Listening: Hello and Goodbye')
print('Level: Beginner - Listen carefully!')

# %% [markdown]
# ## Let's Listen!
#
# ### Step 1: Get Ready
#
# Today you will listen for: Greetings
#
# ### Step 2: What to Listen For
#
# - Greetings
# - Hello/Hi
# - Goodbye/Bye
#
# ### Step 3: Listen and Practice
#
# Listen carefully:
#
# 1. Listen for Greetings
# 2. Try to hear Hello/Hi
# 3. Listen many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Listening 01',
    'listened_for': 'Greetings',
    'did_i_understand': 'Yes/No',
    'notes': 'What was difficult?'
}

print('Good listening!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Find Easy Audio
#
# ### Good websites for A1:
#
# ```
# - YouTube: "English for Beginners"
# - Voice of America: Learning English
# - BBC Learning English: The English We Speak
# - Slow, clear English only!
# ```
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I need very easy listening about hello and goodbye.
# Please:
# 1. Speak VERY slowly
# 2. Use only simple words
# 3. Say words about Greetings
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Find easy audio
# 2. Listen for Greetings
# 3. Listen again and again
# 4. Don't worry if you don't understand everything
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now hear: Greetings, Hello/Hi
#
# **Keep Listening!** It gets easier! 🌟
