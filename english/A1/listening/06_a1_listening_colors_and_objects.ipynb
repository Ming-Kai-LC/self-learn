# %% [markdown]
# # A1 Listening 06: Colors and Objects
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to hear:
#
# 1. Red/blue/green
# 2. Colors
# 3. Objects
# 4. What color
# 5. This/that

# %% [markdown]
# ## Colors and Objects - A1 Listening
#
# Topics: Red/blue/green, Colors, Objects, What color, This/that
#
# ### What You Will Do
# Understand colors and things

# %%
# Colors and Objects
print('A1 Listening: Colors and Objects')
print('Level: Beginner - Listen carefully!')

# %% [markdown]
# ## Let's Listen!
#
# ### Step 1: Get Ready
#
# Today you will listen for: Red/blue/green
#
# ### Step 2: What to Listen For
#
# - Red/blue/green
# - Colors
# - Objects
#
# ### Step 3: Listen and Practice
#
# Listen carefully:
#
# 1. Listen for Red/blue/green
# 2. Try to hear Colors
# 3. Listen many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Listening 06',
    'listened_for': 'Red/blue/green',
    'did_i_understand': 'Yes/No',
    'notes': 'What was difficult?'
}

print('Good listening!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Find Easy Audio
#
# ### Good websites for A1:
#
# ```
# - YouTube: "English for Beginners"
# - Voice of America: Learning English
# - BBC Learning English: The English We Speak
# - Slow, clear English only!
# ```
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I need very easy listening about colors and objects.
# Please:
# 1. Speak VERY slowly
# 2. Use only simple words
# 3. Say words about Red/blue/green
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Find easy audio
# 2. Listen for Red/blue/green
# 3. Listen again and again
# 4. Don't worry if you don't understand everything
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now hear: Red/blue/green, Colors
#
# **Keep Listening!** It gets easier! 🌟
