# %% [markdown]
# # A1 Listening 04: Countries and Places
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to hear:
#
# 1. Where are you from
# 2. Countries
# 3. Cities
# 4. I am from
# 5. Place names

# %% [markdown]
# ## Countries and Places - A1 Listening
#
# Topics: Where are you from, Countries, Cities, I am from, Place names
#
# ### What You Will Do
# Understand country names

# %%
# Countries and Places
print('A1 Listening: Countries and Places')
print('Level: Beginner - Listen carefully!')

# %% [markdown]
# ## Let's Listen!
#
# ### Step 1: Get Ready
#
# Today you will listen for: Where are you from
#
# ### Step 2: What to Listen For
#
# - Where are you from
# - Countries
# - Cities
#
# ### Step 3: Listen and Practice
#
# Listen carefully:
#
# 1. Listen for Where are you from
# 2. Try to hear Countries
# 3. Listen many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Listening 04',
    'listened_for': 'Where are you from',
    'did_i_understand': 'Yes/No',
    'notes': 'What was difficult?'
}

print('Good listening!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Find Easy Audio
#
# ### Good websites for A1:
#
# ```
# - YouTube: "English for Beginners"
# - Voice of America: Learning English
# - BBC Learning English: The English We Speak
# - Slow, clear English only!
# ```
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I need very easy listening about countries and places.
# Please:
# 1. Speak VERY slowly
# 2. Use only simple words
# 3. Say words about Where are you from
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Find easy audio
# 2. Listen for Where are you from
# 3. Listen again and again
# 4. Don't worry if you don't understand everything
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now hear: Where are you from, Countries
#
# **Keep Listening!** It gets easier! 🌟
