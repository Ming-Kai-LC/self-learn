# %% [markdown]
# # A1 Listening 07: Simple Yes No Questions
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to hear:
#
# 1. Yes
# 2. No
# 3. Do you
# 4. Are you
# 5. Questions and answers

# %% [markdown]
# ## Simple Yes No Questions - A1 Listening
#
# Topics: Yes, No, Do you, Are you, Questions and answers
#
# ### What You Will Do
# Understand yes/no questions

# %%
# Simple Yes No Questions
print('A1 Listening: Simple Yes No Questions')
print('Level: Beginner - Listen carefully!')

# %% [markdown]
# ## Let's Listen!
#
# ### Step 1: Get Ready
#
# Today you will listen for: Yes
#
# ### Step 2: What to Listen For
#
# - Yes
# - No
# - Do you
#
# ### Step 3: Listen and Practice
#
# Listen carefully:
#
# 1. Listen for Yes
# 2. Try to hear No
# 3. Listen many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Listening 07',
    'listened_for': 'Yes',
    'did_i_understand': 'Yes/No',
    'notes': 'What was difficult?'
}

print('Good listening!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Find Easy Audio
#
# ### Good websites for A1:
#
# ```
# - YouTube: "English for Beginners"
# - Voice of America: Learning English
# - BBC Learning English: The English We Speak
# - Slow, clear English only!
# ```
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I need very easy listening about simple yes no questions.
# Please:
# 1. Speak VERY slowly
# 2. Use only simple words
# 3. Say words about Yes
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Find easy audio
# 2. Listen for Yes
# 3. Listen again and again
# 4. Don't worry if you don't understand everything
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now hear: Yes, No
#
# **Keep Listening!** It gets easier! 🌟
