# %% [markdown]
# # A1 Listening 03: Numbers 1-20
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to hear:
#
# 1. Counting
# 2. Numbers
# 3. One to twenty
# 4. How many
# 5. Listening for numbers

# %% [markdown]
# ## Numbers 1-20 - A1 Listening
#
# Topics: Counting, Numbers, One to twenty, How many, Listening for numbers
#
# ### What You Will Do
# Hear and recognize numbers

# %%
# Numbers 1-20
print('A1 Listening: Numbers 1-20')
print('Level: Beginner - Listen carefully!')

# %% [markdown]
# ## Let's Listen!
#
# ### Step 1: Get Ready
#
# Today you will listen for: Counting
#
# ### Step 2: What to Listen For
#
# - Counting
# - Numbers
# - One to twenty
#
# ### Step 3: Listen and Practice
#
# Listen carefully:
#
# 1. Listen for Counting
# 2. Try to hear Numbers
# 3. Listen many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Listening 03',
    'listened_for': 'Counting',
    'did_i_understand': 'Yes/No',
    'notes': 'What was difficult?'
}

print('Good listening!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Find Easy Audio
#
# ### Good websites for A1:
#
# ```
# - YouTube: "English for Beginners"
# - Voice of America: Learning English
# - BBC Learning English: The English We Speak
# - Slow, clear English only!
# ```
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I need very easy listening about numbers 1-20.
# Please:
# 1. Speak VERY slowly
# 2. Use only simple words
# 3. Say words about Counting
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Find easy audio
# 2. Listen for Counting
# 3. Listen again and again
# 4. Don't worry if you don't understand everything
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now hear: Counting, Numbers
#
# **Keep Listening!** It gets easier! 🌟
