# %% [markdown]
# # A1 Listening 08: Daily Words
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to hear:
#
# 1. Common words
# 2. Food
# 3. Drinks
# 4. Animals
# 5. Easy vocabulary

# %% [markdown]
# ## Daily Words - A1 Listening
#
# Topics: Common words, Food, Drinks, Animals, Easy vocabulary
#
# ### What You Will Do
# Recognize everyday words

# %%
# Daily Words
print('A1 Listening: Daily Words')
print('Level: Beginner - Listen carefully!')

# %% [markdown]
# ## Let's Listen!
#
# ### Step 1: Get Ready
#
# Today you will listen for: Common words
#
# ### Step 2: What to Listen For
#
# - Common words
# - Food
# - Drinks
#
# ### Step 3: Listen and Practice
#
# Listen carefully:
#
# 1. Listen for Common words
# 2. Try to hear Food
# 3. Listen many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Listening 08',
    'listened_for': 'Common words',
    'did_i_understand': 'Yes/No',
    'notes': 'What was difficult?'
}

print('Good listening!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Find Easy Audio
#
# ### Good websites for A1:
#
# ```
# - YouTube: "English for Beginners"
# - Voice of America: Learning English
# - BBC Learning English: The English We Speak
# - Slow, clear English only!
# ```
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I need very easy listening about daily words.
# Please:
# 1. Speak VERY slowly
# 2. Use only simple words
# 3. Say words about Common words
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Find easy audio
# 2. Listen for Common words
# 3. Listen again and again
# 4. Don't worry if you don't understand everything
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now hear: Common words, Food
#
# **Keep Listening!** It gets easier! 🌟
