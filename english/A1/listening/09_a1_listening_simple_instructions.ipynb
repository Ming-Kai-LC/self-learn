# %% [markdown]
# # A1 Listening 09: Simple Instructions
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to hear:
#
# 1. Come here
# 2. Sit down
# 3. Stand up
# 4. Go
# 5. Simple commands

# %% [markdown]
# ## Simple Instructions - A1 Listening
#
# Topics: Come here, Sit down, Stand up, Go, Simple commands
#
# ### What You Will Do
# Follow simple instructions

# %%
# Simple Instructions
print('A1 Listening: Simple Instructions')
print('Level: Beginner - Listen carefully!')

# %% [markdown]
# ## Let's Listen!
#
# ### Step 1: Get Ready
#
# Today you will listen for: Come here
#
# ### Step 2: What to Listen For
#
# - Come here
# - Sit down
# - Stand up
#
# ### Step 3: Listen and Practice
#
# Listen carefully:
#
# 1. Listen for Come here
# 2. Try to hear Sit down
# 3. Listen many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Listening 09',
    'listened_for': 'Come here',
    'did_i_understand': 'Yes/No',
    'notes': 'What was difficult?'
}

print('Good listening!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Find Easy Audio
#
# ### Good websites for A1:
#
# ```
# - YouTube: "English for Beginners"
# - Voice of America: Learning English
# - BBC Learning English: The English We Speak
# - Slow, clear English only!
# ```
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I need very easy listening about simple instructions.
# Please:
# 1. Speak VERY slowly
# 2. Use only simple words
# 3. Say words about Come here
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Find easy audio
# 2. Listen for Come here
# 3. Listen again and again
# 4. Don't worry if you don't understand everything
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now hear: Come here, Sit down
#
# **Keep Listening!** It gets easier! 🌟
