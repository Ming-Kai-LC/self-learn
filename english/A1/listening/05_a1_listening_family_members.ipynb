# %% [markdown]
# # A1 Listening 05: Family Members
#
# **Difficulty**: ⭐ (Beginner)
# **Time**: 15-20 min
# **Prerequisites**: None (Start here!)
#
# ## Learning Objectives
#
# You will learn to hear:
#
# 1. Mother/father
# 2. Sister/brother
# 3. Family
# 4. This is my
# 5. Relationships

# %% [markdown]
# ## Family Members - A1 Listening
#
# Topics: Mother/father, Sister/brother, Family, This is my, Relationships
#
# ### What You Will Do
# Hear family words

# %%
# Family Members
print('A1 Listening: Family Members')
print('Level: Beginner - Listen carefully!')

# %% [markdown]
# ## Let's Listen!
#
# ### Step 1: Get Ready
#
# Today you will listen for: Mother/father
#
# ### Step 2: What to Listen For
#
# - Mother/father
# - Sister/brother
# - Family
#
# ### Step 3: Listen and Practice
#
# Listen carefully:
#
# 1. Listen for Mother/father
# 2. Try to hear Sister/brother
# 3. Listen many times

# %%
# Your Practice
from datetime import datetime

my_practice = {
    'date': datetime.now().strftime('%Y-%m-%d'),
    'lesson': 'A1 Listening 05',
    'listened_for': 'Mother/father',
    'did_i_understand': 'Yes/No',
    'notes': 'What was difficult?'
}

print('Good listening!')
print(f"Today: {my_practice['lesson']}")

# %% [markdown]
# ## Find Easy Audio
#
# ### Good websites for A1:
#
# ```
# - YouTube: "English for Beginners"
# - Voice of America: Learning English
# - BBC Learning English: The English We Speak
# - Slow, clear English only!
# ```
#
# ### Ask ChatGPT:
#
# ```
# I am A1 beginner. I need very easy listening about family members.
# Please:
# 1. Speak VERY slowly
# 2. Use only simple words
# 3. Say words about Mother/father
# ```

# %% [markdown]
# ## Your Tasks
#
# 1. Find easy audio
# 2. Listen for Mother/father
# 3. Listen again and again
# 4. Don't worry if you don't understand everything
# 5. Practice every day
#
# ## What You Learned
#
# ✅ You can now hear: Mother/father, Sister/brother
#
# **Keep Listening!** It gets easier! 🌟
