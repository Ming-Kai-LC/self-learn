# %% [markdown]
# # Module XX: [Topic Name]
#
# **Difficulty**: ⭐ Beginner
# **Estimated Time**: XX minutes
# **Prerequisites**:
# - [Previous Module or Concept](link)
# - Basic understanding of [required knowledge]
#
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
# 1. [Specific, measurable objective 1]
# 2. [Specific, measurable objective 2]
# 3. [Specific, measurable objective 3]
#
# ---

# %% [markdown]
# ## Setup
#
# Let's start by importing the libraries we'll need for this module.

# %%
# Import libraries for data manipulation
import pandas as pd
import numpy as np

# Import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Configure matplotlib to display plots in the notebook
# %matplotlib inline

# Set random seed for reproducibility
# This ensures we get the same results every time we run the notebook
np.random.seed(42)

print("✅ Setup complete! All libraries imported successfully.")

# %% [markdown]
# ## 1. [First Concept Name]
#
# ### What is it?
# [Clear, simple definition of the concept]
#
# ### Why do we need it?
# [Practical motivation - what problem does it solve?]
#
# ### How does it work?
# [Step-by-step explanation]
#
# Let's see this in action with a concrete example!

# %%
# Step 1: [Describe what we're doing]
# [Explain why this step is important]

# Step 2: [Describe what we're doing]
# [Explain the purpose]

# Display the results so we can see what happened

# %% [markdown]
# **What just happened?**
#
# Let's break this down:
# 1. [Explain step 1]
# 2. [Explain step 2]
# 3. [Explain the outcome]
#
# > 💡 **Pro Tip**: [Helpful insight related to this concept]

# %% [markdown]
# ### Common Mistakes
#
# > ⚠️ **Watch Out!**
# >
# > Many beginners [describe common mistake]. Here's what to avoid:
# > ```python
# > # WRONG - [explain why this doesn't work]
# > # [wrong code example]
# >
# > # CORRECT - [explain the right way]
# > # [correct code example]
# > ```

# %% [markdown]
# ## Exercise 1: [Exercise Name]
#
# **What you'll practice**: [Specific skill being practiced]
#
# **Your task**: [Clear description of what to do]
#
# **Step-by-step guide**:
# 1. [Step 1]
# 2. [Step 2]
# 3. [Step 3]
#
# **Expected result**: [What success looks like]
#
# **Hint**: [Helpful guidance without giving away the answer]

# %%
# Your code here
# TODO: [What to implement]

# %%
# Check your answer - run this cell to validate your solution
# [Add assertion or validation logic]
# assert [condition], "[Helpful error message if wrong]"
print("✅ Excellent work! You got it right!")

# %% [markdown]
# ## 2. [Second Concept Name]
#
# [Repeat the pattern: What/Why/How/Example/Common Mistakes/Exercise]

# %% [markdown]
# ## Quick Recap 🎯
#
# Great progress! Let's review what we just learned:
#
# 1. **[Concept 1]**: [Brief summary]
#    - Key point: [Important takeaway]
#
# 2. **[Concept 2]**: [Brief summary]
#    - Key point: [Important takeaway]
#
# 3. **[Concept 3]**: [Brief summary]
#    - Key point: [Important takeaway]
#
# Try explaining these concepts to yourself in your own words - that really helps them stick!

# %% [markdown]
# ## Summary
#
# ### What You've Accomplished 🎉
#
# Congratulations! You've completed this module. You can now:
# - ✅ [Learning objective 1]
# - ✅ [Learning objective 2]
# - ✅ [Learning objective 3]
#
# ### What's Next?
#
# In the next module, we'll build on what you learned here and explore:
# - [Preview of next topic]
# - [Preview of next topic]
#
# ### Additional Resources
#
# Want to learn more? Check out these resources:
# - [Resource 1](link) - [Brief description]
# - [Resource 2](link) - [Brief description]
# - [Documentation](link) - Official reference
#
# ---
#
# **Great job!** Take a break, then move on to the next module when you're ready. 🚀
